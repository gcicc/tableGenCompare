# %% [markdown]
# # Synthetic Tabular Data Generation - Streamlined Driver
#
# **Streamlined notebook for synthetic tabular data generation with batch processing.**
#
# This notebook provides a config-driven workflow for:
# - Section 1: Setup and imports
# - Section 2: Data loading, preprocessing, and EDA
# - Section 3: Demo models with default parameters
# - Section 4: Hyperparameter optimization
# - Section 5: Final models with best parameters
#
# Based on STG-BreastCancer-testing.ipynb, streamlined for faster iteration.

# %% [markdown]
# ## 1 Setup and Configuration

# %%
# Code Chunk ID: CHUNK_1_0_0_A - Import Setup Module
# Import all functionality from setup.py
import sys
sys.path.insert(0, "/home/ec2-user/SageMaker/tableGenCompare")

from setup import *

# Refresh session timestamp to current date
refresh_session_timestamp()

print("SETUP MODULE IMPORTED SUCCESSFULLY!")
print("="*60)
import sys                                                                                                                                                                                                     
# !{sys.executable} -m pip install ctgan sdv ganeraid
# Out:
# [OK] Essential data science libraries imported successfully!
# [OK] Model registry loaded from src/models/registry.py
# [OK] Batch training module loaded from src/models/batch_training.py
# [OK] Search spaces module loaded from src/models/search_spaces.py
# [OK] Batch optimization module loaded from src/models/batch_optimization.py
# [CONFIG] Session timestamp: 2026-01-22
# [OK] Parameter management functions loaded from src/utils/parameters.py
# [OK] Hyperparameter optimization evaluation functions loaded from src/evaluation/hyperparameters.py
# [OK] Optuna objective functions for PATE-GAN and MEDGAN loaded (Phase 5)
# Detected sklearn 1.7.2 - applying compatibility patch...
# INFO: Applying sklearn compatibility patches for version 1.7.2
# Global sklearn compatibility patch applied successfully
# CTAB-GAN imported successfully
# [OK] CTAB-GAN+ detected and available
# [OK] GANerAidModel imported successfully from src.models.implementations
# [OK] Config-driven preprocessing functions loaded (Phase 3)
# [OK] EDA module loaded from src/data/eda.py
# [OK] Backward compatibility patches loaded from src/compat.py
# [OK] TRTSEvaluator backward compatibility patch applied successfully!
# [SETUP] Thin re-export layer loaded successfully!
# [SETUP] Session timestamp: 2026-01-22
# [SETUP] All functions imported from modular src/ structure
# [SETUP] Backward compatibility maintained for notebooks
# Session timestamp refreshed to: 2026-01-22
# SETUP MODULE IMPORTED SUCCESSFULLY!
# ============================================================
# Requirement already satisfied: ctgan in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (0.11.1)
# Requirement already satisfied: sdv in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (1.32.1)
# Requirement already satisfied: ganeraid in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (1.8)
# Requirement already satisfied: numpy>=1.23.3 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from ctgan) (1.26.4)
# Requirement already satisfied: pandas>=1.4.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from ctgan) (2.3.3)
# Requirement already satisfied: torch>=1.13.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from ctgan) (2.6.0+cu124)
# Requirement already satisfied: tqdm<5,>=4.29 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from ctgan) (4.67.1)
# Requirement already satisfied: rdt>=1.14.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from ctgan) (1.19.0)
# Requirement already satisfied: boto3<2.0.0,>=1.28 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from sdv) (1.42.16)
# Requirement already satisfied: botocore<2.0.0,>=1.31 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from sdv) (1.42.16)
# Requirement already satisfied: cloudpickle>=2.1.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from sdv) (3.1.2)
# Requirement already satisfied: graphviz>=0.13.2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from sdv) (0.21)
# Requirement already satisfied: copulas>=0.12.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from sdv) (0.14.0)
# Requirement already satisfied: deepecho>=0.7.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from sdv) (0.8.0)
# Requirement already satisfied: sdmetrics>=0.21.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from sdv) (0.25.0)
# Requirement already satisfied: platformdirs>=4.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from sdv) (4.5.0)
# Requirement already satisfied: pyyaml>=6.0.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from sdv) (6.0.3)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from boto3<2.0.0,>=1.28->sdv) (1.0.1)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from boto3<2.0.0,>=1.28->sdv) (0.16.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from botocore<2.0.0,>=1.31->sdv) (2.9.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from botocore<2.0.0,>=1.31->sdv) (1.26.20)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.31->sdv) (1.17.0)
# Requirement already satisfied: scikit-learn>=0.22.2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from ganeraid) (1.7.2)
# Requirement already satisfied: seaborn>=0.11.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from ganeraid) (0.13.2)
# Requirement already satisfied: tab-gan-metrics>=1.1.4 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from ganeraid) (1.1.4)
# Requirement already satisfied: matplotlib>=3.4.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from ganeraid) (3.10.7)
# Requirement already satisfied: plotly>=5.10.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from copulas>=0.12.1->sdv) (6.4.0)
# Requirement already satisfied: scipy>=1.9.2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from copulas>=0.12.1->sdv) (1.15.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from matplotlib>=3.4.0->ganeraid) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from matplotlib>=3.4.0->ganeraid) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from matplotlib>=3.4.0->ganeraid) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from matplotlib>=3.4.0->ganeraid) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from matplotlib>=3.4.0->ganeraid) (24.2)
# Requirement already satisfied: pillow>=8 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from matplotlib>=3.4.0->ganeraid) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from matplotlib>=3.4.0->ganeraid) (3.2.5)
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from pandas>=1.4.0->ctgan) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from pandas>=1.4.0->ctgan) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (2.10.2)
# Requirement already satisfied: Faker!=37.11.0,>=17 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from rdt>=1.14.0->ctgan) (40.1.2)
# Requirement already satisfied: joblib>=1.2.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from scikit-learn>=0.22.2->ganeraid) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from scikit-learn>=0.22.2->ganeraid) (3.6.0)
# Requirement already satisfied: psutil in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from tab-gan-metrics>=1.1.4->ganeraid) (7.1.3)
# Requirement already satisfied: dython==0.5.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from tab-gan-metrics>=1.1.4->ganeraid) (0.5.1)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (4.15.0)
# Requirement already satisfied: networkx in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (3.4.2)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (3.1.6)
# Requirement already satisfied: fsspec in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch>=1.13.0->ctgan) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from sympy==1.13.1->torch>=1.13.0->ctgan) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from jinja2->torch>=1.13.0->ctgan) (3.0.3)

# %% [markdown]
# ## 2 Data Loading and Pre-processing

# %% [markdown]
# ### 2.1 Configuration
#
# **USER ATTENTION NEEDED**: Edit the `NOTEBOOK_CONFIG` dictionary below to match your dataset.

# %%
# Code Chunk ID: CHUNK_2_1_1_A - NOTEBOOK CONFIGURATION
# ============================================================================
# USER CONFIGURATION - Edit ONLY this block for your dataset
# ============================================================================

NOTEBOOK_CONFIG = {
    # ========== REQUIRED: Dataset Settings ==========
    "data_file": "data/Breast_cancer_data.csv",  # Path to your CSV file
    "target_column": "diagnosis",                 # Target/outcome column name

    # ========== OPTIONAL: Dataset Metadata ==========
    "dataset_name": "Breast Cancer Dataset",      # Display name
    "dataset_identifier_override": None,          # Override auto-detected ID (or None)

    # ========== OPTIONAL: Column Configuration ==========
    "categorical_columns": [],                    # List categorical cols, or [] for auto-detect
    "task_type": "auto",                          # "auto" | "classification" | "regression"

    # ========== OPTIONAL: Data Subsetting ==========
    "use_row_subset": False,                      # True to sample rows for faster testing
    "sample_n": 500,                              # Number of rows to sample
    "sample_random_state": 42,                    # Random seed for reproducibility

    # ========== OPTIONAL: Missing Data Handling ==========
    "missing_strategy": "none",                   # "none" | "drop" | "median" | "mode" | "mice"
    "mice_max_iter": 10,                          # Max iterations for MICE imputation

    # ========== OPTIONAL: Model Selection ==========
    "models_to_run": "all",                       # "all" or list like ["ctgan", "tvae"]

    # ========== OPTIONAL: Tuning Configuration ==========
    "tuning_mode": "smoke",                        # "smoke" (quick) | "full" (thorough)
    "n_trials_smoke": 5,                          # Trials for smoke testing
    "n_trials_full": 30,                          # Trials for full optimization
}

print("NOTEBOOK_CONFIG set successfully!")
print(f"  Data file: {NOTEBOOK_CONFIG['data_file']}")
print(f"  Target column: {NOTEBOOK_CONFIG['target_column']}")
print(f"  Models to run: {NOTEBOOK_CONFIG['models_to_run']}")
print(f"  Tuning mode: {NOTEBOOK_CONFIG['tuning_mode']}")
# Out:
# NOTEBOOK_CONFIG set successfully!
#   Data file: data/Breast_cancer_data.csv
#   Target column: diagnosis
#   Models to run: all
#   Tuning mode: smoke

# %% [markdown]
# ### 2.2 Load and Preprocess Data

# %%
# Code Chunk ID: CHUNK_2_1_2_A - LOAD AND PREPROCESS DATA
# ============================================================================
# This uses the config-driven preprocessing pipeline
# ============================================================================

# Load and preprocess data using the config
(
    data,                  # Processed DataFrame
    original_data,         # Copy for reference
    target_column,         # Target column name (cleaned)
    DATASET_IDENTIFIER,    # Dataset identifier for results paths
    categorical_columns,   # List of categorical columns
    metadata               # Full preprocessing metadata
) = load_and_preprocess_from_config(NOTEBOOK_CONFIG)

# Set aliases for backward compatibility with existing notebook cells
TARGET_COLUMN = target_column

# Get models to run based on config
models_to_run = get_models_to_run(NOTEBOOK_CONFIG)
tuning_config = get_tuning_config(NOTEBOOK_CONFIG)
N_TRIALS = get_n_trials(NOTEBOOK_CONFIG)

# Set RUN_MODE for backward compatibility with Section 4 tuning cells
RUN_MODE = "debug" if NOTEBOOK_CONFIG['tuning_mode'] == "smoke" else "full"

print()
print("=" * 60)
print("PREPROCESSING COMPLETE")
print("=" * 60)
print(f"  Dataset identifier: {DATASET_IDENTIFIER}")
print(f"  Processed shape: {data.shape}")
print(f"  Target column: {target_column}")
print(f"  Task type: {metadata['task_type']}")
print(f"  Categorical columns: {categorical_columns}")
print(f"  Models to run: {models_to_run}")
print(f"  RUN_MODE: {RUN_MODE}")
print(f"  N_TRIALS: {N_TRIALS}")
print(f"  Session: {SESSION_TIMESTAMP}")
print(f"  Results path: {get_results_path(DATASET_IDENTIFIER, 2)}")
print("=" * 60)
# Out:
# [LOAD] Loading data from: data/Breast_cancer_data.csv
# [LOAD] Loaded 569 rows, 6 columns
# [PREPROCESS] Starting preprocessing pipeline
# [PREPROCESS] Input shape: (569, 6)
# [PREPROCESS] Categorical columns: []
# [PREPROCESS] Task type: classification
# [PREPROCESS] Final shape: (569, 6)
# [PREPROCESS] Dataset identifier: breast-cancer-data
#
# ============================================================
# PREPROCESSING COMPLETE
# ============================================================
#   Dataset identifier: breast-cancer-data
#   Processed shape: (569, 6)
#   Target column: diagnosis
#   Task type: classification
#   Categorical columns: []
#   Models to run: ['ctgan', 'tvae', 'copulagan', 'ctabgan', 'ctabganplus', 'pategan', 'medgan']
#   RUN_MODE: debug
#   N_TRIALS: 5
#   Session: 2026-01-22
#   Results path: results/breast-cancer-data/2026-01-22/Section-2
# ============================================================

# %% [markdown]
# ### 2.3 Exploratory Data Analysis (EDA)
#
# Comprehensive EDA with automated file export to results directory.

# %%
# Code Chunk ID: CHUNK_2_1_EDA - COMPREHENSIVE EDA
# ============================================================================
# Run comprehensive EDA with single function call
# Generates: column_analysis.csv, target_analysis.csv, target_balance_metrics.csv,
#            feature_distributions.png, correlation_heatmap.png, correlation_matrix.csv
# ============================================================================

from src.data.eda import run_comprehensive_eda

eda_results = run_comprehensive_eda(
    data=data,
    target_column=target_column,
    dataset_identifier=DATASET_IDENTIFIER,
    dataset_name=NOTEBOOK_CONFIG.get('dataset_name'),
    categorical_columns=categorical_columns,
    verbose=True
)

# Update categorical_columns from EDA results (in case auto-detected)
categorical_columns = eda_results['categorical_columns']

print(f"\nEDA Results Summary:")
print(f"  Files generated: {len(eda_results['files_generated'])}")
print(f"  Categorical columns: {categorical_columns}")
print(f"  Balance ratio: {eda_results.get('balance_ratio', 'N/A')}")
# Out:
# ============================================================
# COMPREHENSIVE EXPLORATORY DATA ANALYSIS
# ============================================================
# Dataset: Breast Cancer Dataset
# Target column: diagnosis
# Results path: results/breast-cancer-data/2026-01-22/Section-2
# ============================================================
#
# [1/6] Dataset Overview...
#    Dataset Name.................. Breast Cancer Dataset
#    Shape......................... 569 rows x 6 columns
#    Memory Usage.................. 0.03 MB
#    Total Missing Values.......... 0
#    Missing Percentage............ 0.00%
#    Duplicate Rows................ 0
#    Numeric Columns............... 6
#    Categorical Columns........... 0
#
# [2/6] Column Analysis...
#    Saved: column_analysis.csv (6 columns)
#
# [3/6] Target Variable Analysis...
#    Saved: target_analysis.csv
#    Saved: target_balance_metrics.csv
#    Balance Ratio: 0.594 (Moderately Imbalanced)
#
# [4/6] Feature Distributions...
#    Saved: 1 distribution file(s) (5 features)
#
# [5/6] Correlation Analysis...
#    Saved: correlation_heatmap.png
#    Saved: correlation_matrix.csv
#    Saved: target_correlations.csv (5 features)
#
# [6/6] Configuration Validation...
#    Categorical columns: None
#    Numeric columns: 5
#
# ============================================================
# EDA COMPLETE
# ============================================================
# Files generated: 7
#    - column_analysis.csv
#    - target_analysis.csv
#    - target_balance_metrics.csv
#    - feature_distributions.png
#    - correlation_heatmap.png
#    - correlation_matrix.csv
#    - target_correlations.csv
# Results saved to: results/breast-cancer-data/2026-01-22/Section-2
# ============================================================
#
# EDA Results Summary:
#   Files generated: 7
#   Categorical columns: []
#   Balance ratio: 0.5938375350140056

# %% [markdown]
# ## 3 Demo All Models with Default Parameters

# %% [markdown]
# ### 3.1 Batch Model Training

# %%
# Code Chunk ID: CHUNK_3_1_BATCH
# ============================================================================
# SECTION 3.1 - BATCH MODEL TRAINING
# Train all models configured in NOTEBOOK_CONFIG['models_to_run']
# ============================================================================

from src.models.batch_training import train_models_batch, extract_synthetic_data_to_globals

# Run batch training for all configured models
training_results = train_models_batch(
    data=data,
    models_to_run=models_to_run,
    target_column=target_column,
    categorical_columns=categorical_columns,
    n_samples=len(data),
    random_state=42,
    verbose=True
)

# Extract synthetic_data_* variables for Section 3.2 compatibility
# This creates global variables like synthetic_data_ctgan, synthetic_data_tvae, etc.
created_vars = extract_synthetic_data_to_globals(training_results, globals())
print(f"\nCreated variables: {created_vars}")

# Also create model_* variables for backward compatibility
for model_name, result in training_results.items():
    if result['status'] == 'success':
        globals()[f'{model_name}_model'] = result['model']
# Out:
# ============================================================
# BATCH MODEL TRAINING
# ============================================================
# Models to train: 7
# Dataset shape: (569, 6)
# Target column: diagnosis
# Samples to generate: 569
# ============================================================
#
#
# [1/7] Training CTGAN...
# --------------------------------------------------
#   Training CTGAN...
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Gen. (-1.11) | Discrim. (-0.03): 100%|██████████| 300/300 [00:05<00:00, 56.31it/s]
#   Generating 569 synthetic samples...
#   [OK] CTGAN completed in 12.62s
#   Synthetic data shape: (569, 6)
#
# [2/7] Training TVAE...
# --------------------------------------------------
#   Training TVAE...
#   Generating 569 synthetic samples...
# [OK] Target integrity functions loaded from src/data/target_integrity.py
#   [OK] TVAE completed in 6.35s
#   Synthetic data shape: (569, 6)
#
# [3/7] Training CopulaGAN...
# --------------------------------------------------
#   Training CopulaGAN...
#   Generating 569 synthetic samples...
#   [OK] CopulaGAN completed in 7.55s
#   Synthetic data shape: (569, 6)
#
# [4/7] Training CTABGAN...
# --------------------------------------------------
#   Training CTABGAN...
# 100%|██████████| 300/300 [00:17<00:00, 16.78it/s]
# Finished training in 18.72691035270691  seconds.
#   Generating 569 synthetic samples...
#   [OK] CTABGAN completed in 18.78s
#   Synthetic data shape: (569, 6)
#
# [5/7] Training CTABGAN+...
# --------------------------------------------------
#   Training CTABGAN+...
# 100%|██████████| 400/400 [00:16<00:00, 23.78it/s]
# Finished training in 17.68183135986328  seconds.
#   Generating 569 synthetic samples...
#   [OK] CTABGAN+ completed in 17.72s
#   Synthetic data shape: (569, 6)
#
# [6/7] Training PATE-GAN...
# --------------------------------------------------
#   Training PATE-GAN...
#   Generating 569 synthetic samples...
#   [OK] PATE-GAN completed in 2.18s
#   Synthetic data shape: (569, 6)
#
# [7/7] Training MEDGAN...
# --------------------------------------------------
#   Training MEDGAN...
#   Generating 569 synthetic samples...
#   [OK] MEDGAN completed in 6.70s
#   Synthetic data shape: (569, 6)
#
# ============================================================
# BATCH TRAINING SUMMARY
# ============================================================
# Total models: 7
# Successful: 7
# Failed: 0
# ============================================================
#
# Successful models:
#   - CTGAN: 12.62s
#   - TVAE: 6.35s
#   - CopulaGAN: 7.55s
#   - CTABGAN: 18.78s
#   - CTABGAN+: 17.72s
#   - PATE-GAN: 2.18s
#   - MEDGAN: 6.70s
#
# Created variables: ['synthetic_data_ctgan', 'synthetic_data_tvae', 'synthetic_data_copulagan', 'synthetic_data_ctabgan', 'synthetic_data_ctabganplus', 'synthetic_data_pategan', 'synthetic_data_medgan']

# %% [markdown]
# ### 3.2 Batch Evaluation

# %%
# Code Chunk ID: CHUNK_3_2_0_A
# ============================================================================
# SECTION 3.2 - BATCH EVALUATION FOR ALL TRAINED MODELS
# ============================================================================

print("SECTION 3.2 - COMPREHENSIVE BATCH EVALUATION")
print("=" * 60)

section3_results = evaluate_all_available_models(
    section_number=3,
    scope=globals(),
    models_to_evaluate=None,
    real_data=None,
    target_col=None
)

if section3_results:
    print(f"\nSECTION 3 BATCH EVALUATION COMPLETED!")
    print(f"Evaluated {len(section3_results)} models successfully")
    
    # Show ranking by quality score
    best_models = []
    for model_name, results in section3_results.items():
        if 'error' not in results:
            quality_score = results.get('overall_quality_score', 0)
            best_models.append((model_name, quality_score))
    
    if best_models:
        best_models.sort(key=lambda x: x[1], reverse=True)
        print(f"\nRANKING BY QUALITY SCORE:")
        for i, (model, score) in enumerate(best_models, 1):
            print(f"   {i}. {model}: {score:.3f}")
else:
    print("\nNo models available for evaluation")
# Out:
# SECTION 3.2 - COMPREHENSIVE BATCH EVALUATION
# ============================================================
# [OK] Batch evaluation functions loaded from src/evaluation/batch.py
# [SEARCH] UNIFIED BATCH EVALUATION - SECTION 3
# ============================================================
# [INFO] Dataset: breast-cancer-data
# [INFO] Target column: diagnosis
# [INFO] Variable pattern: standard
# [INFO] Found 7 trained models:
#    [OK] CTGAN
#    [OK] CTABGAN
#    [OK] CTABGANPLUS
#    [OK] CopulaGAN
#    [OK] TVAE
#    [OK] MEDGAN
#    [OK] PATEGAN
#
# ==================== EVALUATING CTGAN ====================
# [SEARCH] CTGAN - COMPREHENSIVE DATA QUALITY EVALUATION
# ============================================================
# [FOLDER] Output directory: results/breast-cancer-data/2026-01-22/Section-3/CTGAN
#
# [1] STATISTICAL SIMILARITY
# ------------------------------
#    [CHART] Average Statistical Similarity: 0.744
#
# [2] PCA COMPARISON ANALYSIS WITH OUTCOME COLOR-CODING
# --------------------------------------------------
#    [CHART] PCA comparison plot saved: pca_comparison_with_outcome.png
#    [CHART] PCA Overall Similarity: 0.020
#    [CHART] Explained Variance (PC1, PC2): 0.638, 0.172
#
# [3] DISTRIBUTION SIMILARITY
# ------------------------------
#    [CHART] Average Distribution Similarity: 0.762
#
# [4] CORRELATION STRUCTURE
# ------------------------------
#    [CHART] Correlation Structure Preservation: 0.549
#
# [5] MACHINE LEARNING UTILITY
# ------------------------------
#    [CHART] ML Utility (Cross-Accuracy): 0.554
#    [CHART] Real->Synth Accuracy: 0.564
#    [CHART] Synth->Real Accuracy: 0.543
#
# ============================================================
# [BEST] CTGAN OVERALL QUALITY SCORE: 0.526
# [INFO] Quality Assessment: FAIR
# ============================================================
#
# [FOLDER] Generated 5 output files:
#    - statistical_similarity.csv
#    - pca_comparison_with_outcome.png
#    - distribution_comparison.png
#    - correlation_comparison.png
#    - evaluation_summary.csv
# [OK] CTGAN evaluation completed successfully!
#
# ==================== EVALUATING CTABGAN ====================
# [SEARCH] CTABGAN - COMPREHENSIVE DATA QUALITY EVALUATION
# ============================================================
# [FOLDER] Output directory: results/breast-cancer-data/2026-01-22/Section-3/CTABGAN
#
# [1] STATISTICAL SIMILARITY
# ------------------------------
#    [CHART] Average Statistical Similarity: 0.851
#
# [2] PCA COMPARISON ANALYSIS WITH OUTCOME COLOR-CODING
# --------------------------------------------------
#    [CHART] PCA comparison plot saved: pca_comparison_with_outcome.png
#    [CHART] PCA Overall Similarity: 0.053
#    [CHART] Explained Variance (PC1, PC2): 0.638, 0.172
#
# [3] DISTRIBUTION SIMILARITY
# ------------------------------
#    [CHART] Average Distribution Similarity: 0.860
#
# [4] CORRELATION STRUCTURE
# ------------------------------
#    [CHART] Correlation Structure Preservation: 0.983
#
# [5] MACHINE LEARNING UTILITY
# ------------------------------
#    [CHART] ML Utility (Cross-Accuracy): 0.881
#    [CHART] Real->Synth Accuracy: 0.861
#    [CHART] Synth->Real Accuracy: 0.902
#
# ============================================================
# [BEST] CTABGAN OVERALL QUALITY SCORE: 0.726
# [INFO] Quality Assessment: GOOD
# ============================================================
#
# [FOLDER] Generated 5 output files:
#    - statistical_similarity.csv
#    - pca_comparison_with_outcome.png
#    - distribution_comparison.png
#    - correlation_comparison.png
#    - evaluation_summary.csv
# [OK] CTABGAN evaluation completed successfully!
#
# ==================== EVALUATING CTABGANPLUS ====================
# [SEARCH] CTABGANPLUS - COMPREHENSIVE DATA QUALITY EVALUATION
# ============================================================
# [FOLDER] Output directory: results/breast-cancer-data/2026-01-22/Section-3/CTABGANPLUS
#
# [1] STATISTICAL SIMILARITY
# ------------------------------
#    [CHART] Average Statistical Similarity: 0.851
#
# [2] PCA COMPARISON ANALYSIS WITH OUTCOME COLOR-CODING
# --------------------------------------------------
#    [CHART] PCA comparison plot saved: pca_comparison_with_outcome.png
#    [CHART] PCA Overall Similarity: 0.016
#    [CHART] Explained Variance (PC1, PC2): 0.638, 0.172
#
# [3] DISTRIBUTION SIMILARITY
# ------------------------------
#    [CHART] Average Distribution Similarity: 0.858
#
# [4] CORRELATION STRUCTURE
# ------------------------------
#    [CHART] Correlation Structure Preservation: 0.984
#
# [5] MACHINE LEARNING UTILITY
# ------------------------------
#    [CHART] ML Utility (Cross-Accuracy): 0.873
#    [CHART] Real->Synth Accuracy: 0.831
#    [CHART] Synth->Real Accuracy: 0.916
#
# ============================================================
# [BEST] CTABGANPLUS OVERALL QUALITY SCORE: 0.717
# [INFO] Quality Assessment: GOOD
# ============================================================
#
# [FOLDER] Generated 5 output files:
#    - statistical_similarity.csv
#    - pca_comparison_with_outcome.png
#    - distribution_comparison.png
#    - correlation_comparison.png
#    - evaluation_summary.csv
# [OK] CTABGANPLUS evaluation completed successfully!
#
# ==================== EVALUATING CopulaGAN ====================
# [SEARCH] COPULAGAN - COMPREHENSIVE DATA QUALITY EVALUATION
# ============================================================
# [FOLDER] Output directory: results/breast-cancer-data/2026-01-22/Section-3/COPULAGAN
#
# [1] STATISTICAL SIMILARITY
# ------------------------------
#    [CHART] Average Statistical Similarity: 0.772
#
# [2] PCA COMPARISON ANALYSIS WITH OUTCOME COLOR-CODING
# --------------------------------------------------
#    [CHART] PCA comparison plot saved: pca_comparison_with_outcome.png
#    [CHART] PCA Overall Similarity: 0.018
#    [CHART] Explained Variance (PC1, PC2): 0.638, 0.172
#
# [3] DISTRIBUTION SIMILARITY
# ------------------------------
#    [CHART] Average Distribution Similarity: 0.799
#
# [4] CORRELATION STRUCTURE
# ------------------------------
#    [CHART] Correlation Structure Preservation: 0.724
#
# [5] MACHINE LEARNING UTILITY
# ------------------------------
#    [CHART] ML Utility (Cross-Accuracy): 0.790
#    [CHART] Real->Synth Accuracy: 0.689
#    [CHART] Synth->Real Accuracy: 0.891
#
# ============================================================
# [BEST] COPULAGAN OVERALL QUALITY SCORE: 0.620
# [INFO] Quality Assessment: GOOD
# ============================================================
#
# [FOLDER] Generated 5 output files:
#    - statistical_similarity.csv
#    - pca_comparison_with_outcome.png
#    - distribution_comparison.png
#    - correlation_comparison.png
#    - evaluation_summary.csv
# [OK] CopulaGAN evaluation completed successfully!
#
# ==================== EVALUATING TVAE ====================
# [SEARCH] TVAE - COMPREHENSIVE DATA QUALITY EVALUATION
# ============================================================
# [FOLDER] Output directory: results/breast-cancer-data/2026-01-22/Section-3/TVAE
#
# [1] STATISTICAL SIMILARITY
# ------------------------------
#    [CHART] Average Statistical Similarity: 0.755
#
# [2] PCA COMPARISON ANALYSIS WITH OUTCOME COLOR-CODING
# --------------------------------------------------
#    [CHART] PCA comparison plot saved: pca_comparison_with_outcome.png
#    [CHART] PCA Overall Similarity: 0.036
#    [CHART] Explained Variance (PC1, PC2): 0.638, 0.172
#
# [3] DISTRIBUTION SIMILARITY
# ------------------------------
#    [CHART] Average Distribution Similarity: 0.843
#
# [4] CORRELATION STRUCTURE
# ------------------------------
#    [CHART] Correlation Structure Preservation: 0.950
#
# [5] MACHINE LEARNING UTILITY
# ------------------------------
#    [CHART] ML Utility (Cross-Accuracy): 0.880
#    [CHART] Real->Synth Accuracy: 0.837
#    [CHART] Synth->Real Accuracy: 0.923
#
# ============================================================
# [BEST] TVAE OVERALL QUALITY SCORE: 0.692
# [INFO] Quality Assessment: GOOD
# ============================================================
#
# [FOLDER] Generated 5 output files:
#    - statistical_similarity.csv
#    - pca_comparison_with_outcome.png
#    - distribution_comparison.png
#    - correlation_comparison.png
#    - evaluation_summary.csv
# [OK] TVAE evaluation completed successfully!
#
# ==================== EVALUATING MEDGAN ====================
# [SEARCH] MEDGAN - COMPREHENSIVE DATA QUALITY EVALUATION
# ============================================================
# [FOLDER] Output directory: results/breast-cancer-data/2026-01-22/Section-3/MEDGAN
#
# [1] STATISTICAL SIMILARITY
# ------------------------------
#    [CHART] Average Statistical Similarity: 0.022
#
# [2] PCA COMPARISON ANALYSIS WITH OUTCOME COLOR-CODING
# --------------------------------------------------
#    [CHART] PCA comparison plot saved: pca_comparison_with_outcome.png
#    [CHART] PCA Overall Similarity: 0.045
#    [CHART] Explained Variance (PC1, PC2): 0.638, 0.172
#
# [3] DISTRIBUTION SIMILARITY
# ------------------------------
#    [CHART] Average Distribution Similarity: nan
#
# [4] CORRELATION STRUCTURE
# ------------------------------
#    [CHART] Correlation Structure Preservation: 0.000
#
# [5] MACHINE LEARNING UTILITY
# ------------------------------
#    [CHART] ML Utility (Cross-Accuracy): 0.814
#    [CHART] Real->Synth Accuracy: 1.000
#    [CHART] Synth->Real Accuracy: 0.627
#
# ============================================================
# [BEST] MEDGAN OVERALL QUALITY SCORE: nan
# [INFO] Quality Assessment: POOR
# ============================================================
#
# [FOLDER] Generated 5 output files:
#    - statistical_similarity.csv
#    - pca_comparison_with_outcome.png
#    - distribution_comparison.png
#    - correlation_comparison.png
#    - evaluation_summary.csv
# [OK] MEDGAN evaluation completed successfully!
#
# ==================== EVALUATING PATEGAN ====================
# [SEARCH] PATEGAN - COMPREHENSIVE DATA QUALITY EVALUATION
# ============================================================
# [FOLDER] Output directory: results/breast-cancer-data/2026-01-22/Section-3/PATEGAN
#
# [1] STATISTICAL SIMILARITY
# ------------------------------
#    [CHART] Average Statistical Similarity: 0.068
#
# [2] PCA COMPARISON ANALYSIS WITH OUTCOME COLOR-CODING
# --------------------------------------------------
#    [CHART] PCA comparison plot saved: pca_comparison_with_outcome.png
#    [CHART] PCA Overall Similarity: 0.032
#    [CHART] Explained Variance (PC1, PC2): 0.638, 0.172
#
# [3] DISTRIBUTION SIMILARITY
# ------------------------------
#    [CHART] Average Distribution Similarity: nan
#
# [4] CORRELATION STRUCTURE
# ------------------------------
#    [CHART] Correlation Structure Preservation: 0.000
#
# [5] MACHINE LEARNING UTILITY
# ------------------------------
#    [CHART] ML Utility (Cross-Accuracy): 0.186
#    [CHART] Real->Synth Accuracy: 0.000
#    [CHART] Synth->Real Accuracy: 0.373
#
# ============================================================
# [BEST] PATEGAN OVERALL QUALITY SCORE: nan
# [INFO] Quality Assessment: POOR
# ============================================================
#
# [FOLDER] Generated 5 output files:
#    - statistical_similarity.csv
#    - pca_comparison_with_outcome.png
#    - distribution_comparison.png
#    - correlation_comparison.png
#    - evaluation_summary.csv
# [OK] PATEGAN evaluation completed successfully!
#
# ========================= EVALUATION SUMMARY =========================
# Model           Quality Score   Assessment   Files
# -----------------------------------------------------------------
# CTGAN           0.526           FAIR         5
# CTABGAN         0.726           GOOD         5
# CTABGANPLUS     0.717           GOOD         5
# CopulaGAN       0.620           GOOD         5
# TVAE            0.692           GOOD         5
# MEDGAN          nan             POOR         5
# PATEGAN         nan             POOR         5
#
# [CHART] Batch summary saved to: results/breast-cancer-data/2026-01-22/Section-3/batch_evaluation_summary.csv
#
# ========================= OPTUNA OPTIMIZATION ANALYSIS =========================
# [INFO] No Optuna studies detected in notebook scope
#       Studies are expected with names like: ctgan_study, ctabgan_study, etc.
#
# ========================= COMPREHENSIVE TRTS ANALYSIS =========================
#
# [ANALYSIS] Running TRTS analysis for CTGAN...
# [ANALYSIS] COMPREHENSIVE TRTS FRAMEWORK ANALYSIS (15+ Metrics)
# ============================================================
# [CHART] Data shapes:
#    - Real: (569, 5), Target unique values: 2
#    - Synthetic: (569, 5), Target unique values: 2
#    - Using 5 common features
#
# [PROCESS] 1. TRTR - Train Real, Test Real (Baseline)
#    [OK] TRTR Accuracy: 0.9123 | Balanced Acc: 0.9157 | MCC: 0.8174 (Time: 0.095s)
# [PROCESS] 2. TRTS - Train Real, Test Synthetic
#    [OK] TRTS Accuracy: 0.5789 | Balanced Acc: 0.5631 | MCC: 0.1209 (Time: 0.095s)
# [PROCESS] 3. TSTR - Train Synthetic, Test Real
#    [OK] TSTR Accuracy: 0.6053 | Balanced Acc: 0.4891 | MCC: -0.0439 (Time: 0.109s)
# [PROCESS] 4. TSTS - Train Synthetic, Test Synthetic
#    [OK] TSTS Accuracy: 0.6316 | Balanced Acc: 0.5231 | MCC: 0.0615 (Time: 0.108s)
#
# [CHART] Summary Statistics:
#    - Successful scenarios: 4/4
#    - Average accuracy: 0.6820 (+/-0.1342)
#    - Total training time: 0.408s
#
# [PRIVACY] Calculating privacy risk metrics...
#    [PRIVACY] Using 5 numeric features
#    [PRIVACY] Real: 569 records, Synthetic: 569 records
#    [METRIC] DCR Mean: 1.6838 (min: 0.1691, max: 5.1899)
#    [METRIC] Memorization: 0.00% (0/569 records)
#    [METRIC] NNDR: 1.4274 (+/- 0.6053)
#    [METRIC] Re-identification Risk: 0.00%
#    [METRIC] Overall Privacy Score: 0.905
#
# [ANALYSIS] Running TRTS analysis for CTABGAN...
# [ANALYSIS] COMPREHENSIVE TRTS FRAMEWORK ANALYSIS (15+ Metrics)
# ============================================================
# [CHART] Data shapes:
#    - Real: (569, 5), Target unique values: 2
#    - Synthetic: (569, 5), Target unique values: 2
#    - Using 5 common features
#
# [PROCESS] 1. TRTR - Train Real, Test Real (Baseline)
#    [OK] TRTR Accuracy: 0.9123 | Balanced Acc: 0.9157 | MCC: 0.8174 (Time: 0.094s)
# [PROCESS] 2. TRTS - Train Real, Test Synthetic
#    [OK] TRTS Accuracy: 0.8421 | Balanced Acc: 0.8541 | MCC: 0.6928 (Time: 0.094s)
# [PROCESS] 3. TSTR - Train Synthetic, Test Real
#    [OK] TSTR Accuracy: 0.8772 | Balanced Acc: 0.8532 | MCC: 0.7330 (Time: 0.098s)
# [PROCESS] 4. TSTS - Train Synthetic, Test Synthetic
#    [OK] TSTS Accuracy: 0.8860 | Balanced Acc: 0.8671 | MCC: 0.7614 (Time: 0.100s)
#
# [CHART] Summary Statistics:
#    - Successful scenarios: 4/4
#    - Average accuracy: 0.8794 (+/-0.0251)
#    - Total training time: 0.387s
#
# [PRIVACY] Calculating privacy risk metrics...
#    [PRIVACY] Using 5 numeric features
#    [PRIVACY] Real: 569 records, Synthetic: 569 records
#    [METRIC] DCR Mean: 0.8426 (min: 0.0376, max: 3.5127)
#    [METRIC] Memorization: 0.00% (0/569 records)
#    [METRIC] NNDR: 0.9293 (+/- 0.3600)
#    [METRIC] Re-identification Risk: 0.18%
#    [METRIC] Overall Privacy Score: 0.782
#
# [ANALYSIS] Running TRTS analysis for CTABGANPLUS...
# [ANALYSIS] COMPREHENSIVE TRTS FRAMEWORK ANALYSIS (15+ Metrics)
# ============================================================
# [CHART] Data shapes:
#    - Real: (569, 5), Target unique values: 2
#    - Synthetic: (569, 5), Target unique values: 2
#    - Using 5 common features
#
# [PROCESS] 1. TRTR - Train Real, Test Real (Baseline)
#    [OK] TRTR Accuracy: 0.9123 | Balanced Acc: 0.9157 | MCC: 0.8174 (Time: 0.095s)
# [PROCESS] 2. TRTS - Train Real, Test Synthetic
#    [OK] TRTS Accuracy: 0.8246 | Balanced Acc: 0.8256 | MCC: 0.6349 (Time: 0.096s)
# [PROCESS] 3. TSTR - Train Synthetic, Test Real
#    [OK] TSTR Accuracy: 0.8860 | Balanced Acc: 0.8651 | MCC: 0.7522 (Time: 0.099s)
# [PROCESS] 4. TSTS - Train Synthetic, Test Synthetic
#    [OK] TSTS Accuracy: 0.8333 | Balanced Acc: 0.7950 | MCC: 0.6302 (Time: 0.101s)
#
# [CHART] Summary Statistics:
#    - Successful scenarios: 4/4
#    - Average accuracy: 0.8640 (+/-0.0364)
#    - Total training time: 0.390s
#
# [PRIVACY] Calculating privacy risk metrics...
#    [PRIVACY] Using 5 numeric features
#    [PRIVACY] Real: 569 records, Synthetic: 569 records
#    [METRIC] DCR Mean: 0.7883 (min: 0.1366, max: 4.8196)
#    [METRIC] Memorization: 0.00% (0/569 records)
#    [METRIC] NNDR: 0.8793 (+/- 0.3027)
#    [METRIC] Re-identification Risk: 0.00%
#    [METRIC] Overall Privacy Score: 0.760
#
# [ANALYSIS] Running TRTS analysis for CopulaGAN...
# [ANALYSIS] COMPREHENSIVE TRTS FRAMEWORK ANALYSIS (15+ Metrics)
# ============================================================
# [CHART] Data shapes:
#    - Real: (569, 5), Target unique values: 2
#    - Synthetic: (569, 5), Target unique values: 2
#    - Using 5 common features
#
# [PROCESS] 1. TRTR - Train Real, Test Real (Baseline)
#    [OK] TRTR Accuracy: 0.9123 | Balanced Acc: 0.9157 | MCC: 0.8174 (Time: 0.094s)
# [PROCESS] 2. TRTS - Train Real, Test Synthetic
#    [OK] TRTS Accuracy: 0.6667 | Balanced Acc: 0.6706 | MCC: 0.3487 (Time: 0.097s)
# [PROCESS] 3. TSTR - Train Synthetic, Test Real
#    [OK] TSTR Accuracy: 0.8772 | Balanced Acc: 0.8780 | MCC: 0.7433 (Time: 0.104s)
# [PROCESS] 4. TSTS - Train Synthetic, Test Synthetic
#    [OK] TSTS Accuracy: 0.6754 | Balanced Acc: 0.6753 | MCC: 0.3505 (Time: 0.105s)
#
# [CHART] Summary Statistics:
#    - Successful scenarios: 4/4
#    - Average accuracy: 0.7829 (+/-0.1126)
#    - Total training time: 0.399s
#
# [PRIVACY] Calculating privacy risk metrics...
#    [PRIVACY] Using 5 numeric features
#    [PRIVACY] Real: 569 records, Synthetic: 569 records
#    [METRIC] DCR Mean: 1.5378 (min: 0.1970, max: 3.8967)
#    [METRIC] Memorization: 0.00% (0/569 records)
#    [METRIC] NNDR: 1.4049 (+/- 0.6459)
#    [METRIC] Re-identification Risk: 0.00%
#    [METRIC] Overall Privacy Score: 0.901
#
# [ANALYSIS] Running TRTS analysis for TVAE...
# [ANALYSIS] COMPREHENSIVE TRTS FRAMEWORK ANALYSIS (15+ Metrics)
# ============================================================
# [CHART] Data shapes:
#    - Real: (569, 5), Target unique values: 2
#    - Synthetic: (569, 5), Target unique values: 2
#    - Using 5 common features
#
# [PROCESS] 1. TRTR - Train Real, Test Real (Baseline)
#    [OK] TRTR Accuracy: 0.9123 | Balanced Acc: 0.9157 | MCC: 0.8174 (Time: 0.095s)
# [PROCESS] 2. TRTS - Train Real, Test Synthetic
#    [OK] TRTS Accuracy: 0.8509 | Balanced Acc: 0.8412 | MCC: 0.6565 (Time: 0.097s)
# [PROCESS] 3. TSTR - Train Synthetic, Test Real
#    [OK] TSTR Accuracy: 0.8860 | Balanced Acc: 0.8849 | MCC: 0.7597 (Time: 0.103s)
# [PROCESS] 4. TSTS - Train Synthetic, Test Synthetic
#    [OK] TSTS Accuracy: 0.8596 | Balanced Acc: 0.7935 | MCC: 0.6434 (Time: 0.104s)
#
# [CHART] Summary Statistics:
#    - Successful scenarios: 4/4
#    - Average accuracy: 0.8772 (+/-0.0240)
#    - Total training time: 0.399s
#
# [PRIVACY] Calculating privacy risk metrics...
#    [PRIVACY] Using 5 numeric features
#    [PRIVACY] Real: 569 records, Synthetic: 569 records
#    [METRIC] DCR Mean: 0.6465 (min: 0.0996, max: 2.0919)
#    [METRIC] Memorization: 0.00% (0/569 records)
#    [METRIC] NNDR: 1.0292 (+/- 0.3573)
#    [METRIC] Re-identification Risk: 0.00%
#    [METRIC] Overall Privacy Score: 0.750
#
# [ANALYSIS] Running TRTS analysis for MEDGAN...
# [ANALYSIS] COMPREHENSIVE TRTS FRAMEWORK ANALYSIS (15+ Metrics)
# ============================================================
# [CHART] Data shapes:
#    - Real: (569, 5), Target unique values: 2
#    - Synthetic: (569, 5), Target unique values: 1
#    - Using 5 common features
#
# [PROCESS] 1. TRTR - Train Real, Test Real (Baseline)
#    [OK] TRTR Accuracy: 0.9123 | Balanced Acc: 0.9157 | MCC: 0.8174 (Time: 0.095s)
# [PROCESS] 2. TRTS - Train Real, Test Synthetic
#    [WARNING] Could not calculate AUROC/AUPRC/Brier: y should be a 1d array, got an array of shape (114, 2) instead.
#    [OK] TRTS Accuracy: 1.0000 | Balanced Acc: 1.0000 | MCC: 0.0000 (Time: 0.095s)
# [PROCESS] 3. TSTR - Train Synthetic, Test Real
#    [WARNING] Could not calculate AUROC/AUPRC/Brier: index 1 is out of bounds for axis 1 with size 1
#    [OK] TSTR Accuracy: 0.6316 | Balanced Acc: 0.5000 | MCC: 0.0000 (Time: 0.072s)
# [PROCESS] 4. TSTS - Train Synthetic, Test Synthetic
#    [OK] TSTS Accuracy: 1.0000 | Balanced Acc: 1.0000 | MCC: 0.0000 (Time: 0.072s)
#
# [CHART] Summary Statistics:
#    - Successful scenarios: 4/4
#    - Average accuracy: 0.8860 (+/-0.1512)
#    - Total training time: 0.333s
#
# [PRIVACY] Calculating privacy risk metrics...
#    [PRIVACY] Using 5 numeric features
#    [PRIVACY] Real: 569 records, Synthetic: 569 records
#    [METRIC] DCR Mean: 17.2451 (min: 3.9538, max: 19.7427)
#    [METRIC] Memorization: 0.00% (0/569 records)
#    [METRIC] NNDR: 30455.3918 (+/- 94287.3135)
#    [METRIC] Re-identification Risk: 0.00%
#    [METRIC] Overall Privacy Score: 1.000
#
# [ANALYSIS] Running TRTS analysis for PATEGAN...
# [ANALYSIS] COMPREHENSIVE TRTS FRAMEWORK ANALYSIS (15+ Metrics)
# ============================================================
# [CHART] Data shapes:
#    - Real: (569, 5), Target unique values: 2
#    - Synthetic: (569, 5), Target unique values: 1
#    - Using 5 common features
#
# [PROCESS] 1. TRTR - Train Real, Test Real (Baseline)
#    [OK] TRTR Accuracy: 0.9123 | Balanced Acc: 0.9157 | MCC: 0.8174 (Time: 0.095s)
# [PROCESS] 2. TRTS - Train Real, Test Synthetic
#    [WARNING] Could not calculate AUROC/AUPRC/Brier: y should be a 1d array, got an array of shape (114, 2) instead.
#    [OK] TRTS Accuracy: 0.0000 | Balanced Acc: 0.0000 | MCC: 0.0000 (Time: 0.095s)
# [PROCESS] 3. TSTR - Train Synthetic, Test Real
#    [WARNING] Could not calculate AUROC/AUPRC/Brier: index 1 is out of bounds for axis 1 with size 1
#    [OK] TSTR Accuracy: 0.3684 | Balanced Acc: 0.5000 | MCC: 0.0000 (Time: 0.071s)
# [PROCESS] 4. TSTS - Train Synthetic, Test Synthetic
#    [OK] TSTS Accuracy: 1.0000 | Balanced Acc: 1.0000 | MCC: 0.0000 (Time: 0.072s)
#
# [CHART] Summary Statistics:
#    - Successful scenarios: 4/4
#    - Average accuracy: 0.5702 (+/-0.4085)
#    - Total training time: 0.333s
#
# [PRIVACY] Calculating privacy risk metrics...
#    [PRIVACY] Using 5 numeric features
#    [PRIVACY] Real: 569 records, Synthetic: 569 records
#    [METRIC] DCR Mean: 57.4747 (min: 49.4805, max: 59.3987)
#    [METRIC] Memorization: 0.00% (0/569 records)
#    [METRIC] NNDR: 3096.2589 (+/- 1636.0698)
#    [METRIC] Re-identification Risk: 0.00%
#    [METRIC] Overall Privacy Score: 1.000
#
# [CHART] Creating TRTS visualizations...
# [VIZ] Saved: trts_comprehensive_analysis.png
# [VIZ] Generated 3 TRTS files
# [OK] TRTS visualization files generated:
#    [FOLDER] trts_comprehensive_analysis.png
#    [FOLDER] trts_summary_metrics.csv
#    [FOLDER] trts_detailed_results.csv
#
# [STATS] TRTS Analysis Summary:
#    - Models analyzed: 7
#    - Average combined score: 0.7917
#    - Best performing model: MEDGAN
#    - Total scenarios tested: 28
# [VIZ] Saved: privacy_dashboard.png
# [VIZ] Saved: privacy_summary.csv
#
# ======================================================================
# GENERATING ROC CURVES
# ======================================================================
# [SUCCESS] ROC curves saved: results/breast-cancer-data/2026-01-22/Section-3/trts_roc_curves.png
#
# ======================================================================
# GENERATING PRECISION-RECALL CURVES
# ======================================================================
# [SUCCESS] PR curves saved: results/breast-cancer-data/2026-01-22/Section-3/trts_pr_curves.png
#
# ======================================================================
# GENERATING CALIBRATION CURVES
# ======================================================================
# [SUCCESS] Calibration curves saved: results/breast-cancer-data/2026-01-22/Section-3/trts_calibration_curves.png
#
# SECTION 3 BATCH EVALUATION COMPLETED!
# Evaluated 7 models successfully
#
# RANKING BY QUALITY SCORE:
#    1. CTABGAN: 0.726
#    2. CTABGANPLUS: 0.717
#    3. TVAE: 0.692
#    4. CopulaGAN: 0.620
#    5. CTGAN: 0.526
#    6. MEDGAN: nan
#    7. PATEGAN: nan

# %% [markdown]
# ## 4 Hyperparameter Tuning

# %% [markdown]
# ### 4.1 Batch Hyperparameter Optimization

# %%
# Code Chunk ID: CHUNK_4_1_BATCH
# ============================================================================
# SECTION 4.1 - BATCH HYPERPARAMETER OPTIMIZATION
# ============================================================================

import sys
import importlib

# Ensure Optuna is installed
# !{sys.executable} -m pip install -U optuna -q

import optuna
print(f"Optuna version: {optuna.__version__}")

# Reload modules to pick up optuna
import src.models.search_spaces as ss
ss = importlib.reload(ss)

import src.models.batch_optimization as bo
bo = importlib.reload(bo)

optimize_models_batch = bo.optimize_models_batch
extract_studies_to_globals = bo.extract_studies_to_globals

# Run batch optimization
optimization_results = optimize_models_batch(
    data=data,
    models_to_run=models_to_run,
    target_column=target_column,
    categorical_columns=categorical_columns,
    n_trials=N_TRIALS,
    run_mode=RUN_MODE,
    random_state=42,
    verbose=False
)

# Extract *_study variables for Section 4.2 compatibility
created_vars = extract_studies_to_globals(optimization_results, globals())
print(f"\nCreated study variables: {created_vars}")
# Out:
# [I 2026-01-22 14:58:10,847] A new study created in memory with name: ctgan_hpo
# Optuna version: 4.7.0
# [OK] Search spaces module loaded from src/models/search_spaces.py
# [OK] Batch optimization module loaded from src/models/batch_optimization.py
# Gen. (-0.46) | Discrim. (-0.01): 100%|██████████| 400/400 [00:08<00:00, 44.66it/s]
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.4117
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.7944
# [CHART] Combined Score: 0.5648 (Similarity: 0.4117, Accuracy: 0.7944)
# Gen. (-0.95) | Discrim. (-0.02): 100%|██████████| 200/200 [00:04<00:00, 43.98it/s]
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.3399
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.4772
# [CHART] Combined Score: 0.3948 (Similarity: 0.3399, Accuracy: 0.4772)
# Gen. (-1.48) | Discrim. (-0.11): 100%|██████████| 300/300 [00:06<00:00, 44.52it/s]
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.3955
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.6898
# [CHART] Combined Score: 0.5132 (Similarity: 0.3955, Accuracy: 0.6898)
# Gen. (-0.32) | Discrim. (-0.00): 100%|██████████| 250/250 [00:05<00:00, 44.85it/s]
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.3805
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.6661
# [CHART] Combined Score: 0.4947 (Similarity: 0.3805, Accuracy: 0.6661)
# Gen. (-0.71) | Discrim. (-0.19): 100%|██████████| 400/400 [00:09<00:00, 43.92it/s]
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.4337
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.7214
# [CHART] Combined Score: 0.5488 (Similarity: 0.4337, Accuracy: 0.7214)
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.4702
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.8787
# [CHART] Combined Score: 0.6336 (Similarity: 0.4702, Accuracy: 0.8787)
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.4598
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.8752
# [CHART] Combined Score: 0.6260 (Similarity: 0.4598, Accuracy: 0.8752)
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.5006
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9016
# [CHART] Combined Score: 0.6610 (Similarity: 0.5006, Accuracy: 0.9016)
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.4932
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.8699
# [CHART] Combined Score: 0.6439 (Similarity: 0.4932, Accuracy: 0.8699)
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.4526
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.8541
# [CHART] Combined Score: 0.6132 (Similarity: 0.4526, Accuracy: 0.8541)
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.3908
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.6301
# [CHART] Combined Score: 0.4865 (Similarity: 0.3908, Accuracy: 0.6301)
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.3466
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.3506
# [CHART] Combined Score: 0.3482 (Similarity: 0.3466, Accuracy: 0.3506)
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.3565
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.7293
# [CHART] Combined Score: 0.5056 (Similarity: 0.3565, Accuracy: 0.7293)
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.3860
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.6432
# [CHART] Combined Score: 0.4889 (Similarity: 0.3860, Accuracy: 0.6432)
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.4131
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.8682
# [CHART] Combined Score: 0.5951 (Similarity: 0.4131, Accuracy: 0.8682)
# 100%|██████████| 350/350 [00:20<00:00, 16.86it/s]
# Finished training in 21.62606716156006  seconds.
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.5330
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.8849
# [CHART] Combined Score: 0.6737 (Similarity: 0.5330, Accuracy: 0.8849)
# 100%|██████████| 250/250 [00:14<00:00, 16.90it/s]
# Finished training in 15.63670563697815  seconds.
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.5106
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.8866
# [CHART] Combined Score: 0.6610 (Similarity: 0.5106, Accuracy: 0.8866)
# 100%|██████████| 250/250 [00:14<00:00, 16.95it/s]
# Finished training in 15.611017227172852  seconds.
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.4941
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.8910
# [CHART] Combined Score: 0.6529 (Similarity: 0.4941, Accuracy: 0.8910)
# 100%|██████████| 400/400 [00:23<00:00, 16.96it/s]
# Finished training in 24.44449520111084  seconds.
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.5269
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.8902
# [CHART] Combined Score: 0.6722 (Similarity: 0.5269, Accuracy: 0.8902)
# 100%|██████████| 200/200 [00:11<00:00, 16.90it/s]
# Finished training in 12.682846307754517  seconds.
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.5302
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.8787
# [CHART] Combined Score: 0.6696 (Similarity: 0.5302, Accuracy: 0.8787)
# 100%|██████████| 250/250 [00:25<00:00,  9.85it/s]
# Finished training in 26.22371196746826  seconds.
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.5509
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.8910
# [CHART] Combined Score: 0.6870 (Similarity: 0.5509, Accuracy: 0.8910)
# 100%|██████████| 400/400 [00:17<00:00, 22.96it/s]
# Finished training in 18.269837141036987  seconds.
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.5517
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.8902
# [CHART] Combined Score: 0.6871 (Similarity: 0.5517, Accuracy: 0.8902)
# 100%|██████████| 250/250 [00:10<00:00, 23.71it/s]
# Finished training in 11.385831356048584  seconds.
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.4823
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.8559
# [CHART] Combined Score: 0.6317 (Similarity: 0.4823, Accuracy: 0.8559)
# 100%|██████████| 200/200 [00:08<00:00, 23.63it/s]
# Finished training in 9.304942846298218  seconds.
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.5155
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.8849
# [CHART] Combined Score: 0.6632 (Similarity: 0.5155, Accuracy: 0.8849)
# 100%|██████████| 350/350 [00:20<00:00, 16.77it/s]
# Finished training in 21.72424578666687  seconds.
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.5458
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.8699
# [CHART] Combined Score: 0.6754 (Similarity: 0.5458, Accuracy: 0.8699)
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.2129
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.1863
# [CHART] Combined Score: 0.2023 (Similarity: 0.2129, Accuracy: 0.1863)
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.2043
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.1863
# [CHART] Combined Score: 0.1971 (Similarity: 0.2043, Accuracy: 0.1863)
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.1852
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.1863
# [CHART] Combined Score: 0.1856 (Similarity: 0.1852, Accuracy: 0.1863)
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.2926
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.1863
# [CHART] Combined Score: 0.2501 (Similarity: 0.2926, Accuracy: 0.1863)
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.1904
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.1863
# [CHART] Combined Score: 0.1887 (Similarity: 0.1904, Accuracy: 0.1863)
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.1924
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.1863
# [CHART] Combined Score: 0.1899 (Similarity: 0.1924, Accuracy: 0.1863)
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.1894
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.3260
# [CHART] Combined Score: 0.2440 (Similarity: 0.1894, Accuracy: 0.3260)
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.2149
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.1863
# [CHART] Combined Score: 0.2035 (Similarity: 0.2149, Accuracy: 0.1863)
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.2113
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.1863
# [CHART] Combined Score: 0.2013 (Similarity: 0.2113, Accuracy: 0.1863)
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.2222
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.1863
# [CHART] Combined Score: 0.2079 (Similarity: 0.2222, Accuracy: 0.1863)
#
# Created study variables: ['ctgan_study', 'tvae_study', 'copulagan_study', 'ctabgan_study', 'ctabganplus_study', 'pategan_study', 'medgan_study']

# %% [markdown]
# ### 4.2 Save Best Parameters

# %%
# Code Chunk ID: CHUNK_4_1_SAVE
# ============================================================================
# SECTION 4.2 - SAVE BEST PARAMETERS TO CSV
# ============================================================================

from src.utils.parameters import save_best_parameters_to_csv

# Save all best parameters to CSV for Section 5
save_result = save_best_parameters_to_csv(
    scope=globals(),
    section_number=4,
    dataset_identifier=DATASET_IDENTIFIER
)

print(f"\nParameters saved: {save_result['success']}")
print(f"Files: {save_result.get('files_saved', [])}")
# Out:
# [SAVE] SAVING BEST PARAMETERS FROM SECTION 4
# ============================================================
# [FOLDER] Target directory: results/breast-cancer-data/2026-01-22/Section-4
#
# [CHART] Processing CTGAN parameters...
# [OK] Found CTGAN: 10 parameters, score: 0.5648
#
# [CHART] Processing CTAB-GAN parameters...
# [OK] Found CTAB-GAN: 2 parameters, score: 0.6737
#
# [CHART] Processing CTAB-GAN+ parameters...
# [OK] Found CTAB-GAN+: 2 parameters, score: 0.6871
#
# [CHART] Processing GANerAid parameters...
# [WARNING]  GANerAid: Study variable 'ganeraid_study' not found
#
# [CHART] Processing CopulaGAN parameters...
# [OK] Found CopulaGAN: 6 parameters, score: 0.5951
#
# [CHART] Processing TVAE parameters...
# [OK] Found TVAE: 8 parameters, score: 0.6610
#
# [OK] Parameters saved: results/breast-cancer-data/2026-01-22/Section-4/best_parameters.csv
#    - Total parameter entries: 36
# [OK] Summary saved: results/breast-cancer-data/2026-01-22/Section-4/best_parameters_summary.csv
#    - Models processed: 5
#
# [SAVE] Parameter saving completed!
# [FOLDER] Files saved to: results/breast-cancer-data/2026-01-22/Section-4
#
# Parameters saved: True
# Files: ['results/breast-cancer-data/2026-01-22/Section-4/best_parameters.csv', 'results/breast-cancer-data/2026-01-22/Section-4/best_parameters_summary.csv']

# %% [markdown]
# ### 4.3 Hyperparameter Optimization Batch Analysis

# %%
import inspect
print(inspect.signature(evaluate_hyperparameter_optimization_results))
# Out:
# (section_number=4, scope=None, target_column=None)

# %%
# Code Chunk ID: CHUNK_4_2_0_A
# ============================================================================
# SECTION 4.3 - HYPERPARAMETER OPTIMIZATION BATCH ANALYSIS
# ============================================================================

print("SECTION 4.3 - HYPERPARAMETER OPTIMIZATION BATCH ANALYSIS")
print("=" * 80)

# Build scope dict for evaluation
study_vars_found = sorted([k for k in globals().keys() if k.endswith("_study")])
print(f"Study vars found: {study_vars_found}")

scope_for_eval = dict(globals())

# Use batch evaluation function
try:
    section4_batch_results = evaluate_hyperparameter_optimization_results(
    section_number=4,
    scope=scope_for_eval,
    target_column=TARGET_COLUMN)
    
    print(f"\nSECTION 4 BATCH ANALYSIS COMPLETED!")
    print(f"Models analyzed: {section4_batch_results.get('models_analyzed', 0)}")
    
except Exception as e:
    print(f"Section 4 batch analysis error: {e}")
    import traceback
    traceback.print_exc()
# Out:
# SECTION 4.3 - HYPERPARAMETER OPTIMIZATION BATCH ANALYSIS
# ================================================================================
# Study vars found: ['copulagan_study', 'ctabgan_study', 'ctabganplus_study', 'ctgan_study', 'medgan_study', 'pategan_study', 'tvae_study']
# [LOCATION] Using DATASET_IDENTIFIER from scope: breast-cancer-data
# [TARGET] Final DATASET_IDENTIFIER for Section 4: breast-cancer-data
#
# ================================================================================
# SECTION 4 - HYPERPARAMETER OPTIMIZATION BATCH ANALYSIS
# ================================================================================
# [FOLDER] Base results directory: results/breast-cancer-data/2026-01-22/Section-4
# [TARGET] Target column: diagnosis
# [CHART] Dataset identifier: breast-cancer-data
#
#
# [SEARCH] 4.1.1: CTGAN Hyperparameter Optimization Analysis
# ------------------------------------------------------------
# [OK] CTGAN optimization study found
# [FOLDER] Model directory: results/breast-cancer-data/2026-01-22/Section-4/CTGAN
# [SEARCH] ANALYZING CTGAN HYPERPARAMETER OPTIMIZATION
# ============================================================
# [CHART] 1. TRIAL DATA EXTRACTION AND PROCESSING
# ----------------------------------------
# [OK] Extracted 5 trials for analysis
# [CHART] 2. PARAMETER SPACE EXPLORATION ANALYSIS
# ----------------------------------------
#    - Found 10 hyperparameters: ['params_batch_size', 'params_discriminator_decay', 'params_discriminator_dim', 'params_discriminator_lr', 'params_discriminator_steps', 'params_epochs', 'params_generator_decay', 'params_generator_dim', 'params_generator_lr', 'params_pac']
#    - Using 5 completed trials
# [STATS] Creating parameter vs performance visualizations...
#    [FOLDER] Parameter analysis plot saved: results/breast-cancer-data/2026-01-22/Section-4/CTGAN/ctgan_parameter_analysis.png
# [CHART] 3. BEST TRIAL ANALYSIS
# ----------------------------------------
# [OK] Best Trial #0
#    - Best Score: 0.5648
#    - Duration: 10.2 seconds
#    - Best Parameters:
#      - batch_size: 128
#      - discriminator_decay: 0.0001
#      - discriminator_dim: (256, 256)
#      - discriminator_lr: 0.0000
#      - discriminator_steps: 2
#      - epochs: 400
#      - generator_decay: 0.0000
#      - generator_dim: (128, 128)
#      - generator_lr: 0.0000
#      - pac: 1
# [CHART] 4. CONVERGENCE ANALYSIS
# ----------------------------------------
#    [FOLDER] Convergence plot saved: results/breast-cancer-data/2026-01-22/Section-4/CTGAN/ctgan_convergence_analysis.png
# [CHART] 5. STATISTICAL SUMMARY
# ----------------------------------------
# [OK] Performance Statistics:
#    - Mean Score: 0.5033
#    - Std Dev: 0.0667
#    - Min Score: 0.3948
#    - Max Score: 0.5648
#    - Median Score: 0.5132
#    [FOLDER] Trial results saved: results/breast-cancer-data/2026-01-22/Section-4/CTGAN/ctgan_trial_results.csv
#    [FOLDER] Summary statistics saved: results/breast-cancer-data/2026-01-22/Section-4/CTGAN/ctgan_optimization_summary.csv
# [OK] CTGAN optimization analysis completed successfully!
# [FOLDER] Results saved to: results/breast-cancer-data/2026-01-22/Section-4/CTGAN
# [OK] CTGAN analysis completed - files exported to results/breast-cancer-data/2026-01-22/Section-4/CTGAN
#
# [SEARCH] 4.2.1: CTAB-GAN Hyperparameter Optimization Analysis
# ------------------------------------------------------------
# [OK] CTAB-GAN optimization study found
# [FOLDER] Model directory: results/breast-cancer-data/2026-01-22/Section-4/CTABGAN
# [SEARCH] ANALYZING CTABGAN HYPERPARAMETER OPTIMIZATION
# ============================================================
# [CHART] 1. TRIAL DATA EXTRACTION AND PROCESSING
# ----------------------------------------
# [OK] Extracted 5 trials for analysis
# [CHART] 2. PARAMETER SPACE EXPLORATION ANALYSIS
# ----------------------------------------
#    - Found 2 hyperparameters: ['params_batch_size', 'params_epochs']
#    - Using 5 completed trials
# [STATS] Creating parameter vs performance visualizations...
#    [FOLDER] Parameter analysis plot saved: results/breast-cancer-data/2026-01-22/Section-4/CTABGAN/ctabgan_parameter_analysis.png
# [CHART] 3. BEST TRIAL ANALYSIS
# ----------------------------------------
# [OK] Best Trial #0
#    - Best Score: 0.6737
#    - Duration: 21.9 seconds
#    - Best Parameters:
#      - batch_size: 128
#      - epochs: 350
# [CHART] 4. CONVERGENCE ANALYSIS
# ----------------------------------------
#    [FOLDER] Convergence plot saved: results/breast-cancer-data/2026-01-22/Section-4/CTABGAN/ctabgan_convergence_analysis.png
# [CHART] 5. STATISTICAL SUMMARY
# ----------------------------------------
# [OK] Performance Statistics:
#    - Mean Score: 0.6659
#    - Std Dev: 0.0088
#    - Min Score: 0.6529
#    - Max Score: 0.6737
#    - Median Score: 0.6696
#    [FOLDER] Trial results saved: results/breast-cancer-data/2026-01-22/Section-4/CTABGAN/ctabgan_trial_results.csv
#    [FOLDER] Summary statistics saved: results/breast-cancer-data/2026-01-22/Section-4/CTABGAN/ctabgan_optimization_summary.csv
# [OK] CTABGAN optimization analysis completed successfully!
# [FOLDER] Results saved to: results/breast-cancer-data/2026-01-22/Section-4/CTABGAN
# [OK] CTAB-GAN analysis completed - files exported to results/breast-cancer-data/2026-01-22/Section-4/CTABGAN
#
# [SEARCH] 4.3.1: CTAB-GAN+ Hyperparameter Optimization Analysis
# ------------------------------------------------------------
# [OK] CTAB-GAN+ optimization study found
# [FOLDER] Model directory: results/breast-cancer-data/2026-01-22/Section-4/CTABGANPLUS
# [SEARCH] ANALYZING CTABGANPLUS HYPERPARAMETER OPTIMIZATION
# ============================================================
# [CHART] 1. TRIAL DATA EXTRACTION AND PROCESSING
# ----------------------------------------
# [OK] Extracted 5 trials for analysis
# [CHART] 2. PARAMETER SPACE EXPLORATION ANALYSIS
# ----------------------------------------
#    - Found 2 hyperparameters: ['params_batch_size', 'params_epochs']
#    - Using 5 completed trials
# [STATS] Creating parameter vs performance visualizations...
#    [FOLDER] Parameter analysis plot saved: results/breast-cancer-data/2026-01-22/Section-4/CTABGANPLUS/ctabganplus_parameter_analysis.png
# [CHART] 3. BEST TRIAL ANALYSIS
# ----------------------------------------
# [OK] Best Trial #1
#    - Best Score: 0.6871
#    - Duration: 18.5 seconds
#    - Best Parameters:
#      - batch_size: 256
#      - epochs: 400
# [CHART] 4. CONVERGENCE ANALYSIS
# ----------------------------------------
#    [FOLDER] Convergence plot saved: results/breast-cancer-data/2026-01-22/Section-4/CTABGANPLUS/ctabganplus_convergence_analysis.png
# [CHART] 5. STATISTICAL SUMMARY
# ----------------------------------------
# [OK] Performance Statistics:
#    - Mean Score: 0.6689
#    - Std Dev: 0.0230
#    - Min Score: 0.6317
#    - Max Score: 0.6871
#    - Median Score: 0.6754
#    [FOLDER] Trial results saved: results/breast-cancer-data/2026-01-22/Section-4/CTABGANPLUS/ctabganplus_trial_results.csv
#    [FOLDER] Summary statistics saved: results/breast-cancer-data/2026-01-22/Section-4/CTABGANPLUS/ctabganplus_optimization_summary.csv
# [OK] CTABGANPLUS optimization analysis completed successfully!
# [FOLDER] Results saved to: results/breast-cancer-data/2026-01-22/Section-4/CTABGANPLUS
# [OK] CTAB-GAN+ analysis completed - files exported to results/breast-cancer-data/2026-01-22/Section-4/CTABGANPLUS
#
# [SEARCH] 4.4.1: GANerAid Hyperparameter Optimization Analysis
# ------------------------------------------------------------
# [WARNING]  GANerAid optimization study not found (variable: ganeraid_study)
#    Skipping GANerAid analysis
#
# [SEARCH] 4.5.1: CopulaGAN Hyperparameter Optimization Analysis
# ------------------------------------------------------------
# [OK] CopulaGAN optimization study found
# [FOLDER] Model directory: results/breast-cancer-data/2026-01-22/Section-4/COPULAGAN
# [SEARCH] ANALYZING COPULAGAN HYPERPARAMETER OPTIMIZATION
# ============================================================
# [CHART] 1. TRIAL DATA EXTRACTION AND PROCESSING
# ----------------------------------------
# [OK] Extracted 5 trials for analysis
# [CHART] 2. PARAMETER SPACE EXPLORATION ANALYSIS
# ----------------------------------------
#    - Found 6 hyperparameters: ['params_batch_size', 'params_discriminator_decay', 'params_discriminator_lr', 'params_epochs', 'params_generator_decay', 'params_generator_lr']
#    - Using 5 completed trials
# [STATS] Creating parameter vs performance visualizations...
#    [FOLDER] Parameter analysis plot saved: results/breast-cancer-data/2026-01-22/Section-4/COPULAGAN/copulagan_parameter_analysis.png
# [CHART] 3. BEST TRIAL ANALYSIS
# ----------------------------------------
# [OK] Best Trial #4
#    - Best Score: 0.5951
#    - Duration: 17.9 seconds
#    - Best Parameters:
#      - batch_size: 100
#      - discriminator_decay: 0.0001
#      - discriminator_lr: 0.0000
#      - epochs: 200
#      - generator_decay: 0.0000
#      - generator_lr: 0.0000
# [CHART] 4. CONVERGENCE ANALYSIS
# ----------------------------------------
#    [FOLDER] Convergence plot saved: results/breast-cancer-data/2026-01-22/Section-4/COPULAGAN/copulagan_convergence_analysis.png
# [CHART] 5. STATISTICAL SUMMARY
# ----------------------------------------
# [OK] Performance Statistics:
#    - Mean Score: 0.4849
#    - Std Dev: 0.0884
#    - Min Score: 0.3482
#    - Max Score: 0.5951
#    - Median Score: 0.4889
#    [FOLDER] Trial results saved: results/breast-cancer-data/2026-01-22/Section-4/COPULAGAN/copulagan_trial_results.csv
#    [FOLDER] Summary statistics saved: results/breast-cancer-data/2026-01-22/Section-4/COPULAGAN/copulagan_optimization_summary.csv
# [OK] COPULAGAN optimization analysis completed successfully!
# [FOLDER] Results saved to: results/breast-cancer-data/2026-01-22/Section-4/COPULAGAN
# [OK] CopulaGAN analysis completed - files exported to results/breast-cancer-data/2026-01-22/Section-4/COPULAGAN
#
# [SEARCH] 4.6.1: TVAE Hyperparameter Optimization Analysis
# ------------------------------------------------------------
# [OK] TVAE optimization study found
# [FOLDER] Model directory: results/breast-cancer-data/2026-01-22/Section-4/TVAE
# [SEARCH] ANALYZING TVAE HYPERPARAMETER OPTIMIZATION
# ============================================================
# [CHART] 1. TRIAL DATA EXTRACTION AND PROCESSING
# ----------------------------------------
# [OK] Extracted 5 trials for analysis
# [CHART] 2. PARAMETER SPACE EXPLORATION ANALYSIS
# ----------------------------------------
#    - Found 8 hyperparameters: ['params_batch_size', 'params_compress_dims', 'params_decompress_dims', 'params_dropout', 'params_embedding_dim', 'params_epochs', 'params_l2scale', 'params_learning_rate']
#    - Using 5 completed trials
# [STATS] Creating parameter vs performance visualizations...
#    [FOLDER] Parameter analysis plot saved: results/breast-cancer-data/2026-01-22/Section-4/TVAE/tvae_parameter_analysis.png
# [CHART] 3. BEST TRIAL ANALYSIS
# ----------------------------------------
# [OK] Best Trial #2
#    - Best Score: 0.6610
#    - Duration: 6.5 seconds
#    - Best Parameters:
#      - batch_size: 256
#      - compress_dims: (128, 128)
#      - decompress_dims: (64, 128)
#      - dropout: 0.1604
#      - embedding_dim: 128
#      - epochs: 300
#      - l2scale: 0.0001
#      - learning_rate: 0.0025
# [CHART] 4. CONVERGENCE ANALYSIS
# ----------------------------------------
#    [FOLDER] Convergence plot saved: results/breast-cancer-data/2026-01-22/Section-4/TVAE/tvae_convergence_analysis.png
# [CHART] 5. STATISTICAL SUMMARY
# ----------------------------------------
# [OK] Performance Statistics:
#    - Mean Score: 0.6355
#    - Std Dev: 0.0181
#    - Min Score: 0.6132
#    - Max Score: 0.6610
#    - Median Score: 0.6336
#    [FOLDER] Trial results saved: results/breast-cancer-data/2026-01-22/Section-4/TVAE/tvae_trial_results.csv
#    [FOLDER] Summary statistics saved: results/breast-cancer-data/2026-01-22/Section-4/TVAE/tvae_optimization_summary.csv
# [OK] TVAE optimization analysis completed successfully!
# [FOLDER] Results saved to: results/breast-cancer-data/2026-01-22/Section-4/TVAE
# [OK] TVAE analysis completed - files exported to results/breast-cancer-data/2026-01-22/Section-4/TVAE
#
# [SEARCH] 4.7.1: PATE-GAN Hyperparameter Optimization Analysis
# ------------------------------------------------------------
# [OK] PATE-GAN optimization study found
# [FOLDER] Model directory: results/breast-cancer-data/2026-01-22/Section-4/PATEGAN
# [SEARCH] ANALYZING PATEGAN HYPERPARAMETER OPTIMIZATION
# ============================================================
# [CHART] 1. TRIAL DATA EXTRACTION AND PROCESSING
# ----------------------------------------
# [OK] Extracted 5 trials for analysis
# [CHART] 2. PARAMETER SPACE EXPLORATION ANALYSIS
# ----------------------------------------
#    - Found 10 hyperparameters: ['params_batch_size', 'params_discriminator_dim', 'params_discriminator_lr', 'params_epochs', 'params_generator_dim', 'params_generator_lr', 'params_lap_scale', 'params_noise_multiplier', 'params_num_teachers', 'params_target_epsilon']
#    - Using 5 completed trials
# [STATS] Creating parameter vs performance visualizations...
#    [FOLDER] Parameter analysis plot saved: results/breast-cancer-data/2026-01-22/Section-4/PATEGAN/pategan_parameter_analysis.png
# [CHART] 3. BEST TRIAL ANALYSIS
# ----------------------------------------
# [OK] Best Trial #3
#    - Best Score: 0.2501
#    - Duration: 7.1 seconds
#    - Best Parameters:
#      - batch_size: 128
#      - discriminator_dim: (128, 128)
#      - discriminator_lr: 0.0001
#      - epochs: 300
#      - generator_dim: (256, 128)
#      - generator_lr: 0.0000
#      - lap_scale: 0.0345
#      - noise_multiplier: 1.1357
#      - num_teachers: 5
#      - target_epsilon: 6.7366
# [CHART] 4. CONVERGENCE ANALYSIS
# ----------------------------------------
#    [FOLDER] Convergence plot saved: results/breast-cancer-data/2026-01-22/Section-4/PATEGAN/pategan_convergence_analysis.png
# [CHART] 5. STATISTICAL SUMMARY
# ----------------------------------------
# [OK] Performance Statistics:
#    - Mean Score: 0.2048
#    - Std Dev: 0.0262
#    - Min Score: 0.1856
#    - Max Score: 0.2501
#    - Median Score: 0.1971
#    [FOLDER] Trial results saved: results/breast-cancer-data/2026-01-22/Section-4/PATEGAN/pategan_trial_results.csv
#    [FOLDER] Summary statistics saved: results/breast-cancer-data/2026-01-22/Section-4/PATEGAN/pategan_optimization_summary.csv
# [OK] PATEGAN optimization analysis completed successfully!
# [FOLDER] Results saved to: results/breast-cancer-data/2026-01-22/Section-4/PATEGAN
# [OK] PATE-GAN analysis completed - files exported to results/breast-cancer-data/2026-01-22/Section-4/PATEGAN
#
# [SEARCH] 4.8.1: MEDGAN Hyperparameter Optimization Analysis
# ------------------------------------------------------------
# [OK] MEDGAN optimization study found
# [FOLDER] Model directory: results/breast-cancer-data/2026-01-22/Section-4/MEDGAN
# [SEARCH] ANALYZING MEDGAN HYPERPARAMETER OPTIMIZATION
# ============================================================
# [CHART] 1. TRIAL DATA EXTRACTION AND PROCESSING
# ----------------------------------------
# [OK] Extracted 5 trials for analysis
# [CHART] 2. PARAMETER SPACE EXPLORATION ANALYSIS
# ----------------------------------------
#    - Found 11 hyperparameters: ['params_autoencoder_dim', 'params_autoencoder_lr', 'params_batch_size', 'params_discriminator_dim', 'params_discriminator_lr', 'params_epochs', 'params_generator_dim', 'params_generator_lr', 'params_l2_reg', 'params_latent_dim', 'params_pretrain_epochs']
#    - Using 5 completed trials
# [STATS] Creating parameter vs performance visualizations...
#    [FOLDER] Parameter analysis plot saved: results/breast-cancer-data/2026-01-22/Section-4/MEDGAN/medgan_parameter_analysis.png
# [CHART] 3. BEST TRIAL ANALYSIS
# ----------------------------------------
# [OK] Best Trial #1
#    - Best Score: 0.2440
#    - Duration: 7.4 seconds
#    - Best Parameters:
#      - autoencoder_dim: (64, 64)
#      - autoencoder_lr: 0.0049
#      - batch_size: 64
#      - discriminator_dim: (128, 64)
#      - discriminator_lr: 0.0008
#      - epochs: 250
#      - generator_dim: (64, 64)
#      - generator_lr: 0.0077
#      - l2_reg: 0.0002
#      - latent_dim: 96
#      - pretrain_epochs: 50
# [CHART] 4. CONVERGENCE ANALYSIS
# ----------------------------------------
#    [FOLDER] Convergence plot saved: results/breast-cancer-data/2026-01-22/Section-4/MEDGAN/medgan_convergence_analysis.png
# [CHART] 5. STATISTICAL SUMMARY
# ----------------------------------------
# [OK] Performance Statistics:
#    - Mean Score: 0.2093
#    - Std Dev: 0.0205
#    - Min Score: 0.1899
#    - Max Score: 0.2440
#    - Median Score: 0.2035
#    [FOLDER] Trial results saved: results/breast-cancer-data/2026-01-22/Section-4/MEDGAN/medgan_trial_results.csv
#    [FOLDER] Summary statistics saved: results/breast-cancer-data/2026-01-22/Section-4/MEDGAN/medgan_optimization_summary.csv
# [OK] MEDGAN optimization analysis completed successfully!
# [FOLDER] Results saved to: results/breast-cancer-data/2026-01-22/Section-4/MEDGAN
# [OK] MEDGAN analysis completed - files exported to results/breast-cancer-data/2026-01-22/Section-4/MEDGAN
#
# ============================================================
# HYPERPARAMETER OPTIMIZATION SUMMARY
# ============================================================
# [CHART] Models analyzed: 7
# [STATS] Total optimization trials: 35
# [OK] Successful trials: 35
#
# [INFO] OPTIMIZATION RESULTS SUMMARY:
#     model section  best_score  total_trials  completed_trials  best_trial_number    study_variable
#     CTGAN   4.1.1    0.564754             5                 5                  0       ctgan_study
#  CTAB-GAN   4.2.1    0.673743             5                 5                  0     ctabgan_study
# CTAB-GAN+   4.3.1    0.687075             5                 5                  1 ctabganplus_study
# CopulaGAN   4.5.1    0.595128             5                 5                  4   copulagan_study
#      TVAE   4.6.1    0.660981             5                 5                  2        tvae_study
#  PATE-GAN   4.7.1    0.250069             5                 5                  3     pategan_study
#    MEDGAN   4.8.1    0.244014             5                 5                  1      medgan_study
#
# [SAVE] Summary exported to: results/breast-cancer-data/2026-01-22/Section-4/hyperparameter_optimization_summary.csv
#
# [BEST] BEST PERFORMING MODEL: CTAB-GAN+
#    - Score: 0.6871
#    - Section: 4.3.1
#    - Trials completed: 5
#
# [OK] Section 4 hyperparameter optimization batch analysis completed!
# [FOLDER] All figures and tables exported to: results/breast-cancer-data/2026-01-22/Section-4
# [CHART] Model-specific results in subdirectories: ['CTGAN', 'CTABGAN', 'CTABGANPLUS', 'GANERAID', 'COPULAGAN', 'TVAE', 'PATEGAN', 'MEDGAN']
#
# SECTION 4 BATCH ANALYSIS COMPLETED!
# Models analyzed: 0

# %% [markdown]
# ## 5 Final Model Comparison with Best Parameters

# %% [markdown]
# ### 5.1 Train All Models with Best Parameters from Section 4

# %%
# Code Chunk ID: CHUNK_5_1_BATCH
# ============================================================================
# SECTION 5.1 - BATCH TRAINING WITH BEST PARAMETERS
# Replaces individual 5.1.1-5.1.6 model cells with single batch call
# ============================================================================

from src.models.batch_training import train_models_batch_with_best_params

# Train all models with best parameters from Section 4
# This creates synthetic_*_final variables automatically
section5_results = train_models_batch_with_best_params(
    data=data,
    target_column=target_column,
    models_to_run=models_to_run,
    categorical_columns=categorical_columns,
    n_samples=len(data),
    random_state=42,
    section_number=4,  # Load params from Section 4
    dataset_identifier=DATASET_IDENTIFIER,
    scope=globals(),   # Creates synthetic_*_final variables
    verbose=True
)

# Show summary of created variables
final_vars = [k for k in globals().keys() if k.endswith('_final')]
print(f"\nFinal synthetic data variables: {sorted(final_vars)}")
# Out:
# ============================================================
# SECTION 5.1: BATCH TRAINING WITH BEST PARAMETERS
# ============================================================
# Models to train: 7
# Dataset shape: (569, 6)
# Target column: diagnosis
# Samples to generate: 569
# Loading parameters from: Section 4
# ============================================================
#
# [1/3] Loading best parameters from Section 4...
# [LOAD] LOADING BEST PARAMETERS FROM SECTION 4
# ============================================================
# [FOLDER] Looking for: results/breast-cancer-data/2026-01-22/Section-4/best_parameters.csv
# [OK] Found parameter CSV file
# [OK] Loaded CTGAN: 10 parameters
# [OK] Loaded CTAB-GAN: 2 parameters
# [OK] Loaded CTAB-GAN+: 2 parameters
# [OK] Loaded CopulaGAN: 6 parameters
# [OK] Loaded TVAE: 8 parameters
#
# [LOAD] Parameter loading completed!
# [SEARCH] Source: CSV file
# [CHART] Models loaded: 5
#    - ctgan: 10 parameters
#    - ctabgan: 2 parameters
#    - ctabganplus: 2 parameters
#    - copulagan: 6 parameters
#    - tvae: 8 parameters
#    Parameter source: CSV file
#    Models with parameters: 5
#
# [2/3] Training models with optimized parameters...
#
# [1/7] Training CTGAN...
# --------------------------------------------------
#   Parameters loaded: 10
#     - epochs: 400
#     - batch_size: 128
#     - pac: 1
#     - generator_lr: 0.0000
#     - discriminator_lr: 0.0000
#     ... and 6 more
#   Training CTGAN...
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Gen. (-0.71) | Discrim. (-0.12): 100%|██████████| 400/400 [00:09<00:00, 44.09it/s]
#   Generating 569 synthetic samples...
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.4366
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.8392
# [CHART] Combined Score: 0.5976 (Similarity: 0.4366, Accuracy: 0.8392)
#   [OK] CTGAN completed in 14.12s
#   Synthetic data shape: (569, 6)
#   Objective score: 0.5976
#
# [2/7] Training TVAE...
# --------------------------------------------------
#   Parameters loaded: 8
#     - epochs: 300
#     - batch_size: 256
#     - learning_rate: 0.0025
#     - embedding_dim: 128
#     - l2scale: 0.0001
#     ... and 4 more
#   Training TVAE...
#   Generating 569 synthetic samples...
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.4569
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.8787
# [CHART] Combined Score: 0.6256 (Similarity: 0.4569, Accuracy: 0.8787)
#   [OK] TVAE completed in 6.32s
#   Synthetic data shape: (569, 6)
#   Objective score: 0.6256
#
# [3/7] Training CopulaGAN...
# --------------------------------------------------
#   Parameters loaded: 6
#     - epochs: 200
#     - batch_size: 100
#     - generator_lr: 0.0000
#     - discriminator_lr: 0.0000
#     - generator_decay: 0.0000
#     ... and 2 more
#   Training CopulaGAN...
#   Generating 569 synthetic samples...
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.4413
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.7891
# [CHART] Combined Score: 0.5804 (Similarity: 0.4413, Accuracy: 0.7891)
#   [OK] CopulaGAN completed in 17.55s
#   Synthetic data shape: (569, 6)
#   Objective score: 0.5804
#
# [4/7] Training CTABGAN...
# --------------------------------------------------
#   Parameters loaded: 2
#     - epochs: 350
#     - batch_size: 128
#     - categorical_columns: ['diagnosis']
#     - target_col: diagnosis
#   Training CTABGAN...
# 100%|██████████| 350/350 [00:20<00:00, 16.89it/s]
# Finished training in 21.571963787078857  seconds.
#   Generating 569 synthetic samples...
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.6024
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.8910
# [CHART] Combined Score: 0.7179 (Similarity: 0.6024, Accuracy: 0.8910)
#   [OK] CTABGAN completed in 21.62s
#   Synthetic data shape: (569, 6)
#   Objective score: 0.7179
#
# [5/7] Training CTABGAN+...
# --------------------------------------------------
#   Parameters loaded: 2
#     - epochs: 400
#     - batch_size: 256
#     - categorical_columns: ['diagnosis']
#     - target_col: diagnosis
#   Training CTABGAN+...
# 100%|██████████| 400/400 [00:17<00:00, 23.24it/s]
# Finished training in 18.06275224685669  seconds.
#   Generating 569 synthetic samples...
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.5705
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.8946
# [CHART] Combined Score: 0.7001 (Similarity: 0.5705, Accuracy: 0.8946)
#   [OK] CTABGAN+ completed in 18.10s
#   Synthetic data shape: (569, 6)
#   Objective score: 0.7001
#
# [6/7] Training PATE-GAN...
# --------------------------------------------------
#   WARNING: No parameters found for PATE-GAN, using defaults
#   Parameters loaded: 0
#     - discrete_columns: ['diagnosis']
#   Training PATE-GAN...
#   Generating 569 synthetic samples...
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.1910
# [ERROR] TRTS (Real->Synthetic) failed: Classification metrics can't handle a mix of continuous and binary targets
# [ERROR] TRTS (Synthetic->Real) failed: Unknown label type: continuous. Maybe you are trying to fit a classifier, which expects discrete classes on a regression target with continuous values.
# [CHART] Combined Score: 0.3146 (Similarity: 0.1910, Accuracy: 0.5000)
#   [OK] PATE-GAN completed in 2.32s
#   Synthetic data shape: (569, 6)
#   Objective score: 0.3146
#
# [7/7] Training MEDGAN...
# --------------------------------------------------
#   WARNING: No parameters found for MEDGAN, using defaults
#   Parameters loaded: 0
#     - discrete_columns: ['diagnosis']
#   Training MEDGAN...
#   Generating 569 synthetic samples...
# [TARGET] Enhanced objective function using target column: 'diagnosis'
# [OK] Similarity Analysis: 6/6 valid metrics, Average: 0.1934
# [ERROR] TRTS (Real->Synthetic) failed: Classification metrics can't handle a mix of continuous and binary targets
# [ERROR] TRTS (Synthetic->Real) failed: Unknown label type: continuous. Maybe you are trying to fit a classifier, which expects discrete classes on a regression target with continuous values.
# [CHART] Combined Score: 0.3161 (Similarity: 0.1934, Accuracy: 0.5000)
#   [OK] MEDGAN completed in 6.86s
#   Synthetic data shape: (569, 6)
#   Objective score: 0.3161
#
# [3/3] Creating synthetic_*_final variables...
#    Created: ['synthetic_ctgan_final', 'synthetic_tvae_final', 'synthetic_copulagan_final', 'synthetic_ctabgan_final', 'synthetic_ctabganplus_final', 'synthetic_pategan_final', 'synthetic_medgan_final']
#
# ============================================================
# BATCH TRAINING SUMMARY
# ============================================================
# Total models: 7
# Successful: 7
# Failed: 0
# Parameter source: CSV file
# ============================================================
#
# Successful models:
#   - CTGAN: 14.12s, score: 0.5976
#   - TVAE: 6.32s, score: 0.6256
#   - CopulaGAN: 17.55s, score: 0.5804
#   - CTABGAN: 21.62s, score: 0.7179
#   - CTABGAN+: 18.10s, score: 0.7001
#   - PATE-GAN: 2.32s, score: 0.3146
#   - MEDGAN: 6.86s, score: 0.3161
#
# Final synthetic data variables: ['synthetic_copulagan_final', 'synthetic_ctabgan_final', 'synthetic_ctabganplus_final', 'synthetic_ctgan_final', 'synthetic_medgan_final', 'synthetic_pategan_final', 'synthetic_tvae_final']

# %% [markdown]
# ### 5.2 Batch Evaluation of Optimized Models

# %%
# Code Chunk ID: CHUNK_5_2_0_A
# ============================================================================
# SECTION 5.2 - OPTIMIZED MODELS BATCH EVALUATION
# ============================================================================

print("SECTION 5.2 - OPTIMIZED MODELS BATCH EVALUATION")
print("=" * 80)

from setup import evaluate_section5_optimized_models

try:
    section5_batch_results = evaluate_section5_optimized_models(
        section_number=5,
        scope=globals(),
        target_column=TARGET_COLUMN
    )
    
    print("\n" + "="*80)
    print("SECTION 5.2 OPTIMIZED MODELS BATCH EVALUATION COMPLETED!")
    print("="*80)
    print(f"Models processed: {section5_batch_results['models_processed']}")
    print(f"Results exported to: {section5_batch_results['results_dir']}")
    
    # Show summary
    if 'evaluation_summaries' in section5_batch_results:
        print("\nEVALUATION SUMMARIES:")
        print("-" * 40)
        for model_name, summary in section5_batch_results['evaluation_summaries'].items():
            print(f"{model_name}:")
            print(f"   Synthetic samples: {summary.get('synthetic_samples', 'N/A')}")
            print(f"   Overall score: {summary.get('overall_score', 'N/A')}")
            
except Exception as e:
    print(f"Section 5.2 batch evaluation failed: {e}")
    import traceback
    traceback.print_exc()
# Out:
# SECTION 5.2 - OPTIMIZED MODELS BATCH EVALUATION
# ================================================================================
# [SEARCH] UNIFIED BATCH EVALUATION - SECTION 5
# ============================================================
# [INFO] Dataset: breast-cancer-data
# [INFO] Target column: diagnosis
# [INFO] Variable pattern: final
# [INFO] Found 7 trained models:
#    [OK] CTGAN
#    [OK] CTABGAN
#    [OK] CTABGANPLUS
#    [OK] CopulaGAN
#    [OK] TVAE
#    [OK] MEDGAN
#    [OK] PATEGAN
#
# ==================== EVALUATING CTGAN ====================
# [SEARCH] CTGAN - COMPREHENSIVE DATA QUALITY EVALUATION
# ============================================================
# [FOLDER] Output directory: results/breast-cancer-data/2026-01-22/Section-5/CTGAN
#
# [1] STATISTICAL SIMILARITY
# ------------------------------
#    [CHART] Average Statistical Similarity: 0.779
#
# [2] PCA COMPARISON ANALYSIS WITH OUTCOME COLOR-CODING
# --------------------------------------------------
#    [CHART] PCA comparison plot saved: pca_comparison_with_outcome.png
#    [CHART] PCA Overall Similarity: 0.031
#    [CHART] Explained Variance (PC1, PC2): 0.638, 0.172
#
# [3] DISTRIBUTION SIMILARITY
# ------------------------------
#    [CHART] Average Distribution Similarity: 0.809
#
# [4] CORRELATION STRUCTURE
# ------------------------------
#    [CHART] Correlation Structure Preservation: 0.848
#
# [5] MACHINE LEARNING UTILITY
# ------------------------------
#    [CHART] ML Utility (Cross-Accuracy): 0.841
#    [CHART] Real->Synth Accuracy: 0.784
#    [CHART] Synth->Real Accuracy: 0.898
#
# ============================================================
# [BEST] CTGAN OVERALL QUALITY SCORE: 0.661
# [INFO] Quality Assessment: GOOD
# ============================================================
#
# [FOLDER] Generated 5 output files:
#    - statistical_similarity.csv
#    - pca_comparison_with_outcome.png
#    - distribution_comparison.png
#    - correlation_comparison.png
#    - evaluation_summary.csv
# [OK] CTGAN evaluation completed successfully!
#
# ==================== EVALUATING CTABGAN ====================
# [SEARCH] CTABGAN - COMPREHENSIVE DATA QUALITY EVALUATION
# ============================================================
# [FOLDER] Output directory: results/breast-cancer-data/2026-01-22/Section-5/CTABGAN
#
# [1] STATISTICAL SIMILARITY
# ------------------------------
#    [CHART] Average Statistical Similarity: 0.939
#
# [2] PCA COMPARISON ANALYSIS WITH OUTCOME COLOR-CODING
# --------------------------------------------------
#    [CHART] PCA comparison plot saved: pca_comparison_with_outcome.png
#    [CHART] PCA Overall Similarity: 0.045
#    [CHART] Explained Variance (PC1, PC2): 0.638, 0.172
#
# [3] DISTRIBUTION SIMILARITY
# ------------------------------
#    [CHART] Average Distribution Similarity: 0.876
#
# [4] CORRELATION STRUCTURE
# ------------------------------
#    [CHART] Correlation Structure Preservation: 0.990
#
# [5] MACHINE LEARNING UTILITY
# ------------------------------
#    [CHART] ML Utility (Cross-Accuracy): 0.895
#    [CHART] Real->Synth Accuracy: 0.870
#    [CHART] Synth->Real Accuracy: 0.919
#
# ============================================================
# [BEST] CTABGAN OVERALL QUALITY SCORE: 0.749
# [INFO] Quality Assessment: GOOD
# ============================================================
#
# [FOLDER] Generated 5 output files:
#    - statistical_similarity.csv
#    - pca_comparison_with_outcome.png
#    - distribution_comparison.png
#    - correlation_comparison.png
#    - evaluation_summary.csv
# [OK] CTABGAN evaluation completed successfully!
#
# ==================== EVALUATING CTABGANPLUS ====================
# [SEARCH] CTABGANPLUS - COMPREHENSIVE DATA QUALITY EVALUATION
# ============================================================
# [FOLDER] Output directory: results/breast-cancer-data/2026-01-22/Section-5/CTABGANPLUS
#
# [1] STATISTICAL SIMILARITY
# ------------------------------
#    [CHART] Average Statistical Similarity: 0.908
#
# [2] PCA COMPARISON ANALYSIS WITH OUTCOME COLOR-CODING
# --------------------------------------------------
#    [CHART] PCA comparison plot saved: pca_comparison_with_outcome.png
#    [CHART] PCA Overall Similarity: 0.040
#    [CHART] Explained Variance (PC1, PC2): 0.638, 0.172
#
# [3] DISTRIBUTION SIMILARITY
# ------------------------------
#    [CHART] Average Distribution Similarity: 0.863
#
# [4] CORRELATION STRUCTURE
# ------------------------------
#    [CHART] Correlation Structure Preservation: 0.989
#
# [5] MACHINE LEARNING UTILITY
# ------------------------------
#    [CHART] ML Utility (Cross-Accuracy): 0.895
#    [CHART] Real->Synth Accuracy: 0.880
#    [CHART] Synth->Real Accuracy: 0.910
#
# ============================================================
# [BEST] CTABGANPLUS OVERALL QUALITY SCORE: 0.739
# [INFO] Quality Assessment: GOOD
# ============================================================
#
# [FOLDER] Generated 5 output files:
#    - statistical_similarity.csv
#    - pca_comparison_with_outcome.png
#    - distribution_comparison.png
#    - correlation_comparison.png
#    - evaluation_summary.csv
# [OK] CTABGANPLUS evaluation completed successfully!
#
# ==================== EVALUATING CopulaGAN ====================
# [SEARCH] COPULAGAN - COMPREHENSIVE DATA QUALITY EVALUATION
# ============================================================
# [FOLDER] Output directory: results/breast-cancer-data/2026-01-22/Section-5/COPULAGAN
#
# [1] STATISTICAL SIMILARITY
# ------------------------------
#    [CHART] Average Statistical Similarity: 0.778
#
# [2] PCA COMPARISON ANALYSIS WITH OUTCOME COLOR-CODING
# --------------------------------------------------
#    [CHART] PCA comparison plot saved: pca_comparison_with_outcome.png
#    [CHART] PCA Overall Similarity: 0.030
#    [CHART] Explained Variance (PC1, PC2): 0.638, 0.172
#
# [3] DISTRIBUTION SIMILARITY
# ------------------------------
#    [CHART] Average Distribution Similarity: 0.786
#
# [4] CORRELATION STRUCTURE
# ------------------------------
#    [CHART] Correlation Structure Preservation: 0.861
#
# [5] MACHINE LEARNING UTILITY
# ------------------------------
#    [CHART] ML Utility (Cross-Accuracy): 0.772
#    [CHART] Real->Synth Accuracy: 0.692
#    [CHART] Synth->Real Accuracy: 0.852
#
# ============================================================
# [BEST] COPULAGAN OVERALL QUALITY SCORE: 0.646
# [INFO] Quality Assessment: GOOD
# ============================================================
#
# [FOLDER] Generated 5 output files:
#    - statistical_similarity.csv
#    - pca_comparison_with_outcome.png
#    - distribution_comparison.png
#    - correlation_comparison.png
#    - evaluation_summary.csv
# [OK] CopulaGAN evaluation completed successfully!
#
# ==================== EVALUATING TVAE ====================
# [SEARCH] TVAE - COMPREHENSIVE DATA QUALITY EVALUATION
# ============================================================
# [FOLDER] Output directory: results/breast-cancer-data/2026-01-22/Section-5/TVAE
#
# [1] STATISTICAL SIMILARITY
# ------------------------------
#    [CHART] Average Statistical Similarity: 0.707
#
# [2] PCA COMPARISON ANALYSIS WITH OUTCOME COLOR-CODING
# --------------------------------------------------
#    [CHART] PCA comparison plot saved: pca_comparison_with_outcome.png
#    [CHART] PCA Overall Similarity: 0.036
#    [CHART] Explained Variance (PC1, PC2): 0.638, 0.172
#
# [3] DISTRIBUTION SIMILARITY
# ------------------------------
#    [CHART] Average Distribution Similarity: 0.815
#
# [4] CORRELATION STRUCTURE
# ------------------------------
#    [CHART] Correlation Structure Preservation: 0.952
#
# [5] MACHINE LEARNING UTILITY
# ------------------------------
#    [CHART] ML Utility (Cross-Accuracy): 0.881
#    [CHART] Real->Synth Accuracy: 0.842
#    [CHART] Synth->Real Accuracy: 0.921
#
# ============================================================
# [BEST] TVAE OVERALL QUALITY SCORE: 0.679
# [INFO] Quality Assessment: GOOD
# ============================================================
#
# [FOLDER] Generated 5 output files:
#    - statistical_similarity.csv
#    - pca_comparison_with_outcome.png
#    - distribution_comparison.png
#    - correlation_comparison.png
#    - evaluation_summary.csv
# [OK] TVAE evaluation completed successfully!
#
# ==================== EVALUATING MEDGAN ====================
# [SEARCH] MEDGAN - COMPREHENSIVE DATA QUALITY EVALUATION
# ============================================================
# [FOLDER] Output directory: results/breast-cancer-data/2026-01-22/Section-5/MEDGAN
#
# [1] STATISTICAL SIMILARITY
# ------------------------------
#    [CHART] Average Statistical Similarity: 0.025
#
# [2] PCA COMPARISON ANALYSIS WITH OUTCOME COLOR-CODING
# --------------------------------------------------
#    [CHART] PCA comparison plot saved: pca_comparison_with_outcome.png
#    [CHART] PCA Overall Similarity: 0.037
#    [CHART] Explained Variance (PC1, PC2): 0.638, 0.172
#
# [3] DISTRIBUTION SIMILARITY
# ------------------------------
#    [CHART] Average Distribution Similarity: nan
#
# [4] CORRELATION STRUCTURE
# ------------------------------
#    [CHART] Correlation Structure Preservation: 0.575
#
# [5] MACHINE LEARNING UTILITY
# ------------------------------
#    [CHART] ML Utility (Cross-Accuracy): 0.611
#    [CHART] Real->Synth Accuracy: 0.849
#    [CHART] Synth->Real Accuracy: 0.373
#
# ============================================================
# [BEST] MEDGAN OVERALL QUALITY SCORE: nan
# [INFO] Quality Assessment: POOR
# ============================================================
#
# [FOLDER] Generated 5 output files:
#    - statistical_similarity.csv
#    - pca_comparison_with_outcome.png
#    - distribution_comparison.png
#    - correlation_comparison.png
#    - evaluation_summary.csv
# [OK] MEDGAN evaluation completed successfully!
#
# ==================== EVALUATING PATEGAN ====================
# [SEARCH] PATEGAN - COMPREHENSIVE DATA QUALITY EVALUATION
# ============================================================
# [FOLDER] Output directory: results/breast-cancer-data/2026-01-22/Section-5/PATEGAN
#
# [1] STATISTICAL SIMILARITY
# ------------------------------
#    [CHART] Average Statistical Similarity: 0.039
#
# [2] PCA COMPARISON ANALYSIS WITH OUTCOME COLOR-CODING
# --------------------------------------------------
#    [CHART] PCA comparison plot saved: pca_comparison_with_outcome.png
#    [CHART] PCA Overall Similarity: 0.024
#    [CHART] Explained Variance (PC1, PC2): 0.638, 0.172
#
# [3] DISTRIBUTION SIMILARITY
# ------------------------------
#    [CHART] Average Distribution Similarity: nan
#
# [4] CORRELATION STRUCTURE
# ------------------------------
#    [CHART] Correlation Structure Preservation: 0.000
#
# [5] MACHINE LEARNING UTILITY
# ------------------------------
#    [CHART] ML Utility (Cross-Accuracy): 0.814
#    [CHART] Real->Synth Accuracy: 1.000
#    [CHART] Synth->Real Accuracy: 0.627
#
# ============================================================
# [BEST] PATEGAN OVERALL QUALITY SCORE: nan
# [INFO] Quality Assessment: POOR
# ============================================================
#
# [FOLDER] Generated 5 output files:
#    - statistical_similarity.csv
#    - pca_comparison_with_outcome.png
#    - distribution_comparison.png
#    - correlation_comparison.png
#    - evaluation_summary.csv
# [OK] PATEGAN evaluation completed successfully!
#
# ========================= EVALUATION SUMMARY =========================
# Model           Quality Score   Assessment   Files
# -----------------------------------------------------------------
# CTGAN           0.661           GOOD         5
# CTABGAN         0.749           GOOD         5
# CTABGANPLUS     0.739           GOOD         5
# CopulaGAN       0.646           GOOD         5
# TVAE            0.679           GOOD         5
# MEDGAN          nan             POOR         5
# PATEGAN         nan             POOR         5
#
# [CHART] Batch summary saved to: results/breast-cancer-data/2026-01-22/Section-5/batch_evaluation_summary.csv
#
# ========================= OPTUNA OPTIMIZATION ANALYSIS =========================
# [INFO] Found 7 Optuna studies: ['CTGAN', 'CTABGAN', 'CTABGANPLUS', 'CopulaGAN', 'TVAE', 'PATE-GAN', 'MEDGAN']
#
# [OPTUNA] Generating visualizations for CTGAN...
# [WARNING] Optimization history plot failed for CTGAN:
# Image export using the "kaleido" engine requires the Kaleido package,
# which can be installed using pip:
#
#     $ pip install --upgrade kaleido
#
# [WARNING] Parameter importance plot failed for CTGAN:
# Image export using the "kaleido" engine requires the Kaleido package,
# which can be installed using pip:
#
#     $ pip install --upgrade kaleido
#
# [WARNING] Parallel coordinate plot failed for CTGAN:
# Image export using the "kaleido" engine requires the Kaleido package,
# which can be installed using pip:
#
#     $ pip install --upgrade kaleido
#
#
# [OPTUNA] Generating visualizations for CTABGAN...
# [WARNING] Optimization history plot failed for CTABGAN:
# Image export using the "kaleido" engine requires the Kaleido package,
# which can be installed using pip:
#
#     $ pip install --upgrade kaleido
#
# [WARNING] Parameter importance plot failed for CTABGAN:
# Image export using the "kaleido" engine requires the Kaleido package,
# which can be installed using pip:
#
#     $ pip install --upgrade kaleido
#
# [WARNING] Parallel coordinate plot failed for CTABGAN:
# Image export using the "kaleido" engine requires the Kaleido package,
# which can be installed using pip:
#
#     $ pip install --upgrade kaleido
#
#
# [OPTUNA] Generating visualizations for CTABGANPLUS...
# [WARNING] Optimization history plot failed for CTABGANPLUS:
# Image export using the "kaleido" engine requires the Kaleido package,
# which can be installed using pip:
#
#     $ pip install --upgrade kaleido
#
# [WARNING] Parameter importance plot failed for CTABGANPLUS:
# Image export using the "kaleido" engine requires the Kaleido package,
# which can be installed using pip:
#
#     $ pip install --upgrade kaleido
#
# [WARNING] Parallel coordinate plot failed for CTABGANPLUS:
# Image export using the "kaleido" engine requires the Kaleido package,
# which can be installed using pip:
#
#     $ pip install --upgrade kaleido
#
#
# [OPTUNA] Generating visualizations for CopulaGAN...
# [WARNING] Optimization history plot failed for CopulaGAN:
# Image export using the "kaleido" engine requires the Kaleido package,
# which can be installed using pip:
#
#     $ pip install --upgrade kaleido
#
# [WARNING] Parameter importance plot failed for CopulaGAN:
# Image export using the "kaleido" engine requires the Kaleido package,
# which can be installed using pip:
#
#     $ pip install --upgrade kaleido
#
# [WARNING] Parallel coordinate plot failed for CopulaGAN:
# Image export using the "kaleido" engine requires the Kaleido package,
# which can be installed using pip:
#
#     $ pip install --upgrade kaleido
#
#
# [OPTUNA] Generating visualizations for TVAE...
# [WARNING] Optimization history plot failed for TVAE:
# Image export using the "kaleido" engine requires the Kaleido package,
# which can be installed using pip:
#
#     $ pip install --upgrade kaleido
#
# [WARNING] Parameter importance plot failed for TVAE:
# Image export using the "kaleido" engine requires the Kaleido package,
# which can be installed using pip:
#
#     $ pip install --upgrade kaleido
#
# [WARNING] Parallel coordinate plot failed for TVAE:
# Image export using the "kaleido" engine requires the Kaleido package,
# which can be installed using pip:
#
#     $ pip install --upgrade kaleido
#
#
# [OPTUNA] Generating visualizations for PATE-GAN...
# [WARNING] Optimization history plot failed for PATE-GAN:
# Image export using the "kaleido" engine requires the Kaleido package,
# which can be installed using pip:
#
#     $ pip install --upgrade kaleido
#
# [WARNING] Parameter importance plot failed for PATE-GAN:
# Image export using the "kaleido" engine requires the Kaleido package,
# which can be installed using pip:
#
#     $ pip install --upgrade kaleido
#
# [WARNING] Parallel coordinate plot failed for PATE-GAN:
# Image export using the "kaleido" engine requires the Kaleido package,
# which can be installed using pip:
#
#     $ pip install --upgrade kaleido
#
#
# [OPTUNA] Generating visualizations for MEDGAN...
# [WARNING] Optimization history plot failed for MEDGAN:
# Image export using the "kaleido" engine requires the Kaleido package,
# which can be installed using pip:
#
#     $ pip install --upgrade kaleido
#
# [WARNING] Parameter importance plot failed for MEDGAN:
# Image export using the "kaleido" engine requires the Kaleido package,
# which can be installed using pip:
#
#     $ pip install --upgrade kaleido
#
# [WARNING] Parallel coordinate plot failed for MEDGAN:
# Image export using the "kaleido" engine requires the Kaleido package,
# which can be installed using pip:
#
#     $ pip install --upgrade kaleido
#
#
# [OPTUNA] Generating summary comparison across all models...
# [VIZ] Saved: optuna_summary_all_models.png
# [OK] Optuna summary saved to Section 4: results/breast-cancer-data/2026-01-22/Section-4/optuna_summary_all_models.png
#
# [OK] Optuna visualizations saved to: results/breast-cancer-data/2026-01-22/Section-4
#
# ========================= COMPREHENSIVE TRTS ANALYSIS =========================
#
# [ANALYSIS] Running TRTS analysis for CTGAN...
# [ANALYSIS] COMPREHENSIVE TRTS FRAMEWORK ANALYSIS (15+ Metrics)
# ============================================================
# [CHART] Data shapes:
#    - Real: (569, 5), Target unique values: 2
#    - Synthetic: (569, 5), Target unique values: 2
#    - Using 5 common features
#
# [PROCESS] 1. TRTR - Train Real, Test Real (Baseline)
#    [OK] TRTR Accuracy: 0.9211 | Balanced Acc: 0.9226 | MCC: 0.8341 (Time: 0.186s)
# [PROCESS] 2. TRTS - Train Real, Test Synthetic
#    [OK] TRTS Accuracy: 0.7544 | Balanced Acc: 0.7559 | MCC: 0.5128 (Time: 0.184s)
# [PROCESS] 3. TSTR - Train Synthetic, Test Real
#    [OK] TSTR Accuracy: 0.8596 | Balanced Acc: 0.8740 | MCC: 0.7244 (Time: 0.203s)
# [PROCESS] 4. TSTS - Train Synthetic, Test Synthetic
#    [OK] TSTS Accuracy: 0.7544 | Balanced Acc: 0.7529 | MCC: 0.5082 (Time: 0.199s)
#
# [CHART] Summary Statistics:
#    - Successful scenarios: 4/4
#    - Average accuracy: 0.8224 (+/-0.0714)
#    - Total training time: 0.773s
#
# [PRIVACY] Calculating privacy risk metrics...
#    [PRIVACY] Using 5 numeric features
#    [PRIVACY] Real: 569 records, Synthetic: 569 records
#    [METRIC] DCR Mean: 1.5716 (min: 0.2298, max: 5.0124)
#    [METRIC] Memorization: 0.00% (0/569 records)
#    [METRIC] NNDR: 1.2086 (+/- 0.4473)
#    [METRIC] Re-identification Risk: 0.00%
#    [METRIC] Overall Privacy Score: 0.868
#
# [ANALYSIS] Running TRTS analysis for CTABGAN...
# [ANALYSIS] COMPREHENSIVE TRTS FRAMEWORK ANALYSIS (15+ Metrics)
# ============================================================
# [CHART] Data shapes:
#    - Real: (569, 5), Target unique values: 2
#    - Synthetic: (569, 5), Target unique values: 2
#    - Using 5 common features
#
# [PROCESS] 1. TRTR - Train Real, Test Real (Baseline)
#    [OK] TRTR Accuracy: 0.9211 | Balanced Acc: 0.9226 | MCC: 0.8341 (Time: 0.184s)
# [PROCESS] 2. TRTS - Train Real, Test Synthetic
#    [OK] TRTS Accuracy: 0.8509 | Balanced Acc: 0.8304 | MCC: 0.6852 (Time: 0.185s)
# [PROCESS] 3. TSTR - Train Synthetic, Test Real
#    [OK] TSTR Accuracy: 0.8684 | Balanced Acc: 0.8859 | MCC: 0.7465 (Time: 0.198s)
# [PROCESS] 4. TSTS - Train Synthetic, Test Synthetic
#    [OK] TSTS Accuracy: 0.9123 | Balanced Acc: 0.9043 | MCC: 0.8156 (Time: 0.194s)
#
# [CHART] Summary Statistics:
#    - Successful scenarios: 4/4
#    - Average accuracy: 0.8882 (+/-0.0293)
#    - Total training time: 0.761s
#
# [PRIVACY] Calculating privacy risk metrics...
#    [PRIVACY] Using 5 numeric features
#    [PRIVACY] Real: 569 records, Synthetic: 569 records
#    [METRIC] DCR Mean: 0.6743 (min: 0.0884, max: 3.5168)
#    [METRIC] Memorization: 0.00% (0/569 records)
#    [METRIC] NNDR: 0.8633 (+/- 0.2921)
#    [METRIC] Re-identification Risk: 0.00%
#    [METRIC] Overall Privacy Score: 0.729
#
# [ANALYSIS] Running TRTS analysis for CTABGANPLUS...
# [ANALYSIS] COMPREHENSIVE TRTS FRAMEWORK ANALYSIS (15+ Metrics)
# ============================================================
# [CHART] Data shapes:
#    - Real: (569, 5), Target unique values: 2
#    - Synthetic: (569, 5), Target unique values: 2
#    - Using 5 common features
#
# [PROCESS] 1. TRTR - Train Real, Test Real (Baseline)
#    [OK] TRTR Accuracy: 0.9211 | Balanced Acc: 0.9226 | MCC: 0.8341 (Time: 0.187s)
# [PROCESS] 2. TRTS - Train Real, Test Synthetic
#    [OK] TRTS Accuracy: 0.8947 | Balanced Acc: 0.8911 | MCC: 0.7744 (Time: 0.184s)
# [PROCESS] 3. TSTR - Train Synthetic, Test Real
#    [OK] TSTR Accuracy: 0.8860 | Balanced Acc: 0.8700 | MCC: 0.7525 (Time: 0.194s)
# [PROCESS] 4. TSTS - Train Synthetic, Test Synthetic
#    [OK] TSTS Accuracy: 0.8684 | Balanced Acc: 0.8438 | MCC: 0.7099 (Time: 0.193s)
#
# [CHART] Summary Statistics:
#    - Successful scenarios: 4/4
#    - Average accuracy: 0.8925 (+/-0.0190)
#    - Total training time: 0.759s
#
# [PRIVACY] Calculating privacy risk metrics...
#    [PRIVACY] Using 5 numeric features
#    [PRIVACY] Real: 569 records, Synthetic: 569 records
#    [METRIC] DCR Mean: 0.8105 (min: 0.0888, max: 3.1287)
#    [METRIC] Memorization: 0.00% (0/569 records)
#    [METRIC] NNDR: 0.9221 (+/- 0.3463)
#    [METRIC] Re-identification Risk: 0.00%
#    [METRIC] Overall Privacy Score: 0.773
#
# [ANALYSIS] Running TRTS analysis for CopulaGAN...
# [ANALYSIS] COMPREHENSIVE TRTS FRAMEWORK ANALYSIS (15+ Metrics)
# ============================================================
# [CHART] Data shapes:
#    - Real: (569, 5), Target unique values: 2
#    - Synthetic: (569, 5), Target unique values: 2
#    - Using 5 common features
#
# [PROCESS] 1. TRTR - Train Real, Test Real (Baseline)
#    [OK] TRTR Accuracy: 0.9211 | Balanced Acc: 0.9226 | MCC: 0.8341 (Time: 0.188s)
# [PROCESS] 2. TRTS - Train Real, Test Synthetic
#    [OK] TRTS Accuracy: 0.7281 | Balanced Acc: 0.7268 | MCC: 0.4551 (Time: 0.183s)
# [PROCESS] 3. TSTR - Train Synthetic, Test Real
#    [OK] TSTR Accuracy: 0.8509 | Balanced Acc: 0.8224 | MCC: 0.6744 (Time: 0.197s)
# [PROCESS] 4. TSTS - Train Synthetic, Test Synthetic
#    [OK] TSTS Accuracy: 0.8158 | Balanced Acc: 0.8140 | MCC: 0.6324 (Time: 0.197s)
#
# [CHART] Summary Statistics:
#    - Successful scenarios: 4/4
#    - Average accuracy: 0.8289 (+/-0.0695)
#    - Total training time: 0.765s
#
# [PRIVACY] Calculating privacy risk metrics...
#    [PRIVACY] Using 5 numeric features
#    [PRIVACY] Real: 569 records, Synthetic: 569 records
#    [METRIC] DCR Mean: 1.4018 (min: 0.1492, max: 3.4471)
#    [METRIC] Memorization: 0.00% (0/569 records)
#    [METRIC] NNDR: 1.2677 (+/- 0.5556)
#    [METRIC] Re-identification Risk: 0.00%
#    [METRIC] Overall Privacy Score: 0.878
#
# [ANALYSIS] Running TRTS analysis for TVAE...
# [ANALYSIS] COMPREHENSIVE TRTS FRAMEWORK ANALYSIS (15+ Metrics)
# ============================================================
# [CHART] Data shapes:
#    - Real: (569, 5), Target unique values: 2
#    - Synthetic: (569, 5), Target unique values: 2
#    - Using 5 common features
#
# [PROCESS] 1. TRTR - Train Real, Test Real (Baseline)
#    [OK] TRTR Accuracy: 0.9211 | Balanced Acc: 0.9226 | MCC: 0.8341 (Time: 0.184s)
# [PROCESS] 2. TRTS - Train Real, Test Synthetic
#    [OK] TRTS Accuracy: 0.7895 | Balanced Acc: 0.7351 | MCC: 0.4793 (Time: 0.184s)
# [PROCESS] 3. TSTR - Train Synthetic, Test Real
#    [OK] TSTR Accuracy: 0.8947 | Balanced Acc: 0.9067 | MCC: 0.7908 (Time: 0.197s)
# [PROCESS] 4. TSTS - Train Synthetic, Test Synthetic
#    [OK] TSTS Accuracy: 0.8421 | Balanced Acc: 0.7991 | MCC: 0.6097 (Time: 0.195s)
#
# [CHART] Summary Statistics:
#    - Successful scenarios: 4/4
#    - Average accuracy: 0.8618 (+/-0.0505)
#    - Total training time: 0.761s
#
# [PRIVACY] Calculating privacy risk metrics...
#    [PRIVACY] Using 5 numeric features
#    [PRIVACY] Real: 569 records, Synthetic: 569 records
#    [METRIC] DCR Mean: 0.6332 (min: 0.1221, max: 2.4441)
#    [METRIC] Memorization: 0.00% (0/569 records)
#    [METRIC] NNDR: 1.0635 (+/- 0.3947)
#    [METRIC] Re-identification Risk: 0.00%
#    [METRIC] Overall Privacy Score: 0.752
#
# [ANALYSIS] Running TRTS analysis for MEDGAN...
# [ANALYSIS] COMPREHENSIVE TRTS FRAMEWORK ANALYSIS (15+ Metrics)
# ============================================================
# [CHART] Data shapes:
#    - Real: (569, 5), Target unique values: 2
#    - Synthetic: (569, 5), Target unique values: 2
#    - Using 5 common features
#
# [PROCESS] 1. TRTR - Train Real, Test Real (Baseline)
#    [OK] TRTR Accuracy: 0.9211 | Balanced Acc: 0.9226 | MCC: 0.8341 (Time: 0.184s)
# [PROCESS] 2. TRTS - Train Real, Test Synthetic
#    [OK] TRTS Accuracy: 0.8509 | Balanced Acc: 0.5000 | MCC: 0.0000 (Time: 0.186s)
# [PROCESS] 3. TSTR - Train Synthetic, Test Real
#    [OK] TSTR Accuracy: 0.3684 | Balanced Acc: 0.5000 | MCC: 0.0000 (Time: 0.149s)
# [PROCESS] 4. TSTS - Train Synthetic, Test Synthetic
#    [OK] TSTS Accuracy: 0.9912 | Balanced Acc: 0.9948 | MCC: 0.9668 (Time: 0.147s)
#
# [CHART] Summary Statistics:
#    - Successful scenarios: 4/4
#    - Average accuracy: 0.7829 (+/-0.2444)
#    - Total training time: 0.666s
#
# [PRIVACY] Calculating privacy risk metrics...
#    [PRIVACY] Using 5 numeric features
#    [PRIVACY] Real: 569 records, Synthetic: 569 records
#    [METRIC] DCR Mean: 13.9902 (min: 3.9939, max: 26.9511)
#    [METRIC] Memorization: 0.00% (0/569 records)
#    [METRIC] NNDR: 168.7701 (+/- 254.3828)
#    [METRIC] Re-identification Risk: 0.00%
#    [METRIC] Overall Privacy Score: 1.000
#
# [ANALYSIS] Running TRTS analysis for PATEGAN...
# [ANALYSIS] COMPREHENSIVE TRTS FRAMEWORK ANALYSIS (15+ Metrics)
# ============================================================
# [CHART] Data shapes:
#    - Real: (569, 5), Target unique values: 2
#    - Synthetic: (569, 5), Target unique values: 1
#    - Using 5 common features
#
# [PROCESS] 1. TRTR - Train Real, Test Real (Baseline)
#    [OK] TRTR Accuracy: 0.9211 | Balanced Acc: 0.9226 | MCC: 0.8341 (Time: 0.186s)
# [PROCESS] 2. TRTS - Train Real, Test Synthetic
#    [WARNING] Could not calculate AUROC/AUPRC/Brier: y should be a 1d array, got an array of shape (114, 2) instead.
#    [OK] TRTS Accuracy: 1.0000 | Balanced Acc: 1.0000 | MCC: 0.0000 (Time: 0.184s)
# [PROCESS] 3. TSTR - Train Synthetic, Test Real
#    [WARNING] Could not calculate AUROC/AUPRC/Brier: index 1 is out of bounds for axis 1 with size 1
#    [OK] TSTR Accuracy: 0.6316 | Balanced Acc: 0.5000 | MCC: 0.0000 (Time: 0.139s)
# [PROCESS] 4. TSTS - Train Synthetic, Test Synthetic
#    [OK] TSTS Accuracy: 1.0000 | Balanced Acc: 1.0000 | MCC: 0.0000 (Time: 0.137s)
#
# [CHART] Summary Statistics:
#    - Successful scenarios: 4/4
#    - Average accuracy: 0.8882 (+/-0.1516)
#    - Total training time: 0.646s
#
# [PRIVACY] Calculating privacy risk metrics...
#    [PRIVACY] Using 5 numeric features
#    [PRIVACY] Real: 569 records, Synthetic: 569 records
#    [METRIC] DCR Mean: 70.0998 (min: 54.7392, max: 74.5165)
#    [METRIC] Memorization: 0.00% (0/569 records)
#    [METRIC] NNDR: 2442.1985 (+/- 1257.2291)
#    [METRIC] Re-identification Risk: 0.00%
#    [METRIC] Overall Privacy Score: 1.000
#
# [CHART] Creating TRTS visualizations...
# [VIZ] Saved: trts_comprehensive_analysis.png
# [VIZ] Generated 3 TRTS files
# [OK] TRTS visualization files generated:
#    [FOLDER] trts_comprehensive_analysis.png
#    [FOLDER] trts_summary_metrics.csv
#    [FOLDER] trts_detailed_results.csv
#
# [STATS] TRTS Analysis Summary:
#    - Models analyzed: 7
#    - Average combined score: 0.8521
#    - Best performing model: CTABGANPLUS
#    - Total scenarios tested: 28
# [VIZ] Saved: privacy_dashboard.png
# [VIZ] Saved: privacy_summary.csv
#
# ======================================================================
# GENERATING ROC CURVES
# ======================================================================
# [SUCCESS] ROC curves saved: results/breast-cancer-data/2026-01-22/Section-5/trts_roc_curves.png
#
# ======================================================================
# GENERATING PRECISION-RECALL CURVES
# ======================================================================
# [SUCCESS] PR curves saved: results/breast-cancer-data/2026-01-22/Section-5/trts_pr_curves.png
#
# ======================================================================
# GENERATING CALIBRATION CURVES
# ======================================================================
# [SUCCESS] Calibration curves saved: results/breast-cancer-data/2026-01-22/Section-5/trts_calibration_curves.png
#
# ================================================================================
# SECTION 5.2 OPTIMIZED MODELS BATCH EVALUATION COMPLETED!
# ================================================================================
# Section 5.2 batch evaluation failed: 'models_processed'
# Traceback (most recent call last):
#   File "/tmp/ipykernel_2977/222118672.py", line 21, in <module>
#     print(f"Models processed: {section5_batch_results['models_processed']}")
# KeyError: 'models_processed'

# %% [markdown]
# ### 5.3 Final Summary

# %%
# Code Chunk ID: CHUNK_5_3_SUMMARY
# ============================================================================
# SECTION 5.3 - FINAL SUMMARY
# ============================================================================

print("=" * 80)
print("SYNTHETIC DATA GENERATION - FINAL SUMMARY")
print("=" * 80)
print(f"\nDataset: {DATASET_IDENTIFIER}")
print(f"Session: {SESSION_TIMESTAMP}")
print(f"\nResults directories:")
print(f"  Section 2 (EDA): {get_results_path(DATASET_IDENTIFIER, 2)}")
print(f"  Section 3 (Demo): {get_results_path(DATASET_IDENTIFIER, 3)}")
print(f"  Section 4 (HPO): {get_results_path(DATASET_IDENTIFIER, 4)}")
print(f"  Section 5 (Final): {get_results_path(DATASET_IDENTIFIER, 5)}")

# Show final model performance
if 'section5_results' in dir() and section5_results:
    print(f"\nFinal Model Performance (with optimized parameters):")
    print("-" * 60)
    
    scores = []
    for model_name, result in section5_results.items():
        if result['status'] == 'success':
            score = result.get('objective_score', 0)
            time_taken = result.get('training_time', 0)
            scores.append((model_name, score, time_taken))
    
    # Sort by score descending
    scores.sort(key=lambda x: x[1], reverse=True)
    
    for i, (model, score, time_taken) in enumerate(scores, 1):
        print(f"  {i}. {model.upper()}: score={score:.4f}, time={time_taken:.1f}s")
    
    if scores:
        best_model = scores[0][0]
        print(f"\nBest performing model: {best_model.upper()}")
        print(f"Best synthetic data variable: synthetic_{best_model}_final")

print("\n" + "=" * 80)
print("NOTEBOOK COMPLETE")
print("=" * 80)
# Out:
# ================================================================================
# SYNTHETIC DATA GENERATION - FINAL SUMMARY
# ================================================================================
#
# Dataset: breast-cancer-data
# Session: 2026-01-22
#
# Results directories:
#   Section 2 (EDA): results/breast-cancer-data/2026-01-22/Section-2
#   Section 3 (Demo): results/breast-cancer-data/2026-01-22/Section-3
#   Section 4 (HPO): results/breast-cancer-data/2026-01-22/Section-4
#   Section 5 (Final): results/breast-cancer-data/2026-01-22/Section-5
#
# Final Model Performance (with optimized parameters):
# ------------------------------------------------------------
#   1. CTABGAN: score=0.7179, time=21.6s
#   2. CTABGANPLUS: score=0.7001, time=18.1s
#   3. TVAE: score=0.6256, time=6.3s
#   4. CTGAN: score=0.5976, time=14.1s
#   5. COPULAGAN: score=0.5804, time=17.5s
#   6. MEDGAN: score=0.3161, time=6.9s
#   7. PATEGAN: score=0.3146, time=2.3s
#
# Best performing model: CTABGAN
# Best synthetic data variable: synthetic_ctabgan_final
#
# ================================================================================
# NOTEBOOK COMPLETE
# ================================================================================
