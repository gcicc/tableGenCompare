# %% [markdown]
# # Clinical Synthetic Data Generation Framework
#
# This notebook explores the performance of the following Synthetic Table Generation Methods
#
# - **CTGAN** (Conditional Tabular GAN)
# - **CTAB-GAN** (Conditional Tabular GAN with advanced preprocessing)
# - **CTAB-GAN+** (Enhanced version with WGAN-GP losses, general transforms, and improved stability)
# - **GANerAid** (Custom implementation)
# - **CopulaGAN** (Copula-based GAN)
# - **TVAE** (Variational Autoencoder)

# %% [markdown]
# - Section 1 prepares the environment and sources setup.py.
# - Section 2 reads in the dataset and produces an initial suite of EDA.
#   - 2.1.1 - user needs to adapt for incoming dataset
#   - 2.1.2 - user should review to ensure target colummns and categorical columns are properly identified
#   - 2.1.3 - user should confirm that data has loaded properly
#   - 2.1.4 - if your data has missing values, MICE is employed; user should review
#   - CHUNK_2_1_4_C: This code samples 500 rows to be used in rest of notebook for purposes of testing; comment out this code for production.
#   - 2.1.5 - Exploratory data analysis
# - Section 3 demonstrates the performance of each metholodogy with some default hyperparameters.
#    - 3.1.1-3.1.6 Subsections for each method
#    - 3.2 batch processing of figures/tables from section 3
# - Section 4 runs hyperparameter optimization.
#    - 4.1.1-4.1.6 Subsections for each method
#    - 4.2 batch processing of figures/tables from section 4 describing the optimization process
# - Section 5 re-runs each model with their respective best hyperparameters.
#    - 5.1.1-5.1.6 re-run each model using the best hyperparameters identified in Section 4.1.1-4.1.6, resp.
#    - 5.2 batch processing of figures/tables from Section 5.
#
#
# Refer to readme.md, doc\Model-descriptions.md, doc\Objective-function.md.

# %% [markdown]
# ## 1 Setup and Configuration

# %%
# !pip install -r requirements.txt
# !pip install sdv
# !pip install ctgan
# !pip install numpy==1.26.4
# !pip install GANerAid

# %%
# Code Chunk ID: CHUNK_1_0_0_A - Import Setup Module
# Import all functionality from setup.py
from setup import *

print("🎯 SETUP MODULE IMPORTED SUCCESSFULLY!")
print("="*60)
# Out:
# Session timestamp captured: 2025-11-05
# [OK] Essential data science libraries imported successfully!
# Detected sklearn 1.7.2 - applying compatibility patch...
# INFO: Applying sklearn compatibility patches for version 1.7.2
# Global sklearn compatibility patch applied successfully
# GANerAid not available. Install with: pip install GANerAid
# CTAB-GAN imported successfully from ./CTAB-GAN
# [OK] CTAB-GAN+ detected and available
# Session timestamp captured: 2025-11-05
# [OK] Essential data science libraries imported successfully!
# Detected sklearn 1.7.2 - applying compatibility patch...
# INFO: Applying sklearn compatibility patches for version 1.7.2
# Global sklearn compatibility patch applied successfully
# CTAB-GAN imported successfully
# [OK] CTAB-GAN+ detected and available
# [OK] GANerAidModel imported successfully from src.models.implementations
# [OK] All required libraries imported successfully
# [OK] Comprehensive data quality evaluation function loaded!
# [OK] Batch evaluation system loaded!
# [OK] Enhanced objective function v2 with DYNAMIC TARGET COLUMN support defined!
# [OK] Enhanced hyperparameter optimization analysis function loaded!
# [TARGET] SETUP MODULE LOADED SUCCESSFULLY!
# ============================================================
# [OK] Enhanced objective function dependencies imported
# [PACKAGE] Basic libraries imported successfully
# [OK] Optuna imported successfully
# [OK] CTGAN imported successfully
# [CONFIG] Setup imports cell restored from main branch - wasserstein_distance now available globally
# [OK] Parameter management functions added to setup.py!
# [OK] Comprehensive TRTS framework functions added to setup.py!
# [OK] Unified evaluation function added to setup.py!
# [OK] Hyperparameter optimization data preprocessing function added to setup.py!
# [OK] Notebook compatibility functions added to setup.py!
# [OK] TRTSEvaluator backward compatibility patch applied successfully!
# [OK] Emergency backward compatibility patches applied!
# [OK] Immediate fix function available: call fix_trts_evaluator_now() in notebooks!
# [OK] Nuclear reload function available: call reload_trts_evaluator() in notebooks!
# [OK] GANerAidModel imported successfully from src.models.implementations
# [OK] All required libraries imported successfully
# [OK] Comprehensive data quality evaluation function loaded!
# [OK] Batch evaluation system loaded!
# [OK] Enhanced objective function v2 with DYNAMIC TARGET COLUMN support defined!
# [OK] Enhanced hyperparameter optimization analysis function loaded!
# [TARGET] SETUP MODULE LOADED SUCCESSFULLY!
# ============================================================
# [OK] Enhanced objective function dependencies imported
# [PACKAGE] Basic libraries imported successfully
# [OK] Optuna imported successfully
# [OK] CTGAN imported successfully
# [CONFIG] Setup imports cell restored from main branch - wasserstein_distance now available globally
# [OK] Parameter management functions added to setup.py!
# [OK] Comprehensive TRTS framework functions added to setup.py!
# [OK] Unified evaluation function added to setup.py!
# [OK] Hyperparameter optimization data preprocessing function added to setup.py!
# [OK] Notebook compatibility functions added to setup.py!
# [OK] TRTSEvaluator backward compatibility patch applied successfully!
# [OK] Emergency backward compatibility patches applied!
# [OK] Immediate fix function available: call fix_trts_evaluator_now() in notebooks!
# [OK] Nuclear reload function available: call reload_trts_evaluator() in notebooks!
# 🎯 SETUP MODULE IMPORTED SUCCESSFULLY!
# ============================================================

# %% [markdown]
# ## 2 Data Loading and Pre-processing

# %% [markdown]
# #### 2.1.1 USER ATTENTION NEEDED

# %% [markdown]
# Adapt this for your incoming dataset.

# %%
# Code Chunk ID: CHUNK_2_1_1_A
# =================== USER CONFIGURATION ===================
# 📝 CONFIGURE YOUR DATASET: Update these settings for your data
DATA_FILE = 'data/Pakistani_Diabetes_Dataset.csv'  # Path to your CSV file
TARGET_COLUMN = 'Outcome'                          # Name of your target/outcome column

# 🔧 DATASET IDENTIFIER (for results folder naming)
# Option 1: Manual override (recommended for consistent naming)
DATASET_IDENTIFIER_OVERRIDE = 'pakistani-diabetes-dataset'  # Set to None for auto-detection

# 🔧 OPTIONAL ADVANCED SETTINGS (Auto-detected if left empty)
CATEGORICAL_COLUMNS = ['Gender', 'Rgn']            # List categorical columns or leave empty for auto-detection
MISSING_STRATEGY = 'median'                        # Options: 'mice', 'drop', 'median', 'mode'
DATASET_NAME = 'Pakistani Diabetes Dataset'       # Descriptive name for your dataset

# 🚨 IMPORTANT: Verify these settings match your dataset before running!
print(f"📊 Configuration Summary:")
print(f"   Dataset: {DATASET_NAME}")
print(f"   File: {DATA_FILE}")
print(f"   Target: {TARGET_COLUMN}")
print(f"   Manual ID Override: {DATASET_IDENTIFIER_OVERRIDE}")
print(f"   Categorical: {CATEGORICAL_COLUMNS}")
print(f"   Missing Data Strategy: {MISSING_STRATEGY}")

# Load and prepare the dataset
data_file = DATA_FILE
target_column = TARGET_COLUMN

print(f"\n🔍 Loading dataset from: {data_file}")

try:
    data = pd.read_csv(data_file)
    print(f"✅ Dataset loaded successfully!")
    print(f"📊 Original shape: {data.shape}")
    
    # Set up dataset identifier with manual override option
    import setup
    
    # Use manual override if provided, otherwise auto-extract from filename
    if DATASET_IDENTIFIER_OVERRIDE:
        dataset_identifier = DATASET_IDENTIFIER_OVERRIDE
        print(f"📁 Using manual dataset identifier: {dataset_identifier}")
    else:
        dataset_identifier = setup.extract_dataset_identifier(data_file)
        print(f"📁 Auto-extracted dataset identifier: {dataset_identifier}")
    
    # Set global variables for setup module
    setup.DATASET_IDENTIFIER = dataset_identifier
    setup.CURRENT_DATA_FILE = data_file
    
    # Also set notebook global for consistency
    DATASET_IDENTIFIER = dataset_identifier
    
    print(f"✅ Dataset identifier set: {DATASET_IDENTIFIER}")
    print(f"📅 Session timestamp: {setup.SESSION_TIMESTAMP}")
    print(f"🗂️  Results will be saved to: results/{DATASET_IDENTIFIER}/")
    
except FileNotFoundError:
    print(f"❌ Error: File not found at {data_file}")
    print("   Please check the DATA_FILE path in your configuration above")
    print("   Current working directory:", os.getcwd())
    data = None

except Exception as e:
    print(f"❌ Error loading dataset: {e}")
    data = None

if data is not None:
    print(f"\n📋 Dataset Info:")
    print(f"   • Shape: {data.shape}")
    print(f"   • Columns: {list(data.columns)}")
    
    # Validate target column exists
    if target_column not in data.columns:
        print(f"\n❌ WARNING: Target column '{target_column}' not found!")
        print(f"   Available columns: {list(data.columns)}")
        print("   Please update TARGET_COLUMN in the configuration above")
    else:
        print(f"   • Target column '{target_column}' found ✅")
        print(f"   • Target distribution: {data[target_column].value_counts().to_dict()}")
    
    # Check for missing values
    missing_counts = data.isnull().sum()
    if missing_counts.sum() > 0:
        print(f"\n⚠️  Missing values detected:")
        for col, count in missing_counts[missing_counts > 0].items():
            print(f"   • {col}: {count} missing ({count/len(data)*100:.1f}%)")
    else:
        print(f"\n✅ No missing values detected")
else:
    print("\n❌ Dataset loading failed - please fix the configuration and try again")
# Out:
# 📊 Configuration Summary:
#    Dataset: Pakistani Diabetes Dataset
#    File: data/Pakistani_Diabetes_Dataset.csv
#    Target: Outcome
#    Manual ID Override: pakistani-diabetes-dataset
#    Categorical: ['Gender', 'Rgn']
#    Missing Data Strategy: median
#
# 🔍 Loading dataset from: data/Pakistani_Diabetes_Dataset.csv
# ✅ Dataset loaded successfully!
# 📊 Original shape: (912, 19)
# 📁 Using manual dataset identifier: pakistani-diabetes-dataset
# ✅ Dataset identifier set: pakistani-diabetes-dataset
# 📅 Session timestamp: 2025-11-05
# 🗂️  Results will be saved to: results/pakistani-diabetes-dataset/
#
# 📋 Dataset Info:
#    • Shape: (912, 19)
#    • Columns: ['Age', 'Gender', 'Rgn ', 'wt', 'BMI', 'wst', 'sys', 'dia', 'his', 'A1c', 'B.S.R', 'vision', 'Exr', 'dipsia', 'uria', 'Dur', 'neph', 'HDL', 'Outcome']
#    • Target column 'Outcome' found ✅
#    • Target distribution: {1: 486, 0: 426}
#
# ✅ No missing values detected

# %% [markdown]
# The code defines utilities for column name standardization and dataset analysis using the pandas library in Python. It includes functions to clean and normalize column names, identify the target variable, categorize column types, and validate dataset configurations. These functions enhance data preprocessing by ensuring consistency and integrity, making it easier to manage various data types and handle potential issues like missing values. Overall, they provide a structured approach for effective dataset analysis.

# %% [markdown]
# #### 2.1.2 Column Name Standardization and Dataset Analysis Utilities

# %%
# Code Chunk ID: CHUNK_2_1_2_A
# Column Name Standardization and Dataset Analysis Utilities
import re
import pandas as pd
import numpy as np
from typing import Dict, List, Tuple, Any

def standardize_column_names(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    
    # Create mapping of old to new column names
    name_mapping = {}
    
    for col in df.columns:
        # Remove special characters and normalize
        new_name = re.sub(r'[^\w\s]', '', str(col))  # Remove special chars
        new_name = re.sub(r'\s+', '_', new_name.strip())  # Replace spaces with underscores
        new_name = new_name.lower()  # Convert to lowercase
        
        # Handle duplicate names
        if new_name in name_mapping.values():
            counter = 1
            while f"{new_name}_{counter}" in name_mapping.values():
                counter += 1
            new_name = f"{new_name}_{counter}"
            
        name_mapping[col] = new_name
    
    # Rename columns
    df = df.rename(columns=name_mapping)
    
    print(f"🔄 Column Name Standardization:")
    for old, new in name_mapping.items():
        if old != new:
            print(f"   '{old}' → '{new}'")
    
    return df, name_mapping

def detect_target_column(df: pd.DataFrame, target_hint: str = None) -> str:
    """
    Detect the target column in the dataset.
    
    Args:
        df: Input dataframe
        target_hint: User-provided hint for target column name
        
    Returns:
        Name of the detected target column
    """
    # Common target column patterns
    target_patterns = [
        'target', 'label', 'class', 'outcome', 'result', 'diagnosis', 
        'response', 'y', 'dependent', 'output', 'prediction'
    ]
    
    # If user provided hint, try to find it first
    if target_hint:
        # Try exact match (case insensitive)
        for col in df.columns:
            if col.lower() == target_hint.lower():
                print(f"✅ Target column found: '{col}' (user specified)")
                return col
        
        # Try partial match
        for col in df.columns:
            if target_hint.lower() in col.lower():
                print(f"✅ Target column found: '{col}' (partial match to '{target_hint}')")
                return col
    
    # Auto-detect based on patterns
    for pattern in target_patterns:
        for col in df.columns:
            if pattern in col.lower():
                print(f"✅ Target column auto-detected: '{col}' (pattern: '{pattern}')")
                return col
    
    # If no pattern match, check for binary columns (likely targets)
    binary_cols = []
    for col in df.columns:
        unique_vals = df[col].dropna().nunique()
        if unique_vals == 2:
            binary_cols.append(col)
    
    if binary_cols:
        target_col = binary_cols[0]  # Take first binary column
        print(f"✅ Target column inferred: '{target_col}' (binary column)")
        return target_col
    
    # Last resort: use last column
    target_col = df.columns[-1]
    print(f"⚠️ Target column defaulted to: '{target_col}' (last column)")
    return target_col

def analyze_column_types(df: pd.DataFrame, categorical_hint: List[str] = None) -> Dict[str, str]:
    """
    Analyze and categorize column types.
    
    Args:
        df: Input dataframe
        categorical_hint: User-provided list of categorical columns
        
    Returns:
        Dictionary mapping column names to types ('categorical', 'continuous', 'binary')
    """
    column_types = {}
    
    for col in df.columns:
        # Skip if user explicitly specified as categorical
        if categorical_hint and col in categorical_hint:
            column_types[col] = 'categorical'
            continue
            
        # Analyze column characteristics
        non_null_data = df[col].dropna()
        unique_count = non_null_data.nunique()
        total_count = len(non_null_data)
        
        # Determine type based on data characteristics
        if unique_count == 2:
            column_types[col] = 'binary'
        elif df[col].dtype == 'object' or unique_count < 10:
            column_types[col] = 'categorical'
        elif df[col].dtype in ['int64', 'float64'] and unique_count > 10:
            column_types[col] = 'continuous'
        else:
            # Default based on uniqueness ratio
            uniqueness_ratio = unique_count / total_count
            if uniqueness_ratio < 0.1:
                column_types[col] = 'categorical'
            else:
                column_types[col] = 'continuous'
    
    return column_types

def validate_dataset_config(df: pd.DataFrame, target_col: str, config: Dict[str, Any]) -> bool:
    """
    Validate dataset configuration and provide warnings.
    
    Args:
        df: Input dataframe
        target_col: Target column name
        config: Configuration dictionary
        
    Returns:
        True if validation passes, False otherwise
    """
    print(f"\n🔍 Dataset Validation:")
    
    valid = True
    
    # Check if target column exists
    if target_col not in df.columns:
        print(f"❌ Target column '{target_col}' not found in dataset!")
        print(f"   Available columns: {list(df.columns)}")
        valid = False
    else:
        print(f"✅ Target column '{target_col}' found")
    
    # Check dataset size
    if len(df) < 100:
        print(f"⚠️ Small dataset: {len(df)} rows (recommend >1000 for synthetic data)")
    else:
        print(f"✅ Dataset size: {len(df)} rows")
    
    # Check for missing data
    missing_pct = (df.isnull().sum().sum() / (len(df) * len(df.columns))) * 100
    if missing_pct > 20:
        print(f"⚠️ High missing data: {missing_pct:.1f}% (recommend MICE imputation)")
    elif missing_pct > 0:
        print(f"🔍 Missing data: {missing_pct:.1f}% (manageable)")
    else:
        print(f"✅ No missing data")
    
    return valid

print("✅ Dataset analysis utilities loaded successfully!")
# Out:
# ✅ Dataset analysis utilities loaded successfully!

# %% [markdown]
# #### 2.1.3 Load and Analyze Dataset with Generalized Configuration

# %% [markdown]
# This code loads and analyzes a dataset using a specified configuration. It imports necessary libraries, attempts to read a CSV file, and standardizes the column names while allowing for potential updates to the target column. The script detects the target column, analyzes data types, and validates the dataset configuration, providing a summary of the dataset’s shape and missing values. Finally, it stores metadata about the dataset for future reference.

# %%
# Code Chunk ID: CHUNK_2_1_3_A
# =================== USER CONFIGURATION ===================
# 📝 CONFIGURE YOUR DATASET: Update these settings for your data
DATA_FILE = 'data/Pakistani_Diabetes_Dataset.csv'  # Path to your CSV file
TARGET_COLUMN = 'Outcome'                          # Name of your target/outcome column

# 🔧 DATASET IDENTIFIER (for results folder naming)
# Option 1: Manual override (recommended for consistent naming)
DATASET_IDENTIFIER_OVERRIDE = 'pakistani-diabetes-dataset'  # Set to None for auto-detection

# 🔧 OPTIONAL ADVANCED SETTINGS (Auto-detected if left empty)
CATEGORICAL_COLUMNS = ['Gender', 'Rgn']            # List categorical columns or leave empty for auto-detection
MISSING_STRATEGY = 'median'                        # Options: 'mice', 'drop', 'median', 'mode'
DATASET_NAME = 'Pakistani Diabetes Dataset'       # Descriptive name for your dataset

# 🚨 IMPORTANT: Verify these settings match your dataset before running!
print(f"📊 Configuration Summary:")
print(f"   Dataset: {DATASET_NAME}")
print(f"   File: {DATA_FILE}")
print(f"   Target: {TARGET_COLUMN}")
print(f"   Manual ID Override: {DATASET_IDENTIFIER_OVERRIDE}")
print(f"   Categorical: {CATEGORICAL_COLUMNS}")
print(f"   Missing Data Strategy: {MISSING_STRATEGY}")

# Load and prepare the dataset
data_file = DATA_FILE
target_column = TARGET_COLUMN

print(f"\n🔍 Loading dataset from: {data_file}")

try:
    data = pd.read_csv(data_file)
    print(f"✅ Dataset loaded successfully!")
    print(f"📊 Original shape: {data.shape}")
    
    # Set up dataset identifier with manual override option
    import setup
    
    # Use manual override if provided, otherwise auto-extract from filename
    if DATASET_IDENTIFIER_OVERRIDE:
        dataset_identifier = DATASET_IDENTIFIER_OVERRIDE
        setup.DATASET_IDENTIFIER = DATASET_IDENTIFIER_OVERRIDE
        setup.CURRENT_DATA_FILE = data_file
        print(f"📁 Using manual dataset identifier: {dataset_identifier}")
    else:
        dataset_identifier = setup.extract_dataset_identifier(data_file)
        setup.DATASET_IDENTIFIER = dataset_identifier
        setup.CURRENT_DATA_FILE = data_file
        print(f"📁 Auto-extracted dataset identifier: {dataset_identifier}")
    
    # 🔧 CRITICAL FIX: Set global DATASET_IDENTIFIER for use in other chunks
    DATASET_IDENTIFIER = dataset_identifier  # This ensures other chunks can access it
    
    # 📁 NEW: Update RESULTS_DIR for organized file outputs using proper structure
    # Don't set a specific RESULTS_DIR here - let each section use get_results_path()
    # This ensures proper date/section structure like: results/dataset/2025-09-12/Section-2/
    RESULTS_DIR = f"results/{dataset_identifier}/"  # Base directory only
    
    print(f"✅ Dataset identifier set: {DATASET_IDENTIFIER}")
    print(f"📅 Session timestamp: {setup.SESSION_TIMESTAMP}")
    print(f"🗂️  Results will be saved to: results/{dataset_identifier}/")
    
except FileNotFoundError:
    print(f"❌ Error: File not found at {data_file}")
    print("   Please check the DATA_FILE path in your configuration above")
    print("   Current working directory:", os.getcwd())
    data = None

except Exception as e:
    print(f"❌ Error loading dataset: {e}")
    data = None

if data is not None:
    print(f"\n📋 Dataset Info:")
    print(f"   • Shape: {data.shape}")
    print(f"   • Columns: {list(data.columns)}")
    
    # Check if target column exists
    if target_column not in data.columns:
        print(f"\n❌ WARNING: Target column '{target_column}' not found!")
        print(f"   Available columns: {list(data.columns)}")
        print("   Please update TARGET_COLUMN in the configuration above")
    else:
        print(f"   • Target column '{target_column}' found ✅")
        print(f"   • Target distribution: {data[target_column].value_counts().to_dict()}")
    
    # Check for missing values
    missing_values = data.isnull().sum()
    if missing_values.sum() > 0:
        print(f"\n⚠️  Missing values detected:")
        for col, count in missing_values[missing_values > 0].items():
            print(f"   • {col}: {count} missing ({count/len(data)*100:.1f}%)")
    else:
        print(f"\n✅ No missing values detected")
else:
    print("\n❌ Dataset loading failed - please fix the configuration and try again")
# Out:
# 📊 Configuration Summary:
#    Dataset: Pakistani Diabetes Dataset
#    File: data/Pakistani_Diabetes_Dataset.csv
#    Target: Outcome
#    Manual ID Override: pakistani-diabetes-dataset
#    Categorical: ['Gender', 'Rgn']
#    Missing Data Strategy: median
#
# 🔍 Loading dataset from: data/Pakistani_Diabetes_Dataset.csv
# ✅ Dataset loaded successfully!
# 📊 Original shape: (912, 19)
# 📁 Using manual dataset identifier: pakistani-diabetes-dataset
# ✅ Dataset identifier set: pakistani-diabetes-dataset
# 📅 Session timestamp: 2025-11-05
# 🗂️  Results will be saved to: results/pakistani-diabetes-dataset/
#
# 📋 Dataset Info:
#    • Shape: (912, 19)
#    • Columns: ['Age', 'Gender', 'Rgn ', 'wt', 'BMI', 'wst', 'sys', 'dia', 'his', 'A1c', 'B.S.R', 'vision', 'Exr', 'dipsia', 'uria', 'Dur', 'neph', 'HDL', 'Outcome']
#    • Target column 'Outcome' found ✅
#    • Target distribution: {1: 486, 0: 426}
#
# ✅ No missing values detected

# %% [markdown]
# This code provides advanced utilities for handling missing data using various strategies in Python. It includes functions to assess missing data patterns, apply Multiple Imputation by Chained Equations (MICE), visualize missing patterns, and implement different strategies for managing missing values. The `assess_missing_patterns` function analyzes and summarizes missing data, while `apply_mice_imputation` leverages an iterative imputer for numeric columns. The `visualize_missing_patterns` function creates visual representations of missing data, and the `handle_missing_data_strategy` function executes the chosen strategy, offering options like MICE, dropping rows, or filling with median or mode values. Collectively, these utilities facilitate effective management of missing data to improve dataset quality.

# %% [markdown]
# #### 2.1.4 Advanced Missing Data Handling with MICE

# %% [markdown]
# This code provides a comprehensive toolkit for analyzing, visualizing, and handling missing data in a pandas DataFrame using advanced and flexible approaches. It includes functions to assess the extent and patterns of missingness, visualize those patterns, and apply various imputation techniques. The centerpiece is the ability to perform Multiple Imputation by Chained Equations (MICE) using scikit-learn’s IterativeImputer with a RandomForestRegressor (for numerical features), which statistically estimates and fills in missing values based on all other feature relationships. For categorical variables, the code defaults to simpler mode imputation. Users can also choose alternative strategies like dropping rows (drop), filling with column medians (median), or filling with the most frequent value (mode). The code features detailed feedback and visual support with heatmaps and bar plots to help the user understand and monitor missing data patterns throughout the handling process. Together, these utilities help users robustly prepare data for machine learning or statistical analysis, reducing bias and maximizing data retention and utility.

# %%
# Code Chunk ID: CHUNK_2_1_4_A
# Advanced Missing Data Handling with MICE
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def assess_missing_patterns(df: pd.DataFrame) -> dict:
    """
    Comprehensive assessment of missing data patterns.
    
    Args:
        df: Input dataframe
        
    Returns:
        Dictionary with missing data analysis
    """
    missing_analysis = {}
    
    # Basic missing statistics
    missing_counts = df.isnull().sum()
    missing_percentages = (missing_counts / len(df)) * 100
    
    missing_analysis['missing_counts'] = missing_counts[missing_counts > 0]
    missing_analysis['missing_percentages'] = missing_percentages[missing_percentages > 0]
    missing_analysis['total_missing_cells'] = df.isnull().sum().sum()
    missing_analysis['total_cells'] = df.size
    missing_analysis['overall_missing_rate'] = (missing_analysis['total_missing_cells'] / missing_analysis['total_cells']) * 100
    
    # Missing patterns
    missing_patterns = df.isnull().value_counts()
    missing_analysis['missing_patterns'] = missing_patterns
    
    return missing_analysis

def apply_mice_imputation(df: pd.DataFrame, target_col: str = None, max_iter: int = 10, random_state: int = 42) -> pd.DataFrame:
    """
    Apply Multiple Imputation by Chained Equations (MICE) to handle missing data.
    
    Args:
        df: Input dataframe with missing values
        target_col: Target column name (excluded from imputation predictors)
        max_iter: Maximum number of imputation iterations
        random_state: Random state for reproducibility
        
    Returns:
        DataFrame with imputed values
    """
    print(f"🔧 Applying MICE imputation...")
    
    # Separate features and target
    if target_col and target_col in df.columns:
        features = df.drop(columns=[target_col])
        target = df[target_col]
    else:
        features = df.copy()
        target = None
    
    # Identify numeric and categorical columns
    numeric_cols = features.select_dtypes(include=[np.number]).columns.tolist()
    categorical_cols = features.select_dtypes(include=['object', 'category']).columns.tolist()
    
    df_imputed = features.copy()
    
    # Handle numeric columns with MICE
    if numeric_cols:
        print(f"   Imputing {len(numeric_cols)} numeric columns...")
        numeric_imputer = IterativeImputer(
            estimator=RandomForestRegressor(n_estimators=10, random_state=random_state),
            max_iter=max_iter,
            random_state=random_state
        )
        
        numeric_imputed = numeric_imputer.fit_transform(features[numeric_cols])
        df_imputed[numeric_cols] = numeric_imputed
    
    # Handle categorical columns with mode imputation (simpler approach)
    if categorical_cols:
        print(f"   Imputing {len(categorical_cols)} categorical columns with mode...")
        for col in categorical_cols:
            mode_value = features[col].mode()
            if len(mode_value) > 0:
                df_imputed[col] = features[col].fillna(mode_value[0])
            else:
                # If no mode, fill with 'Unknown'
                df_imputed[col] = features[col].fillna('Unknown')
    
    # Add target back if it exists
    if target is not None:
        df_imputed[target_col] = target
    
    print(f"✅ MICE imputation completed!")
    print(f"   Missing values before: {features.isnull().sum().sum()}")
    print(f"   Missing values after: {df_imputed.isnull().sum().sum()}")
    
    return df_imputed

def visualize_missing_patterns(df: pd.DataFrame, title: str = "Missing Data Patterns") -> None:
    """
    Create visualizations for missing data patterns.
    
    Args:
        df: Input dataframe
        title: Title for the plot
    """
    missing_data = df.isnull()
    
    if missing_data.sum().sum() == 0:
        print("✅ No missing data to visualize!")
        return
    
    fig, axes = plt.subplots(1, 2, figsize=(15, 6))
    
    # Missing data heatmap
    sns.heatmap(missing_data, 
                yticklabels=False, 
                cbar=True, 
                cmap='viridis',
                ax=axes[0])
    axes[0].set_title('Missing Data Heatmap')
    axes[0].set_xlabel('Columns')
    
    # Missing data bar chart
    missing_counts = missing_data.sum()
    missing_counts = missing_counts[missing_counts > 0]
    
    if len(missing_counts) > 0:
        missing_counts.plot(kind='bar', ax=axes[1], color='coral')
        axes[1].set_title('Missing Values by Column')
        axes[1].set_ylabel('Count of Missing Values')
        axes[1].tick_params(axis='x', rotation=45)
    else:
        axes[1].text(0.5, 0.5, 'No Missing Data', 
                    horizontalalignment='center', 
                    verticalalignment='center',
                    transform=axes[1].transAxes,
                    fontsize=16)
        axes[1].set_title('Missing Values by Column')
    
    plt.suptitle(title, fontsize=16)
    plt.tight_layout()
    plt.show()

def handle_missing_data_strategy(df: pd.DataFrame, strategy: str, target_col: str = None) -> pd.DataFrame:
    """
    Apply the specified missing data handling strategy.
    
    Args:
        df: Input dataframe
        strategy: Strategy to use ('mice', 'drop', 'median', 'mode')
        target_col: Target column name
        
    Returns:
        DataFrame with missing data handled
    """
    print(f"\n🔧 Applying missing data strategy: {strategy.upper()}")
    
    if df.isnull().sum().sum() == 0:
        print("✅ No missing data detected - no imputation needed")
        return df.copy()
    
    if strategy.lower() == 'mice':
        return apply_mice_imputation(df, target_col)
    
    elif strategy.lower() == 'drop':
        print(f"   Dropping rows with missing values...")
        df_clean = df.dropna()
        print(f"   Rows before: {len(df)}, Rows after: {len(df_clean)}")
        return df_clean
    
    elif strategy.lower() == 'median':
        print(f"   Filling missing values with median/mode...")
        df_filled = df.copy()
        
        # Numeric columns: fill with median
        numeric_cols = df.select_dtypes(include=[np.number]).columns
        for col in numeric_cols:
            if df[col].isnull().sum() > 0:
                median_val = df[col].median()
                df_filled[col] = df[col].fillna(median_val)
                print(f"     {col}: filled {df[col].isnull().sum()} values with median {median_val:.2f}")
        
        # Categorical columns: fill with mode
        categorical_cols = df.select_dtypes(include=['object', 'category']).columns
        for col in categorical_cols:
            if df[col].isnull().sum() > 0:
                mode_val = df[col].mode()
                if len(mode_val) > 0:
                    df_filled[col] = df[col].fillna(mode_val[0])
                    print(f"     {col}: filled {df[col].isnull().sum()} values with mode '{mode_val[0]}'")
        
        return df_filled
    
    elif strategy.lower() == 'mode':
        print(f"   Filling missing values with mode...")
        df_filled = df.copy()
        
        for col in df.columns:
            if df[col].isnull().sum() > 0:
                mode_val = df[col].mode()
                if len(mode_val) > 0:
                    df_filled[col] = df[col].fillna(mode_val[0])
                    print(f"     {col}: filled {df[col].isnull().sum()} values with mode '{mode_val[0]}'")
        
        return df_filled
    
    else:
        print(f"⚠️ Unknown strategy '{strategy}'. Using 'median' as fallback.")
        return handle_missing_data_strategy(df, 'median', target_col)

print("✅ Missing data handling utilities loaded successfully!")
# Out:
# ✅ Missing data handling utilities loaded successfully!

# %% [markdown]
# ⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️
#
# Note that next chunk samples 500 rows
#
# ⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️⚠️

# %%
# CHUNK_2_1_4_C
# This chunk samples 500 rows for quicker testing - remove for full dataset
# data=data.sample(n=500, random_state=42)
# data.shape
# data.head()

# %% [markdown]
# #### 2.1.5 EDA
# This code snippet provides an enhanced overview and analysis of a dataset. It generates basic statistics, including the dataset name, shape, memory usage, total missing values, missing percentage, number of duplicate rows, and counts of numeric and categorical columns. The results are organized into a dictionary called `overview_stats`, which is then iterated over to print each statistic in a formatted manner. Additionally, it sets up for displaying a sample of the data afterward.

# %%
# Code Chunk ID: CHUNK_2_1_5_A
# Enhanced Dataset Overview and Analysis
print("📋 COMPREHENSIVE DATASET OVERVIEW")
print("=" * 60)

# Basic statistics
overview_stats = {
    'Dataset Name': 'Breast Cancer Wisconsin (Diagnostic)',
    'Shape': f"{data.shape[0]} rows × {data.shape[1]} columns",
    'Memory Usage': f"{data.memory_usage(deep=True).sum() / 1024**2:.2f} MB",
    'Total Missing Values': data.isnull().sum().sum(),
    'Missing Percentage': f"{(data.isnull().sum().sum() / data.size) * 100:.2f}%",
    'Duplicate Rows': data.duplicated().sum(),
    'Numeric Columns': len(data.select_dtypes(include=[np.number]).columns),
    'Categorical Columns': len(data.select_dtypes(include=['object']).columns)
}

for key, value in overview_stats.items():
    print(f"{key:.<25} {value}")
# Out:
# 📋 COMPREHENSIVE DATASET OVERVIEW
# ============================================================
# Dataset Name............. Breast Cancer Wisconsin (Diagnostic)
# Shape.................... 912 rows × 19 columns
# Memory Usage............. 0.13 MB
# Total Missing Values..... 0
# Missing Percentage....... 0.00%
# Duplicate Rows........... 2
# Numeric Columns.......... 19
# Categorical Columns...... 0

# %%
# Code Chunk ID: CHUNK_2_1_5_B
# Enhanced Column Analysis - OUTPUT TO FILE
print("📊 DETAILED COLUMN ANALYSIS (SAVING TO FILE)")
print("=" * 50)

column_analysis = pd.DataFrame({
    'Column': data.columns,
    'Data_Type': data.dtypes.astype(str),
    'Unique_Values': [data[col].nunique() for col in data.columns],
    'Missing_Count': [data[col].isnull().sum() for col in data.columns],
    'Missing_Percent': [f"{(data[col].isnull().sum()/len(data)*100):.2f}%" for col in data.columns],
    'Min_Value': [data[col].min() if data[col].dtype in ['int64', 'float64'] else 'N/A' for col in data.columns],
    'Max_Value': [data[col].max() if data[col].dtype in ['int64', 'float64'] else 'N/A' for col in data.columns]
})

# Use new folder structure: results/dataset_identifier/YYYY-MM-DD/Section-2
results_path = get_results_path(DATASET_IDENTIFIER, 2)
os.makedirs(results_path, exist_ok=True)
csv_file = f'{results_path}/column_analysis.csv'
column_analysis.to_csv(csv_file, index=False)

print(f"📊 Column analysis table saved to {csv_file}")
print(f"📊 Analysis completed for {len(data.columns)} features")
# Out:
# 📊 DETAILED COLUMN ANALYSIS (SAVING TO FILE)
# ==================================================
# 📊 Column analysis table saved to results/pakistani-diabetes-dataset/2025-11-05/Section-2/column_analysis.csv
# 📊 Analysis completed for 19 features

# %% [markdown]
# This code conducts an enhanced analysis of the target variable within a dataset. It computes the counts and percentages of target classes, organizing the results into a DataFrame called `target_summary`, which distinguishes between benign and malignant classes if applicable. The class balance is assessed by calculating a balance ratio, with outputs indicating whether the dataset is balanced, moderately imbalanced, or highly imbalanced. If the specified target column is not found, it displays a warning and lists available columns in the dataset.

# %%
# Code Chunk ID: CHUNK_2_1_5_C
# Enhanced Target Variable Analysis - OUTPUT TO FILE
print("🎯 TARGET VARIABLE ANALYSIS (SAVING TO FILE)")
print("=" * 40)

if target_column in data.columns:
    target_counts = data[target_column].value_counts().sort_index()
    target_props = data[target_column].value_counts(normalize=True).sort_index() * 100
    
    target_summary = pd.DataFrame({
        'Class': target_counts.index,
        'Count': target_counts.values,
        'Percentage': [f"{prop:.1f}%" for prop in target_props.values],
        'Description': ['Benign (Non-cancerous)', 'Malignant (Cancerous)'] if len(target_counts) == 2 else [f'Class {i}' for i in target_counts.index]
    })
    
    # Use new folder structure: results/dataset_identifier/YYYY-MM-DD/Section-2
    results_path = get_results_path(DATASET_IDENTIFIER, 2)
    os.makedirs(results_path, exist_ok=True)
    csv_file = f'{results_path}/target_analysis.csv'
    target_summary.to_csv(csv_file, index=False)
    
    # Calculate class balance metrics
    balance_ratio = target_counts.min() / target_counts.max()
    
    # Save balance metrics to separate file
    balance_metrics = pd.DataFrame({
        'Metric': ['Class_Balance_Ratio', 'Dataset_Balance_Category'],
        'Value': [f"{balance_ratio:.3f}", 
                 'Balanced' if balance_ratio > 0.8 else 'Moderately Imbalanced' if balance_ratio > 0.5 else 'Highly Imbalanced']
    })
    balance_file = f'{results_path}/target_balance_metrics.csv'
    balance_metrics.to_csv(balance_file, index=False)
    
    print(f"📊 Target variable analysis saved to {csv_file}")
    print(f"📊 Class balance metrics saved to {balance_file}")
    print(f"📊 Class Balance Ratio: {balance_ratio:.3f}")
    print(f"📊 Dataset Balance: {'Balanced' if balance_ratio > 0.8 else 'Moderately Imbalanced' if balance_ratio > 0.5 else 'Highly Imbalanced'}")
    
else:
    print(f"⚠️ Warning: Target column '{target_column}' not found!")
    print(f"Available columns: {list(data.columns)}")
# Out:
# 🎯 TARGET VARIABLE ANALYSIS (SAVING TO FILE)
# ========================================
# 📊 Target variable analysis saved to results/pakistani-diabetes-dataset/2025-11-05/Section-2/target_analysis.csv
# 📊 Class balance metrics saved to results/pakistani-diabetes-dataset/2025-11-05/Section-2/target_balance_metrics.csv
# 📊 Class Balance Ratio: 0.877
# 📊 Dataset Balance: Balanced

# %% [markdown]
# This code provides enhanced visualizations of feature distributions in a dataset. It retrieves numeric columns, excluding the target variable, and generates histograms for each numeric feature, displaying them in a grid layout. The histograms are enhanced with options for density, color, and grid lines to improve readability. If no numeric features are found, a warning message is displayed; otherwise, the generated plots give insights into the distributions of the numeric features in the dataset.

# %%
# Code Chunk ID: CHUNK_2_1_5_D
# Enhanced Feature Distribution Visualizations - OUTPUT TO FILE
print("📊 FEATURE DISTRIBUTION ANALYSIS (SAVING TO FILE)")
print("=" * 40)

# Turn off interactive mode to prevent figures from displaying in notebook
import matplotlib
matplotlib.use('Agg')  # Use non-interactive backend
plt.ioff()  # Turn off interactive mode

# Get numeric columns excluding target
numeric_cols = data.select_dtypes(include=[np.number]).columns.tolist()
if target_column in numeric_cols:
    numeric_cols.remove(target_column)

if numeric_cols:
    n_cols = min(3, len(numeric_cols))
    n_rows = (len(numeric_cols) + n_cols - 1) // n_cols
    
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(5*n_cols, 4*n_rows))
    # Use dataset name fallback for title
    dataset_name = DATASET_IDENTIFIER.title() if DATASET_IDENTIFIER else "Dataset"
    fig.suptitle(f'{dataset_name} - Feature Distributions', fontsize=16, fontweight='bold')
    
    # Handle different subplot configurations
    if n_rows == 1 and n_cols == 1:
        axes = [axes]
    elif n_rows == 1:
        axes = axes
    else:
        axes = axes.flatten()
    
    for i, col in enumerate(numeric_cols):
        if i < len(axes):
            # Enhanced histogram
            axes[i].hist(data[col], bins=30, alpha=0.7, color='skyblue', 
                        edgecolor='black', density=True)
            
            axes[i].set_title(f'{col}', fontsize=12, fontweight='bold')
            axes[i].set_xlabel(col)
            axes[i].set_ylabel('Density')
            axes[i].grid(True, alpha=0.3)
    
    # Remove empty subplots
    for j in range(len(numeric_cols), len(axes)):
        fig.delaxes(axes[j])
    
    plt.tight_layout()
    
    # Use new folder structure: results/dataset_identifier/YYYY-MM-DD/Section-2
    results_path = get_results_path(DATASET_IDENTIFIER, 2)
    os.makedirs(results_path, exist_ok=True)
    plot_file = f'{results_path}/feature_distributions.png'
    plt.savefig(plot_file, dpi=300, bbox_inches='tight')
    plt.close()  # Close the figure to free memory
    
    print(f"📊 Feature distribution plots saved to {plot_file}")
    print(f"📊 Distribution analysis completed for {len(numeric_cols)} numeric features")
else:
    print("⚠️ No numeric features found for visualization")
# Out:
# 📊 FEATURE DISTRIBUTION ANALYSIS (SAVING TO FILE)
# ========================================
# 📊 Feature distribution plots saved to results/pakistani-diabetes-dataset/2025-11-05/Section-2/feature_distributions.png
# 📊 Distribution analysis completed for 18 numeric features

# %% [markdown]
# This code conducts an enhanced correlation analysis of features within a dataset. It calculates the correlation matrix for numeric columns and includes the target variable if it is numeric, displaying the results in a heatmap for better visualization. The analysis identifies correlations with the target variable, categorizing each feature based on its correlation strength (strong, moderate, or weak) and presenting the findings in a DataFrame. If there are insufficient numeric features, a warning message is displayed, indicating that correlation analysis cannot be performed.

# %%
# Code Chunk ID: CHUNK_2_1_5_E
# Enhanced Correlation Analysis - OUTPUT TO FILE
print("🔍 CORRELATION ANALYSIS (SAVING TO FILE)")
print("=" * 30)

# Turn off interactive mode to prevent figures from displaying in notebook
import matplotlib
matplotlib.use('Agg')  # Use non-interactive backend
plt.ioff()  # Turn off interactive mode

if len(numeric_cols) > 1:
    # Include target in correlation if numeric
    cols_for_corr = numeric_cols.copy()
    if data[target_column].dtype in ['int64', 'float64']:
        cols_for_corr.append(target_column)
    
    correlation_matrix = data[cols_for_corr].corr()
    
    # Enhanced correlation heatmap
    fig, ax = plt.subplots(figsize=(10, 8))
    
    sns.heatmap(correlation_matrix, 
                annot=True, 
                cmap='RdBu_r',
                center=0, 
                square=True, 
                linewidths=0.5,
                fmt='.3f',
                ax=ax)
    
    # Use dataset name fallback for title
    dataset_name = DATASET_IDENTIFIER.title() if DATASET_IDENTIFIER else "Dataset"
    ax.set_title(f'{dataset_name} - Feature Correlation Matrix', 
              fontsize=14, fontweight='bold', pad=20)
    plt.tight_layout()
    
    # Use new folder structure: results/dataset_identifier/YYYY-MM-DD/Section-2
    results_path = get_results_path(DATASET_IDENTIFIER, 2)
    os.makedirs(results_path, exist_ok=True)
    heatmap_file = f'{results_path}/correlation_heatmap.png'
    plt.savefig(heatmap_file, dpi=300, bbox_inches='tight')
    plt.close()  # Close the figure to free memory
    
    # Save correlation matrix to CSV
    corr_matrix_file = f'{results_path}/correlation_matrix.csv'
    correlation_matrix.to_csv(corr_matrix_file)
    
    print(f"🔍 Correlation heatmap saved to {heatmap_file}")
    print(f"🔍 Correlation matrix saved to {corr_matrix_file}")
    
    # Correlation with target analysis
    if target_column in correlation_matrix.columns:
        print("\n🔍 CORRELATIONS WITH TARGET VARIABLE (SAVING TO FILE)")
        print("=" * 45)
        
        target_corrs = correlation_matrix[target_column].abs().sort_values(ascending=False)
        target_corrs = target_corrs[target_corrs.index != target_column]
        
        corr_analysis = pd.DataFrame({
            'Feature': target_corrs.index,
            'Absolute_Correlation': target_corrs.values,
            'Raw_Correlation': [correlation_matrix.loc[feat, target_column] for feat in target_corrs.index],
            'Strength': ['Strong' if abs(corr) > 0.7 else 'Moderate' if abs(corr) > 0.3 else 'Weak' 
                        for corr in target_corrs.values]
        })
        
        # Save correlation analysis to CSV instead of displaying
        corr_analysis_file = f'{results_path}/target_correlations.csv'
        corr_analysis.to_csv(corr_analysis_file, index=False)
        
        print(f"🔍 Target correlation analysis saved to {corr_analysis_file}")
        print(f"📊 Correlation analysis completed for {len(target_corrs)} features")
    
else:
    print("⚠️ Insufficient numeric features for correlation analysis")
# Out:
# 🔍 CORRELATION ANALYSIS (SAVING TO FILE)
# ==============================
# 🔍 Correlation heatmap saved to results/pakistani-diabetes-dataset/2025-11-05/Section-2/correlation_heatmap.png
# 🔍 Correlation matrix saved to results/pakistani-diabetes-dataset/2025-11-05/Section-2/correlation_matrix.csv
#
# 🔍 CORRELATIONS WITH TARGET VARIABLE (SAVING TO FILE)
# =============================================
# 🔍 Target correlation analysis saved to results/pakistani-diabetes-dataset/2025-11-05/Section-2/target_correlations.csv
# 📊 Correlation analysis completed for 18 features

# %% [markdown]
# This code sets up global configuration variables for consistent evaluation across model evaluations. It checks for the existence of required variables, such as `data` and `target_column`, and raises an error if they are not defined. The code establishes global constants for the target column, results directory, and a copy of the original data while defining categorical columns, excluding the target. It then creates the results directory if it does not already exist and verifies that all necessary global variables are present, providing feedback on the setup's success.

# %%
# Code Chunk ID: CHUNK_2_1_5_F
# ============================================================================
# GLOBAL CONFIGURATION VARIABLES
# ============================================================================
# These variables are used across all sections for consistent evaluation

# Verify required variables exist before setting globals
if 'data' not in globals() or 'target_column' not in globals():
    raise ValueError("❌ ERROR: 'data' and 'target_column' must be defined before setting global variables. Please run the data loading cell first.")

# Set up global variables for use in all model evaluations
TARGET_COLUMN = target_column  # Use the target column from data loading

# 🔧 UPDATED: Preserve dataset-specific RESULTS_DIR that was set in CHUNK_005
# Don't override it with a generic path - maintain the structured approach
if 'RESULTS_DIR' not in globals() or RESULTS_DIR is None:
    # Fallback: reconstruct proper results directory structure
    RESULTS_DIR = f"results/{setup.DATASET_IDENTIFIER}/"
    print(f"⚠️  RESULTS_DIR was missing - using fallback: {RESULTS_DIR}")
else:
    print(f"✅ Using existing RESULTS_DIR: {RESULTS_DIR}")

data = data.copy()    # Create a copy of original data for evaluation functions

# Define categorical columns for all models
categorical_columns = data.select_dtypes(include=['object']).columns.tolist()
if TARGET_COLUMN in categorical_columns:
    categorical_columns.remove(TARGET_COLUMN)  # Remove target from categorical list

# Apply user-specified categorical columns if provided
if 'CATEGORICAL_COLUMNS' in globals() and CATEGORICAL_COLUMNS:
    categorical_columns = CATEGORICAL_COLUMNS
    print(f"   • Using user-specified categorical columns: {categorical_columns}")
else:
    print(f"   • Auto-detected categorical columns: {categorical_columns}")

print("🔧 Global Configuration Summary:")
print(f"   • TARGET_COLUMN: {TARGET_COLUMN}")
print(f"   • RESULTS_DIR: {RESULTS_DIR}")
print(f"   • data shape: {data.shape}")
print(f"   • categorical_columns: {categorical_columns}")

# Create base results directory if it doesn't exist
import os
if not os.path.exists(RESULTS_DIR):
    os.makedirs(RESULTS_DIR, exist_ok=True)
    print(f"   • Created base results directory: {RESULTS_DIR}")
else:
    print(f"   • Base results directory already exists: {RESULTS_DIR}")

# Validate that all required variables are now available
required_vars = ['TARGET_COLUMN', 'RESULTS_DIR', 'data', 'categorical_columns']
missing_vars = [var for var in required_vars if var not in globals()]

if missing_vars:
    raise ValueError(f"❌ ERROR: Missing required global variables: {missing_vars}")
else:
    print("✅ All required global variables are now available for Section 3 evaluations")
# Out:
# ✅ Using existing RESULTS_DIR: results/pakistani-diabetes-dataset/
#    • Using user-specified categorical columns: ['Gender', 'Rgn']
# 🔧 Global Configuration Summary:
#    • TARGET_COLUMN: Outcome
#    • RESULTS_DIR: results/pakistani-diabetes-dataset/
#    • data shape: (912, 19)
#    • categorical_columns: ['Gender', 'Rgn']
#    • Base results directory already exists: results/pakistani-diabetes-dataset/
# ✅ All required global variables are now available for Section 3 evaluations

# %% [markdown]
# ## 3 Demo All Models with Default Parameters

# %% [markdown]
# ### 3.1 Demos

# %% [markdown]
# Each model is run with default parameters for purposes of testing.

# %% [markdown]
# #### 3.1.1 CTGAN Demo

# %%
# Code Chunk ID: CHUNK_3_1_1_A
import time
try:
    print("🔄 CTGAN Demo - Default Parameters")
    print("=" * 500)
    
    # Import and initialize CTGAN model using ModelFactory
    from src.models.model_factory import ModelFactory
    
    ctgan_model = ModelFactory.create("ctgan", random_state=42)
    
    # Define demo parameters for quick execution
    demo_params = {
        'epochs': 500,
        'batch_size': 100,
        'generator_dim': (128, 128),
        'discriminator_dim': (128, 128)
    }
    
    # Train with demo parameters
    print("Training CTGAN with demo parameters...")
    start_time = time.time()
    
    # Auto-detect discrete columns
    discrete_columns = data.select_dtypes(include=['object']).columns.tolist()
    
    ctgan_model.train(data, discrete_columns=discrete_columns, **demo_params)
    train_time = time.time() - start_time
    
    # Generate synthetic data
    demo_samples = len(data)  # Same size as original dataset
    print(f"Generating {demo_samples} synthetic samples...")
    synthetic_data_ctgan = ctgan_model.generate(demo_samples)
    
    print(f"✅ CTGAN Demo completed successfully!")
    print(f"   - Training time: {train_time:.2f} seconds")
    print(f"   - Generated samples: {len(synthetic_data_ctgan)}")
    print(f"   - Original data shape: {data.shape}")
    print(f"   - Synthetic data shape: {synthetic_data_ctgan.shape}")
    
    # Store for later use in comprehensive evaluation
    demo_results_ctgan = {
        'model': ctgan_model,
        'synthetic_data': synthetic_data_ctgan,
        'training_time': train_time,
        'parameters_used': demo_params
    }
    
except ImportError as e:
    print(f"❌ CTGAN not available: {e}")
    print(f"   Please ensure CTGAN dependencies are installed")
except Exception as e:
    print(f"❌ Error during CTGAN demo: {str(e)}")
    print("   Check model implementation and data compatibility")
    import traceback
    traceback.print_exc()
# Out:
# 🔄 CTGAN Demo - Default Parameters
# ====================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# Training CTGAN with demo parameters...
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Gen. (-0.33) | Discrim. (-0.31): 100%|██████████| 500/500 [00:29<00:00, 16.76it/s]
# Generating 912 synthetic samples...
# ✅ CTGAN Demo completed successfully!
#    - Training time: 45.38 seconds
#    - Generated samples: 912
#    - Original data shape: (912, 19)
#    - Synthetic data shape: (912, 19)

# %% [markdown]
# #### 3.1.2 CTAB-GAN Demo

# %%
# Code Chunk ID: CHUNK_3_1_2_A
try:
    print("🔄 CTAB-GAN Demo - Default Parameters")
    print("=" * 50)
    
    # Check CTABGAN availability (imported from setup.py)
    if not CTABGAN_AVAILABLE:
        raise ImportError("CTAB-GAN not available - clone and install CTAB-GAN repository")
    
    # Initialize CTAB-GAN model (already defined in notebook)
    ctabgan_model = CTABGANModel()
    print("✅ CTAB-GAN model initialized successfully")
    
    # Record start time
    start_time = time.time()
    
    # Train the model with demo parameters
    print("🚀 Training CTAB-GAN model (epochs=500)...")
    ctabgan_model.fit(data, categorical_columns=None, target_column=target_column)
    
    # Record training time
    train_time = time.time() - start_time
    
    # Generate synthetic data
    print("🎯 Generating synthetic data...")
    synthetic_data_ctabgan = ctabgan_model.generate(len(data))
    
    # Display results
    print("✅ CTAB-GAN Demo completed successfully!")
    print(f"   - Training time: {train_time:.2f} seconds")
    print(f"   - Generated samples: {len(synthetic_data_ctabgan)}")
    print(f"   - Original shape: {data.shape}")
    print(f"   - Synthetic shape: {synthetic_data_ctabgan.shape}")
    
    # Show sample of synthetic data with proper handling for both DataFrame and array
    print(f"\n📊 Sample of generated data:")
    if hasattr(synthetic_data_ctabgan, 'head'):
        # It's a DataFrame
        print(synthetic_data_ctabgan.head())
    else:
        # It's likely a numpy array
        print("First 5 rows of synthetic data:")
        print(synthetic_data_ctabgan[:5])
    print("=" * 50)
    
except ImportError as e:
    print(f"❌ CTAB-GAN not available: {e}")
    print(f"   Please ensure CTAB-GAN dependencies are installed")
    print(f"   Note: CTABGAN_AVAILABLE = {globals().get('CTABGAN_AVAILABLE', 'undefined')}")
except Exception as e:
    print(f"❌ Error during CTAB-GAN demo: {str(e)}")
    print("   Check model implementation and data compatibility")
    import traceback
    traceback.print_exc()
# Out:
# 🔄 CTAB-GAN Demo - Default Parameters
# ==================================================
# ✅ CTAB-GAN model initialized successfully
# 🚀 Training CTAB-GAN model (epochs=500)...
# [CTABGAN] Applying comprehensive data preprocessing...
# [DATA_CLEANING] Processing 912 rows, 19 columns
# [DATA_CLEANING] Categorical columns: []
# [DATA_CLEANING] Data cleaning completed successfully
# [DATA_CLEANING] Final shape: (912, 19)
# [DATA_CLEANING] Data types: {'Age': dtype('float64'), 'Gender': dtype('int64'), 'Rgn ': dtype('int64'), 'wt': dtype('float64'), 'BMI': dtype('float64'), 'wst': dtype('float64'), 'sys': dtype('int64'), 'dia': dtype('int64'), 'his': dtype('int64'), 'A1c': dtype('float64'), 'B.S.R': dtype('int64'), 'vision': dtype('int64'), 'Exr': dtype('int64'), 'dipsia': dtype('int64'), 'uria': dtype('int64'), 'Dur': dtype('float64'), 'neph': dtype('int64'), 'HDL': dtype('int64'), 'Outcome': dtype('int64')}
# [CTABGAN] Using categorical columns: []
# [CTABGAN] Data shape after preprocessing: (912, 19)
# [CTABGAN] Training CTAB-GAN for 100 epochs...
# [ERROR] CTAB-GAN training failed: BayesianGaussianMixture.__init__() takes 1 positional argument but 2 positional arguments (and 5 keyword-only arguments) were given
#    Error type: TypeError
#    Full error: BayesianGaussianMixture.__init__() takes 1 positional argument but 2 positional arguments (and 5 keyword-only arguments) were given
# ❌ Error during CTAB-GAN demo: CTAB-GAN training error: BayesianGaussianMixture.__init__() takes 1 positional argument but 2 positional arguments (and 5 keyword-only arguments) were given
#    Check model implementation and data compatibility
# Traceback (most recent call last):
#   File "/home/ec2-user/SageMaker/tableGenCompare/setup.py", line 440, in fit
#     self.model.fit(cleaned_data)
#   File "/home/ec2-user/SageMaker/tableGenCompare/./CTAB-GAN/model/synthesizer/ctabgan_synthesizer.py", line 598, in fit
#     self.transformer.fit()
#   File "/home/ec2-user/SageMaker/tableGenCompare/./CTAB-GAN/model/synthesizer/transformer.py", line 93, in fit
#     gm = BayesianGaussianMixture(
# TypeError: BayesianGaussianMixture.__init__() takes 1 positional argument but 2 positional arguments (and 5 keyword-only arguments) were given
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/tmp/ipykernel_9729/3482901495.py", line 19, in <module>
#     ctabgan_model.fit(data, categorical_columns=None, target_column=target_column)
#   File "/home/ec2-user/SageMaker/tableGenCompare/setup.py", line 447, in fit
#     raise RuntimeError(f"CTAB-GAN training error: {str(e)}")
# RuntimeError: CTAB-GAN training error: BayesianGaussianMixture.__init__() takes 1 positional argument but 2 positional arguments (and 5 keyword-only arguments) were given

# %% [markdown]
# #### 3.1.3 CTAB-GAN+ Demo

# %%
# Code Chunk ID: CHUNK_3_1_3_A
try:
    print("🔄 CTAB-GAN+ Demo - Default Parameters")
    print("=" * 50)
    
    # Check CTABGAN+ availability with fallback
    try:
        ctabganplus_available = CTABGANPLUS_AVAILABLE
    except NameError:
        print("⚠️  CTABGANPLUS_AVAILABLE variable not defined - checking direct import...")
        try:
            # Try to check if CTABGANPLUS (the imported class) exists
            from model.ctabgan import CTABGAN as CTABGANPLUS
            ctabganplus_available = True
            print("✅ CTAB-GAN+ import check successful")
        except ImportError:
            ctabganplus_available = False
            print("❌ CTAB-GAN+ import check failed")
    
    if not ctabganplus_available:
        raise ImportError("CTAB-GAN+ not available - clone and install CTAB-GAN+ repository")
    
    # Initialize CTAB-GAN+ model with epochs parameter in constructor
    ctabganplus_model = CTABGANPlusModel(epochs=500)
    print("✅ CTAB-GAN+ model initialized successfully")
    
    # Record start time
    start_time = time.time()
    
    # Train the model (epochs already set in constructor)
    print("🚀 Training CTAB-GAN+ model (epochs=500)...")
    ctabganplus_model.fit(data)
    
    # Record training time
    train_time = time.time() - start_time
    
    # Generate synthetic data
    print("🎯 Generating synthetic data...")
    synthetic_data_ctabganplus = ctabganplus_model.generate(len(data))
    
    # Display results
    print("✅ CTAB-GAN+ Demo completed successfully!")
    print(f"   - Training time: {train_time:.2f} seconds")
    print(f"   - Generated samples: {len(synthetic_data_ctabganplus)}")
    print(f"   - Original shape: {data.shape}")
    print(f"   - Synthetic shape: {synthetic_data_ctabganplus.shape}")
    
    # Show sample of synthetic data with proper handling for both DataFrame and array
    print(f"\n📊 Sample of generated data:")
    if hasattr(synthetic_data_ctabganplus, 'head'):
        # It's a DataFrame
        print(synthetic_data_ctabganplus.head())
    else:
        # It's likely a numpy array
        print("First 5 rows of synthetic data:")
        print(synthetic_data_ctabganplus[:5])
    print("=" * 50)
    
except ImportError as e:
    print(f"❌ CTAB-GAN+ not available: {e}")
    print(f"   Please ensure CTAB-GAN+ dependencies are installed")
except Exception as e:
    print(f"❌ Error during CTAB-GAN+ demo: {str(e)}")
    print("   Check model implementation and data compatibility")
    import traceback
    traceback.print_exc()
# Out:
# 🔄 CTAB-GAN+ Demo - Default Parameters
# ==================================================
# ✅ CTAB-GAN+ model initialized successfully
# 🚀 Training CTAB-GAN+ model (epochs=500)...
# [CTABGAN+] Applying comprehensive data preprocessing...
# [DATA_CLEANING] Processing 912 rows, 19 columns
# [DATA_CLEANING] Categorical columns: []
# [DATA_CLEANING] Data cleaning completed successfully
# [DATA_CLEANING] Final shape: (912, 19)
# [DATA_CLEANING] Data types: {'Age': dtype('float64'), 'Gender': dtype('int64'), 'Rgn ': dtype('int64'), 'wt': dtype('float64'), 'BMI': dtype('float64'), 'wst': dtype('float64'), 'sys': dtype('int64'), 'dia': dtype('int64'), 'his': dtype('int64'), 'A1c': dtype('float64'), 'B.S.R': dtype('int64'), 'vision': dtype('int64'), 'Exr': dtype('int64'), 'dipsia': dtype('int64'), 'uria': dtype('int64'), 'Dur': dtype('float64'), 'neph': dtype('int64'), 'HDL': dtype('int64'), 'Outcome': dtype('int64')}
# [CTABGAN+] Using categorical columns: []
# [CTABGAN+] Data shape after preprocessing: (912, 19)
# [CTABGAN+] Using Classification with target: Outcome (2 unique values)
# [CTABGAN+] Validating data for robust training...
# [CTABGAN+] Initializing CTAB-GAN+ with validated parameters...
# [CTABGAN+] Training CTAB-GAN+ (Enhanced) for 500 epochs...
# [ERROR] CTAB-GAN+ initialization failed: BayesianGaussianMixture.__init__() takes 1 positional argument but 2 positional arguments (and 5 keyword-only arguments) were given
# [ERROR] CTAB-GAN+ training failed: BayesianGaussianMixture.__init__() takes 1 positional argument but 2 positional arguments (and 5 keyword-only arguments) were given
#    Error type: TypeError
#    Full error: BayesianGaussianMixture.__init__() takes 1 positional argument but 2 positional arguments (and 5 keyword-only arguments) were given
# ❌ Error during CTAB-GAN+ demo: CTAB-GAN+ training error: BayesianGaussianMixture.__init__() takes 1 positional argument but 2 positional arguments (and 5 keyword-only arguments) were given
#    Check model implementation and data compatibility
# Traceback (most recent call last):
#   File "/home/ec2-user/SageMaker/tableGenCompare/setup.py", line 716, in fit
#     raise model_error
#   File "/home/ec2-user/SageMaker/tableGenCompare/setup.py", line 694, in fit
#     self.model.fit()
#   File "/home/ec2-user/SageMaker/tableGenCompare/src/models/implementations/../../../CTAB-GAN/model/ctabgan.py", line 59, in fit
#     self.synthesizer.fit(train_data=self.data_prep.df, categorical = self.data_prep.column_types["categorical"],
#   File "/home/ec2-user/SageMaker/tableGenCompare/./CTAB-GAN/model/synthesizer/ctabgan_synthesizer.py", line 598, in fit
#     self.transformer.fit()
#   File "/home/ec2-user/SageMaker/tableGenCompare/./CTAB-GAN/model/synthesizer/transformer.py", line 93, in fit
#     gm = BayesianGaussianMixture(
# TypeError: BayesianGaussianMixture.__init__() takes 1 positional argument but 2 positional arguments (and 5 keyword-only arguments) were given
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/tmp/ipykernel_9729/722174319.py", line 32, in <module>
#     ctabganplus_model.fit(data)
#   File "/home/ec2-user/SageMaker/tableGenCompare/setup.py", line 747, in fit
#     raise RuntimeError(f"CTAB-GAN+ training error: {str(e)}")
# RuntimeError: CTAB-GAN+ training error: BayesianGaussianMixture.__init__() takes 1 positional argument but 2 positional arguments (and 5 keyword-only arguments) were given

# %% [markdown]
# #### 3.1.4 GANerAid Demo

# %%
# Code Chunk ID: CHUNK_3_1_4_A
try:
    print("🔄 GANerAid Demo - Default Parameters")
    print("=" * 50)
    
    # Check GANerAid availability with fallback
    try:
        ganeraid_available = GANERAID_AVAILABLE
        GANerAidModel  # Test if the class is available
    except NameError:
        print("⚠️ GANerAidModel not available - checking import...")
        try:
            # Try to import GANerAidModel
            from src.models.implementations.ganeraid_model import GANerAidModel
            ganeraid_available = True
            print("✅ GANerAidModel import successful")
        except ImportError:
            ganeraid_available = False
            print("❌ GANerAidModel import failed")
    
    if not ganeraid_available:
        raise ImportError("GANerAid not available - please install GANerAid dependencies")
    
    # Initialize GANerAid model
    ganeraid_model = GANerAidModel()
    print("✅ GANerAid model initialized successfully")
    
    # Define demo_samples variable for synthetic data generation
    demo_samples = len(data)  # Same size as original dataset
    
    # Train with minimal parameters for demo
    demo_params = {'epochs': 500, 'batch_size': 100}
    start_time = time.time()
    ganeraid_model.train(data, **demo_params)  # GANerAid uses train method
    train_time = time.time() - start_time
    
    # Generate synthetic data
    synthetic_data_ganeraid = ganeraid_model.generate(demo_samples)
    
    print(f"✅ GANerAid Demo completed successfully!")
    print(f"   - Training time: {train_time:.2f} seconds")
    print(f"   - Generated samples: {len(synthetic_data_ganeraid)}")
    print(f"   - Original shape: {data.shape}")
    print(f"   - Synthetic shape: {synthetic_data_ganeraid.shape}")
    
    # Show sample of synthetic data with proper handling for both DataFrame and array
    print(f"\n📊 Sample of generated data:")
    if hasattr(synthetic_data_ganeraid, 'head'):
        # It's a DataFrame
        print(synthetic_data_ganeraid.head())
    else:
        # It's likely a numpy array
        print("First 5 rows of synthetic data:")
        print(synthetic_data_ganeraid[:5])
    print("=" * 50)
    
except ImportError as e:
    print(f"❌ GANerAid not available: {e}")
    print(f"   Please ensure GANerAid dependencies are installed")
except Exception as e:
    print(f"❌ Error during GANerAid demo: {str(e)}")
    print("   Check model implementation and data compatibility")
    import traceback
    traceback.print_exc()
# Out:
# 🔄 GANerAid Demo - Default Parameters
# ==================================================
# ❌ GANerAid not available: GANerAid is not available. Please install it with: pip install GANerAid
#    Please ensure GANerAid dependencies are installed

# %% [markdown]
# #### 3.1.5 CopulaGAN Demo

# %%
# Code Chunk ID: CHUNK_3_1_5_A
try:
    print("🔄 CopulaGAN Demo - Default Parameters")
    print("=" * 50)
    
    # Import and initialize CopulaGAN model using ModelFactory
    from src.models.model_factory import ModelFactory
    
    copulagan_model = ModelFactory.create("copulagan", random_state=42)
    
    # Define demo parameters optimized for CopulaGAN
    demo_params = {
        'epochs': 500,
        'batch_size': 100,
        'generator_dim': (128, 128),
        'discriminator_dim': (128, 128),
        'default_distribution': 'beta',  # Good for bounded data
        'enforce_min_max_values': True
    }
    
    # Train with demo parameters
    print("Training CopulaGAN with demo parameters...")
    start_time = time.time()
    
    # Auto-detect discrete columns for CopulaGAN
    discrete_columns = data.select_dtypes(include=['object']).columns.tolist()
    
    copulagan_model.train(data, discrete_columns=discrete_columns, **demo_params)
    train_time = time.time() - start_time
    
    # Generate synthetic data
    demo_samples = len(data)  # Same size as original dataset
    print(f"Generating {demo_samples} synthetic samples...")
    synthetic_data_copulagan = copulagan_model.generate(demo_samples)
    
    print(f"✅ CopulaGAN Demo completed successfully!")
    print(f"   - Training time: {train_time:.2f} seconds")
    print(f"   - Generated samples: {len(synthetic_data_copulagan)}")
    print(f"   - Original data shape: {data.shape}")
    print(f"   - Synthetic data shape: {synthetic_data_copulagan.shape}")
    print(f"   - Distribution used: {demo_params['default_distribution']}")
    
    # Store for later use in comprehensive evaluation
    demo_results_copulagan = {
        'model': copulagan_model,
        'synthetic_data': synthetic_data_copulagan,
        'training_time': train_time,
        'parameters_used': demo_params
    }
    
except ImportError as e:
    print(f"❌ CopulaGAN not available: {e}")
    print(f"   Please ensure CopulaGAN dependencies are installed")
except Exception as e:
    print(f"❌ Error during CopulaGAN demo: {str(e)}")
    print("   Check model implementation and data compatibility")
    import traceback
    traceback.print_exc()
# Out:
# 🔄 CopulaGAN Demo - Default Parameters
# ==================================================
# Training CopulaGAN with demo parameters...
# Generating 912 synthetic samples...
# ✅ CopulaGAN Demo completed successfully!
#    - Training time: 259.00 seconds
#    - Generated samples: 912
#    - Original data shape: (912, 19)
#    - Synthetic data shape: (912, 19)
#    - Distribution used: beta

# %% [markdown]
# #### 3.1.6 TVAE Demo

# %%
# Code Chunk ID: CHUNK_3_1_6_A
try:
    print("🔄 TVAE Demo - Default Parameters")
    print("=" * 50)
    
    # Import and initialize TVAE model using ModelFactory
    from src.models.model_factory import ModelFactory
    
    tvae_model = ModelFactory.create("tvae", random_state=42)
    
    # Define demo parameters optimized for TVAE
    demo_params = {
        'epochs': 50,
        'batch_size': 100,
        'compress_dims': (128, 128),
        'decompress_dims': (128, 128),
        'l2scale': 1e-5,
        'loss_factor': 2,
        'learning_rate': 1e-3  # VAE-specific learning rate
    }
    
    # Train with demo parameters
    print("Training TVAE with demo parameters...")
    start_time = time.time()
    
    # Auto-detect discrete columns for TVAE
    discrete_columns = data.select_dtypes(include=['object']).columns.tolist()
    
    tvae_model.train(data, discrete_columns=discrete_columns, **demo_params)
    train_time = time.time() - start_time
    
    # Generate synthetic data
    demo_samples = len(data)  # Same size as original dataset
    print(f"Generating {demo_samples} synthetic samples...")
    synthetic_data_tvae = tvae_model.generate(demo_samples)
    
    print(f"✅ TVAE Demo completed successfully!")
    print(f"   - Training time: {train_time:.2f} seconds")
    print(f"   - Generated samples: {len(synthetic_data_tvae)}")
    print(f"   - Original data shape: {data.shape}")
    print(f"   - Synthetic data shape: {synthetic_data_tvae.shape}")
    print(f"   - VAE architecture: compress{demo_params['compress_dims']} → decompress{demo_params['decompress_dims']}")
    
    # Store for later use in comprehensive evaluation
    demo_results_tvae = {
        'model': tvae_model,
        'synthetic_data': synthetic_data_tvae,
        'training_time': train_time,
        'parameters_used': demo_params
    }
    
except ImportError as e:
    print(f"❌ TVAE not available: {e}")
    print(f"   Please ensure TVAE dependencies are installed")
except Exception as e:
    print(f"❌ Error during TVAE demo: {str(e)}")
    print("   Check model implementation and data compatibility")
    import traceback
    traceback.print_exc()
# Out:
# 🔄 TVAE Demo - Default Parameters
# ==================================================
# Training TVAE with demo parameters...
# Generating 912 synthetic samples...
# ✅ TVAE Demo completed successfully!
#    - Training time: 52.16 seconds
#    - Generated samples: 912
#    - Original data shape: (912, 19)
#    - Synthetic data shape: (912, 19)
#    - VAE architecture: compress(128, 128) → decompress(128, 128)

# %% [markdown]
# ### 3.2 Batch Process

# %% [markdown]
# This section outputs figures and graphics from models run in 3.1. The next chunk will output results for whatever subsections of 3.1 were run. I.e., if there's need to debug one method, there's no need to run all subsections of 3.1.

# %%
# Code Chunk ID: CHUNK_3_2_0_A
# ============================================================================
# SECTION 3 - BATCH EVALUATION FOR ALL TRAINED MODELS
# Standardized evaluation using enhanced batch evaluation system
# ============================================================================

print("🔍 SECTION 3 - COMPREHENSIVE BATCH EVALUATION")
print("=" * 60)

section3_results = evaluate_all_available_models(
    section_number=3,
    scope=globals(),  # Pass notebook scope to access synthetic data variables
    models_to_evaluate=None,  # Evaluate all available models
    real_data=None,  # Will use 'data' from scope
    target_col=None   # Will use 'target_column' from scope
)

if section3_results:
    print(f"\n🎉 SECTION 3 BATCH EVALUATION COMPLETED!")
    print(f"📊 Evaluated {len(section3_results)} models successfully")
    print(f"📁 All results saved to organized folder structure")
    
    # Show quick summary of best performing models
    best_models = []
    for model_name, results in section3_results.items():
        if 'error' not in results:
            quality_score = results.get('overall_quality_score', 0)
            best_models.append((model_name, quality_score))
    
    if best_models:
        best_models.sort(key=lambda x: x[1], reverse=True)
        print(f"\n🏆 RANKING BY QUALITY SCORE:")
        for i, (model, score) in enumerate(best_models, 1):
            print(f"   {i}. {model}: {score:.3f}")
else:
    print("\n⚠️ No models available for evaluation")
    print("   Train some models first in previous sections")
# Out:
# 🔍 SECTION 3 - COMPREHENSIVE BATCH EVALUATION
# ============================================================
# [SEARCH] UNIFIED BATCH EVALUATION - SECTION 3
# ============================================================
# [INFO] Dataset: pakistani-diabetes-dataset
# [INFO] Target column: Outcome
# [INFO] Variable pattern: standard
# [INFO] Found 3 trained models:
#    [OK] CTGAN
#    [OK] CopulaGAN
#    [OK] TVAE
#
# ==================== EVALUATING CTGAN ====================
# [SEARCH] CTGAN - COMPREHENSIVE DATA QUALITY EVALUATION
# ============================================================
# [FOLDER] Output directory: results/pakistani-diabetes-dataset/2025-11-05/Section-3/CTGAN
#
# [1] STATISTICAL SIMILARITY
# ------------------------------
#    [CHART] Average Statistical Similarity: 0.771
#
# [2] PCA COMPARISON ANALYSIS WITH OUTCOME COLOR-CODING
# --------------------------------------------------
#    [CHART] PCA comparison plot saved: pca_comparison_with_outcome.png
#    [CHART] PCA Overall Similarity: 0.055
#    [CHART] Explained Variance (PC1, PC2): 0.303, 0.085
#
# [3] DISTRIBUTION SIMILARITY
# ------------------------------
#    [CHART] Average Distribution Similarity: 0.832
#
# [4] CORRELATION STRUCTURE
# ------------------------------
#    [CHART] Correlation Structure Preservation: 0.642
#
# [5] MACHINE LEARNING UTILITY
# ------------------------------
#    [CHART] ML Utility (Cross-Accuracy): 0.600
#    [CHART] Real->Synth Accuracy: 0.482
#    [CHART] Synth->Real Accuracy: 0.717
#
# ============================================================
# [BEST] CTGAN OVERALL QUALITY SCORE: 0.580
# [INFO] Quality Assessment: FAIR
# ============================================================
#
# [FOLDER] Generated 5 output files:
#    - statistical_similarity.csv
#    - pca_comparison_with_outcome.png
#    - distribution_comparison.png
#    - correlation_comparison.png
#    - evaluation_summary.csv
# [OK] CTGAN evaluation completed successfully!
#
# ==================== EVALUATING CopulaGAN ====================
# [SEARCH] COPULAGAN - COMPREHENSIVE DATA QUALITY EVALUATION
# ============================================================
# [FOLDER] Output directory: results/pakistani-diabetes-dataset/2025-11-05/Section-3/COPULAGAN
#
# [1] STATISTICAL SIMILARITY
# ------------------------------
#    [CHART] Average Statistical Similarity: 0.853
#
# [2] PCA COMPARISON ANALYSIS WITH OUTCOME COLOR-CODING
# --------------------------------------------------
#    [CHART] PCA comparison plot saved: pca_comparison_with_outcome.png
#    [CHART] PCA Overall Similarity: 0.015
#    [CHART] Explained Variance (PC1, PC2): 0.303, 0.085
#
# [3] DISTRIBUTION SIMILARITY
# ------------------------------
#    [CHART] Average Distribution Similarity: 0.879
#
# [4] CORRELATION STRUCTURE
# ------------------------------
#    [CHART] Correlation Structure Preservation: 0.945
#
# [5] MACHINE LEARNING UTILITY
# ------------------------------
#    [CHART] ML Utility (Cross-Accuracy): 0.944
#    [CHART] Real->Synth Accuracy: 0.900
#    [CHART] Synth->Real Accuracy: 0.987
#
# ============================================================
# [BEST] COPULAGAN OVERALL QUALITY SCORE: 0.727
# [INFO] Quality Assessment: GOOD
# ============================================================
#
# [FOLDER] Generated 5 output files:
#    - statistical_similarity.csv
#    - pca_comparison_with_outcome.png
#    - distribution_comparison.png
#    - correlation_comparison.png
#    - evaluation_summary.csv
# [OK] CopulaGAN evaluation completed successfully!
#
# ==================== EVALUATING TVAE ====================
# [SEARCH] TVAE - COMPREHENSIVE DATA QUALITY EVALUATION
# ============================================================
# [FOLDER] Output directory: results/pakistani-diabetes-dataset/2025-11-05/Section-3/TVAE
#
# [1] STATISTICAL SIMILARITY
# ------------------------------
#    [CHART] Average Statistical Similarity: 0.490
#
# [2] PCA COMPARISON ANALYSIS WITH OUTCOME COLOR-CODING
# --------------------------------------------------
#    [CHART] PCA comparison plot saved: pca_comparison_with_outcome.png
#    [CHART] PCA Overall Similarity: 0.011
#    [CHART] Explained Variance (PC1, PC2): 0.303, 0.085
#
# [3] DISTRIBUTION SIMILARITY
# ------------------------------
#    [CHART] Average Distribution Similarity: 0.691
#
# [4] CORRELATION STRUCTURE
# ------------------------------
#    [CHART] Correlation Structure Preservation: 0.000
#
# [5] MACHINE LEARNING UTILITY
# ------------------------------
#    [CHART] ML Utility (Cross-Accuracy): 0.708
#    [CHART] Real->Synth Accuracy: 0.534
#    [CHART] Synth->Real Accuracy: 0.883
#
# ============================================================
# [BEST] TVAE OVERALL QUALITY SCORE: 0.380
# [INFO] Quality Assessment: POOR
# ============================================================
#
# [FOLDER] Generated 5 output files:
#    - statistical_similarity.csv
#    - pca_comparison_with_outcome.png
#    - distribution_comparison.png
#    - correlation_comparison.png
#    - evaluation_summary.csv
# [OK] TVAE evaluation completed successfully!
#
# ========================= EVALUATION SUMMARY =========================
# Model           Quality Score   Assessment   Files
# -----------------------------------------------------------------
# CTGAN           0.580           FAIR         5
# CopulaGAN       0.727           GOOD         5
# TVAE            0.380           POOR         5
#
# [CHART] Batch summary saved to: results/pakistani-diabetes-dataset/2025-11-05/Section-3/batch_evaluation_summary.csv
#
# ========================= COMPREHENSIVE TRTS ANALYSIS =========================
#
# [ANALYSIS] Running TRTS analysis for CTGAN...
# [ANALYSIS] COMPREHENSIVE TRTS FRAMEWORK ANALYSIS
# ============================================================
# [CHART] Data shapes:
#    - Real: (912, 18), Target unique values: 2
#    - Synthetic: (912, 18), Target unique values: 2
#    - Using 18 common features
#
# [PROCESS] 1. TRTR - Train Real, Test Real (Baseline)
#    [OK] TRTR Accuracy: 1.0000 (Time: 0.154s)
# [PROCESS] 2. TRTS - Train Real, Test Synthetic
#    [OK] TRTS Accuracy: 0.4317 (Time: 0.152s)
# [PROCESS] 3. TSTR - Train Synthetic, Test Real
#    [OK] TSTR Accuracy: 0.7213 (Time: 0.218s)
# [PROCESS] 4. TSTS - Train Synthetic, Test Synthetic
#    [OK] TSTS Accuracy: 0.5847 (Time: 0.196s)
#
# [CHART] Summary Statistics:
#    - Successful scenarios: 4/4
#    - Average accuracy: 0.6844 (+/-0.2090)
#    - Total training time: 0.720s
#
# [ANALYSIS] Running TRTS analysis for CopulaGAN...
# [ANALYSIS] COMPREHENSIVE TRTS FRAMEWORK ANALYSIS
# ============================================================
# [CHART] Data shapes:
#    - Real: (912, 18), Target unique values: 2
#    - Synthetic: (912, 18), Target unique values: 2
#    - Using 18 common features
#
# [PROCESS] 1. TRTR - Train Real, Test Real (Baseline)
#    [OK] TRTR Accuracy: 1.0000 (Time: 0.149s)
# [PROCESS] 2. TRTS - Train Real, Test Synthetic
#    [OK] TRTS Accuracy: 0.8689 (Time: 0.141s)
# [PROCESS] 3. TSTR - Train Synthetic, Test Real
#    [OK] TSTR Accuracy: 1.0000 (Time: 0.177s)
# [PROCESS] 4. TSTS - Train Synthetic, Test Synthetic
#    [OK] TSTS Accuracy: 0.9290 (Time: 0.179s)
#
# [CHART] Summary Statistics:
#    - Successful scenarios: 4/4
#    - Average accuracy: 0.9495 (+/-0.0548)
#    - Total training time: 0.646s
#
# [ANALYSIS] Running TRTS analysis for TVAE...
# [ANALYSIS] COMPREHENSIVE TRTS FRAMEWORK ANALYSIS
# ============================================================
# [CHART] Data shapes:
#    - Real: (912, 18), Target unique values: 2
#    - Synthetic: (912, 18), Target unique values: 2
#    - Using 18 common features
#
# [PROCESS] 1. TRTR - Train Real, Test Real (Baseline)
#    [OK] TRTR Accuracy: 1.0000 (Time: 0.141s)
# [PROCESS] 2. TRTS - Train Real, Test Synthetic
#    [OK] TRTS Accuracy: 0.5246 (Time: 0.147s)
# [PROCESS] 3. TSTR - Train Synthetic, Test Real
#    [OK] TSTR Accuracy: 0.8907 (Time: 0.168s)
# [PROCESS] 4. TSTS - Train Synthetic, Test Synthetic
#    [OK] TSTS Accuracy: 0.9508 (Time: 0.166s)
#
# [CHART] Summary Statistics:
#    - Successful scenarios: 4/4
#    - Average accuracy: 0.8415 (+/-0.1870)
#    - Total training time: 0.621s
#
# [CHART] Creating TRTS visualizations...
# [CHART] TRTS comprehensive plot saved: results/pakistani-diabetes-dataset/2025-11-05/Section-3/trts_comprehensive_analysis.png
# [FOLDER] TRTS tables saved: 3 files
# [OK] TRTS visualization files generated:
#    [FOLDER] trts_comprehensive_analysis.png
#    [FOLDER] trts_summary_metrics.csv
#    [FOLDER] trts_detailed_results.csv
#
# [STATS] TRTS Analysis Summary:
#    - Models analyzed: 3
#    - Average combined score: 0.8251
#    - Best performing model: CopulaGAN
#    - Total scenarios tested: 12
#
# 🎉 SECTION 3 BATCH EVALUATION COMPLETED!
# 📊 Evaluated 3 models successfully
# 📁 All results saved to organized folder structure
#
# 🏆 RANKING BY QUALITY SCORE:
#    1. CopulaGAN: 0.727
#    2. CTGAN: 0.580
#    3. TVAE: 0.380

# %% [markdown]
# ## 4: Hyperparameter Tuning for Each Model

# %% [markdown]
# ### 4.1 Hyperparameter Optimization

# %% [markdown]
# #### 4.1.1 CTGAN Hyperparameter Optimization

# %%
# Code Chunk ID: CHUNK_4_1_1_A
# CTGAN Hyperparameter Optimization Execution
# Complete optimization study with search space definition and execution

# Import required libraries
import optuna
import numpy as np
import pandas as pd
from scipy.stats import wasserstein_distance  # FIXED: Add missing wasserstein_distance import

def ctgan_search_space(trial):
    """Define CTGAN hyperparameter search space with corrected PAC validation."""
    # Select batch size first
    batch_size = trial.suggest_categorical('batch_size', [32, 64, 128, 256, 500, 1000])
    
    # PAC must be <= batch_size and batch_size must be divisible by PAC
    max_pac = min(20, batch_size)
    pac = trial.suggest_int('pac', 1, max_pac)
    
    return {
        'epochs': trial.suggest_int('epochs', 100, 1000, step=50),
        'batch_size': batch_size,
        'generator_lr': trial.suggest_loguniform('generator_lr', 5e-6, 5e-3),
        'discriminator_lr': trial.suggest_loguniform('discriminator_lr', 5e-6, 5e-3),
        'generator_dim': trial.suggest_categorical('generator_dim', [
            (128, 128),
            (256, 256), 
            (512, 256),
            (256, 512),
            (512, 512),
            (128, 256, 128),
            (256, 128, 64),
            (256, 512, 256)
        ]),
        'discriminator_dim': trial.suggest_categorical('discriminator_dim', [
            (128, 128),
            (256, 256),
            (256, 512), 
            (512, 256),
            (128, 256, 128),
            (256, 512, 256)
        ]),
        'pac': pac,
        'discriminator_steps': trial.suggest_int('discriminator_steps', 1, 5),
        'generator_decay': trial.suggest_loguniform('generator_decay', 1e-8, 1e-4),
        'discriminator_decay': trial.suggest_loguniform('discriminator_decay', 1e-8, 1e-4),
        'log_frequency': trial.suggest_categorical('log_frequency', [True, False]),
        'verbose': trial.suggest_categorical('verbose', [True])
    }

def ctgan_objective(trial):
    """CTGAN objective function with corrected PAC validation and fixed imports."""
    try:
        # Get hyperparameters from trial
        params = ctgan_search_space(trial)
        
        # CORRECTED PAC VALIDATION: Fix incompatible combinations if needed
        batch_size = params['batch_size']
        original_pac = params['pac']
        
        # Find the largest compatible PAC value <= original_pac
        compatible_pac = original_pac
        while compatible_pac > 1 and batch_size % compatible_pac != 0:
            compatible_pac -= 1
        
        # Update PAC to be compatible
        if compatible_pac != original_pac:
            print(f"🔧 PAC adjusted: {original_pac} → {compatible_pac} (for batch_size={batch_size})")
            params['pac'] = compatible_pac
        
        print(f"\n🔄 CTGAN Trial {trial.number + 1}: epochs={params['epochs']}, batch_size={params['batch_size']}, pac={params['pac']}, lr={params['generator_lr']:.2e}")
        print(f"✅ PAC validation: {params['batch_size']} % {params['pac']} = {params['batch_size'] % params['pac']}")
        
        # FIXED: Use proper TARGET_COLUMN from global scope
        global TARGET_COLUMN
        if 'TARGET_COLUMN' not in globals() or TARGET_COLUMN is None:
            TARGET_COLUMN = data.columns[-1]  # Use last column as fallback
        print(f"🎯 Using target column: '{TARGET_COLUMN}'")
        
        # FIXED: Use correct CTGAN import - try multiple import paths
        try:
            from ctgan import CTGAN
            print("✅ Using CTGAN from ctgan package")
        except ImportError:
            try:
                from sdv.single_table import CTGANSynthesizer
                CTGAN = CTGANSynthesizer
                print("✅ Using CTGANSynthesizer from sdv.single_table")
            except ImportError:
                try:
                    from sdv.tabular import CTGAN
                    print("✅ Using CTGAN from sdv.tabular")
                except ImportError:
                    raise ImportError("❌ Could not import CTGAN from any known package")
        
        # Auto-detect discrete columns  
        if 'data' not in globals():
            raise ValueError("Data not available in global scope")
            
        discrete_columns = data.select_dtypes(include=['object']).columns.tolist()
        
        # FIXED: Initialize CTGAN using flexible approach
        try:
            # Try direct CTGAN initialization
            model = CTGAN(
                epochs=params['epochs'],
                batch_size=params['batch_size'],
                generator_lr=params['generator_lr'],
                discriminator_lr=params['discriminator_lr'],
                generator_dim=params['generator_dim'],
                discriminator_dim=params['discriminator_dim'],
                pac=params['pac'],
                discriminator_steps=params['discriminator_steps'],
                generator_decay=params['generator_decay'],
                discriminator_decay=params['discriminator_decay'],
                log_frequency=params['log_frequency'],
                verbose=params['verbose']
            )
        except TypeError as te:
            # Fallback: Use basic parameters only
            print(f"⚠️ Full parameter initialization failed, using basic parameters: {te}")
            model = CTGAN(
                epochs=params['epochs'],
                batch_size=params['batch_size'],
                pac=params['pac'],
                verbose=params['verbose']
            )
        
        # Train the model
        model.fit(data)
        
        # Generate synthetic data
        synthetic_data = model.sample(len(data))
        
        # Use enhanced objective function with proper target column passing
        score, similarity_score, accuracy_score = enhanced_objective_function_v2(
            data, synthetic_data, TARGET_COLUMN
        )
        
        print(f"✅ CTGAN Trial {trial.number + 1} Score: {score:.4f} (Similarity: {similarity_score:.4f}, Accuracy: {accuracy_score:.4f})")
        
        return score
        
    except Exception as e:
        print(f"❌ CTGAN trial {trial.number + 1} failed: {str(e)}")
        print(f"🔍 Error details: {type(e).__name__}(\"{str(e)}\")") 
        import traceback
        traceback.print_exc()
        return 0.0

print("🎯 Starting CTGAN Hyperparameter Optimization - FIXED IMPORT")
print(f"   • Target column: '{TARGET_COLUMN}' (dynamic detection)")

# Create the optimization study
ctgan_study = optuna.create_study(
    direction='maximize',
    pruner=optuna.pruners.MedianPruner(n_startup_trials=5, n_warmup_steps=2)
)

# Run the optimization
try:
    # Ensure we have the required global variables
    if 'data' not in globals():
        raise ValueError("❌ Data not available - please run data loading sections first")
        
    if 'TARGET_COLUMN' not in globals():
        TARGET_COLUMN = data.columns[-1]  # Use last column as fallback
        print(f"⚠️  TARGET_COLUMN not set, using fallback: '{TARGET_COLUMN}'")
    
    print(f"📊 Dataset info: {data.shape[0]} rows, {data.shape[1]} columns")
    print(f"📊 Target column '{TARGET_COLUMN}' unique values: {data[TARGET_COLUMN].nunique()}")
    print()
    
    # Run the optimization trials
    ctgan_study.optimize(ctgan_objective, n_trials=50)  
    
    # Display results
    print(f"\n📊 CTGAN hyperparameter optimization with corrected PAC compatibility completed!")
    print("🎯 No more dynamic parameter name issues - simplified and robust approach")
    
    # Best trial information
    best_trial = ctgan_study.best_trial
    print(f"\n🏆 Best Trial Results:")
    print(f"   • Best Score: {best_trial.value:.4f}")
    print(f"   • Trial Number: {best_trial.number}")
    print(f"   • Best Parameters:")
    for key, value in best_trial.params.items():
        print(f"     - {key}: {value}")
    
    # Summary statistics
    completed_trials = [t for t in ctgan_study.trials if t.state == optuna.trial.TrialState.COMPLETE]
    failed_trials = [t for t in ctgan_study.trials if t.state == optuna.trial.TrialState.FAIL]
    
    print(f"\n📈 Optimization Summary:")
    print(f"   • Total trials completed: {len(completed_trials)}")
    print(f"   • Failed trials: {len(failed_trials)}")
    if completed_trials:
        scores = [t.value for t in completed_trials]
        print(f"   • Best score: {max(scores):.4f}")
        print(f"   • Mean score: {sum(scores)/len(scores):.4f}")
        print(f"   • Score range: {max(scores) - min(scores):.4f}")
    
    # Store results for Section 4.1.1 analysis
    ctgan_optimization_results = {
        'study': ctgan_study,
        'best_trial': best_trial,
        'completed_trials': completed_trials,
        'failed_trials': failed_trials
    }
    
    print(f"\n✅ CTGAN optimization data ready for Section 4.1.1 analysis")
    
except Exception as e:
    print(f"❌ CTGAN hyperparameter optimization failed: {str(e)}")
    print(f"🔍 Error details: {repr(e)}")
    import traceback
    traceback.print_exc()
    
    # Create dummy results for analysis to continue
    ctgan_study = None
    ctgan_optimization_results = None
    print("⚠️  CTGAN optimization failed - Section 4.1.1 analysis will show 'data not found' message")
# Out:
# [I 2025-11-05 12:09:49,731] A new study created in memory with name: no-name-1cd1cc26-d0d7-41f8-a181-4e58c8f1e5d0
# 🎯 Starting CTGAN Hyperparameter Optimization - FIXED IMPORT
#    • Target column: 'Outcome' (dynamic detection)
# 📊 Dataset info: 912 rows, 19 columns
# 📊 Target column 'Outcome' unique values: 2
#
# 🔧 PAC adjusted: 11 → 8 (for batch_size=256)
#
# 🔄 CTGAN Trial 1: epochs=500, batch_size=256, pac=8, lr=1.22e-04
# ✅ PAC validation: 256 % 8 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# Gen. (-0.52) | Discrim. (-0.26): 100%|██████████| 500/500 [03:20<00:00,  2.50it/s]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6164
# [I 2025-11-05 12:13:17,592] Trial 0 finished with value: 0.7295082246150235 and parameters: {'batch_size': 256, 'pac': 11, 'epochs': 500, 'generator_lr': 0.00012179221654508802, 'discriminator_lr': 0.004498309710053735, 'generator_dim': (128, 128), 'discriminator_dim': (256, 256), 'discriminator_steps': 3, 'generator_decay': 6.976402911096988e-06, 'discriminator_decay': 2.3048940014981224e-07, 'log_frequency': False, 'verbose': True}. Best is trial 0 with value: 0.7295082246150235.
# [OK] TRTS (Synthetic->Real): 0.9781
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.8991
# [CHART] Combined Score: 0.7295 (Similarity: 0.6164, Accuracy: 0.8991)
# ✅ CTGAN Trial 1 Score: 0.7295 (Similarity: 0.6164, Accuracy: 0.8991)
# 🔧 PAC adjusted: 6 → 5 (for batch_size=1000)
#
# 🔄 CTGAN Trial 2: epochs=350, batch_size=1000, pac=5, lr=2.31e-05
# ✅ PAC validation: 1000 % 5 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# Gen. (-0.42) | Discrim. (-0.81): 100%|██████████| 350/350 [00:48<00:00,  7.26it/s]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6463
# [I 2025-11-05 12:14:12,081] Trial 1 finished with value: 0.5577363005668848 and parameters: {'batch_size': 1000, 'pac': 6, 'epochs': 350, 'generator_lr': 2.3078478154139403e-05, 'discriminator_lr': 0.00020067902982014, 'generator_dim': (256, 128, 64), 'discriminator_dim': (512, 256), 'discriminator_steps': 3, 'generator_decay': 4.6136840643183306e-05, 'discriminator_decay': 4.89135601076552e-07, 'log_frequency': False, 'verbose': True}. Best is trial 0 with value: 0.7295082246150235.
# [OK] TRTS (Synthetic->Real): 0.3695
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.4249
# [CHART] Combined Score: 0.5577 (Similarity: 0.6463, Accuracy: 0.4249)
# ✅ CTGAN Trial 2 Score: 0.5577 (Similarity: 0.6463, Accuracy: 0.4249)
# 🔧 PAC adjusted: 3 → 2 (for batch_size=64)
#
# 🔄 CTGAN Trial 3: epochs=850, batch_size=64, pac=2, lr=4.68e-05
# ✅ PAC validation: 64 % 2 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# Gen. (-0.18) | Discrim. (-0.24): 100%|██████████| 850/850 [40:53<00:00,  2.89s/it]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6887
# [I 2025-11-05 12:55:10,898] Trial 2 finished with value: 0.7996477665543316 and parameters: {'batch_size': 64, 'pac': 3, 'epochs': 850, 'generator_lr': 4.681321169887416e-05, 'discriminator_lr': 5.028132155972075e-05, 'generator_dim': (256, 256), 'discriminator_dim': (128, 256, 128), 'discriminator_steps': 5, 'generator_decay': 4.704625892105342e-05, 'discriminator_decay': 1.7128222063402212e-06, 'log_frequency': False, 'verbose': True}. Best is trial 2 with value: 0.7996477665543316.
# [OK] TRTS (Synthetic->Real): 0.9868
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9660
# [CHART] Combined Score: 0.7996 (Similarity: 0.6887, Accuracy: 0.9660)
# ✅ CTGAN Trial 3 Score: 0.7996 (Similarity: 0.6887, Accuracy: 0.9660)
# 🔧 PAC adjusted: 17 → 16 (for batch_size=32)
#
# 🔄 CTGAN Trial 4: epochs=800, batch_size=32, pac=16, lr=1.88e-03
# ✅ PAC validation: 32 % 16 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Gen. (2.73) | Discrim. (-0.95): 100%|██████████| 800/800 [1:03:10<00:00,  4.74s/it]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.4931
# [I 2025-11-05 13:58:35,194] Trial 3 finished with value: 0.5074867666831566 and parameters: {'batch_size': 32, 'pac': 17, 'epochs': 800, 'generator_lr': 0.0018826686650247107, 'discriminator_lr': 0.0012270796898818316, 'generator_dim': (256, 256), 'discriminator_dim': (128, 256, 128), 'discriminator_steps': 4, 'generator_decay': 5.104420904434536e-08, 'discriminator_decay': 2.032908666906233e-07, 'log_frequency': False, 'verbose': True}. Best is trial 2 with value: 0.7996477665543316.
# [OK] TRTS (Synthetic->Real): 0.5197
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.5291
# [CHART] Combined Score: 0.5075 (Similarity: 0.4931, Accuracy: 0.5291)
# ✅ CTGAN Trial 4 Score: 0.5075 (Similarity: 0.4931, Accuracy: 0.5291)
# 🔧 PAC adjusted: 14 → 8 (for batch_size=128)
#
# 🔄 CTGAN Trial 5: epochs=550, batch_size=128, pac=8, lr=1.03e-05
# ✅ PAC validation: 128 % 8 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Gen. (1.10) | Discrim. (0.09): 100%|██████████| 550/550 [06:07<00:00,  1.50it/s]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6516
# [I 2025-11-05 14:04:55,388] Trial 4 finished with value: 0.734173709925469 and parameters: {'batch_size': 128, 'pac': 14, 'epochs': 550, 'generator_lr': 1.0298198566297435e-05, 'discriminator_lr': 0.0042370116130852386, 'generator_dim': (256, 512, 256), 'discriminator_dim': (512, 256), 'discriminator_steps': 2, 'generator_decay': 5.5372323524336035e-05, 'discriminator_decay': 2.4343657877562363e-08, 'log_frequency': False, 'verbose': True}. Best is trial 2 with value: 0.7996477665543316.
# [OK] TRTS (Synthetic->Real): 0.9770
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.8580
# [CHART] Combined Score: 0.7342 (Similarity: 0.6516, Accuracy: 0.8580)
# ✅ CTGAN Trial 5 Score: 0.7342 (Similarity: 0.6516, Accuracy: 0.8580)
# 🔧 PAC adjusted: 3 → 2 (for batch_size=128)
#
# 🔄 CTGAN Trial 6: epochs=100, batch_size=128, pac=2, lr=8.62e-05
# ✅ PAC validation: 128 % 2 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Gen. (0.06) | Discrim. (-0.57): 100%|██████████| 100/100 [01:05<00:00,  1.52it/s]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5183
# [I 2025-11-05 14:06:15,930] Trial 5 finished with value: 0.5254779795316936 and parameters: {'batch_size': 128, 'pac': 3, 'epochs': 100, 'generator_lr': 8.621985401580642e-05, 'discriminator_lr': 0.00012207533342295897, 'generator_dim': (256, 512, 256), 'discriminator_dim': (128, 128), 'discriminator_steps': 2, 'generator_decay': 1.6680201639576552e-06, 'discriminator_decay': 1.6580471520121263e-06, 'log_frequency': True, 'verbose': True}. Best is trial 2 with value: 0.7996477665543316.
# [OK] TRTS (Synthetic->Real): 0.4660
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.5362
# [CHART] Combined Score: 0.5255 (Similarity: 0.5183, Accuracy: 0.5362)
# ✅ CTGAN Trial 6 Score: 0.5255 (Similarity: 0.5183, Accuracy: 0.5362)
# 🔧 PAC adjusted: 11 → 8 (for batch_size=32)
#
# 🔄 CTGAN Trial 7: epochs=850, batch_size=32, pac=8, lr=1.40e-05
# ✅ PAC validation: 32 % 8 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# Gen. (-0.74) | Discrim. (-0.78): 100%|██████████| 850/850 [34:14<00:00,  2.42s/it]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6766
# [I 2025-11-05 14:40:36,707] Trial 6 finished with value: 0.7857691708885977 and parameters: {'batch_size': 32, 'pac': 11, 'epochs': 850, 'generator_lr': 1.3979000915028298e-05, 'discriminator_lr': 0.00030570025210867693, 'generator_dim': (128, 256, 128), 'discriminator_dim': (128, 128), 'discriminator_steps': 2, 'generator_decay': 4.618359211897586e-06, 'discriminator_decay': 3.2241702881708357e-06, 'log_frequency': False, 'verbose': True}. Best is trial 2 with value: 0.7996477665543316.
# [OK] TRTS (Synthetic->Real): 0.9879
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9496
# [CHART] Combined Score: 0.7858 (Similarity: 0.6766, Accuracy: 0.9496)
# ✅ CTGAN Trial 7 Score: 0.7858 (Similarity: 0.6766, Accuracy: 0.9496)
# 🔧 PAC adjusted: 11 → 8 (for batch_size=128)
#
# 🔄 CTGAN Trial 8: epochs=550, batch_size=128, pac=8, lr=1.75e-04
# ✅ PAC validation: 128 % 8 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Gen. (0.21) | Discrim. (-0.27): 100%|██████████| 550/550 [08:39<00:00,  1.06it/s]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6100
# [I 2025-11-05 14:49:30,053] Trial 7 finished with value: 0.7392634136810743 and parameters: {'batch_size': 128, 'pac': 11, 'epochs': 550, 'generator_lr': 0.00017476485789176562, 'discriminator_lr': 0.001479216912823536, 'generator_dim': (512, 256), 'discriminator_dim': (128, 128), 'discriminator_steps': 4, 'generator_decay': 3.078702213799616e-05, 'discriminator_decay': 1.5527960876823337e-08, 'log_frequency': False, 'verbose': True}. Best is trial 2 with value: 0.7996477665543316.
# [OK] TRTS (Synthetic->Real): 0.9879
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9331
# [CHART] Combined Score: 0.7393 (Similarity: 0.6100, Accuracy: 0.9331)
# ✅ CTGAN Trial 8 Score: 0.7393 (Similarity: 0.6100, Accuracy: 0.9331)
# 🔧 PAC adjusted: 18 → 10 (for batch_size=1000)
#
# 🔄 CTGAN Trial 9: epochs=700, batch_size=1000, pac=10, lr=3.37e-04
# ✅ PAC validation: 1000 % 10 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Gen. (-0.07) | Discrim. (-0.46): 100%|██████████| 700/700 [01:47<00:00,  6.48it/s]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6537
# [I 2025-11-05 14:51:32,011] Trial 8 finished with value: 0.769404396346233 and parameters: {'batch_size': 1000, 'pac': 18, 'epochs': 700, 'generator_lr': 0.00033748636140552846, 'discriminator_lr': 0.0003380333385724374, 'generator_dim': (128, 128), 'discriminator_dim': (256, 256), 'discriminator_steps': 4, 'generator_decay': 1.0024879895463955e-08, 'discriminator_decay': 1.4692823570297148e-08, 'log_frequency': False, 'verbose': True}. Best is trial 2 with value: 0.7996477665543316.
# [OK] TRTS (Synthetic->Real): 0.9846
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9430
# [CHART] Combined Score: 0.7694 (Similarity: 0.6537, Accuracy: 0.9430)
# ✅ CTGAN Trial 9 Score: 0.7694 (Similarity: 0.6537, Accuracy: 0.9430)
# 🔧 PAC adjusted: 11 → 8 (for batch_size=256)
#
# 🔄 CTGAN Trial 10: epochs=900, batch_size=256, pac=8, lr=3.81e-03
# ✅ PAC validation: 256 % 8 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# Gen. (1.29) | Discrim. (-0.37): 100%|██████████| 900/900 [02:07<00:00,  7.08it/s]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.7295
# [I 2025-11-05 14:53:44,295] Trial 9 finished with value: 0.8098611344702742 and parameters: {'batch_size': 256, 'pac': 11, 'epochs': 900, 'generator_lr': 0.003814421365652385, 'discriminator_lr': 0.0005719926950337527, 'generator_dim': (128, 128), 'discriminator_dim': (128, 256, 128), 'discriminator_steps': 1, 'generator_decay': 2.1895028077392207e-08, 'discriminator_decay': 3.700450504756251e-06, 'log_frequency': True, 'verbose': True}. Best is trial 9 with value: 0.8098611344702742.
# [OK] TRTS (Synthetic->Real): 0.9879
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9304
# [CHART] Combined Score: 0.8099 (Similarity: 0.7295, Accuracy: 0.9304)
# ✅ CTGAN Trial 10 Score: 0.8099 (Similarity: 0.7295, Accuracy: 0.9304)
# 🔧 PAC adjusted: 6 → 4 (for batch_size=256)
#
# 🔄 CTGAN Trial 11: epochs=950, batch_size=256, pac=4, lr=4.46e-03
# ✅ PAC validation: 256 % 4 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# Gen. (-3.05) | Discrim. (0.05): 100%|██████████| 950/950 [02:27<00:00,  6.43it/s]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.3331
# [I 2025-11-05 14:56:18,528] Trial 10 finished with value: 0.5064114906250151 and parameters: {'batch_size': 256, 'pac': 6, 'epochs': 950, 'generator_lr': 0.004464559433005012, 'discriminator_lr': 9.167052501012498e-06, 'generator_dim': (512, 512), 'discriminator_dim': (256, 512, 256), 'discriminator_steps': 1, 'generator_decay': 2.252451289159519e-07, 'discriminator_decay': 6.439761559622904e-05, 'log_frequency': True, 'verbose': True}. Best is trial 9 with value: 0.8098611344702742.
# [OK] TRTS (Synthetic->Real): 0.5329
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.7664
# [CHART] Combined Score: 0.5064 (Similarity: 0.3331, Accuracy: 0.7664)
# ✅ CTGAN Trial 11 Score: 0.5064 (Similarity: 0.3331, Accuracy: 0.7664)
#
# 🔄 CTGAN Trial 12: epochs=1000, batch_size=64, pac=2, lr=9.37e-04
# ✅ PAC validation: 64 % 2 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# Gen. (-0.83) | Discrim. (-0.48): 100%|██████████| 1000/1000 [39:47<00:00,  2.39s/it]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.4301
# [I 2025-11-05 15:36:11,911] Trial 11 finished with value: 0.5113242984454163 and parameters: {'batch_size': 64, 'pac': 2, 'epochs': 1000, 'generator_lr': 0.0009370845557112859, 'discriminator_lr': 2.860198307002394e-05, 'generator_dim': (256, 512), 'discriminator_dim': (128, 256, 128), 'discriminator_steps': 5, 'generator_decay': 2.8931840804308517e-07, 'discriminator_decay': 1.5046804357779833e-05, 'log_frequency': True, 'verbose': True}. Best is trial 9 with value: 0.8098611344702742.
# [OK] TRTS (Synthetic->Real): 0.5340
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.6332
# [CHART] Combined Score: 0.5113 (Similarity: 0.4301, Accuracy: 0.6332)
# ✅ CTGAN Trial 12 Score: 0.5113 (Similarity: 0.4301, Accuracy: 0.6332)
# 🔧 PAC adjusted: 7 → 4 (for batch_size=64)
#
# 🔄 CTGAN Trial 13: epochs=750, batch_size=64, pac=4, lr=4.39e-05
# ✅ PAC validation: 64 % 4 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Gen. (-0.03) | Discrim. (0.13): 100%|██████████| 750/750 [29:31<00:00,  2.36s/it]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6759
# [I 2025-11-05 16:05:57,172] Trial 12 finished with value: 0.7952444005094914 and parameters: {'batch_size': 64, 'pac': 7, 'epochs': 750, 'generator_lr': 4.3919596558909026e-05, 'discriminator_lr': 4.114310018429319e-05, 'generator_dim': (256, 256), 'discriminator_dim': (128, 256, 128), 'discriminator_steps': 5, 'generator_decay': 1.1549353155245163e-08, 'discriminator_decay': 6.2119834391711995e-06, 'log_frequency': True, 'verbose': True}. Best is trial 9 with value: 0.8098611344702742.
# [OK] TRTS (Synthetic->Real): 0.9890
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9742
# [CHART] Combined Score: 0.7952 (Similarity: 0.6759, Accuracy: 0.9742)
# ✅ CTGAN Trial 13 Score: 0.7952 (Similarity: 0.6759, Accuracy: 0.9742)
# 🔧 PAC adjusted: 14 → 10 (for batch_size=500)
#
# 🔄 CTGAN Trial 14: epochs=900, batch_size=500, pac=10, lr=5.21e-04
# ✅ PAC validation: 500 % 10 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Gen. (-4.15) | Discrim. (-0.01): 100%|██████████| 900/900 [00:46<00:00, 19.54it/s]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.4239
# [I 2025-11-05 16:06:57,235] Trial 13 finished with value: 0.5269169714019195 and parameters: {'batch_size': 500, 'pac': 14, 'epochs': 900, 'generator_lr': 0.0005206062274140494, 'discriminator_lr': 5.440115298506805e-05, 'generator_dim': (256, 256), 'discriminator_dim': (256, 512), 'discriminator_steps': 1, 'generator_decay': 2.6443544242798737e-07, 'discriminator_decay': 1.782866106822777e-05, 'log_frequency': True, 'verbose': True}. Best is trial 9 with value: 0.8098611344702742.
# [OK] TRTS (Synthetic->Real): 0.5362
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.6815
# [CHART] Combined Score: 0.5269 (Similarity: 0.4239, Accuracy: 0.6815)
# ✅ CTGAN Trial 14 Score: 0.5269 (Similarity: 0.4239, Accuracy: 0.6815)
#
# 🔄 CTGAN Trial 15: epochs=700, batch_size=64, pac=8, lr=5.25e-06
# ✅ PAC validation: 64 % 8 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# Gen. (0.83) | Discrim. (-0.17): 100%|██████████| 700/700 [27:28<00:00,  2.36s/it]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6432
# [I 2025-11-05 16:34:31,253] Trial 14 finished with value: 0.6067623905357441 and parameters: {'batch_size': 64, 'pac': 8, 'epochs': 700, 'generator_lr': 5.254613480119194e-06, 'discriminator_lr': 9.79649304665662e-06, 'generator_dim': (128, 128), 'discriminator_dim': (128, 256, 128), 'discriminator_steps': 5, 'generator_decay': 5.8278307371029676e-08, 'discriminator_decay': 9.961500823880515e-07, 'log_frequency': True, 'verbose': True}. Best is trial 9 with value: 0.8098611344702742.
# [OK] TRTS (Synthetic->Real): 0.5680
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.5521
# [CHART] Combined Score: 0.6068 (Similarity: 0.6432, Accuracy: 0.5521)
# ✅ CTGAN Trial 15 Score: 0.6068 (Similarity: 0.6432, Accuracy: 0.5521)
#
# 🔄 CTGAN Trial 16: epochs=1000, batch_size=256, pac=1, lr=4.70e-05
# ✅ PAC validation: 256 % 1 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Gen. (-0.22) | Discrim. (-0.19): 100%|██████████| 1000/1000 [02:22<00:00,  7.04it/s]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.7075
# [I 2025-11-05 16:37:07,500] Trial 15 finished with value: 0.8130814333610048 and parameters: {'batch_size': 256, 'pac': 1, 'epochs': 1000, 'generator_lr': 4.697786974900118e-05, 'discriminator_lr': 0.0006618524188373988, 'generator_dim': (256, 512), 'discriminator_dim': (128, 256, 128), 'discriminator_steps': 1, 'generator_decay': 8.94749186363822e-06, 'discriminator_decay': 1.0400398494672715e-07, 'log_frequency': True, 'verbose': True}. Best is trial 15 with value: 0.8130814333610048.
# [OK] TRTS (Synthetic->Real): 0.9912
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9715
# [CHART] Combined Score: 0.8131 (Similarity: 0.7075, Accuracy: 0.9715)
# ✅ CTGAN Trial 16 Score: 0.8131 (Similarity: 0.7075, Accuracy: 0.9715)
# 🔧 PAC adjusted: 14 → 8 (for batch_size=256)
#
# 🔄 CTGAN Trial 17: epochs=1000, batch_size=256, pac=8, lr=3.45e-03
# ✅ PAC validation: 256 % 8 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# Gen. (0.76) | Discrim. (-0.26): 100%|██████████| 1000/1000 [02:27<00:00,  6.76it/s]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6736
# [I 2025-11-05 16:39:41,768] Trial 16 finished with value: 0.7892366015851581 and parameters: {'batch_size': 256, 'pac': 14, 'epochs': 1000, 'generator_lr': 0.003454018158787485, 'discriminator_lr': 0.0007578887727903101, 'generator_dim': (256, 512), 'discriminator_dim': (256, 512, 256), 'discriminator_steps': 1, 'generator_decay': 1.0563149609442761e-05, 'discriminator_decay': 1.0273406498662568e-07, 'log_frequency': True, 'verbose': True}. Best is trial 15 with value: 0.8130814333610048.
# [OK] TRTS (Synthetic->Real): 0.9901
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9627
# [CHART] Combined Score: 0.7892 (Similarity: 0.6736, Accuracy: 0.9627)
# ✅ CTGAN Trial 17 Score: 0.7892 (Similarity: 0.6736, Accuracy: 0.9627)
#
# 🔄 CTGAN Trial 18: epochs=350, batch_size=256, pac=1, lr=3.15e-04
# ✅ PAC validation: 256 % 1 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# Gen. (-1.02) | Discrim. (0.01): 100%|██████████| 350/350 [00:50<00:00,  6.87it/s]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5279
# [I 2025-11-05 16:40:37,176] Trial 17 finished with value: 0.7070825217014227 and parameters: {'batch_size': 256, 'pac': 1, 'epochs': 350, 'generator_lr': 0.00031541105577173595, 'discriminator_lr': 0.0006047035710745705, 'generator_dim': (256, 512), 'discriminator_dim': (256, 512), 'discriminator_steps': 1, 'generator_decay': 1.610604259044585e-06, 'discriminator_decay': 5.932463051885827e-08, 'log_frequency': True, 'verbose': True}. Best is trial 15 with value: 0.8130814333610048.
# [OK] TRTS (Synthetic->Real): 0.9901
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9759
# [CHART] Combined Score: 0.7071 (Similarity: 0.5279, Accuracy: 0.9759)
# ✅ CTGAN Trial 18 Score: 0.7071 (Similarity: 0.5279, Accuracy: 0.9759)
# 🔧 PAC adjusted: 20 → 16 (for batch_size=256)
#
# 🔄 CTGAN Trial 19: epochs=650, batch_size=256, pac=16, lr=1.10e-03
# ✅ PAC validation: 256 % 16 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# Gen. (2.03) | Discrim. (-1.12): 100%|██████████| 650/650 [02:36<00:00,  4.16it/s]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5753
# [I 2025-11-05 16:43:19,416] Trial 18 finished with value: 0.638174938136078 and parameters: {'batch_size': 256, 'pac': 20, 'epochs': 650, 'generator_lr': 0.001101232383273902, 'discriminator_lr': 0.0023064660248703723, 'generator_dim': (512, 256), 'discriminator_dim': (128, 256, 128), 'discriminator_steps': 2, 'generator_decay': 1.51089416646157e-05, 'discriminator_decay': 4.887161946465684e-07, 'log_frequency': True, 'verbose': True}. Best is trial 15 with value: 0.8130814333610048.
# [OK] TRTS (Synthetic->Real): 0.8827
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.7325
# [CHART] Combined Score: 0.6382 (Similarity: 0.5753, Accuracy: 0.7325)
# ✅ CTGAN Trial 19 Score: 0.6382 (Similarity: 0.5753, Accuracy: 0.7325)
#
# 🔄 CTGAN Trial 20: epochs=900, batch_size=500, pac=5, lr=5.44e-05
# ✅ PAC validation: 500 % 5 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# Gen. (-1.29) | Discrim. (-0.40): 100%|██████████| 900/900 [00:50<00:00, 17.99it/s]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5529
# [I 2025-11-05 16:44:14,618] Trial 19 finished with value: 0.613537594224135 and parameters: {'batch_size': 500, 'pac': 5, 'epochs': 900, 'generator_lr': 5.436943252423703e-05, 'discriminator_lr': 0.00010365622556780123, 'generator_dim': (512, 512), 'discriminator_dim': (128, 256, 128), 'discriminator_steps': 1, 'generator_decay': 3.3773583891677995e-06, 'discriminator_decay': 8.639747653174914e-05, 'log_frequency': True, 'verbose': True}. Best is trial 15 with value: 0.8130814333610048.
# [OK] TRTS (Synthetic->Real): 0.8355
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.7045
# [CHART] Combined Score: 0.6135 (Similarity: 0.5529, Accuracy: 0.7045)
# ✅ CTGAN Trial 20 Score: 0.6135 (Similarity: 0.5529, Accuracy: 0.7045)
# 🔧 PAC adjusted: 9 → 8 (for batch_size=256)
#
# 🔄 CTGAN Trial 21: epochs=400, batch_size=256, pac=8, lr=1.94e-04
# ✅ PAC validation: 256 % 8 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# Gen. (0.31) | Discrim. (0.01): 100%|██████████| 400/400 [01:40<00:00,  3.98it/s]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6069
# [I 2025-11-05 16:46:01,583] Trial 20 finished with value: 0.7424499354117802 and parameters: {'batch_size': 256, 'pac': 9, 'epochs': 400, 'generator_lr': 0.0001936042616853629, 'discriminator_lr': 0.0004986167779097633, 'generator_dim': (256, 128, 64), 'discriminator_dim': (128, 256, 128), 'discriminator_steps': 2, 'generator_decay': 4.334267831018381e-08, 'discriminator_decay': 6.903535427923063e-08, 'log_frequency': True, 'verbose': True}. Best is trial 15 with value: 0.8130814333610048.
# [OK] TRTS (Synthetic->Real): 0.9857
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9457
# [CHART] Combined Score: 0.7424 (Similarity: 0.6069, Accuracy: 0.9457)
# ✅ CTGAN Trial 21 Score: 0.7424 (Similarity: 0.6069, Accuracy: 0.9457)
#
# 🔄 CTGAN Trial 22: epochs=850, batch_size=64, pac=4, lr=4.26e-05
# ✅ PAC validation: 64 % 4 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# Gen. (-0.03) | Discrim. (0.21): 100%|██████████| 850/850 [21:41<00:00,  1.53s/it]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6630
# [I 2025-11-05 17:07:48,057] Trial 21 finished with value: 0.7826972990082762 and parameters: {'batch_size': 64, 'pac': 4, 'epochs': 850, 'generator_lr': 4.25664099863751e-05, 'discriminator_lr': 2.302482217920579e-05, 'generator_dim': (256, 512), 'discriminator_dim': (128, 256, 128), 'discriminator_steps': 3, 'generator_decay': 1.8418853734894437e-05, 'discriminator_decay': 5.259414169772585e-06, 'log_frequency': False, 'verbose': True}. Best is trial 15 with value: 0.8130814333610048.
# [OK] TRTS (Synthetic->Real): 0.9879
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9622
# [CHART] Combined Score: 0.7827 (Similarity: 0.6630, Accuracy: 0.9622)
# ✅ CTGAN Trial 22 Score: 0.7827 (Similarity: 0.6630, Accuracy: 0.9622)
#
# 🔄 CTGAN Trial 23: epochs=1000, batch_size=256, pac=1, lr=2.52e-05
# ✅ PAC validation: 256 % 1 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Gen. (0.32) | Discrim. (-0.18): 100%|██████████| 1000/1000 [02:26<00:00,  6.84it/s]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.7116
# [I 2025-11-05 17:10:27,273] Trial 22 finished with value: 0.8067633500466299 and parameters: {'batch_size': 256, 'pac': 1, 'epochs': 1000, 'generator_lr': 2.5184967554159745e-05, 'discriminator_lr': 0.00020145251313847588, 'generator_dim': (128, 256, 128), 'discriminator_dim': (128, 256, 128), 'discriminator_steps': 1, 'generator_decay': 6.341626946883288e-07, 'discriminator_decay': 1.4760923615680434e-06, 'log_frequency': True, 'verbose': True}. Best is trial 15 with value: 0.8130814333610048.
# [OK] TRTS (Synthetic->Real): 0.9814
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9496
# [CHART] Combined Score: 0.8068 (Similarity: 0.7116, Accuracy: 0.9496)
# ✅ CTGAN Trial 23 Score: 0.8068 (Similarity: 0.7116, Accuracy: 0.9496)
#
# 🔄 CTGAN Trial 24: epochs=1000, batch_size=256, pac=2, lr=1.92e-05
# ✅ PAC validation: 256 % 2 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# Gen. (-0.06) | Discrim. (-0.37): 100%|██████████| 1000/1000 [02:39<00:00,  6.25it/s]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.7277
# [I 2025-11-05 17:13:12,453] Trial 23 finished with value: 0.8083449961121909 and parameters: {'batch_size': 256, 'pac': 2, 'epochs': 1000, 'generator_lr': 1.9173329331708013e-05, 'discriminator_lr': 0.00025662120093976424, 'generator_dim': (128, 256, 128), 'discriminator_dim': (128, 256, 128), 'discriminator_steps': 1, 'generator_decay': 6.948912217104277e-07, 'discriminator_decay': 6.124626017038175e-07, 'log_frequency': True, 'verbose': True}. Best is trial 15 with value: 0.8130814333610048.
# [OK] TRTS (Synthetic->Real): 0.9868
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9293
# [CHART] Combined Score: 0.8083 (Similarity: 0.7277, Accuracy: 0.9293)
# ✅ CTGAN Trial 24 Score: 0.8083 (Similarity: 0.7277, Accuracy: 0.9293)
# 🔧 PAC adjusted: 13 → 8 (for batch_size=256)
#
# 🔄 CTGAN Trial 25: epochs=950, batch_size=256, pac=8, lr=5.58e-06
# ✅ PAC validation: 256 % 8 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# Gen. (-1.53) | Discrim. (-2.35): 100%|██████████| 950/950 [02:17<00:00,  6.92it/s]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6485
# [I 2025-11-05 17:15:34,568] Trial 24 finished with value: 0.6016144179383309 and parameters: {'batch_size': 256, 'pac': 13, 'epochs': 950, 'generator_lr': 5.576178695825472e-06, 'discriminator_lr': 0.0010082209388338848, 'generator_dim': (128, 256, 128), 'discriminator_dim': (128, 256, 128), 'discriminator_steps': 1, 'generator_decay': 1.1801819159558739e-07, 'discriminator_decay': 5.286261127290833e-07, 'log_frequency': True, 'verbose': True}. Best is trial 15 with value: 0.8130814333610048.
# [OK] TRTS (Synthetic->Real): 0.5680
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.5312
# [CHART] Combined Score: 0.6016 (Similarity: 0.6485, Accuracy: 0.5312)
# ✅ CTGAN Trial 25 Score: 0.6016 (Similarity: 0.6485, Accuracy: 0.5312)
# 🔧 PAC adjusted: 9 → 8 (for batch_size=256)
#
# 🔄 CTGAN Trial 26: epochs=100, batch_size=256, pac=8, lr=1.74e-05
# ✅ PAC validation: 256 % 8 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# Gen. (-1.78) | Discrim. (-2.90): 100%|██████████| 100/100 [00:22<00:00,  4.39it/s]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5856
# [I 2025-11-05 17:16:01,966] Trial 25 finished with value: 0.5114179911321242 and parameters: {'batch_size': 256, 'pac': 9, 'epochs': 100, 'generator_lr': 1.7436702720126125e-05, 'discriminator_lr': 0.0019306694381839898, 'generator_dim': (128, 128), 'discriminator_dim': (512, 256), 'discriminator_steps': 2, 'generator_decay': 6.917720216777551e-07, 'discriminator_decay': 2.805479910680929e-07, 'log_frequency': True, 'verbose': True}. Best is trial 15 with value: 0.8130814333610048.
# [OK] TRTS (Synthetic->Real): 0.3158
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.4002
# [CHART] Combined Score: 0.5114 (Similarity: 0.5856, Accuracy: 0.4002)
# ✅ CTGAN Trial 26 Score: 0.5114 (Similarity: 0.5856, Accuracy: 0.4002)
#
# 🔄 CTGAN Trial 27: epochs=800, batch_size=256, pac=4, lr=8.16e-05
# ✅ PAC validation: 256 % 4 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# Gen. (-0.93) | Discrim. (-0.09): 100%|██████████| 800/800 [02:05<00:00,  6.40it/s]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6481
# [I 2025-11-05 17:18:10,956] Trial 26 finished with value: 0.7774354978316855 and parameters: {'batch_size': 256, 'pac': 4, 'epochs': 800, 'generator_lr': 8.160763749822944e-05, 'discriminator_lr': 0.0003845771181947399, 'generator_dim': (128, 256, 128), 'discriminator_dim': (256, 512, 256), 'discriminator_steps': 1, 'generator_decay': 2.82315645349149e-08, 'discriminator_decay': 3.9858711522565466e-08, 'log_frequency': True, 'verbose': True}. Best is trial 15 with value: 0.8130814333610048.
# [OK] TRTS (Synthetic->Real): 0.9879
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9715
# [CHART] Combined Score: 0.7774 (Similarity: 0.6481, Accuracy: 0.9715)
# ✅ CTGAN Trial 27 Score: 0.7774 (Similarity: 0.6481, Accuracy: 0.9715)
#
# 🔄 CTGAN Trial 28: epochs=950, batch_size=256, pac=1, lr=1.05e-05
# ✅ PAC validation: 256 % 1 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# Gen. (0.38) | Discrim. (-0.49): 100%|██████████| 950/950 [03:47<00:00,  4.18it/s]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.7277
# [I 2025-11-05 17:22:04,572] Trial 27 finished with value: 0.7855382188039168 and parameters: {'batch_size': 256, 'pac': 1, 'epochs': 950, 'generator_lr': 1.0544594448482298e-05, 'discriminator_lr': 8.735917654851283e-05, 'generator_dim': (256, 512), 'discriminator_dim': (256, 256), 'discriminator_steps': 2, 'generator_decay': 2.9786553375283174e-06, 'discriminator_decay': 1.4577137961625351e-07, 'log_frequency': True, 'verbose': True}. Best is trial 15 with value: 0.8130814333610048.
# [OK] TRTS (Synthetic->Real): 0.9770
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.8723
# [CHART] Combined Score: 0.7855 (Similarity: 0.7277, Accuracy: 0.8723)
# ✅ CTGAN Trial 28 Score: 0.7855 (Similarity: 0.7277, Accuracy: 0.8723)
# 🔧 PAC adjusted: 9 → 8 (for batch_size=32)
#
# 🔄 CTGAN Trial 29: epochs=200, batch_size=32, pac=8, lr=3.17e-05
# ✅ PAC validation: 32 % 8 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# Gen. (0.07) | Discrim. (-1.34): 100%|██████████| 200/200 [04:32<00:00,  1.36s/it]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6189
# [I 2025-11-05 17:26:42,619] Trial 28 finished with value: 0.7195953118506696 and parameters: {'batch_size': 32, 'pac': 9, 'epochs': 200, 'generator_lr': 3.171573666823995e-05, 'discriminator_lr': 0.0002004136692446721, 'generator_dim': (128, 256, 128), 'discriminator_dim': (256, 512), 'discriminator_steps': 1, 'generator_decay': 8.43160182238081e-05, 'discriminator_decay': 1.2248157767238732e-05, 'log_frequency': True, 'verbose': True}. Best is trial 15 with value: 0.8130814333610048.
# [OK] TRTS (Synthetic->Real): 0.9616
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.8706
# [CHART] Combined Score: 0.7196 (Similarity: 0.6189, Accuracy: 0.8706)
# ✅ CTGAN Trial 29 Score: 0.7196 (Similarity: 0.6189, Accuracy: 0.8706)
# 🔧 PAC adjusted: 3 → 2 (for batch_size=256)
#
# 🔄 CTGAN Trial 30: epochs=900, batch_size=256, pac=2, lr=1.12e-04
# ✅ PAC validation: 256 % 2 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# Gen. (-2.42) | Discrim. (-0.25): 100%|██████████| 900/900 [04:35<00:00,  3.26it/s]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.7336
# [I 2025-11-05 17:31:24,702] Trial 29 finished with value: 0.8265357469259473 and parameters: {'batch_size': 256, 'pac': 3, 'epochs': 900, 'generator_lr': 0.0001122781349121671, 'discriminator_lr': 0.0034877862570778834, 'generator_dim': (128, 128), 'discriminator_dim': (256, 256), 'discriminator_steps': 3, 'generator_decay': 1.3503519201309317e-07, 'discriminator_decay': 9.441848644161499e-07, 'log_frequency': True, 'verbose': True}. Best is trial 29 with value: 0.8265357469259473.
# [OK] TRTS (Synthetic->Real): 0.9890
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9660
# [CHART] Combined Score: 0.8265 (Similarity: 0.7336, Accuracy: 0.9660)
# ✅ CTGAN Trial 30 Score: 0.8265 (Similarity: 0.7336, Accuracy: 0.9660)
# 🔧 PAC adjusted: 12 → 10 (for batch_size=1000)
#
# 🔄 CTGAN Trial 31: epochs=650, batch_size=1000, pac=10, lr=1.18e-04
# ✅ PAC validation: 1000 % 10 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# Gen. (-0.23) | Discrim. (-0.40): 100%|██████████| 650/650 [01:12<00:00,  9.00it/s]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6368
# [I 2025-11-05 17:32:43,137] Trial 30 finished with value: 0.7471861392747752 and parameters: {'batch_size': 1000, 'pac': 12, 'epochs': 650, 'generator_lr': 0.0001177119053599501, 'discriminator_lr': 0.00331923830684646, 'generator_dim': (128, 128), 'discriminator_dim': (256, 256), 'discriminator_steps': 3, 'generator_decay': 2.0331152418334386e-08, 'discriminator_decay': 3.0302871506791056e-05, 'log_frequency': True, 'verbose': True}. Best is trial 29 with value: 0.8265357469259473.
# [OK] TRTS (Synthetic->Real): 0.9792
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9128
# [CHART] Combined Score: 0.7472 (Similarity: 0.6368, Accuracy: 0.9128)
# ✅ CTGAN Trial 31 Score: 0.7472 (Similarity: 0.6368, Accuracy: 0.9128)
# 🔧 PAC adjusted: 3 → 2 (for batch_size=256)
#
# 🔄 CTGAN Trial 32: epochs=900, batch_size=256, pac=2, lr=7.26e-05
# ✅ PAC validation: 256 % 2 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# Gen. (-0.56) | Discrim. (-0.15): 100%|██████████| 900/900 [02:24<00:00,  6.22it/s]
# ...
# ✅ CTGAN Trial 39 Score: 0.8358 (Similarity: 0.7487, Accuracy: 0.9666)
# 🔧 PAC adjusted: 3 → 2 (for batch_size=1000)
#
# 🔄 CTGAN Trial 40: epochs=600, batch_size=1000, pac=2, lr=2.21e-03
# ✅ PAC validation: 1000 % 2 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# Gen. (-1.48) | Discrim. (-0.23): 100%|██████████| 600/600 [01:19<00:00,  7.58it/s]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.7030
# [I 2025-11-05 18:00:14,147] Trial 39 finished with value: 0.8060377245356958 and parameters: {'batch_size': 1000, 'pac': 3, 'epochs': 600, 'generator_lr': 0.002205121720160228, 'discriminator_lr': 0.0033391431449241536, 'generator_dim': (256, 512, 256), 'discriminator_dim': (256, 256), 'discriminator_steps': 3, 'generator_decay': 4.316316160871485e-07, 'discriminator_decay': 3.826497209651359e-05, 'log_frequency': False, 'verbose': True}. Best is trial 38 with value: 0.8358345407781438.
# [OK] TRTS (Synthetic->Real): 0.9857
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9605
# [CHART] Combined Score: 0.8060 (Similarity: 0.7030, Accuracy: 0.9605)
# ✅ CTGAN Trial 40 Score: 0.8060 (Similarity: 0.7030, Accuracy: 0.9605)
#
# 🔄 CTGAN Trial 41: epochs=750, batch_size=1000, pac=4, lr=1.84e-04
# ✅ PAC validation: 1000 % 4 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# Gen. (-0.52) | Discrim. (-0.16): 100%|██████████| 750/750 [01:30<00:00,  8.25it/s]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6422
# [I 2025-11-05 18:01:53,468] Trial 40 finished with value: 0.7723535248272477 and parameters: {'batch_size': 1000, 'pac': 4, 'epochs': 750, 'generator_lr': 0.0001843184907251991, 'discriminator_lr': 0.002612295034357277, 'generator_dim': (256, 512, 256), 'discriminator_dim': (256, 256), 'discriminator_steps': 3, 'generator_decay': 1.682304740329382e-07, 'discriminator_decay': 1.0120118949731151e-05, 'log_frequency': False, 'verbose': True}. Best is trial 38 with value: 0.8358345407781438.
# [OK] TRTS (Synthetic->Real): 0.9912
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9677
# [CHART] Combined Score: 0.7724 (Similarity: 0.6422, Accuracy: 0.9677)
# ✅ CTGAN Trial 41 Score: 0.7724 (Similarity: 0.6422, Accuracy: 0.9677)
#
# 🔄 CTGAN Trial 42: epochs=850, batch_size=1000, pac=2, lr=6.00e-05
# ✅ PAC validation: 1000 % 2 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# Gen. (-1.01) | Discrim. (-0.38): 100%|██████████| 850/850 [01:15<00:00, 11.20it/s]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.7025
# [I 2025-11-05 18:03:15,013] Trial 41 finished with value: 0.8100678155454031 and parameters: {'batch_size': 1000, 'pac': 2, 'epochs': 850, 'generator_lr': 5.997285509932557e-05, 'discriminator_lr': 0.001632693149912275, 'generator_dim': (256, 512, 256), 'discriminator_dim': (256, 256), 'discriminator_steps': 2, 'generator_decay': 1.759579632087466e-06, 'discriminator_decay': 2.473405333210028e-05, 'log_frequency': False, 'verbose': True}. Best is trial 38 with value: 0.8358345407781438.
# [OK] TRTS (Synthetic->Real): 0.9879
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9715
# [CHART] Combined Score: 0.8101 (Similarity: 0.7025, Accuracy: 0.9715)
# ✅ CTGAN Trial 42 Score: 0.8101 (Similarity: 0.7025, Accuracy: 0.9715)
#
# 🔄 CTGAN Trial 43: epochs=800, batch_size=1000, pac=2, lr=2.98e-05
# ✅ PAC validation: 1000 % 2 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# Gen. (-1.38) | Discrim. (-0.40): 100%|██████████| 800/800 [01:36<00:00,  8.28it/s]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.7426
# [I 2025-11-05 18:04:57,429] Trial 42 finished with value: 0.8266862363119565 and parameters: {'batch_size': 1000, 'pac': 2, 'epochs': 800, 'generator_lr': 2.981622724191662e-05, 'discriminator_lr': 0.003768066705066273, 'generator_dim': (256, 512, 256), 'discriminator_dim': (256, 256), 'discriminator_steps': 3, 'generator_decay': 3.5959190982072913e-07, 'discriminator_decay': 4.9036231540721786e-05, 'log_frequency': False, 'verbose': True}. Best is trial 38 with value: 0.8358345407781438.
# [OK] TRTS (Synthetic->Real): 0.9901
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9529
# [CHART] Combined Score: 0.8267 (Similarity: 0.7426, Accuracy: 0.9529)
# ✅ CTGAN Trial 43 Score: 0.8267 (Similarity: 0.7426, Accuracy: 0.9529)
# 🔧 PAC adjusted: 6 → 5 (for batch_size=1000)
#
# 🔄 CTGAN Trial 44: epochs=800, batch_size=1000, pac=5, lr=3.39e-05
# ✅ PAC validation: 1000 % 5 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# Gen. (-0.41) | Discrim. (-0.38): 100%|██████████| 800/800 [01:59<00:00,  6.67it/s]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6727
# [I 2025-11-05 18:07:04,350] Trial 43 finished with value: 0.7784273194424375 and parameters: {'batch_size': 1000, 'pac': 6, 'epochs': 800, 'generator_lr': 3.391455020389684e-05, 'discriminator_lr': 0.004834225026536536, 'generator_dim': (256, 512, 256), 'discriminator_dim': (256, 256), 'discriminator_steps': 4, 'generator_decay': 3.7489689216668126e-07, 'discriminator_decay': 5.2350470361213945e-05, 'log_frequency': False, 'verbose': True}. Best is trial 38 with value: 0.8358345407781438.
# [OK] TRTS (Synthetic->Real): 0.9923
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9370
# [CHART] Combined Score: 0.7784 (Similarity: 0.6727, Accuracy: 0.9370)
# ✅ CTGAN Trial 44 Score: 0.7784 (Similarity: 0.6727, Accuracy: 0.9370)
# 🔧 PAC adjusted: 3 → 2 (for batch_size=1000)
#
# 🔄 CTGAN Trial 45: epochs=850, batch_size=1000, pac=2, lr=8.28e-05
# ✅ PAC validation: 1000 % 2 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# Gen. (-0.77) | Discrim. (-0.30): 100%|██████████| 850/850 [01:48<00:00,  7.81it/s]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.7124
# [I 2025-11-05 18:08:59,406] Trial 44 finished with value: 0.8156122908332644 and parameters: {'batch_size': 1000, 'pac': 3, 'epochs': 850, 'generator_lr': 8.277936243604392e-05, 'discriminator_lr': 0.0011428091530514288, 'generator_dim': (256, 512, 256), 'discriminator_dim': (256, 256), 'discriminator_steps': 3, 'generator_decay': 1.95347020915397e-07, 'discriminator_decay': 9.955403370191928e-05, 'log_frequency': False, 'verbose': True}. Best is trial 38 with value: 0.8358345407781438.
# [OK] TRTS (Synthetic->Real): 0.9912
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9704
# [CHART] Combined Score: 0.8156 (Similarity: 0.7124, Accuracy: 0.9704)
# ✅ CTGAN Trial 45 Score: 0.8156 (Similarity: 0.7124, Accuracy: 0.9704)
#
# 🔄 CTGAN Trial 46: epochs=700, batch_size=1000, pac=2, lr=4.46e-04
# ✅ PAC validation: 1000 % 2 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# Gen. (0.33) | Discrim. (-0.17): 100%|██████████| 700/700 [01:27<00:00,  8.01it/s]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5958
# [I 2025-11-05 18:10:32,771] Trial 45 finished with value: 0.742331202955151 and parameters: {'batch_size': 1000, 'pac': 2, 'epochs': 700, 'generator_lr': 0.00044597678979151404, 'discriminator_lr': 0.003562229760990857, 'generator_dim': (256, 512, 256), 'discriminator_dim': (128, 128), 'discriminator_steps': 3, 'generator_decay': 1.1503636283808402e-06, 'discriminator_decay': 2.3787958082730767e-06, 'log_frequency': False, 'verbose': True}. Best is trial 38 with value: 0.8358345407781438.
# [OK] TRTS (Synthetic->Real): 0.9836
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9622
# [CHART] Combined Score: 0.7423 (Similarity: 0.5958, Accuracy: 0.9622)
# ✅ CTGAN Trial 46 Score: 0.7423 (Similarity: 0.5958, Accuracy: 0.9622)
#
# 🔄 CTGAN Trial 47: epochs=800, batch_size=128, pac=4, lr=2.18e-04
# ✅ PAC validation: 128 % 4 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# Gen. (-1.25) | Discrim. (0.86): 100%|██████████| 800/800 [13:57<00:00,  1.05s/it]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6147
# [I 2025-11-05 18:24:36,181] Trial 46 finished with value: 0.7414140971423553 and parameters: {'batch_size': 128, 'pac': 4, 'epochs': 800, 'generator_lr': 0.00021846400821741332, 'discriminator_lr': 0.002738593487415263, 'generator_dim': (256, 512, 256), 'discriminator_dim': (256, 256), 'discriminator_steps': 4, 'generator_decay': 5.005334198902799e-07, 'discriminator_decay': 9.548156548227028e-06, 'log_frequency': False, 'verbose': True}. Best is trial 38 with value: 0.8358345407781438.
# [OK] TRTS (Synthetic->Real): 0.9846
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9315
# [CHART] Combined Score: 0.7414 (Similarity: 0.6147, Accuracy: 0.9315)
# ✅ CTGAN Trial 47 Score: 0.7414 (Similarity: 0.6147, Accuracy: 0.9315)
# 🔧 PAC adjusted: 3 → 2 (for batch_size=1000)
#
# 🔄 CTGAN Trial 48: epochs=950, batch_size=1000, pac=2, lr=1.39e-04
# ✅ PAC validation: 1000 % 2 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Gen. (-0.79) | Discrim. (-0.40): 100%|██████████| 950/950 [01:59<00:00,  7.93it/s]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6362
# [I 2025-11-05 18:26:48,736] Trial 47 finished with value: 0.7679064073887465 and parameters: {'batch_size': 1000, 'pac': 3, 'epochs': 950, 'generator_lr': 0.00013858785489884653, 'discriminator_lr': 0.0015605276225558018, 'generator_dim': (256, 512, 256), 'discriminator_dim': (256, 256), 'discriminator_steps': 3, 'generator_decay': 8.615774924706209e-08, 'discriminator_decay': 2.5390635646307395e-05, 'log_frequency': False, 'verbose': True}. Best is trial 38 with value: 0.8358345407781438.
# [OK] TRTS (Synthetic->Real): 0.9879
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9655
# [CHART] Combined Score: 0.7679 (Similarity: 0.6362, Accuracy: 0.9655)
# ✅ CTGAN Trial 48 Score: 0.7679 (Similarity: 0.6362, Accuracy: 0.9655)
# 🔧 PAC adjusted: 6 → 4 (for batch_size=32)
#
# 🔄 CTGAN Trial 49: epochs=850, batch_size=32, pac=4, lr=2.81e-05
# ✅ PAC validation: 32 % 4 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# Gen. (0.94) | Discrim. (-0.62): 100%|██████████| 850/850 [39:39<00:00,  2.80s/it]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6152
# [I 2025-11-05 19:06:34,192] Trial 48 finished with value: 0.7226153846135139 and parameters: {'batch_size': 32, 'pac': 6, 'epochs': 850, 'generator_lr': 2.8050798528354386e-05, 'discriminator_lr': 0.003846048815034221, 'generator_dim': (512, 256), 'discriminator_dim': (256, 256), 'discriminator_steps': 4, 'generator_decay': 3.00965128545827e-07, 'discriminator_decay': 4.8942065790179484e-05, 'log_frequency': False, 'verbose': True}. Best is trial 38 with value: 0.8358345407781438.
# [OK] TRTS (Synthetic->Real): 0.9857
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.8838
# [CHART] Combined Score: 0.7226 (Similarity: 0.6152, Accuracy: 0.8838)
# ✅ CTGAN Trial 49 Score: 0.7226 (Similarity: 0.6152, Accuracy: 0.8838)
#
# 🔄 CTGAN Trial 50: epochs=500, batch_size=1000, pac=5, lr=6.08e-05
# ✅ PAC validation: 1000 % 5 = 0
# 🎯 Using target column: 'Outcome'
# ✅ Using CTGAN from ctgan package
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Gen. (-0.39) | Discrim. (-0.32): 100%|██████████| 500/500 [00:48<00:00, 10.23it/s]
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6835
# [I 2025-11-05 19:07:38,589] Trial 49 finished with value: 0.7872737584290155 and parameters: {'batch_size': 1000, 'pac': 5, 'epochs': 500, 'generator_lr': 6.0825954903008094e-05, 'discriminator_lr': 0.002012646565137497, 'generator_dim': (512, 512), 'discriminator_dim': (256, 256), 'discriminator_steps': 2, 'generator_decay': 1.471098763359012e-07, 'discriminator_decay': 2.051570545127127e-05, 'log_frequency': False, 'verbose': True}. Best is trial 38 with value: 0.8358345407781438.
# [OK] TRTS (Synthetic->Real): 0.9890
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9430
# [CHART] Combined Score: 0.7873 (Similarity: 0.6835, Accuracy: 0.9430)
# ✅ CTGAN Trial 50 Score: 0.7873 (Similarity: 0.6835, Accuracy: 0.9430)
#
# 📊 CTGAN hyperparameter optimization with corrected PAC compatibility completed!
# 🎯 No more dynamic parameter name issues - simplified and robust approach
#
# 🏆 Best Trial Results:
#    • Best Score: 0.8358
#    • Trial Number: 38
#    • Best Parameters:
#      - batch_size: 1000
#      - pac: 3
#      - epochs: 800
#      - generator_lr: 6.06656088925087e-05
#      - discriminator_lr: 0.0031235585599621325
#      - generator_dim: (256, 512, 256)
#      - discriminator_dim: (256, 256)
#      - discriminator_steps: 3
#      - generator_decay: 3.221089025088075e-07
#      - discriminator_decay: 3.547122654188149e-05
#      - log_frequency: False
#      - verbose: True
#
# 📈 Optimization Summary:
#    • Total trials completed: 50
#    • Failed trials: 0
#    • Best score: 0.8358
#    • Mean score: 0.7298
#    • Score range: 0.3294
#
# ✅ CTGAN optimization data ready for Section 4.1.1 analysis

# %%
# Generate Optuna visualizations for CTGANfrom src.visualization.section4 import create_optuna_visualizationscreate_optuna_visualizations(    study=ctgan_study,    model_name='CTGAN',    results_path=results_path,    verbose=True)

# %% [markdown]
# #### 4.1.2 CTAB-GAN Hyperparameter Optimization

# %%
# Code Chunk ID: CHUNK_4_1_2_A
# Import required libraries for CTAB-GAN optimization
import optuna
import numpy as np
import pandas as pd
from src.models.model_factory import ModelFactory
from src.evaluation.trts_framework import TRTSEvaluator

# CORRECTED CTAB-GAN Search Space (3 supported parameters only)
def ctabgan_search_space(trial):
    """Realistic CTAB-GAN hyperparameter space - ONLY supported parameters"""
    return {
        'epochs': trial.suggest_int('epochs', 100, 1000, step=50),
        'batch_size': trial.suggest_categorical('batch_size', [64, 128, 256]),  # Remove 500 - not stable
        'test_ratio': trial.suggest_float('test_ratio', 0.15, 0.25, step=0.05),
        # REMOVED: class_dim, random_dim, num_channels (not supported by constructor)
    }

def ctabgan_objective(trial):
    """FINAL CORRECTED CTAB-GAN objective function with SCORE EXTRACTION FIX"""
    try:
        # Get realistic hyperparameters from trial
        params = ctabgan_search_space(trial)
        
        print(f"\n🔄 CTAB-GAN Trial {trial.number + 1}: epochs={params['epochs']}, batch_size={params['batch_size']}, test_ratio={params['test_ratio']:.3f}")
        
        # Initialize CTAB-GAN using ModelFactory
        model = ModelFactory.create("ctabgan", random_state=42)
        
        # Only pass supported parameters to train()
        result = model.train(data, 
                           epochs=params['epochs'],
                           batch_size=params['batch_size'],
                           test_ratio=params['test_ratio'])
        
        print(f"🏋️ Training CTAB-GAN with corrected parameters...")
        
        # Generate synthetic data for evaluation
        synthetic_data = model.generate(len(data))
        
        # CRITICAL FIX: Convert synthetic data labels to match original data types before TRTS evaluation
        synthetic_data_converted = synthetic_data.copy()
        if target_column in synthetic_data_converted.columns and target_column in data.columns:
            # Convert string labels to numeric to match original data type
            if synthetic_data_converted[target_column].dtype == 'object' and data[target_column].dtype != 'object':
                print(f"🔧 Converting synthetic labels from {synthetic_data_converted[target_column].dtype} to {data[target_column].dtype}")
                synthetic_data_converted[target_column] = pd.to_numeric(synthetic_data_converted[target_column], errors='coerce')
                
                # Handle any conversion failures
                if synthetic_data_converted[target_column].isna().any():
                    print(f"⚠️ Some labels failed conversion - filling with mode")
                    mode_value = data[target_column].mode()[0]
                    synthetic_data_converted[target_column].fillna(mode_value, inplace=True)
                
                # Ensure same data type as original
                synthetic_data_converted[target_column] = synthetic_data_converted[target_column].astype(data[target_column].dtype)
                print(f"✅ Label conversion successful: {synthetic_data_converted[target_column].dtype}")
        
        # Calculate similarity score using TRTS framework with converted data
        trts = TRTSEvaluator(random_state=42)
        trts_results = trts.evaluate_trts_scenarios(data, synthetic_data_converted, target_column=target_column)
        
        # 🎯 CRITICAL FIX: Correct Score Extraction (targeting ML accuracy scores, not percentages)
        if 'trts_scores' in trts_results and isinstance(trts_results['trts_scores'], dict):
            trts_scores = list(trts_results['trts_scores'].values())  # Extract ML accuracy scores (0-1 scale)
            print(f"🎯 CORRECTED: ML accuracy scores = {trts_scores}")
        else:
            # Fallback to filtered method if structure unexpected
            print(f"⚠️ Using fallback score extraction")
            trts_scores = [score for score in trts_results.values() if isinstance(score, (int, float)) and 0 <= score <= 1]
            print(f"🔍 Fallback extracted scores = {trts_scores}")
        
        # CORRECTED EVALUATION FAILURE DETECTION (using proper 0-1 scale)
        if not trts_scores:
            print(f"❌ TRTS evaluation failure: NO NUMERIC SCORES RETURNED")
            return 0.0
        elif all(score >= 0.99 for score in trts_scores):  # Now checking 0-1 scale scores
            print(f"❌ TRTS evaluation failure: ALL SCORES ≥0.99 (suspicious perfect scores)")
            print(f"   • Perfect scores detected: {trts_scores}")
            return 0.0  
        else:
            # TRTS evaluation successful
            similarity_score = np.mean(trts_scores) if trts_scores else 0.0
            similarity_score = max(0.0, min(1.0, similarity_score))
            print(f"✅ TRTS evaluation successful: {similarity_score:.4f} (from {len(trts_scores)} ML accuracy scores)")
        
        # Calculate accuracy with converted labels
        try:
            from sklearn.ensemble import RandomForestClassifier
            from sklearn.metrics import accuracy_score
            from sklearn.model_selection import train_test_split
            
            # Use converted synthetic data for accuracy calculation
            if target_column in data.columns and target_column in synthetic_data_converted.columns:
                X_real = data.drop(target_column, axis=1)
                y_real = data[target_column]
                X_synth = synthetic_data_converted.drop(target_column, axis=1) 
                y_synth = synthetic_data_converted[target_column]
                
                # Train on synthetic, test on real (TRTS approach)
                X_train, X_test, y_train, y_test = train_test_split(X_real, y_real, test_size=0.2, random_state=42)
                
                clf = RandomForestClassifier(random_state=42, n_estimators=50)
                clf.fit(X_synth, y_synth)
                
                predictions = clf.predict(X_test)
                accuracy = accuracy_score(y_test, predictions)
                
                # Combined score (weighted average of similarity and accuracy)
                score = 0.6 * similarity_score + 0.4 * accuracy
                score = max(0.0, min(1.0, score))  # Ensure 0-1 range
                
                print(f"✅ CTAB-GAN Trial {trial.number + 1} Score: {score:.4f} (Similarity: {similarity_score:.4f}, Accuracy: {accuracy:.4f})")
            else:
                score = similarity_score
                print(f"✅ CTAB-GAN Trial {trial.number + 1} Score: {score:.4f} (Similarity: {similarity_score:.4f})")
                
        except Exception as e:
            print(f"⚠️ Accuracy calculation failed: {e}")
            score = similarity_score
            print(f"✅ CTAB-GAN Trial {trial.number + 1} Score: {score:.4f} (Similarity: {similarity_score:.4f})")
        
        return score
        
    except Exception as e:
        print(f"❌ CTAB-GAN trial {trial.number + 1} failed: {str(e)}")
        return 0.0  # FAILED MODELS RETURN 0.0, NOT 1.0

# Execute CTAB-GAN hyperparameter optimization with SCORE EXTRACTION FIX
print("\n🎯 Starting CTAB-GAN Hyperparameter Optimization - SCORE EXTRACTION FIX")
print("   • Search space: 3 supported parameters (epochs, batch_size, test_ratio)")
print("   • Parameter validation: Only constructor-supported parameters")
print("   • 🎯 CRITICAL FIX: Correct ML accuracy score extraction (0-1 scale)")
print("   • Proper threshold detection: Using 0-1 scale for perfect score detection")
print("   • Number of trials: 5")
print(f"   • Algorithm: TPE with median pruning")

# Create and execute study
ctabgan_study = optuna.create_study(direction="maximize", pruner=optuna.pruners.MedianPruner())
ctabgan_study.optimize(ctabgan_objective, n_trials=50)

# Display results
print(f"\n✅ CTAB-GAN Optimization with Score Fix Complete:")
print(f"   • Best objective score: {ctabgan_study.best_value:.4f}")
print(f"   • Best hyperparameters:")
for key, value in ctabgan_study.best_params.items():
    if isinstance(value, float):
        print(f"     - {key}: {value:.4f}")
    else:
        print(f"     - {key}: {value}")

# Store best parameters for later use
ctabgan_best_params = ctabgan_study.best_params
print("\n📊 CTAB-GAN hyperparameter optimization with score extraction fix completed!")
print(f"🎯 Expected: Variable scores reflecting actual ML accuracy performance")

# %%
# Generate Optuna visualizations for CTABGANfrom src.visualization.section4 import create_optuna_visualizationscreate_optuna_visualizations(    study=ctabgan_study,    model_name='CTABGAN',    results_path=results_path,    verbose=True)

# %% [markdown]
# #### 4.1.3 CTAB-GAN+ Hyperparameter Optimization

# %%
# Code Chunk ID: CHUNK_4_1_3_A
# Import required libraries for CTAB-GAN+ optimization
import optuna
import numpy as np
import pandas as pd
from src.models.model_factory import ModelFactory
from src.evaluation.trts_framework import TRTSEvaluator

# CORRECTED CTAB-GAN+ Search Space (3 supported parameters only)
def ctabganplus_search_space(trial):
    """Realistic CTAB-GAN+ hyperparameter space - ONLY supported parameters"""
    return {
        'epochs': trial.suggest_int('epochs', 150, 1000, step=50),  # Slightly higher range for "plus" version
        'batch_size': trial.suggest_categorical('batch_size', [64, 128, 256, 512]),  # Add 512 for enhanced version
        'test_ratio': trial.suggest_float('test_ratio', 0.10, 0.25, step=0.05),  # Slightly wider range
        # REMOVED: All "enhanced" parameters (not supported by constructor)
    }

def ctabganplus_objective(trial):
    """FINAL CORRECTED CTAB-GAN+ objective function with SCORE EXTRACTION FIX"""
    try:
        # Get realistic hyperparameters from trial
        params = ctabganplus_search_space(trial)
        
        print(f"\n🔄 CTAB-GAN+ Trial {trial.number + 1}: epochs={params['epochs']}, batch_size={params['batch_size']}, test_ratio={params['test_ratio']:.3f}")
        
        # Initialize CTAB-GAN+ using ModelFactory
        model = ModelFactory.create("ctabganplus", random_state=42)
        
        # Only pass supported parameters to train()
        result = model.train(data, 
                           epochs=params['epochs'],
                           batch_size=params['batch_size'],
                           test_ratio=params['test_ratio'])
        
        print(f"🏋️ Training CTAB-GAN+ with corrected parameters...")
        
        # Generate synthetic data for evaluation
        synthetic_data = model.generate(len(data))
        
        # CRITICAL FIX: Convert synthetic data labels to match original data types before TRTS evaluation
        synthetic_data_converted = synthetic_data.copy()
        if target_column in synthetic_data_converted.columns and target_column in data.columns:
            # Convert string labels to numeric to match original data type
            if synthetic_data_converted[target_column].dtype == 'object' and data[target_column].dtype != 'object':
                print(f"🔧 Converting synthetic labels from {synthetic_data_converted[target_column].dtype} to {data[target_column].dtype}")
                synthetic_data_converted[target_column] = pd.to_numeric(synthetic_data_converted[target_column], errors='coerce')
                
                # Handle any conversion failures
                if synthetic_data_converted[target_column].isna().any():
                    print(f"⚠️ Some labels failed conversion - filling with mode")
                    mode_value = data[target_column].mode()[0]
                    synthetic_data_converted[target_column].fillna(mode_value, inplace=True)
                
                # Ensure same data type as original
                synthetic_data_converted[target_column] = synthetic_data_converted[target_column].astype(data[target_column].dtype)
                print(f"✅ Label conversion successful: {synthetic_data_converted[target_column].dtype}")
        
        # Calculate similarity score using TRTS framework with converted data
        trts = TRTSEvaluator(random_state=42)
        trts_results = trts.evaluate_trts_scenarios(data, synthetic_data_converted, target_column=target_column)
        
        # 🎯 CRITICAL FIX: Correct Score Extraction (targeting ML accuracy scores, not percentages)
        if 'trts_scores' in trts_results and isinstance(trts_results['trts_scores'], dict):
            trts_scores = list(trts_results['trts_scores'].values())  # Extract ML accuracy scores (0-1 scale)
            print(f"🎯 CORRECTED: ML accuracy scores = {trts_scores}")
        else:
            # Fallback to filtered method if structure unexpected
            print(f"⚠️ Using fallback score extraction")
            trts_scores = [score for score in trts_results.values() if isinstance(score, (int, float)) and 0 <= score <= 1]
            print(f"🔍 Fallback extracted scores = {trts_scores}")
        
        # CORRECTED EVALUATION FAILURE DETECTION (using proper 0-1 scale)
        if not trts_scores:
            print(f"❌ TRTS evaluation failure: NO NUMERIC SCORES RETURNED")
            return 0.0
        elif all(score >= 0.99 for score in trts_scores):  # Now checking 0-1 scale scores
            print(f"❌ TRTS evaluation failure: ALL SCORES ≥0.99 (suspicious perfect scores)")
            print(f"   • Perfect scores detected: {trts_scores}")
            return 0.0  
        else:
            # TRTS evaluation successful
            similarity_score = np.mean(trts_scores) if trts_scores else 0.0
            similarity_score = max(0.0, min(1.0, similarity_score))
            print(f"✅ TRTS evaluation successful: {similarity_score:.4f} (from {len(trts_scores)} ML accuracy scores)")
        
        # Calculate accuracy with converted labels
        try:
            from sklearn.ensemble import RandomForestClassifier
            from sklearn.metrics import accuracy_score
            from sklearn.model_selection import train_test_split
            
            # Use converted synthetic data for accuracy calculation
            if target_column in data.columns and target_column in synthetic_data_converted.columns:
                X_real = data.drop(target_column, axis=1)
                y_real = data[target_column]
                X_synth = synthetic_data_converted.drop(target_column, axis=1) 
                y_synth = synthetic_data_converted[target_column]
                
                # Train on synthetic, test on real (TRTS approach)
                X_train, X_test, y_train, y_test = train_test_split(X_real, y_real, test_size=0.2, random_state=42)
                
                clf = RandomForestClassifier(random_state=42, n_estimators=50)
                clf.fit(X_synth, y_synth)
                
                predictions = clf.predict(X_test)
                accuracy = accuracy_score(y_test, predictions)
                
                # Combined score (weighted average of similarity and accuracy)
                score = 0.6 * similarity_score + 0.4 * accuracy
                score = max(0.0, min(1.0, score))  # Ensure 0-1 range
                
                print(f"✅ CTAB-GAN+ Trial {trial.number + 1} Score: {score:.4f} (Similarity: {similarity_score:.4f}, Accuracy: {accuracy:.4f})")
            else:
                score = similarity_score
                print(f"✅ CTAB-GAN+ Trial {trial.number + 1} Score: {score:.4f} (Similarity: {similarity_score:.4f})")
                
        except Exception as e:
            print(f"⚠️ Accuracy calculation failed: {e}")
            score = similarity_score
            print(f"✅ CTAB-GAN+ Trial {trial.number + 1} Score: {score:.4f} (Similarity: {similarity_score:.4f})")
        
        return score
        
    except Exception as e:
        print(f"❌ CTAB-GAN+ trial {trial.number + 1} failed: {str(e)}")
        return 0.0  # FAILED MODELS RETURN 0.0, NOT 1.0

# Execute CTAB-GAN+ hyperparameter optimization with SCORE EXTRACTION FIX
print("\n🎯 Starting CTAB-GAN+ Hyperparameter Optimization - SCORE EXTRACTION FIX")
print("   • Search space: 3 supported parameters (epochs, batch_size, test_ratio)")
print("   • Enhanced ranges: Slightly higher epochs and wider test_ratio range")
print("   • Parameter validation: Only constructor-supported parameters")
print("   • 🎯 CRITICAL FIX: Correct ML accuracy score extraction (0-1 scale)")
print("   • Proper threshold detection: Using 0-1 scale for perfect score detection")
print("   • Number of trials: 5")
print(f"   • Algorithm: TPE with median pruning")

# Create and execute study
ctabganplus_study = optuna.create_study(direction="maximize", pruner=optuna.pruners.MedianPruner())
ctabganplus_study.optimize(ctabganplus_objective, n_trials=50)

# Display results
print(f"\n✅ CTAB-GAN+ Optimization with Score Fix Complete:")
print(f"   • Best objective score: {ctabganplus_study.best_value:.4f}")
print(f"   • Best hyperparameters:")
for key, value in ctabganplus_study.best_params.items():
    if isinstance(value, float):
        print(f"     - {key}: {value:.4f}")
    else:
        print(f"     - {key}: {value}")

# Store best parameters for later use
ctabganplus_best_params = ctabganplus_study.best_params
print("\n📊 CTAB-GAN+ hyperparameter optimization with score extraction fix completed!")
print(f"🎯 Expected: Variable scores reflecting actual ML accuracy performance")

# %%
# Generate Optuna visualizations for CTABGANPLUSfrom src.visualization.section4 import create_optuna_visualizationscreate_optuna_visualizations(    study=ctabganplus_study,    model_name='CTABGANPLUS',    results_path=results_path,    verbose=True)

# %% [markdown]
# #### 4.1.4 GANerAid Hyperparameter Optimization

# %%
# Code Chunk ID: CHUNK_4_1_4_A
# GANerAid Search Space and Hyperparameter Optimization

def ganeraid_search_space(trial):
    """
    GENERALIZED GANerAid hyperparameter search space with dynamic constraint adjustment.
    
    CRITICAL INSIGHT: Following CTGAN's compatible_pac pattern for robust constraint handling.
    GANerAid requires: batch_size % nr_of_rows == 0 AND nr_of_rows < dataset_size
    """
    
    # Define available batch sizes (easily extensible like CTGAN)
    batch_size = trial.suggest_categorical('batch_size', [32, 64, 100, 128, 200, 256, 400, 500])
    
    # Suggest nr_of_rows from a reasonable range (will be adjusted at runtime)
    max_nr_of_rows = min(50, batch_size // 2)  # Conservative upper bound
    nr_of_rows = trial.suggest_int('nr_of_rows', 4, max_nr_of_rows)
    
    return {
        'epochs': trial.suggest_int('epochs', 100, 500, step=50),  # REDUCED for troubleshooting
        'batch_size': batch_size,
        'nr_of_rows': nr_of_rows,  # Will be adjusted in objective function
        'lr_d': trial.suggest_loguniform('lr_d', 1e-6, 5e-3),
        'lr_g': trial.suggest_loguniform('lr_g', 1e-6, 5e-3),
        'hidden_feature_space': trial.suggest_categorical('hidden_feature_space', [
            100, 150, 200, 300, 400, 500, 600
        ]),
        'binary_noise': trial.suggest_uniform('binary_noise', 0.05, 0.6),
        'generator_decay': trial.suggest_loguniform('generator_decay', 1e-8, 1e-3),
        'discriminator_decay': trial.suggest_loguniform('discriminator_decay', 1e-8, 1e-3),
        'dropout_generator': trial.suggest_uniform('dropout_generator', 0.0, 0.5),
        'dropout_discriminator': trial.suggest_uniform('dropout_discriminator', 0.0, 0.5)
    }

def find_compatible_nr_of_rows(batch_size, requested_nr_of_rows, dataset_size, hidden_feature_space):
    """
    Find largest compatible nr_of_rows <= requested_nr_of_rows that satisfies ALL GANerAid constraints.
    
    DISCOVERED CONSTRAINTS:
    1. batch_size % nr_of_rows == 0 (divisibility for batching)
    2. nr_of_rows < dataset_size (avoid dataset index out of bounds)
    3. hidden_feature_space % nr_of_rows == 0 (CRITICAL: for internal LSTM step calculation)
    4. nr_of_rows >= 4 (reasonable minimum for GANerAid)
    
    From GANerAid model.py line 90: step = int(hidden_size / rows)
    The loop runs 'rows' times, accessing output[:, c, :] where c goes from 0 to rows-1
    """
    
    # Start with requested value and work downward
    compatible_nr_of_rows = requested_nr_of_rows
    
    while compatible_nr_of_rows >= 4:
        # Check all constraints
        batch_divisible = batch_size % compatible_nr_of_rows == 0
        size_safe = compatible_nr_of_rows < dataset_size
        hidden_divisible = hidden_feature_space % compatible_nr_of_rows == 0  # CRITICAL NEW CONSTRAINT
        
        if batch_divisible and size_safe and hidden_divisible:
            return compatible_nr_of_rows
            
        compatible_nr_of_rows -= 1
    
    # If no compatible value found, return 4 as fallback (most likely to work)
    return 4

def ganeraid_objective(trial):
    """GENERALIZED GANerAid objective function with ALL constraint validation."""
    try:
        # Get hyperparameters from trial
        params = ganeraid_search_space(trial)
        
        # DYNAMIC CONSTRAINT ADJUSTMENT (following CTGAN pattern)
        batch_size = params['batch_size']
        requested_nr_of_rows = params['nr_of_rows']
        hidden_feature_space = params['hidden_feature_space']
        dataset_size = len(data) if 'data' in globals() else 569  # fallback
        
        # Find compatible nr_of_rows using runtime adjustment with ALL constraints
        compatible_nr_of_rows = find_compatible_nr_of_rows(batch_size, requested_nr_of_rows, dataset_size, hidden_feature_space)
        
        # Update parameters with compatible value
        if compatible_nr_of_rows != requested_nr_of_rows:
            print(f"🔧 nr_of_rows adjusted: {requested_nr_of_rows} → {compatible_nr_of_rows}")
            print(f"   Reason: batch_size={batch_size}, dataset_size={dataset_size}, hidden_feature_space={hidden_feature_space}")
            params['nr_of_rows'] = compatible_nr_of_rows
        
        print(f"\n🔄 GANerAid Trial {trial.number + 1}: epochs={params['epochs']}, batch_size={params['batch_size']}, nr_of_rows={params['nr_of_rows']}, hidden={params['hidden_feature_space']}")
        print(f"✅ COMPLETE Constraint validation:")
        print(f"   • Batch divisibility: {params['batch_size']} % {params['nr_of_rows']} = {params['batch_size'] % params['nr_of_rows']} (should be 0)")
        print(f"   • Size safety: {params['nr_of_rows']} < {dataset_size} = {params['nr_of_rows'] < dataset_size}")
        print(f"   • Hidden divisibility: {params['hidden_feature_space']} % {params['nr_of_rows']} = {params['hidden_feature_space'] % params['nr_of_rows']} (should be 0)")
        print(f"   • LSTM step size: int({params['hidden_feature_space']} / {params['nr_of_rows']}) = {int(params['hidden_feature_space'] / params['nr_of_rows'])}")
        
        # CORRECTED: Ensure TARGET_COLUMN is available with proper global access
        global TARGET_COLUMN
        if TARGET_COLUMN is None:
            # Try to find target column from various sources
            if 'target_column' in globals():
                TARGET_COLUMN = globals()['target_column']
            elif hasattr(data, 'columns') and len(data.columns) > 0:
                TARGET_COLUMN = data.columns[-1]  # Use last column as fallback
                print(f"🔧 Using fallback target column: {TARGET_COLUMN}")
            else:
                print("❌ No target column available - cannot proceed")
                return 0.0
        
        # CRITICAL DEBUG: Check if enhanced_objective_function_v2 is available
        if 'enhanced_objective_function_v2' not in globals():
            print("❌ enhanced_objective_function_v2 not available - cannot evaluate model")
            return 0.0
        
        # Initialize GANerAid using ModelFactory with corrected parameters
        model = ModelFactory.create("ganeraid", random_state=42)
        model.set_config(params)
        
        # ENHANCED ERROR HANDLING: Wrap training in try-catch for constraint violations
        print("🏋️ Training GANerAid with ALL CONSTRAINTS SATISFIED...")
        start_time = time.time()
        
        try:
            model.train(data, epochs=params['epochs'])
            training_time = time.time() - start_time
            print(f"⏱️ Training completed successfully in {training_time:.1f} seconds")
        except IndexError as e:
            if "index" in str(e) and "out of bounds" in str(e):
                print(f"❌ INDEX ERROR STILL OCCURRED: {e}")
                print(f"   batch_size: {params['batch_size']}, nr_of_rows: {params['nr_of_rows']}, dataset_size: {dataset_size}")
                print(f"   hidden_feature_space: {params['hidden_feature_space']}")
                print(f"   batch_divisible: {params['batch_size']} % {params['nr_of_rows']} = {params['batch_size'] % params['nr_of_rows']}")
                print(f"   size_safe: {params['nr_of_rows']} < {dataset_size} = {params['nr_of_rows'] < dataset_size}")
                print(f"   hidden_divisible: {params['hidden_feature_space']} % {params['nr_of_rows']} = {params['hidden_feature_space'] % params['nr_of_rows']}")
                print(f"   lstm_step: {int(params['hidden_feature_space'] / params['nr_of_rows'])}")
                print("   If error persists, GANerAid may have additional undocumented constraints")
                
                # Try to understand the exact error location
                import traceback
                traceback.print_exc()
                
                return 0.0
            else:
                raise  # Re-raise if it's a different IndexError
        except Exception as e:
            print(f"❌ Training failed with error: {e}")
            return 0.0
        
        # Generate synthetic data
        try:
            synthetic_data = model.generate(len(data))
            print(f"📊 Generated synthetic data: {synthetic_data.shape}")
        except Exception as e:
            print(f"❌ Generation failed with error: {e}")
            return 0.0
        
        # ENHANCED EVALUATION with NaN handling and FIXED pandas.isfinite issue
        try:
            score, similarity_score, accuracy_score = enhanced_objective_function_v2(
                data, synthetic_data, TARGET_COLUMN
            )
            
            print(f"📊 Raw evaluation scores - Similarity: {similarity_score}, Accuracy: {accuracy_score}, Combined: {score}")
            
            # CRITICAL FIX: Handle NaN values which cause trial failures (use np.isfinite, not pd.isfinite)
            if pd.isna(score) or pd.isna(similarity_score) or pd.isna(accuracy_score):
                print(f"⚠️ NaN detected in scores - similarity: {similarity_score}, accuracy: {accuracy_score}, combined: {score}")
                print("   Replacing NaN values with 0.0 to prevent trial failure")
                
                # Replace NaN with reasonable defaults
                if pd.isna(similarity_score):
                    similarity_score = 0.0
                if pd.isna(accuracy_score):
                    accuracy_score = 0.0
                if pd.isna(score):
                    # Recalculate score if main score is NaN
                    score = 0.6 * similarity_score + 0.4 * accuracy_score
            
            # Ensure score is not NaN or infinite (FIXED: use np.isfinite instead of pd.isfinite)
            if pd.isna(score) or not np.isfinite(score):
                print(f"❌ Final score is invalid: {score}, setting to 0.0")
                score = 0.0
            
            # Clamp score to valid range
            score = max(0.0, min(1.0, score))
            
            print(f"✅ GANerAid Trial {trial.number + 1} FINAL Score: {score:.4f} (Similarity: {similarity_score:.4f}, Accuracy: {accuracy_score:.4f})")
            return float(score)  # Ensure it's a regular float, not numpy float
            
        except Exception as e:
            print(f"❌ Evaluation failed: {e}")
            import traceback
            traceback.print_exc()
            return 0.0
        
    except Exception as e:
        print(f"❌ GANerAid trial {trial.number + 1} failed: {str(e)}")
        import traceback
        traceback.print_exc()
        return 0.0

# Execute GANerAid hyperparameter optimization with COMPLETE constraint handling
print("\n🎯 Starting GANerAid Hyperparameter Optimization - COMPLETE CONSTRAINT DISCOVERY")
print("   • DISCOVERED CRITICAL CONSTRAINT: hidden_feature_space % nr_of_rows == 0")
print("   • FOLLOWING CTGAN PATTERN: Dynamic runtime constraint adjustment")
print("   • EASILY EXTENSIBLE: Add new batch_size values without hardcoding combinations")
print("   • ALL CONSTRAINTS: batch_size % nr_of_rows == 0 AND nr_of_rows < dataset_size AND hidden_feature_space % nr_of_rows == 0")
print("   • EPOCHS: Reduced to 100-500 for troubleshooting")
print("   • ALGORITHM: TPE with median pruning")

# Show the complete constraint handling
print(f"🔧 Complete constraint handling discovered from GANerAid model.py:")
print(f"   • Batch constraint: batch_size % nr_of_rows == 0 (for proper batching)")
print(f"   • Size constraint: nr_of_rows < dataset_size (avoid dataset index errors)")
print(f"   • CRITICAL Hidden constraint: hidden_feature_space % nr_of_rows == 0 (for LSTM step calculation)")
print(f"   • LSTM step formula: int(hidden_feature_space / nr_of_rows)")
print(f"   • Output tensor access: output[:, c, :] where c ranges from 0 to nr_of_rows-1")

# Validate dataset availability before starting optimization
if 'data' not in globals() or data is None:
    print("❌ Dataset not available - cannot perform optimization")
else:
    dataset_info = f"Dataset size: {len(data)}, Columns: {len(data.columns)}"
    print(f"📊 {dataset_info}")
    
    # Demonstrate complete constraint adjustment for current dataset
    print(f"\n🔍 Example COMPLETE constraint adjustments for dataset size {len(data)}:")
    example_cases = [
        (128, 32, 200),  # The failing case from the error
        (64, 16, 200),
        (100, 25, 300),
        (256, 16, 400)
    ]
    
    for batch_size, requested_nr_of_rows, hidden_feature_space in example_cases:
        compatible = find_compatible_nr_of_rows(batch_size, requested_nr_of_rows, len(data), hidden_feature_space)
        adjustment = "" if compatible == requested_nr_of_rows else f" → {compatible}"
        print(f"   • batch_size={batch_size}, hidden={hidden_feature_space}, requested_nr_of_rows={requested_nr_of_rows}{adjustment}")
        print(f"     - Batch check: {batch_size} % {compatible} = {batch_size % compatible}")
        print(f"     - Size check: {compatible} < {len(data)} = {compatible < len(data)}")  
        print(f"     - Hidden check: {hidden_feature_space} % {compatible} = {hidden_feature_space % compatible}")
        print(f"     - LSTM step: {int(hidden_feature_space / compatible)}")
    
    # Create and execute study with enhanced error handling
    try:
        print(f"\n🚀 Starting optimization with {5} trials (increased for troubleshooting as requested)...")
        
        ganeraid_study = optuna.create_study(direction="maximize", pruner=optuna.pruners.MedianPruner())
        ganeraid_study.optimize(ganeraid_objective, n_trials=50)  # INCREASED to 5 as requested
        
        # Display results
        print(f"\n✅ GANerAid Optimization Complete:")
        print(f"   • Best objective score: {ganeraid_study.best_value:.4f}")
        print(f"   • Best parameters:")
        for key, value in ganeraid_study.best_params.items():
            if isinstance(value, float):
                print(f"     - {key}: {value:.6f}")
            else:
                print(f"     - {key}: {value}")
        print(f"   • Total trials completed: {len(ganeraid_study.trials)}")
        print(f"   • Successful trials: {len([t for t in ganeraid_study.trials if t.value is not None and t.value > 0])}")
        print(f"   • Failed trials: {len([t for t in ganeraid_study.trials if t.state == optuna.trial.TrialState.FAIL])}")
        
        # Validate the best parameters follow all constraints
        best_params = ganeraid_study.best_params
        if 'batch_size' in best_params and 'nr_of_rows' in best_params and 'hidden_feature_space' in best_params:
            best_batch_size = best_params['batch_size']
            best_nr_of_rows = best_params['nr_of_rows'] 
            best_hidden = best_params['hidden_feature_space']
            
            # Reconstruct the compatible adjustment that would have been used
            dataset_size = len(data)
            compatible_check = find_compatible_nr_of_rows(best_batch_size, best_nr_of_rows, dataset_size, best_hidden)
            
            print(f"   • Best combination COMPLETE validation:")
            print(f"     - batch_size={best_batch_size}, nr_of_rows={best_nr_of_rows}, hidden={best_hidden}")
            print(f"     - Batch divisibility: {best_batch_size} % {best_nr_of_rows} = {best_batch_size % best_nr_of_rows}")
            print(f"     - Size safety: {best_nr_of_rows} < {dataset_size} = {best_nr_of_rows < dataset_size}")
            print(f"     - Hidden divisibility: {best_hidden} % {best_nr_of_rows} = {best_hidden % best_nr_of_rows}")
            print(f"     - Compatible check result: {compatible_check}")
            print(f"     - LSTM step size: {int(best_hidden / best_nr_of_rows)}")
            
            all_constraints_satisfied = (
                best_batch_size % best_nr_of_rows == 0 and
                best_nr_of_rows < dataset_size and
                best_hidden % best_nr_of_rows == 0
            )
            
            if all_constraints_satisfied:
                print("     ✅ Best parameters satisfy ALL discovered constraints")
            else:
                print("     ❌ WARNING: Best parameters show constraint violations")
        
        # Store best parameters for later use
        ganeraid_best_params = ganeraid_study.best_params
        print("\n📊 GANerAid hyperparameter optimization with COMPLETE constraints discovered!")
        print("🎯 BREAKTHROUGH: Found the missing hidden_feature_space % nr_of_rows == 0 constraint")
        print("🎯 Approach: Dynamic runtime adjustment (like CTGAN's compatible_pac)")
        print("🎯 Extensible: Add new batch_size/hidden values without hardcoding combinations")
        print("🎯 DEBUG: Enhanced error reporting and evaluation function validation")
        
    except Exception as e:
        print(f"❌ GANerAid optimization failed: {e}")
        import traceback
        traceback.print_exc()

# %%
# Generate Optuna visualizations for GANERAIDfrom src.visualization.section4 import create_optuna_visualizationscreate_optuna_visualizations(    study=ganeraid_study,    model_name='GANERAID',    results_path=results_path,    verbose=True)

# %% [markdown]
# #### 4.1.5 CopulaGAN Hyperparameter Optimization

# %%
# Code Chunk ID: CHUNK_4_1_5_A
# CopulaGAN Search Space and Hyperparameter Optimization

# Import required libraries at the top
import optuna
import time
from src.models.model_factory import ModelFactory
from setup import enhanced_objective_function_v2

def copulagan_search_space(trial):
    """
    GENERALIZED CopulaGAN hyperparameter search space with dynamic constraint adjustment.
    
    CRITICAL INSIGHT: Following CTGAN's compatible_pac pattern for robust constraint handling.
    CopulaGAN requires discrete_columns to be properly defined.
    """
    return {
        'epochs': trial.suggest_int('epochs', 50, 500, step=50),
        'batch_size': trial.suggest_categorical('batch_size', [100, 200, 500]),
        'generator_lr': trial.suggest_loguniform('generator_lr', 1e-5, 1e-2),
        'discriminator_lr': trial.suggest_loguniform('discriminator_lr', 1e-5, 1e-2),
        'generator_decay': trial.suggest_loguniform('generator_decay', 1e-8, 1e-4),
        'discriminator_decay': trial.suggest_loguniform('discriminator_decay', 1e-8, 1e-4),
    }

def copulagan_objective(trial):
    """GENERALIZED CopulaGAN objective function."""
    try:
        # Get hyperparameters from trial
        params = copulagan_search_space(trial)
        
        print(f"\n🔄 CopulaGAN Trial {trial.number + 1}: epochs={params['epochs']}, batch_size={params['batch_size']}")
        
        # Initialize CopulaGAN using ModelFactory
        model = ModelFactory.create("copulagan", random_state=42)
        
        # Auto-detect discrete columns for CopulaGAN
        discrete_columns = data.select_dtypes(include=['object']).columns.tolist()
        print(f"📊 Detected discrete columns: {discrete_columns}")
        
        # Train model
        print(f"🏋️ Training CopulaGAN...")
        start_time = time.time()
        
        try:
            model.train(data, discrete_columns=discrete_columns, **params)
            training_time = time.time() - start_time
            print(f"⏱️ Training completed successfully in {training_time:.1f} seconds")
        except Exception as e:
            print(f"❌ Training failed: {str(e)}")
            return 0.0

        # Generate synthetic data for evaluation
        synthetic_data = model.generate(5000)
        print(f"📊 Generated synthetic data: {synthetic_data.shape}")
        
        # Use enhanced objective function
        combined_score, similarity_score, accuracy_score = enhanced_objective_function_v2(
            data, synthetic_data, TARGET_COLUMN
        )
        
        print(f"🎯 Trial {trial.number + 1} Results:")
        print(f"   • Combined Score: {combined_score:.4f}")
        print(f"   • Similarity: {similarity_score:.4f}")
        print(f"   • Accuracy: {accuracy_score:.4f}")
        
        return combined_score
        
    except Exception as e:
        print(f"❌ Trial {trial.number + 1} failed: {str(e)}")
        import traceback
        traceback.print_exc()
        return 0.0

# Create and run optimization study
print(f"\n🔧 SECTION 4.5: CopulaGAN HYPERPARAMETER OPTIMIZATION")
print("=" * 80)
print(f"🔄 Creating CopulaGAN optimization study...")
print(f"📊 Dataset info: {len(data)} rows, {len(data.columns)} columns")
print(f"📊 Target column '{TARGET_COLUMN}' unique values: {data[TARGET_COLUMN].nunique()}")
print()

# Create study and optimize
copulagan_study = optuna.create_study(direction='maximize')
copulagan_study.optimize(copulagan_objective, n_trials=50)

# Extract and display results
print(f"\n🎯 ============================================================================")
print(f"🎯 CopulaGAN OPTIMIZATION COMPLETE!")
print(f"🎯 ============================================================================")

best_trial = copulagan_study.best_trial
best_params_copulagan = best_trial.params
best_score_copulagan = best_trial.value

print(f"🏆 Best CopulaGAN Trial: {best_trial.number + 1}")
print(f"📈 Best Score: {best_score_copulagan:.4f}")
print(f"⚙️ Best Parameters:")
for param, value in best_params_copulagan.items():
    print(f"   • {param}: {value}")

# Store results in standardized format for Section 5.5
copulagan_results = {
    'model_name': 'CopulaGAN',
    'best_score': best_score_copulagan,
    'best_params': best_params_copulagan,
    'study': copulagan_study,
    'n_trials': len(copulagan_study.trials)
}

print(f"💾 Results stored for Section 5.5 final model training")
print("=" * 80)
# Out:
# [I 2025-11-05 19:07:38,656] A new study created in memory with name: no-name-53568fdb-92be-4197-ab13-a920ee498013
# 🔧 SECTION 4.5: CopulaGAN HYPERPARAMETER OPTIMIZATION
# ================================================================================
# 🔄 Creating CopulaGAN optimization study...
# 📊 Dataset info: 912 rows, 19 columns
# 📊 Target column 'Outcome' unique values: 2
#
#
# 🔄 CopulaGAN Trial 1: epochs=350, batch_size=200
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 95.1 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5431
# [I 2025-11-05 19:09:15,501] Trial 0 finished with value: 0.6779375310332731 and parameters: {'epochs': 350, 'batch_size': 200, 'generator_lr': 0.0042222339533360175, 'discriminator_lr': 0.0033206370697043595, 'generator_decay': 1.070925704520007e-08, 'discriminator_decay': 3.396764341551503e-05}. Best is trial 0 with value: 0.6779375310332731.
# [OK] TRTS (Synthetic->Real): 0.9309
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.8803
# [CHART] Combined Score: 0.6779 (Similarity: 0.5431, Accuracy: 0.8803)
# 🎯 Trial 1 Results:
#    • Combined Score: 0.6779
#    • Similarity: 0.5431
#    • Accuracy: 0.8803
#
# 🔄 CopulaGAN Trial 2: epochs=150, batch_size=500
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 17.2 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5347
# [I 2025-11-05 19:09:34,344] Trial 1 finished with value: 0.5061580484280359 and parameters: {'epochs': 150, 'batch_size': 500, 'generator_lr': 0.0001733188660418163, 'discriminator_lr': 0.007081823146059281, 'generator_decay': 2.3273254308885205e-06, 'discriminator_decay': 6.792336940806449e-07}. Best is trial 0 with value: 0.6779375310332731.
# [OK] TRTS (Synthetic->Real): 0.4167
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.4633
# [CHART] Combined Score: 0.5062 (Similarity: 0.5347, Accuracy: 0.4633)
# 🎯 Trial 2 Results:
#    • Combined Score: 0.5062
#    • Similarity: 0.5347
#    • Accuracy: 0.4633
#
# 🔄 CopulaGAN Trial 3: epochs=200, batch_size=500
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 20.5 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5479
# [I 2025-11-05 19:09:57,848] Trial 2 finished with value: 0.5415992295577863 and parameters: {'epochs': 200, 'batch_size': 500, 'generator_lr': 0.004964100228459133, 'discriminator_lr': 0.0023164206905858004, 'generator_decay': 1.770947805322254e-07, 'discriminator_decay': 5.174410431139811e-07}. Best is trial 0 with value: 0.6779375310332731.
# [OK] TRTS (Synthetic->Real): 0.5384
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.5321
# [CHART] Combined Score: 0.5416 (Similarity: 0.5479, Accuracy: 0.5321)
# 🎯 Trial 3 Results:
#    • Combined Score: 0.5416
#    • Similarity: 0.5479
#    • Accuracy: 0.5321
#
# 🔄 CopulaGAN Trial 4: epochs=200, batch_size=200
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 57.8 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5327
# [I 2025-11-05 19:10:57,573] Trial 3 finished with value: 0.6212020474571867 and parameters: {'epochs': 200, 'batch_size': 200, 'generator_lr': 0.00851994667784914, 'discriminator_lr': 0.0003706462381418257, 'generator_decay': 5.453502796518602e-06, 'discriminator_decay': 1.5342039750080536e-05}. Best is trial 0 with value: 0.6779375310332731.
# [OK] TRTS (Synthetic->Real): 0.8947
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.7540
# [CHART] Combined Score: 0.6212 (Similarity: 0.5327, Accuracy: 0.7540)
# 🎯 Trial 4 Results:
#    • Combined Score: 0.6212
#    • Similarity: 0.5327
#    • Accuracy: 0.7540
#
# 🔄 CopulaGAN Trial 5: epochs=200, batch_size=200
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 58.1 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5132
# [I 2025-11-05 19:11:57,611] Trial 4 finished with value: 0.5936433948082237 and parameters: {'epochs': 200, 'batch_size': 200, 'generator_lr': 0.004062838924856345, 'discriminator_lr': 1.2633180922348513e-05, 'generator_decay': 2.6380980067497696e-05, 'discriminator_decay': 1.0971193238322234e-07}. Best is trial 0 with value: 0.6779375310332731.
# [OK] TRTS (Synthetic->Real): 0.9002
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.7143
# [CHART] Combined Score: 0.5936 (Similarity: 0.5132, Accuracy: 0.7143)
# 🎯 Trial 5 Results:
#    • Combined Score: 0.5936
#    • Similarity: 0.5132
#    • Accuracy: 0.7143
#
# 🔄 CopulaGAN Trial 6: epochs=500, batch_size=100
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 238.8 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5873
# [I 2025-11-05 19:15:58,500] Trial 5 finished with value: 0.7304511312727215 and parameters: {'epochs': 500, 'batch_size': 100, 'generator_lr': 5.041389481706064e-05, 'discriminator_lr': 0.0004933422914702964, 'generator_decay': 2.806621001479141e-07, 'discriminator_decay': 2.5554218656181783e-06}. Best is trial 5 with value: 0.7304511312727215.
# [OK] TRTS (Synthetic->Real): 0.9825
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9451
# [CHART] Combined Score: 0.7305 (Similarity: 0.5873, Accuracy: 0.9451)
# 🎯 Trial 6 Results:
#    • Combined Score: 0.7305
#    • Similarity: 0.5873
#    • Accuracy: 0.9451
#
# 🔄 CopulaGAN Trial 7: epochs=150, batch_size=500
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 16.0 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5357
# [I 2025-11-05 19:16:16,337] Trial 6 finished with value: 0.5036162582849812 and parameters: {'epochs': 150, 'batch_size': 500, 'generator_lr': 0.0001829531159169381, 'discriminator_lr': 0.0007495595892836664, 'generator_decay': 9.656130233319114e-05, 'discriminator_decay': 2.544776409006488e-06}. Best is trial 5 with value: 0.7304511312727215.
# [OK] TRTS (Synthetic->Real): 0.4178
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.4555
# [CHART] Combined Score: 0.5036 (Similarity: 0.5357, Accuracy: 0.4555)
# 🎯 Trial 7 Results:
#    • Combined Score: 0.5036
#    • Similarity: 0.5357
#    • Accuracy: 0.4555
#
# 🔄 CopulaGAN Trial 8: epochs=100, batch_size=200
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 27.7 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5325
# [I 2025-11-05 19:16:45,820] Trial 7 finished with value: 0.5360468987325192 and parameters: {'epochs': 100, 'batch_size': 200, 'generator_lr': 0.0008594007282902874, 'discriminator_lr': 0.00016698212025309623, 'generator_decay': 1.1284519956643373e-07, 'discriminator_decay': 1.6507059326095358e-06}. Best is trial 5 with value: 0.7304511312727215.
# [OK] TRTS (Synthetic->Real): 0.5428
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.5414
# [CHART] Combined Score: 0.5360 (Similarity: 0.5325, Accuracy: 0.5414)
# 🎯 Trial 8 Results:
#    • Combined Score: 0.5360
#    • Similarity: 0.5325
#    • Accuracy: 0.5414
#
# 🔄 CopulaGAN Trial 9: epochs=200, batch_size=500
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 19.7 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5342
# [I 2025-11-05 19:17:07,839] Trial 8 finished with value: 0.530199973195381 and parameters: {'epochs': 200, 'batch_size': 500, 'generator_lr': 0.00034148376939942753, 'discriminator_lr': 2.9888739475906516e-05, 'generator_decay': 1.6492206580928035e-06, 'discriminator_decay': 1.8698837249475575e-06}. Best is trial 5 with value: 0.7304511312727215.
# [OK] TRTS (Synthetic->Real): 0.5110
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.5242
# [CHART] Combined Score: 0.5302 (Similarity: 0.5342, Accuracy: 0.5242)
# 🎯 Trial 9 Results:
#    • Combined Score: 0.5302
#    • Similarity: 0.5342
#    • Accuracy: 0.5242
#
# 🔄 CopulaGAN Trial 10: epochs=100, batch_size=200
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 26.4 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5728
# [I 2025-11-05 19:17:36,323] Trial 9 finished with value: 0.549241541871387 and parameters: {'epochs': 100, 'batch_size': 200, 'generator_lr': 0.009800728715977113, 'discriminator_lr': 0.0010998054150850847, 'generator_decay': 4.8434069225364465e-05, 'discriminator_decay': 1.5156608384075035e-08}. Best is trial 5 with value: 0.7304511312727215.
# [OK] TRTS (Synthetic->Real): 0.5000
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.5139
# [CHART] Combined Score: 0.5492 (Similarity: 0.5728, Accuracy: 0.5139)
# 🎯 Trial 10 Results:
#    • Combined Score: 0.5492
#    • Similarity: 0.5728
#    • Accuracy: 0.5139
#
# 🔄 CopulaGAN Trial 11: epochs=500, batch_size=100
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 222.2 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6237
# [I 2025-11-05 19:21:20,702] Trial 10 finished with value: 0.7509045589981704 and parameters: {'epochs': 500, 'batch_size': 100, 'generator_lr': 1.2332279725710795e-05, 'discriminator_lr': 8.97018868893898e-05, 'generator_decay': 1.443866192190459e-07, 'discriminator_decay': 9.4880943685767e-05}. Best is trial 10 with value: 0.7509045589981704.
# [OK] TRTS (Synthetic->Real): 0.9923
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9418
# [CHART] Combined Score: 0.7509 (Similarity: 0.6237, Accuracy: 0.9418)
# 🎯 Trial 11 Results:
#    • Combined Score: 0.7509
#    • Similarity: 0.6237
#    • Accuracy: 0.9418
#
# 🔄 CopulaGAN Trial 12: epochs=500, batch_size=100
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 228.6 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6191
# [I 2025-11-05 19:25:11,470] Trial 11 finished with value: 0.7495406349291911 and parameters: {'epochs': 500, 'batch_size': 100, 'generator_lr': 1.020957348554539e-05, 'discriminator_lr': 0.00010329251774484369, 'generator_decay': 1.9818588202453092e-07, 'discriminator_decay': 5.94683435272975e-05}. Best is trial 10 with value: 0.7509045589981704.
# [OK] TRTS (Synthetic->Real): 0.9879
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9452
# [CHART] Combined Score: 0.7495 (Similarity: 0.6191, Accuracy: 0.9452)
# 🎯 Trial 12 Results:
#    • Combined Score: 0.7495
#    • Similarity: 0.6191
#    • Accuracy: 0.9452
#
# 🔄 CopulaGAN Trial 13: epochs=500, batch_size=100
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 231.5 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6090
# [I 2025-11-05 19:29:04,654] Trial 12 finished with value: 0.740530118278452 and parameters: {'epochs': 500, 'batch_size': 100, 'generator_lr': 1.1212024640260402e-05, 'discriminator_lr': 9.022785298289982e-05, 'generator_decay': 1.234675229546731e-08, 'discriminator_decay': 9.574182966282227e-05}. Best is trial 10 with value: 0.7509045589981704.
# [OK] TRTS (Synthetic->Real): 0.9879
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9378
# [CHART] Combined Score: 0.7405 (Similarity: 0.6090, Accuracy: 0.9378)
# 🎯 Trial 13 Results:
#    • Combined Score: 0.7405
#    • Similarity: 0.6090
#    • Accuracy: 0.9378
#
# 🔄 CopulaGAN Trial 14: epochs=400, batch_size=100
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 173.9 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5855
# [I 2025-11-05 19:32:00,260] Trial 13 finished with value: 0.7216328743337168 and parameters: {'epochs': 400, 'batch_size': 100, 'generator_lr': 1.579748653944355e-05, 'discriminator_lr': 6.848996343735702e-05, 'generator_decay': 5.602652895180329e-08, 'discriminator_decay': 2.3638251371190325e-05}. Best is trial 10 with value: 0.7509045589981704.
# [OK] TRTS (Synthetic->Real): 0.9660
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9259
# [CHART] Combined Score: 0.7216 (Similarity: 0.5855, Accuracy: 0.9259)
# 🎯 Trial 14 Results:
#    • Combined Score: 0.7216
#    • Similarity: 0.5855
#    • Accuracy: 0.9259
#
# 🔄 CopulaGAN Trial 15: epochs=400, batch_size=100
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 176.5 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5952
# [I 2025-11-05 19:34:58,439] Trial 14 finished with value: 0.7308446291363315 and parameters: {'epochs': 400, 'batch_size': 100, 'generator_lr': 4.347985637252541e-05, 'discriminator_lr': 3.244020680093317e-05, 'generator_decay': 5.398163593156428e-07, 'discriminator_decay': 8.507946738150598e-05}. Best is trial 10 with value: 0.7509045589981704.
# [OK] TRTS (Synthetic->Real): 0.9868
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9343
# [CHART] Combined Score: 0.7308 (Similarity: 0.5952, Accuracy: 0.9343)
# 🎯 Trial 15 Results:
#    • Combined Score: 0.7308
#    • Similarity: 0.5952
#    • Accuracy: 0.9343
#
# 🔄 CopulaGAN Trial 16: epochs=450, batch_size=100
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 194.5 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5997
# [I 2025-11-05 19:38:14,774] Trial 15 finished with value: 0.7336459786882343 and parameters: {'epochs': 450, 'batch_size': 100, 'generator_lr': 3.559829648405896e-05, 'discriminator_lr': 0.00016876132345566874, 'generator_decay': 4.0542354953267165e-08, 'discriminator_decay': 9.050340845203737e-06}. Best is trial 10 with value: 0.7509045589981704.
# [OK] TRTS (Synthetic->Real): 0.9890
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9345
# [CHART] Combined Score: 0.7336 (Similarity: 0.5997, Accuracy: 0.9345)
# 🎯 Trial 16 Results:
#    • Combined Score: 0.7336
#    • Similarity: 0.5997
#    • Accuracy: 0.9345
#
# 🔄 CopulaGAN Trial 17: epochs=300, batch_size=100
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 135.3 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5556
# [I 2025-11-05 19:40:31,764] Trial 16 finished with value: 0.6987935984734881 and parameters: {'epochs': 300, 'batch_size': 100, 'generator_lr': 2.1296186888201818e-05, 'discriminator_lr': 4.803138303014407e-05, 'generator_decay': 5.282674113960398e-07, 'discriminator_decay': 7.626480674095686e-06}. Best is trial 10 with value: 0.7509045589981704.
# [OK] TRTS (Synthetic->Real): 0.9759
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9136
# [CHART] Combined Score: 0.6988 (Similarity: 0.5556, Accuracy: 0.9136)
# 🎯 Trial 17 Results:
#    • Combined Score: 0.6988
#    • Similarity: 0.5556
#    • Accuracy: 0.9136
#
# 🔄 CopulaGAN Trial 18: epochs=450, batch_size=100
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 196.0 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5965
# [I 2025-11-05 19:43:49,421] Trial 17 finished with value: 0.732469645996479 and parameters: {'epochs': 450, 'batch_size': 100, 'generator_lr': 8.673694548331747e-05, 'discriminator_lr': 1.5037900839917514e-05, 'generator_decay': 6.3261290976623e-06, 'discriminator_decay': 5.6964016204102003e-05}. Best is trial 10 with value: 0.7509045589981704.
# [OK] TRTS (Synthetic->Real): 0.9846
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9364
# [CHART] Combined Score: 0.7325 (Similarity: 0.5965, Accuracy: 0.9364)
# 🎯 Trial 18 Results:
#    • Combined Score: 0.7325
#    • Similarity: 0.5965
#    • Accuracy: 0.9364
#
# 🔄 CopulaGAN Trial 19: epochs=350, batch_size=100
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 153.4 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5728
# [I 2025-11-05 19:46:24,502] Trial 18 finished with value: 0.7084438879295392 and parameters: {'epochs': 350, 'batch_size': 100, 'generator_lr': 0.0009947853683256551, 'discriminator_lr': 0.00019023239204146757, 'generator_decay': 4.1309702416940575e-08, 'discriminator_decay': 2.0846002318064985e-07}. Best is trial 10 with value: 0.7509045589981704.
# [OK] TRTS (Synthetic->Real): 0.9561
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9119
# [CHART] Combined Score: 0.7084 (Similarity: 0.5728, Accuracy: 0.9119)
# 🎯 Trial 19 Results:
#    • Combined Score: 0.7084
#    • Similarity: 0.5728
#    • Accuracy: 0.9119
#
# 🔄 CopulaGAN Trial 20: epochs=500, batch_size=100
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 215.5 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6140
# [I 2025-11-05 19:50:02,200] Trial 19 finished with value: 0.7445906954120904 and parameters: {'epochs': 500, 'batch_size': 100, 'generator_lr': 1.007702132567576e-05, 'discriminator_lr': 0.0001029494947372072, 'generator_decay': 8.720450949099462e-08, 'discriminator_decay': 5.240487375590035e-06}. Best is trial 10 with value: 0.7509045589981704.
# [OK] TRTS (Synthetic->Real): 0.9846
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9404
# [CHART] Combined Score: 0.7446 (Similarity: 0.6140, Accuracy: 0.9404)
# 🎯 Trial 20 Results:
#    • Combined Score: 0.7446
#    • Similarity: 0.6140
#    • Accuracy: 0.9404
#
# 🔄 CopulaGAN Trial 21: epochs=450, batch_size=100
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 192.8 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6026
# [I 2025-11-05 19:53:17,155] Trial 20 finished with value: 0.7360510658865589 and parameters: {'epochs': 450, 'batch_size': 100, 'generator_lr': 2.5159828601295244e-05, 'discriminator_lr': 2.6273610984502277e-05, 'generator_decay': 4.779510568811382e-07, 'discriminator_decay': 3.857140347901162e-05}. Best is trial 10 with value: 0.7509045589981704.
# [OK] TRTS (Synthetic->Real): 0.9868
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9362
# [CHART] Combined Score: 0.7361 (Similarity: 0.6026, Accuracy: 0.9362)
# 🎯 Trial 21 Results:
#    • Combined Score: 0.7361
#    • Similarity: 0.6026
#    • Accuracy: 0.9362
#
# 🔄 CopulaGAN Trial 22: epochs=500, batch_size=100
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 214.2 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6522
# [I 2025-11-05 19:56:53,558] Trial 21 finished with value: 0.7672079131185447 and parameters: {'epochs': 500, 'batch_size': 100, 'generator_lr': 1.0890284891781855e-05, 'discriminator_lr': 8.924578567594168e-05, 'generator_decay': 9.447062089525266e-08, 'discriminator_decay': 6.487869822916734e-06}. Best is trial 21 with value: 0.7672079131185447.
# [OK] TRTS (Synthetic->Real): 0.9901
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9398
# [CHART] Combined Score: 0.7672 (Similarity: 0.6522, Accuracy: 0.9398)
# 🎯 Trial 22 Results:
#    • Combined Score: 0.7672
#    • Similarity: 0.6522
#    • Accuracy: 0.9398
#
# 🔄 CopulaGAN Trial 23: epochs=400, batch_size=100
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 175.4 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5912
# [I 2025-11-05 19:59:51,291] Trial 22 finished with value: 0.7240038428002316 and parameters: {'epochs': 400, 'batch_size': 100, 'generator_lr': 8.050461252195366e-05, 'discriminator_lr': 0.0002302575337886053, 'generator_decay': 1.8981623794853338e-07, 'discriminator_decay': 1.4791584519545151e-05}. Best is trial 21 with value: 0.7672079131185447.
# [OK] TRTS (Synthetic->Real): 0.9715
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9232
# [CHART] Combined Score: 0.7240 (Similarity: 0.5912, Accuracy: 0.9232)
# 🎯 Trial 23 Results:
#    • Combined Score: 0.7240
#    • Similarity: 0.5912
#    • Accuracy: 0.9232
#
# 🔄 CopulaGAN Trial 24: epochs=500, batch_size=100
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 220.0 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5846
# [I 2025-11-05 20:03:33,022] Trial 23 finished with value: 0.7293564499694832 and parameters: {'epochs': 500, 'batch_size': 100, 'generator_lr': 1.8783642532302727e-05, 'discriminator_lr': 6.38467386663567e-05, 'generator_decay': 1.1335998768166584e-06, 'discriminator_decay': 3.7047480636736065e-05}. Best is trial 21 with value: 0.7672079131185447.
# [OK] TRTS (Synthetic->Real): 0.9868
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9464
# [CHART] Combined Score: 0.7294 (Similarity: 0.5846, Accuracy: 0.9464)
# 🎯 Trial 24 Results:
#    • Combined Score: 0.7294
#    • Similarity: 0.5846
#    • Accuracy: 0.9464
#
# 🔄 CopulaGAN Trial 25: epochs=450, batch_size=100
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 194.1 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6360
# [I 2025-11-05 20:06:48,955] Trial 24 finished with value: 0.7552219780828627 and parameters: {'epochs': 450, 'batch_size': 100, 'generator_lr': 1.1492976183046536e-05, 'discriminator_lr': 0.00010544968991476789, 'generator_decay': 2.6089328028138946e-08, 'discriminator_decay': 4.954272429095973e-06}. Best is trial 21 with value: 0.7672079131185447.
# [OK] TRTS (Synthetic->Real): 0.9868
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9341
# [CHART] Combined Score: 0.7552 (Similarity: 0.6360, Accuracy: 0.9341)
# 🎯 Trial 25 Results:
#    • Combined Score: 0.7552
#    • Similarity: 0.6360
#    • Accuracy: 0.9341
#
# 🔄 CopulaGAN Trial 26: epochs=450, batch_size=100
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 196.1 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5768
# [I 2025-11-05 20:10:06,826] Trial 25 finished with value: 0.7209273179576008 and parameters: {'epochs': 450, 'batch_size': 100, 'generator_lr': 2.7178004678845815e-05, 'discriminator_lr': 3.9870479799403234e-05, 'generator_decay': 2.206223955544212e-08, 'discriminator_decay': 5.236546566405646e-06}. Best is trial 21 with value: 0.7672079131185447.
# [OK] TRTS (Synthetic->Real): 0.9857
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9372
# [CHART] Combined Score: 0.7209 (Similarity: 0.5768, Accuracy: 0.9372)
# 🎯 Trial 26 Results:
#    • Combined Score: 0.7209
#    • Similarity: 0.5768
#    • Accuracy: 0.9372
#
# 🔄 CopulaGAN Trial 27: epochs=300, batch_size=100
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 139.3 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5543
# [I 2025-11-05 20:12:27,881] Trial 26 finished with value: 0.7040156648232903 and parameters: {'epochs': 300, 'batch_size': 100, 'generator_lr': 6.945433068734628e-05, 'discriminator_lr': 1.9404476117263012e-05, 'generator_decay': 2.995515665189074e-08, 'discriminator_decay': 6.24974027165543e-08}. Best is trial 21 with value: 0.7672079131185447.
# [OK] TRTS (Synthetic->Real): 0.9868
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9286
# [CHART] Combined Score: 0.7040 (Similarity: 0.5543, Accuracy: 0.9286)
# 🎯 Trial 27 Results:
#    • Combined Score: 0.7040
#    • Similarity: 0.5543
#    • Accuracy: 0.9286
#
# 🔄 CopulaGAN Trial 28: epochs=350, batch_size=100
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 158.9 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5750
# [I 2025-11-05 20:15:08,619] Trial 27 finished with value: 0.713274129571094 and parameters: {'epochs': 350, 'batch_size': 100, 'generator_lr': 1.541903687339932e-05, 'discriminator_lr': 0.00011414812016824575, 'generator_decay': 9.428466437006946e-08, 'discriminator_decay': 3.8512068192252193e-07}. Best is trial 21 with value: 0.7672079131185447.
# [OK] TRTS (Synthetic->Real): 0.9737
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9206
# [CHART] Combined Score: 0.7133 (Similarity: 0.5750, Accuracy: 0.9206)
# 🎯 Trial 28 Results:
#    • Combined Score: 0.7133
#    • Similarity: 0.5750
#    • Accuracy: 0.9206
#
# 🔄 CopulaGAN Trial 29: epochs=400, batch_size=100
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 176.2 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5634
# [I 2025-11-05 20:18:06,187] Trial 28 finished with value: 0.7138289250697119 and parameters: {'epochs': 400, 'batch_size': 100, 'generator_lr': 0.00016548057376074464, 'discriminator_lr': 0.0005513785496633944, 'generator_decay': 2.688415565208993e-08, 'discriminator_decay': 3.962579335812408e-06}. Best is trial 21 with value: 0.7672079131185447.
# [OK] TRTS (Synthetic->Real): 0.9857
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9395
# [CHART] Combined Score: 0.7138 (Similarity: 0.5634, Accuracy: 0.9395)
# 🎯 Trial 29 Results:
#    • Combined Score: 0.7138
#    • Similarity: 0.5634
#    • Accuracy: 0.9395
#
# 🔄 CopulaGAN Trial 30: epochs=450, batch_size=500
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 23.1 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5695
# [I 2025-11-05 20:18:30,465] Trial 29 finished with value: 0.5322969745812356 and parameters: {'epochs': 450, 'batch_size': 500, 'generator_lr': 3.261698530009223e-05, 'discriminator_lr': 0.00029799562293626194, 'generator_decay': 1.205788184815886e-08, 'discriminator_decay': 1.1054390217312035e-06}. Best is trial 21 with value: 0.7672079131185447.
# [OK] TRTS (Synthetic->Real): 0.4353
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.4765
# [CHART] Combined Score: 0.5323 (Similarity: 0.5695, Accuracy: 0.4765)
# 🎯 Trial 30 Results:
#    • Combined Score: 0.5323
#    • Similarity: 0.5695
#    • Accuracy: 0.4765
#
# 🔄 CopulaGAN Trial 31: epochs=350, batch_size=200
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 58.0 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5596
# [I 2025-11-05 20:19:29,777] Trial 30 finished with value: 0.6948959663311017 and parameters: {'epochs': 350, 'batch_size': 200, 'generator_lr': 0.0006358496550291067, 'discriminator_lr': 5.844096920496036e-05, 'generator_decay': 8.663391751759974e-08, 'discriminator_decay': 1.528127490166618e-05}. Best is trial 21 with value: 0.7672079131185447.
# [OK] TRTS (Synthetic->Real): 0.9792
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.8979
# [CHART] Combined Score: 0.6949 (Similarity: 0.5596, Accuracy: 0.8979)
# 🎯 Trial 31 Results:
#    • Combined Score: 0.6949
#    • Similarity: 0.5596
#    • Accuracy: 0.8979
#
# 🔄 CopulaGAN Trial 32: epochs=500, batch_size=100
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 171.3 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6143
# [I 2025-11-05 20:22:22,739] Trial 31 finished with value: 0.7443022266655575 and parameters: {'epochs': 500, 'batch_size': 100, 'generator_lr': 1.0379380034888934e-05, 'discriminator_lr': 9.152921613024251e-05, 'generator_decay': 3.0859506026409463e-07, 'discriminator_decay': 2.67428516610614e-05}. Best is trial 21 with value: 0.7672079131185447.
# [OK] TRTS (Synthetic->Real): 0.9879
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9393
# [CHART] Combined Score: 0.7443 (Similarity: 0.6143, Accuracy: 0.9393)
# 🎯 Trial 32 Results:
#    • Combined Score: 0.7443
#    • Similarity: 0.6143
#    • Accuracy: 0.9393
#
# 🔄 CopulaGAN Trial 33: epochs=500, batch_size=100
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 169.7 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6247
# [I 2025-11-05 20:25:13,975] Trial 32 finished with value: 0.7504898851192254 and parameters: {'epochs': 500, 'batch_size': 100, 'generator_lr': 1.7151401123159616e-05, 'discriminator_lr': 0.00013122162967380149, 'generator_decay': 1.573483768383015e-07, 'discriminator_decay': 5.5303123043872016e-05}. Best is trial 21 with value: 0.7672079131185447.
# [OK] TRTS (Synthetic->Real): 0.9759
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9391
# [CHART] Combined Score: 0.7505 (Similarity: 0.6247, Accuracy: 0.9391)
# 🎯 Trial 33 Results:
#    • Combined Score: 0.7505
#    • Similarity: 0.6247
#    • Accuracy: 0.9391
#
# 🔄 CopulaGAN Trial 34: epochs=450, batch_size=100
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 153.1 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6361
# [I 2025-11-05 20:27:48,451] Trial 33 finished with value: 0.755388107739247 and parameters: {'epochs': 450, 'batch_size': 100, 'generator_lr': 1.724415908747354e-05, 'discriminator_lr': 0.00013397662531179158, 'generator_decay': 1.77069244189694e-08, 'discriminator_decay': 1.080003076257184e-05}. Best is trial 21 with value: 0.7672079131185447.
# [OK] TRTS (Synthetic->Real): 0.9814
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9343
# [CHART] Combined Score: 0.7554 (Similarity: 0.6361, Accuracy: 0.9343)
# 🎯 Trial 34 Results:
#    • Combined Score: 0.7554
#    • Similarity: 0.6361
#    • Accuracy: 0.9343
#
# 🔄 CopulaGAN Trial 35: epochs=450, batch_size=500
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 22.5 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5101
# [I 2025-11-05 20:28:12,038] Trial 34 finished with value: 0.5472162469411895 and parameters: {'epochs': 450, 'batch_size': 500, 'generator_lr': 5.345094130552251e-05, 'discriminator_lr': 0.0002856938616425593, 'generator_decay': 2.0183115501771015e-08, 'discriminator_decay': 8.684514478393607e-06}. Best is trial 21 with value: 0.7672079131185447.
# [OK] TRTS (Synthetic->Real): 0.5329
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.6028
# [CHART] Combined Score: 0.5472 (Similarity: 0.5101, Accuracy: 0.6028)
# 🎯 Trial 35 Results:
#    • Combined Score: 0.5472
#    • Similarity: 0.5101
#    • Accuracy: 0.6028
#
# 🔄 CopulaGAN Trial 36: epochs=400, batch_size=100
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 133.1 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5628
# [I 2025-11-05 20:30:26,583] Trial 35 finished with value: 0.7119263495095658 and parameters: {'epochs': 400, 'batch_size': 100, 'generator_lr': 1.592692646435548e-05, 'discriminator_lr': 0.005411516079642614, 'generator_decay': 5.714235368781858e-08, 'discriminator_decay': 8.037857543596552e-07}. Best is trial 21 with value: 0.7672079131185447.
# [OK] TRTS (Synthetic->Real): 0.9857
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9356
# [CHART] Combined Score: 0.7119 (Similarity: 0.5628, Accuracy: 0.9356)
# 🎯 Trial 36 Results:
#    • Combined Score: 0.7119
#    • Similarity: 0.5628
#    • Accuracy: 0.9356
#
# 🔄 CopulaGAN Trial 37: epochs=450, batch_size=100
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 150.9 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5854
# [I 2025-11-05 20:32:58,866] Trial 36 finished with value: 0.7268912155375515 and parameters: {'epochs': 450, 'batch_size': 100, 'generator_lr': 0.0021005012606370482, 'discriminator_lr': 0.002199814389614798, 'generator_decay': 1.5634080659390826e-08, 'discriminator_decay': 1.7994978964421603e-05}. Best is trial 21 with value: 0.7672079131185447.
# [OK] TRTS (Synthetic->Real): 0.9890
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9391
# [CHART] Combined Score: 0.7269 (Similarity: 0.5854, Accuracy: 0.9391)
# 🎯 Trial 37 Results:
#    • Combined Score: 0.7269
#    • Similarity: 0.5854
#    • Accuracy: 0.9391
#
# 🔄 CopulaGAN Trial 38: epochs=50, batch_size=200
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 11.2 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5459
# [I 2025-11-05 20:33:11,235] Trial 37 finished with value: 0.5129284992734051 and parameters: {'epochs': 50, 'batch_size': 200, 'generator_lr': 2.6178314523877882e-05, 'discriminator_lr': 0.00040442318775788866, 'generator_decay': 6.150484765625694e-08, 'discriminator_decay': 3.918627258402713e-06}. Best is trial 21 with value: 0.7672079131185447.
# [OK] TRTS (Synthetic->Real): 0.3936
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.4635
# [CHART] Combined Score: 0.5129 (Similarity: 0.5459, Accuracy: 0.4635)
# 🎯 Trial 38 Results:
#    • Combined Score: 0.5129
#    • Similarity: 0.5459
#    • Accuracy: 0.4635
#
# 🔄 CopulaGAN Trial 39: epochs=250, batch_size=500
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 14.7 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5378
# [I 2025-11-05 20:33:27,235] Trial 38 finished with value: 0.5544600028987761 and parameters: {'epochs': 250, 'batch_size': 500, 'generator_lr': 1.457256683328644e-05, 'discriminator_lr': 6.906993622819702e-05, 'generator_decay': 4.922950039595593e-06, 'discriminator_decay': 1.1298548399140194e-05}. Best is trial 21 with value: 0.7672079131185447.
# [OK] TRTS (Synthetic->Real): 0.5932
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.5795
# [CHART] Combined Score: 0.5545 (Similarity: 0.5378, Accuracy: 0.5795)
# 🎯 Trial 39 Results:
#    • Combined Score: 0.5545
#    • Similarity: 0.5378
#    • Accuracy: 0.5795
#
# 🔄 CopulaGAN Trial 40: epochs=500, batch_size=100
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 168.3 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5855
# [I 2025-11-05 20:36:17,021] Trial 39 finished with value: 0.7247010137528052 and parameters: {'epochs': 500, 'batch_size': 100, 'generator_lr': 0.0001156405373202525, 'discriminator_lr': 0.0001509781584280613, 'generator_decay': 2.7733820691705906e-08, 'discriminator_decay': 1.2444295123529838e-06}. Best is trial 21 with value: 0.7672079131185447.
# [OK] TRTS (Synthetic->Real): 0.9868
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9335
# [CHART] Combined Score: 0.7247 (Similarity: 0.5855, Accuracy: 0.9335)
# 🎯 Trial 40 Results:
#    • Combined Score: 0.7247
#    • Similarity: 0.5855
#    • Accuracy: 0.9335
#
# 🔄 CopulaGAN Trial 41: epochs=350, batch_size=200
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 56.9 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5380
# [I 2025-11-05 20:37:15,270] Trial 40 finished with value: 0.6843692873620785 and parameters: {'epochs': 350, 'batch_size': 200, 'generator_lr': 5.2407007717892895e-05, 'discriminator_lr': 0.0010230191029292047, 'generator_decay': 3.9248296745271637e-08, 'discriminator_decay': 3.5266593423029622e-06}. Best is trial 21 with value: 0.7672079131185447.
# [OK] TRTS (Synthetic->Real): 0.9836
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9040
# [CHART] Combined Score: 0.6844 (Similarity: 0.5380, Accuracy: 0.9040)
# 🎯 Trial 41 Results:
#    • Combined Score: 0.6844
#    • Similarity: 0.5380
#    • Accuracy: 0.9040
#
# 🔄 CopulaGAN Trial 42: epochs=500, batch_size=100
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 170.8 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6144
# [I 2025-11-05 20:40:07,488] Trial 41 finished with value: 0.7416993353869052 and parameters: {'epochs': 500, 'batch_size': 100, 'generator_lr': 2.1313274591439756e-05, 'discriminator_lr': 0.00023985479299730583, 'generator_decay': 1.2579488667202306e-07, 'discriminator_decay': 5.083005215496428e-05}. Best is trial 21 with value: 0.7672079131185447.
# [OK] TRTS (Synthetic->Real): 0.9857
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9327
# [CHART] Combined Score: 0.7417 (Similarity: 0.6144, Accuracy: 0.9327)
# 🎯 Trial 42 Results:
#    • Combined Score: 0.7417
#    • Similarity: 0.6144
#    • Accuracy: 0.9327
#
# 🔄 CopulaGAN Trial 43: epochs=450, batch_size=100
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 150.3 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6289
# [I 2025-11-05 20:42:39,170] Trial 42 finished with value: 0.7493188063722256 and parameters: {'epochs': 450, 'batch_size': 100, 'generator_lr': 1.3827749916457122e-05, 'discriminator_lr': 0.0001436624177546389, 'generator_decay': 1.3441408568115832e-07, 'discriminator_decay': 9.041894453779025e-05}. Best is trial 21 with value: 0.7672079131185447.
# [OK] TRTS (Synthetic->Real): 0.9836
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9299
# [CHART] Combined Score: 0.7493 (Similarity: 0.6289, Accuracy: 0.9299)
# 🎯 Trial 43 Results:
#    • Combined Score: 0.7493
#    • Similarity: 0.6289
#    • Accuracy: 0.9299
#
# 🔄 CopulaGAN Trial 44: epochs=500, batch_size=100
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 169.1 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6127
# [I 2025-11-05 20:45:29,602] Trial 43 finished with value: 0.7410316125091659 and parameters: {'epochs': 500, 'batch_size': 100, 'generator_lr': 3.6589326776554964e-05, 'discriminator_lr': 4.482553594600672e-05, 'generator_decay': 1.653167632666922e-08, 'discriminator_decay': 2.6814741524351353e-05}. Best is trial 21 with value: 0.7672079131185447.
# [OK] TRTS (Synthetic->Real): 0.9857
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9336
# [CHART] Combined Score: 0.7410 (Similarity: 0.6127, Accuracy: 0.9336)
# 🎯 Trial 44 Results:
#    • Combined Score: 0.7410
#    • Similarity: 0.6127
#    • Accuracy: 0.9336
#
# 🔄 CopulaGAN Trial 45: epochs=500, batch_size=100
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 166.9 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6401
# [I 2025-11-05 20:48:18,103] Trial 44 finished with value: 0.7586800252367072 and parameters: {'epochs': 500, 'batch_size': 100, 'generator_lr': 2.0498530795584592e-05, 'discriminator_lr': 0.00012461765444621463, 'generator_decay': 2.760533995376544e-07, 'discriminator_decay': 2.1581297973430493e-06}. Best is trial 21 with value: 0.7672079131185447.
# [OK] TRTS (Synthetic->Real): 0.9890
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9366
# [CHART] Combined Score: 0.7587 (Similarity: 0.6401, Accuracy: 0.9366)
# 🎯 Trial 45 Results:
#    • Combined Score: 0.7587
#    • Similarity: 0.6401
#    • Accuracy: 0.9366
#
# 🔄 CopulaGAN Trial 46: epochs=400, batch_size=100
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 134.9 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5942
# [I 2025-11-05 20:50:34,321] Trial 45 finished with value: 0.7292736943760181 and parameters: {'epochs': 400, 'batch_size': 100, 'generator_lr': 1.2929646033378348e-05, 'discriminator_lr': 7.205601613925683e-05, 'generator_decay': 2.9244804228843467e-07, 'discriminator_decay': 2.1391386985412794e-06}. Best is trial 21 with value: 0.7672079131185447.
# [OK] TRTS (Synthetic->Real): 0.9868
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9319
# [CHART] Combined Score: 0.7293 (Similarity: 0.5942, Accuracy: 0.9319)
# 🎯 Trial 46 Results:
#    • Combined Score: 0.7293
#    • Similarity: 0.5942
#    • Accuracy: 0.9319
#
# 🔄 CopulaGAN Trial 47: epochs=450, batch_size=500
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 23.1 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5534
# [I 2025-11-05 20:50:58,724] Trial 46 finished with value: 0.6030984704028263 and parameters: {'epochs': 450, 'batch_size': 500, 'generator_lr': 2.1291837641023326e-05, 'discriminator_lr': 0.00018187111945385415, 'generator_decay': 7.600154864076052e-07, 'discriminator_decay': 5.633797110052824e-07}. Best is trial 21 with value: 0.7672079131185447.
# [OK] TRTS (Synthetic->Real): 0.8070
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.6776
# [CHART] Combined Score: 0.6031 (Similarity: 0.5534, Accuracy: 0.6776)
# 🎯 Trial 47 Results:
#    • Combined Score: 0.6031
#    • Similarity: 0.5534
#    • Accuracy: 0.6776
#
# 🔄 CopulaGAN Trial 48: epochs=500, batch_size=100
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 167.7 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6252
# [I 2025-11-05 20:53:47,990] Trial 47 finished with value: 0.7500046768462623 and parameters: {'epochs': 500, 'batch_size': 100, 'generator_lr': 0.000357481178076665, 'discriminator_lr': 0.0006040194598825947, 'generator_decay': 6.986937698984335e-08, 'discriminator_decay': 6.360782406258213e-06}. Best is trial 21 with value: 0.7672079131185447.
# [OK] TRTS (Synthetic->Real): 0.9737
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9371
# [CHART] Combined Score: 0.7500 (Similarity: 0.6252, Accuracy: 0.9371)
# 🎯 Trial 48 Results:
#    • Combined Score: 0.7500
#    • Similarity: 0.6252
#    • Accuracy: 0.9371
#
# 🔄 CopulaGAN Trial 49: epochs=450, batch_size=100
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 151.0 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6007
# [I 2025-11-05 20:56:20,594] Trial 48 finished with value: 0.7357113555002921 and parameters: {'epochs': 450, 'batch_size': 100, 'generator_lr': 3.408871839007875e-05, 'discriminator_lr': 8.432609601850638e-05, 'generator_decay': 2.7561364355581746e-07, 'discriminator_decay': 2.8110663027677985e-06}. Best is trial 21 with value: 0.7672079131185447.
# [OK] TRTS (Synthetic->Real): 0.9890
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9382
# [CHART] Combined Score: 0.7357 (Similarity: 0.6007, Accuracy: 0.9382)
# 🎯 Trial 49 Results:
#    • Combined Score: 0.7357
#    • Similarity: 0.6007
#    • Accuracy: 0.9382
#
# 🔄 CopulaGAN Trial 50: epochs=150, batch_size=200
# 📊 Detected discrete columns: []
# 🏋️ Training CopulaGAN...
# ⏱️ Training completed successfully in 27.9 seconds
# 📊 Generated synthetic data: (5000, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5706
# [I 2025-11-05 20:56:49,868] Trial 49 finished with value: 0.5722545177446765 and parameters: {'epochs': 150, 'batch_size': 200, 'generator_lr': 0.00598177107858865, 'discriminator_lr': 3.292610902887273e-05, 'generator_decay': 4.03508485636913e-08, 'discriminator_decay': 1.6369373171850141e-06}. Best is trial 21 with value: 0.7672079131185447.
# [OK] TRTS (Synthetic->Real): 0.5471
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.5747
# [CHART] Combined Score: 0.5723 (Similarity: 0.5706, Accuracy: 0.5747)
# 🎯 Trial 50 Results:
#    • Combined Score: 0.5723
#    • Similarity: 0.5706
#    • Accuracy: 0.5747
#
# 🎯 ============================================================================
# 🎯 CopulaGAN OPTIMIZATION COMPLETE!
# 🎯 ============================================================================
# 🏆 Best CopulaGAN Trial: 22
# 📈 Best Score: 0.7672
# ⚙️ Best Parameters:
#    • epochs: 500
#    • batch_size: 100
#    • generator_lr: 1.0890284891781855e-05
#    • discriminator_lr: 8.924578567594168e-05
#    • generator_decay: 9.447062089525266e-08
#    • discriminator_decay: 6.487869822916734e-06
# 💾 Results stored for Section 5.5 final model training
# ================================================================================

# %%
# Generate Optuna visualizations for COPULAGANfrom src.visualization.section4 import create_optuna_visualizationscreate_optuna_visualizations(    study=copulagan_study,    model_name='COPULAGAN',    results_path=results_path,    verbose=True)

# %% [markdown]
# #### 4.1.6 TVAE Hyperparameter Optimization

# %%
# Code Chunk ID: CHUNK_4_1_6_A
# TVAE Robust Search Space (from hypertuning_eg.md)
def tvae_search_space(trial):
    return {
        "epochs": trial.suggest_int("epochs", 50, 500, step=50),  # Training cycles
        "batch_size": trial.suggest_categorical("batch_size", [64, 128, 256, 512]),  # Training batch size
        "learning_rate": trial.suggest_loguniform("learning_rate", 1e-5, 1e-2),  # Learning rate
        "compress_dims": trial.suggest_categorical(  # Encoder architecture
            "compress_dims", [[128, 128], [256, 128], [256, 128, 64]]
        ),
        "decompress_dims": trial.suggest_categorical(  # Decoder architecture
            "decompress_dims", [[128, 128], [64, 128], [64, 128, 256]]
        ),
        "embedding_dim": trial.suggest_int("embedding_dim", 32, 256, step=32),  # Latent space bottleneck size
        "l2scale": trial.suggest_loguniform("l2scale", 1e-6, 1e-2),  # L2 regularization weight
        "dropout": trial.suggest_uniform("dropout", 0.0, 0.5),  # Dropout probability
        "log_frequency": trial.suggest_categorical("log_frequency", [True, False]),  # Use log frequency for representation
        "conditional_generation": trial.suggest_categorical("conditional_generation", [True, False]),  # Conditioned generation
        "verbose": trial.suggest_categorical("verbose", [True])
    }

# TVAE Objective Function using robust search space
def tvae_objective(trial):
    params = tvae_search_space(trial)
    
    try:
        print(f"\n🔄 TVAE Trial {trial.number + 1}: epochs={params['epochs']}, batch_size={params['batch_size']}, lr={params['learning_rate']:.2e}")
        
        # Initialize TVAE using ModelFactory with robust params
        model = ModelFactory.create("TVAE", random_state=42)
        model.set_config(params)
        
        # Train model
        print("🏋️ Training TVAE...")
        start_time = time.time()
        model.train(data, **params)
        training_time = time.time() - start_time
        print(f"⏱️ Training completed in {training_time:.1f} seconds")
        
        # Generate synthetic data
        synthetic_data = model.generate(len(data))
        
        # Evaluate using enhanced objective function
        score, similarity_score, accuracy_score = enhanced_objective_function_v2(data, synthetic_data, target_column)
        
        print(f"✅ TVAE Trial {trial.number + 1} Score: {score:.4f} (Similarity: {similarity_score:.4f}, Accuracy: {accuracy_score:.4f})")
        
        return score
        
    except Exception as e:
        print(f"❌ TVAE trial {trial.number + 1} failed: {str(e)}")
        return 0.0

# Execute TVAE hyperparameter optimization
print("\n🎯 Starting TVAE Hyperparameter Optimization")
print(f"   • Search space: 5 parameters")
print(f"   • Number of trials: 5")
print(f"   • Algorithm: TPE with median pruning")

# Create and execute study
tvae_study = optuna.create_study(direction="maximize", pruner=optuna.pruners.MedianPruner())
tvae_study.optimize(tvae_objective, n_trials=50)

# Display results
print(f"\n✅ TVAE Optimization Complete:")
print(f"Best score: {tvae_study.best_value:.4f}")
print(f"Best params: {tvae_study.best_params}")

# Store best parameters
tvae_best_params = tvae_study.best_params
print("\n📊 TVAE hyperparameter optimization completed successfully!")
# Out:
# [I 2025-11-05 20:56:49,888] A new study created in memory with name: no-name-8ea5a7b5-166b-4c89-a51e-125b869bb0b6
# 🎯 Starting TVAE Hyperparameter Optimization
#    • Search space: 5 parameters
#    • Number of trials: 5
#    • Algorithm: TPE with median pruning
#
# 🔄 TVAE Trial 1: epochs=400, batch_size=256, lr=5.35e-05
# 🏋️ Training TVAE...
# ⏱️ Training completed in 29.8 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6650
# [I 2025-11-05 20:57:20,061] Trial 0 finished with value: 0.7862651060435756 and parameters: {'epochs': 400, 'batch_size': 256, 'learning_rate': 5.3450255883530034e-05, 'compress_dims': [128, 128], 'decompress_dims': [128, 128], 'embedding_dim': 256, 'l2scale': 6.683202433070318e-05, 'dropout': 0.39788559404105334, 'log_frequency': False, 'conditional_generation': False, 'verbose': True}. Best is trial 0 with value: 0.7862651060435756.
# [OK] TRTS (Synthetic->Real): 0.9879
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9682
# [CHART] Combined Score: 0.7863 (Similarity: 0.6650, Accuracy: 0.9682)
# ✅ TVAE Trial 1 Score: 0.7863 (Similarity: 0.6650, Accuracy: 0.9682)
#
# 🔄 TVAE Trial 2: epochs=200, batch_size=128, lr=5.62e-04
# 🏋️ Training TVAE...
# ⏱️ Training completed in 23.0 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6433
# [I 2025-11-05 20:57:43,433] Trial 1 finished with value: 0.7756779739026239 and parameters: {'epochs': 200, 'batch_size': 128, 'learning_rate': 0.0005615653695342308, 'compress_dims': [128, 128], 'decompress_dims': [128, 128], 'embedding_dim': 64, 'l2scale': 1.2371577529289046e-05, 'dropout': 0.0692453634240468, 'log_frequency': True, 'conditional_generation': True, 'verbose': True}. Best is trial 0 with value: 0.7862651060435756.
# [OK] TRTS (Synthetic->Real): 0.9857
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9742
# [CHART] Combined Score: 0.7757 (Similarity: 0.6433, Accuracy: 0.9742)
# ✅ TVAE Trial 2 Score: 0.7757 (Similarity: 0.6433, Accuracy: 0.9742)
#
# 🔄 TVAE Trial 3: epochs=300, batch_size=512, lr=2.76e-03
# 🏋️ Training TVAE...
# ⏱️ Training completed in 16.2 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6029
# [I 2025-11-05 20:58:00,040] Trial 2 finished with value: 0.7461904797255376 and parameters: {'epochs': 300, 'batch_size': 512, 'learning_rate': 0.002761977892897041, 'compress_dims': [256, 128, 64], 'decompress_dims': [64, 128], 'embedding_dim': 256, 'l2scale': 0.00011980667361785595, 'dropout': 0.2928367825231894, 'log_frequency': True, 'conditional_generation': True, 'verbose': True}. Best is trial 0 with value: 0.7862651060435756.
# [OK] TRTS (Synthetic->Real): 0.9781
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9611
# [CHART] Combined Score: 0.7462 (Similarity: 0.6029, Accuracy: 0.9611)
# ✅ TVAE Trial 3 Score: 0.7462 (Similarity: 0.6029, Accuracy: 0.9611)
#
# 🔄 TVAE Trial 4: epochs=100, batch_size=256, lr=8.21e-04
# 🏋️ Training TVAE...
# ⏱️ Training completed in 9.6 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5370
# [I 2025-11-05 20:58:10,117] Trial 3 finished with value: 0.6875268963730545 and parameters: {'epochs': 100, 'batch_size': 256, 'learning_rate': 0.0008209487015268831, 'compress_dims': [256, 128, 64], 'decompress_dims': [64, 128], 'embedding_dim': 192, 'l2scale': 4.255087486421114e-06, 'dropout': 0.48379552273388127, 'log_frequency': False, 'conditional_generation': True, 'verbose': True}. Best is trial 0 with value: 0.7862651060435756.
# [OK] TRTS (Synthetic->Real): 0.9693
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9134
# [CHART] Combined Score: 0.6875 (Similarity: 0.5370, Accuracy: 0.9134)
# ✅ TVAE Trial 4 Score: 0.6875 (Similarity: 0.5370, Accuracy: 0.9134)
#
# 🔄 TVAE Trial 5: epochs=250, batch_size=64, lr=2.13e-05
# 🏋️ Training TVAE...
# ⏱️ Training completed in 61.0 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5927
# [I 2025-11-05 20:59:11,648] Trial 4 finished with value: 0.7438013523325073 and parameters: {'epochs': 250, 'batch_size': 64, 'learning_rate': 2.12951670657683e-05, 'compress_dims': [256, 128, 64], 'decompress_dims': [64, 128, 256], 'embedding_dim': 128, 'l2scale': 0.00013211019353692396, 'dropout': 0.1796269099954808, 'log_frequency': False, 'conditional_generation': True, 'verbose': True}. Best is trial 0 with value: 0.7862651060435756.
# [OK] TRTS (Synthetic->Real): 0.9879
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9704
# [CHART] Combined Score: 0.7438 (Similarity: 0.5927, Accuracy: 0.9704)
# ✅ TVAE Trial 5 Score: 0.7438 (Similarity: 0.5927, Accuracy: 0.9704)
#
# 🔄 TVAE Trial 6: epochs=300, batch_size=128, lr=1.79e-05
# 🏋️ Training TVAE...
# ⏱️ Training completed in 40.8 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6419
# [I 2025-11-05 20:59:52,858] Trial 5 finished with value: 0.7730616202037908 and parameters: {'epochs': 300, 'batch_size': 128, 'learning_rate': 1.7941623216367377e-05, 'compress_dims': [256, 128], 'decompress_dims': [64, 128], 'embedding_dim': 96, 'l2scale': 0.0028575750836026628, 'dropout': 0.0772877359550731, 'log_frequency': False, 'conditional_generation': True, 'verbose': True}. Best is trial 0 with value: 0.7862651060435756.
# [OK] TRTS (Synthetic->Real): 0.9879
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9698
# [CHART] Combined Score: 0.7731 (Similarity: 0.6419, Accuracy: 0.9698)
# ✅ TVAE Trial 6 Score: 0.7731 (Similarity: 0.6419, Accuracy: 0.9698)
#
# 🔄 TVAE Trial 7: epochs=450, batch_size=256, lr=1.30e-03
# 🏋️ Training TVAE...
# ⏱️ Training completed in 34.2 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6647
# [I 2025-11-05 21:00:27,474] Trial 6 finished with value: 0.7825885015860916 and parameters: {'epochs': 450, 'batch_size': 256, 'learning_rate': 0.001304513878004373, 'compress_dims': [128, 128], 'decompress_dims': [64, 128], 'embedding_dim': 224, 'l2scale': 0.0028972157884098607, 'dropout': 0.4869636459090999, 'log_frequency': True, 'conditional_generation': False, 'verbose': True}. Best is trial 0 with value: 0.7862651060435756.
# [OK] TRTS (Synthetic->Real): 0.9846
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9594
# [CHART] Combined Score: 0.7826 (Similarity: 0.6647, Accuracy: 0.9594)
# ✅ TVAE Trial 7 Score: 0.7826 (Similarity: 0.6647, Accuracy: 0.9594)
#
# 🔄 TVAE Trial 8: epochs=300, batch_size=512, lr=1.87e-04
# 🏋️ Training TVAE...
# ⏱️ Training completed in 16.8 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5746
# [I 2025-11-05 21:00:44,737] Trial 7 finished with value: 0.7204420194391163 and parameters: {'epochs': 300, 'batch_size': 512, 'learning_rate': 0.0001872775173858573, 'compress_dims': [256, 128, 64], 'decompress_dims': [64, 128], 'embedding_dim': 160, 'l2scale': 2.2802868922002364e-05, 'dropout': 0.459861673893919, 'log_frequency': True, 'conditional_generation': False, 'verbose': True}. Best is trial 0 with value: 0.7862651060435756.
# [OK] TRTS (Synthetic->Real): 0.9792
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9391
# [CHART] Combined Score: 0.7204 (Similarity: 0.5746, Accuracy: 0.9391)
# ✅ TVAE Trial 8 Score: 0.7204 (Similarity: 0.5746, Accuracy: 0.9391)
#
# 🔄 TVAE Trial 9: epochs=350, batch_size=512, lr=5.19e-04
# 🏋️ Training TVAE...
# ⏱️ Training completed in 18.7 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6233
# [I 2025-11-05 21:01:03,774] Trial 8 finished with value: 0.7634355311010983 and parameters: {'epochs': 350, 'batch_size': 512, 'learning_rate': 0.0005190902405330709, 'compress_dims': [128, 128], 'decompress_dims': [64, 128, 256], 'embedding_dim': 128, 'l2scale': 1.0771985429064734e-05, 'dropout': 0.17548368643157208, 'log_frequency': False, 'conditional_generation': True, 'verbose': True}. Best is trial 0 with value: 0.7862651060435756.
# [OK] TRTS (Synthetic->Real): 0.9836
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9737
# [CHART] Combined Score: 0.7634 (Similarity: 0.6233, Accuracy: 0.9737)
# ✅ TVAE Trial 9 Score: 0.7634 (Similarity: 0.6233, Accuracy: 0.9737)
#
# 🔄 TVAE Trial 10: epochs=150, batch_size=64, lr=1.37e-03
# 🏋️ Training TVAE...
# ⏱️ Training completed in 30.9 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6035
# [I 2025-11-05 21:01:35,139] Trial 9 finished with value: 0.7528659501829542 and parameters: {'epochs': 150, 'batch_size': 64, 'learning_rate': 0.0013657048571393872, 'compress_dims': [128, 128], 'decompress_dims': [64, 128, 256], 'embedding_dim': 128, 'l2scale': 2.6148444491705837e-06, 'dropout': 0.15784908355963845, 'log_frequency': True, 'conditional_generation': True, 'verbose': True}. Best is trial 0 with value: 0.7862651060435756.
# [OK] TRTS (Synthetic->Real): 0.9868
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9770
# [CHART] Combined Score: 0.7529 (Similarity: 0.6035, Accuracy: 0.9770)
# ✅ TVAE Trial 10 Score: 0.7529 (Similarity: 0.6035, Accuracy: 0.9770)
#
# 🔄 TVAE Trial 11: epochs=500, batch_size=256, lr=7.98e-05
# 🏋️ Training TVAE...
# ⏱️ Training completed in 40.1 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6608
# [I 2025-11-05 21:02:15,680] Trial 10 finished with value: 0.7809191523195051 and parameters: {'epochs': 500, 'batch_size': 256, 'learning_rate': 7.975295672668071e-05, 'compress_dims': [256, 128], 'decompress_dims': [128, 128], 'embedding_dim': 32, 'l2scale': 0.0004427084756472533, 'dropout': 0.3503915900346722, 'log_frequency': False, 'conditional_generation': False, 'verbose': True}. Best is trial 0 with value: 0.7862651060435756.
# [OK] TRTS (Synthetic->Real): 0.9825
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9611
# [CHART] Combined Score: 0.7809 (Similarity: 0.6608, Accuracy: 0.9611)
# ✅ TVAE Trial 11 Score: 0.7809 (Similarity: 0.6608, Accuracy: 0.9611)
#
# 🔄 TVAE Trial 12: epochs=450, batch_size=256, lr=6.65e-03
# 🏋️ Training TVAE...
# ⏱️ Training completed in 35.7 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6574
# [I 2025-11-05 21:02:51,874] Trial 11 finished with value: 0.782388993778047 and parameters: {'epochs': 450, 'batch_size': 256, 'learning_rate': 0.006649126653176318, 'compress_dims': [128, 128], 'decompress_dims': [128, 128], 'embedding_dim': 256, 'l2scale': 0.003915508529707242, 'dropout': 0.39178303940028236, 'log_frequency': True, 'conditional_generation': False, 'verbose': True}. Best is trial 0 with value: 0.7862651060435756.
# [OK] TRTS (Synthetic->Real): 0.9792
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9698
# [CHART] Combined Score: 0.7824 (Similarity: 0.6574, Accuracy: 0.9698)
# ✅ TVAE Trial 12 Score: 0.7824 (Similarity: 0.6574, Accuracy: 0.9698)
#
# 🔄 TVAE Trial 13: epochs=400, batch_size=256, lr=6.85e-05
# 🏋️ Training TVAE...
# ⏱️ Training completed in 28.2 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6461
# [I 2025-11-05 21:03:20,471] Trial 12 finished with value: 0.7749673461570306 and parameters: {'epochs': 400, 'batch_size': 256, 'learning_rate': 6.850436062350657e-05, 'compress_dims': [128, 128], 'decompress_dims': [128, 128], 'embedding_dim': 224, 'l2scale': 0.0005361073339629012, 'dropout': 0.39473270399338967, 'log_frequency': True, 'conditional_generation': False, 'verbose': True}. Best is trial 0 with value: 0.7862651060435756.
# [OK] TRTS (Synthetic->Real): 0.9868
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9682
# [CHART] Combined Score: 0.7750 (Similarity: 0.6461, Accuracy: 0.9682)
# ✅ TVAE Trial 13 Score: 0.7750 (Similarity: 0.6461, Accuracy: 0.9682)
#
# 🔄 TVAE Trial 14: epochs=500, batch_size=256, lr=1.37e-04
# 🏋️ Training TVAE...
# ⏱️ Training completed in 36.9 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6281
# [I 2025-11-05 21:03:57,772] Trial 13 finished with value: 0.7658903729948987 and parameters: {'epochs': 500, 'batch_size': 256, 'learning_rate': 0.00013744715182434402, 'compress_dims': [128, 128], 'decompress_dims': [64, 128], 'embedding_dim': 192, 'l2scale': 0.008095249845520468, 'dropout': 0.4545448788315274, 'log_frequency': False, 'conditional_generation': False, 'verbose': True}. Best is trial 0 with value: 0.7862651060435756.
# [OK] TRTS (Synthetic->Real): 0.9836
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9726
# [CHART] Combined Score: 0.7659 (Similarity: 0.6281, Accuracy: 0.9726)
# ✅ TVAE Trial 14 Score: 0.7659 (Similarity: 0.6281, Accuracy: 0.9726)
#
# 🔄 TVAE Trial 15: epochs=400, batch_size=256, lr=3.65e-05
# 🏋️ Training TVAE...
# ⏱️ Training completed in 30.3 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6469
# [I 2025-11-05 21:04:28,470] Trial 14 finished with value: 0.7743218020699897 and parameters: {'epochs': 400, 'batch_size': 256, 'learning_rate': 3.6458483595944704e-05, 'compress_dims': [128, 128], 'decompress_dims': [128, 128], 'embedding_dim': 224, 'l2scale': 0.0011189449302629294, 'dropout': 0.32447544412841856, 'log_frequency': False, 'conditional_generation': False, 'verbose': True}. Best is trial 0 with value: 0.7862651060435756.
# [OK] TRTS (Synthetic->Real): 0.9792
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9655
# [CHART] Combined Score: 0.7743 (Similarity: 0.6469, Accuracy: 0.9655)
# ✅ TVAE Trial 15 Score: 0.7743 (Similarity: 0.6469, Accuracy: 0.9655)
#
# 🔄 TVAE Trial 16: epochs=400, batch_size=256, lr=2.57e-03
# 🏋️ Training TVAE...
# ⏱️ Training completed in 26.7 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6613
# [I 2025-11-05 21:04:55,585] Trial 15 finished with value: 0.7801381736528049 and parameters: {'epochs': 400, 'batch_size': 256, 'learning_rate': 0.0025711064723437566, 'compress_dims': [256, 128], 'decompress_dims': [64, 128], 'embedding_dim': 224, 'l2scale': 4.222242421727149e-05, 'dropout': 0.24897245046239083, 'log_frequency': True, 'conditional_generation': False, 'verbose': True}. Best is trial 0 with value: 0.7862651060435756.
# [OK] TRTS (Synthetic->Real): 0.9890
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9583
# [CHART] Combined Score: 0.7801 (Similarity: 0.6613, Accuracy: 0.9583)
# ✅ TVAE Trial 16 Score: 0.7801 (Similarity: 0.6613, Accuracy: 0.9583)
#
# 🔄 TVAE Trial 17: epochs=450, batch_size=256, lr=2.77e-04
# 🏋️ Training TVAE...
# ⏱️ Training completed in 30.0 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6517
# [I 2025-11-05 21:05:26,023] Trial 16 finished with value: 0.778056193348543 and parameters: {'epochs': 450, 'batch_size': 256, 'learning_rate': 0.0002770061997556037, 'compress_dims': [128, 128], 'decompress_dims': [128, 128], 'embedding_dim': 256, 'l2scale': 0.0002779017035270846, 'dropout': 0.40354009626650106, 'log_frequency': True, 'conditional_generation': False, 'verbose': True}. Best is trial 0 with value: 0.7862651060435756.
# [OK] TRTS (Synthetic->Real): 0.9879
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9677
# [CHART] Combined Score: 0.7781 (Similarity: 0.6517, Accuracy: 0.9677)
# ✅ TVAE Trial 17 Score: 0.7781 (Similarity: 0.6517, Accuracy: 0.9677)
#
# 🔄 TVAE Trial 18: epochs=350, batch_size=128, lr=1.09e-05
# 🏋️ Training TVAE...
# ⏱️ Training completed in 45.0 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6290
# [I 2025-11-05 21:06:11,468] Trial 17 finished with value: 0.7625042375323935 and parameters: {'epochs': 350, 'batch_size': 128, 'learning_rate': 1.0917748870868441e-05, 'compress_dims': [128, 128], 'decompress_dims': [64, 128], 'embedding_dim': 192, 'l2scale': 6.345057688031008e-05, 'dropout': 0.48688883058817845, 'log_frequency': False, 'conditional_generation': False, 'verbose': True}. Best is trial 0 with value: 0.7862651060435756.
# [OK] TRTS (Synthetic->Real): 0.9846
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9627
# [CHART] Combined Score: 0.7625 (Similarity: 0.6290, Accuracy: 0.9627)
# ✅ TVAE Trial 18 Score: 0.7625 (Similarity: 0.6290, Accuracy: 0.9627)
#
# 🔄 TVAE Trial 19: epochs=50, batch_size=64, lr=4.48e-03
# 🏋️ Training TVAE...
# ⏱️ Training completed in 12.6 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5467
# [I 2025-11-05 21:06:24,561] Trial 18 finished with value: 0.6885183739011506 and parameters: {'epochs': 50, 'batch_size': 64, 'learning_rate': 0.004476390760094567, 'compress_dims': [128, 128], 'decompress_dims': [128, 128], 'embedding_dim': 160, 'l2scale': 0.0013302318969007794, 'dropout': 0.24948156806476704, 'log_frequency': True, 'conditional_generation': False, 'verbose': True}. Best is trial 0 with value: 0.7862651060435756.
# [OK] TRTS (Synthetic->Real): 0.9463
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9013
# [CHART] Combined Score: 0.6885 (Similarity: 0.5467, Accuracy: 0.9013)
# ✅ TVAE Trial 19 Score: 0.6885 (Similarity: 0.5467, Accuracy: 0.9013)
#
# 🔄 TVAE Trial 20: epochs=450, batch_size=256, lr=1.26e-03
# 🏋️ Training TVAE...
# ⏱️ Training completed in 35.9 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5866
# [I 2025-11-05 21:07:00,840] Trial 19 finished with value: 0.7396581224207157 and parameters: {'epochs': 450, 'batch_size': 256, 'learning_rate': 0.0012567944780688953, 'compress_dims': [256, 128], 'decompress_dims': [64, 128, 256], 'embedding_dim': 224, 'l2scale': 0.009001485576968381, 'dropout': 0.4258856373666148, 'log_frequency': False, 'conditional_generation': False, 'verbose': True}. Best is trial 0 with value: 0.7862651060435756.
# [OK] TRTS (Synthetic->Real): 0.9890
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9693
# [CHART] Combined Score: 0.7397 (Similarity: 0.5866, Accuracy: 0.9693)
# ✅ TVAE Trial 20 Score: 0.7397 (Similarity: 0.5866, Accuracy: 0.9693)
#
# 🔄 TVAE Trial 21: epochs=350, batch_size=256, lr=5.33e-05
# 🏋️ Training TVAE...
# ⏱️ Training completed in 25.8 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6662
# [I 2025-11-05 21:07:27,041] Trial 20 finished with value: 0.7887454312248869 and parameters: {'epochs': 350, 'batch_size': 256, 'learning_rate': 5.3278006171063654e-05, 'compress_dims': [128, 128], 'decompress_dims': [128, 128], 'embedding_dim': 256, 'l2scale': 0.00021851407006129124, 'dropout': 0.010784840778201993, 'log_frequency': False, 'conditional_generation': False, 'verbose': True}. Best is trial 20 with value: 0.7887454312248869.
# [OK] TRTS (Synthetic->Real): 0.9912
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9726
# [CHART] Combined Score: 0.7887 (Similarity: 0.6662, Accuracy: 0.9726)
# ✅ TVAE Trial 21 Score: 0.7887 (Similarity: 0.6662, Accuracy: 0.9726)
#
# 🔄 TVAE Trial 22: epochs=350, batch_size=256, lr=5.17e-05
# 🏋️ Training TVAE...
# ⏱️ Training completed in 26.9 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6637
# [I 2025-11-05 21:07:54,377] Trial 21 finished with value: 0.7844248461550443 and parameters: {'epochs': 350, 'batch_size': 256, 'learning_rate': 5.1747777755984654e-05, 'compress_dims': [128, 128], 'decompress_dims': [128, 128], 'embedding_dim': 256, 'l2scale': 0.0001920935268653306, 'dropout': 0.01433902057253673, 'log_frequency': False, 'conditional_generation': False, 'verbose': True}. Best is trial 20 with value: 0.7887454312248869.
# [OK] TRTS (Synthetic->Real): 0.9803
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9655
# [CHART] Combined Score: 0.7844 (Similarity: 0.6637, Accuracy: 0.9655)
# ✅ TVAE Trial 22 Score: 0.7844 (Similarity: 0.6637, Accuracy: 0.9655)
#
# 🔄 TVAE Trial 23: epochs=350, batch_size=256, lr=4.88e-05
# 🏋️ Training TVAE...
# ⏱️ Training completed in 26.0 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6501
# [I 2025-11-05 21:08:20,728] Trial 22 finished with value: 0.7773308296134316 and parameters: {'epochs': 350, 'batch_size': 256, 'learning_rate': 4.88019429414814e-05, 'compress_dims': [128, 128], 'decompress_dims': [128, 128], 'embedding_dim': 256, 'l2scale': 0.00016470051154853486, 'dropout': 0.026756329110181724, 'log_frequency': False, 'conditional_generation': False, 'verbose': True}. Best is trial 20 with value: 0.7887454312248869.
# [OK] TRTS (Synthetic->Real): 0.9825
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9682
# [CHART] Combined Score: 0.7773 (Similarity: 0.6501, Accuracy: 0.9682)
# ✅ TVAE Trial 23 Score: 0.7773 (Similarity: 0.6501, Accuracy: 0.9682)
#
# 🔄 TVAE Trial 24: epochs=250, batch_size=256, lr=1.05e-04
# 🏋️ Training TVAE...
# ⏱️ Training completed in 19.8 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6388
# [I 2025-11-05 21:08:40,915] Trial 23 finished with value: 0.767514356724334 and parameters: {'epochs': 250, 'batch_size': 256, 'learning_rate': 0.00010496734957682223, 'compress_dims': [128, 128], 'decompress_dims': [128, 128], 'embedding_dim': 256, 'l2scale': 5.8661944470836195e-05, 'dropout': 0.006931190125766807, 'log_frequency': False, 'conditional_generation': False, 'verbose': True}. Best is trial 20 with value: 0.7887454312248869.
# [OK] TRTS (Synthetic->Real): 0.9792
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9605
# [CHART] Combined Score: 0.7675 (Similarity: 0.6388, Accuracy: 0.9605)
# ✅ TVAE Trial 24 Score: 0.7675 (Similarity: 0.6388, Accuracy: 0.9605)
#
# 🔄 TVAE Trial 25: epochs=350, batch_size=256, lr=3.43e-05
# 🏋️ Training TVAE...
# ⏱️ Training completed in 24.9 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6665
# [I 2025-11-05 21:09:06,238] Trial 24 finished with value: 0.7895673162034724 and parameters: {'epochs': 350, 'batch_size': 256, 'learning_rate': 3.430509913197863e-05, 'compress_dims': [128, 128], 'decompress_dims': [128, 128], 'embedding_dim': 192, 'l2scale': 0.0002818837876954759, 'dropout': 0.11884474583718793, 'log_frequency': False, 'conditional_generation': False, 'verbose': True}. Best is trial 24 with value: 0.7895673162034724.
# [OK] TRTS (Synthetic->Real): 0.9825
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9742
# [CHART] Combined Score: 0.7896 (Similarity: 0.6665, Accuracy: 0.9742)
# ✅ TVAE Trial 25 Score: 0.7896 (Similarity: 0.6665, Accuracy: 0.9742)
#
# 🔄 TVAE Trial 26: epochs=200, batch_size=256, lr=2.85e-05
# 🏋️ Training TVAE...
# ⏱️ Training completed in 16.5 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6147
# [I 2025-11-05 21:09:23,109] Trial 25 finished with value: 0.7466488056727956 and parameters: {'epochs': 200, 'batch_size': 256, 'learning_rate': 2.845100149427353e-05, 'compress_dims': [128, 128], 'decompress_dims': [128, 128], 'embedding_dim': 192, 'l2scale': 0.0006797719145988132, 'dropout': 0.1172760466184459, 'log_frequency': False, 'conditional_generation': False, 'verbose': True}. Best is trial 24 with value: 0.7895673162034724.
# [OK] TRTS (Synthetic->Real): 0.9583
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9446
# [CHART] Combined Score: 0.7466 (Similarity: 0.6147, Accuracy: 0.9446)
# ✅ TVAE Trial 26 Score: 0.7466 (Similarity: 0.6147, Accuracy: 0.9446)
#
# 🔄 TVAE Trial 27: epochs=400, batch_size=128, lr=1.84e-05
# 🏋️ Training TVAE...
# ⏱️ Training completed in 46.9 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6581
# [I 2025-11-05 21:10:10,419] Trial 26 finished with value: 0.7777789663296851 and parameters: {'epochs': 400, 'batch_size': 128, 'learning_rate': 1.8438760833472825e-05, 'compress_dims': [128, 128], 'decompress_dims': [128, 128], 'embedding_dim': 160, 'l2scale': 2.683803238602121e-05, 'dropout': 0.06434966505641215, 'log_frequency': False, 'conditional_generation': False, 'verbose': True}. Best is trial 24 with value: 0.7895673162034724.
# [OK] TRTS (Synthetic->Real): 0.9846
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9572
# [CHART] Combined Score: 0.7778 (Similarity: 0.6581, Accuracy: 0.9572)
# ✅ TVAE Trial 27 Score: 0.7778 (Similarity: 0.6581, Accuracy: 0.9572)
#
# 🔄 TVAE Trial 28: epochs=350, batch_size=64, lr=1.08e-05
# 🏋️ Training TVAE...
# ⏱️ Training completed in 76.3 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6703
# [I 2025-11-05 21:11:27,076] Trial 27 finished with value: 0.78638123716298 and parameters: {'epochs': 350, 'batch_size': 64, 'learning_rate': 1.0836668180373958e-05, 'compress_dims': [128, 128], 'decompress_dims': [128, 128], 'embedding_dim': 224, 'l2scale': 0.0003569900405716611, 'dropout': 0.12176275438099661, 'log_frequency': False, 'conditional_generation': False, 'verbose': True}. Best is trial 24 with value: 0.7895673162034724.
# [OK] TRTS (Synthetic->Real): 0.9846
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9605
# [CHART] Combined Score: 0.7864 (Similarity: 0.6703, Accuracy: 0.9605)
# ✅ TVAE Trial 28 Score: 0.7864 (Similarity: 0.6703, Accuracy: 0.9605)
#
# 🔄 TVAE Trial 29: epochs=250, batch_size=64, lr=1.07e-05
# 🏋️ Training TVAE...
# ⏱️ Training completed in 61.4 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6032
# [I 2025-11-05 21:12:28,898] Trial 28 finished with value: 0.752060002499237 and parameters: {'epochs': 250, 'batch_size': 64, 'learning_rate': 1.0707205024861384e-05, 'compress_dims': [256, 128, 64], 'decompress_dims': [128, 128], 'embedding_dim': 192, 'l2scale': 0.000372108269294189, 'dropout': 0.11815447455776482, 'log_frequency': False, 'conditional_generation': False, 'verbose': True}. Best is trial 24 with value: 0.7895673162034724.
# [OK] TRTS (Synthetic->Real): 0.9857
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9753
# [CHART] Combined Score: 0.7521 (Similarity: 0.6032, Accuracy: 0.9753)
# ✅ TVAE Trial 29 Score: 0.7521 (Similarity: 0.6032, Accuracy: 0.9753)
#
# 🔄 TVAE Trial 30: epochs=300, batch_size=64, lr=3.14e-05
# 🏋️ Training TVAE...
# ⏱️ Training completed in 77.3 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6565
# [I 2025-11-05 21:13:46,665] Trial 29 finished with value: 0.780985451902336 and parameters: {'epochs': 300, 'batch_size': 64, 'learning_rate': 3.144499467645216e-05, 'compress_dims': [256, 128], 'decompress_dims': [128, 128], 'embedding_dim': 224, 'l2scale': 0.00126056555730949, 'dropout': 0.11592816260401494, 'log_frequency': False, 'conditional_generation': False, 'verbose': True}. Best is trial 24 with value: 0.7895673162034724.
# [OK] TRTS (Synthetic->Real): 0.9879
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9677
# [CHART] Combined Score: 0.7810 (Similarity: 0.6565, Accuracy: 0.9677)
# ✅ TVAE Trial 30 Score: 0.7810 (Similarity: 0.6565, Accuracy: 0.9677)
#
# 🔄 TVAE Trial 31: epochs=350, batch_size=64, lr=1.43e-05
# 🏋️ Training TVAE...
# ⏱️ Training completed in 65.5 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6633
# [I 2025-11-05 21:14:52,644] Trial 30 finished with value: 0.7828301387341902 and parameters: {'epochs': 350, 'batch_size': 64, 'learning_rate': 1.4330273780438299e-05, 'compress_dims': [128, 128], 'decompress_dims': [128, 128], 'embedding_dim': 192, 'l2scale': 1.0013833775395566e-06, 'dropout': 0.20373689137846382, 'log_frequency': False, 'conditional_generation': False, 'verbose': True}. Best is trial 24 with value: 0.7895673162034724.
# [OK] TRTS (Synthetic->Real): 0.9890
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9622
# [CHART] Combined Score: 0.7828 (Similarity: 0.6633, Accuracy: 0.9622)
# ✅ TVAE Trial 31 Score: 0.7828 (Similarity: 0.6633, Accuracy: 0.9622)
#
# 🔄 TVAE Trial 32: epochs=400, batch_size=64, lr=4.45e-05
# 🏋️ Training TVAE...
# ⏱️ Training completed in 91.5 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6556
# [I 2025-11-05 21:16:24,541] Trial 31 finished with value: 0.7830754388042231 and parameters: {'epochs': 400, 'batch_size': 64, 'learning_rate': 4.4548837681989476e-05, 'compress_dims': [128, 128], 'decompress_dims': [128, 128], 'embedding_dim': 224, 'l2scale': 0.00022382101962217145, 'dropout': 0.05164653097050119, 'log_frequency': False, 'conditional_generation': False, 'verbose': True}. Best is trial 24 with value: 0.7895673162034724.
# [OK] TRTS (Synthetic->Real): 0.9879
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9742
# [CHART] Combined Score: 0.7831 (Similarity: 0.6556, Accuracy: 0.9742)
# ✅ TVAE Trial 32 Score: 0.7831 (Similarity: 0.6556, Accuracy: 0.9742)
#
# 🔄 TVAE Trial 33: epochs=350, batch_size=512, lr=2.93e-05
# 🏋️ Training TVAE...
# ⏱️ Training completed in 18.4 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6263
# [I 2025-11-05 21:16:43,385] Trial 32 finished with value: 0.7639099495208779 and parameters: {'epochs': 350, 'batch_size': 512, 'learning_rate': 2.925346526304913e-05, 'compress_dims': [128, 128], 'decompress_dims': [128, 128], 'embedding_dim': 256, 'l2scale': 8.378037625974962e-05, 'dropout': 0.22591984816177763, 'log_frequency': False, 'conditional_generation': False, 'verbose': True}. Best is trial 24 with value: 0.7895673162034724.
# [OK] TRTS (Synthetic->Real): 0.9868
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9704
# [CHART] Combined Score: 0.7639 (Similarity: 0.6263, Accuracy: 0.9704)
# ✅ TVAE Trial 33 Score: 0.7639 (Similarity: 0.6263, Accuracy: 0.9704)
#
# 🔄 TVAE Trial 34: epochs=300, batch_size=128, lr=7.32e-05
# 🏋️ Training TVAE...
# ⏱️ Training completed in 31.7 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6501
# [I 2025-11-05 21:17:15,559] Trial 33 finished with value: 0.7742550068484613 and parameters: {'epochs': 300, 'batch_size': 128, 'learning_rate': 7.318820914347912e-05, 'compress_dims': [128, 128], 'decompress_dims': [128, 128], 'embedding_dim': 224, 'l2scale': 9.996946624553042e-05, 'dropout': 0.2761966590606073, 'log_frequency': False, 'conditional_generation': False, 'verbose': True}. Best is trial 24 with value: 0.7895673162034724.
# [OK] TRTS (Synthetic->Real): 0.9781
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9605
# [CHART] Combined Score: 0.7743 (Similarity: 0.6501, Accuracy: 0.9605)
# ✅ TVAE Trial 34 Score: 0.7743 (Similarity: 0.6501, Accuracy: 0.9605)
#
# 🔄 TVAE Trial 35: epochs=200, batch_size=256, lr=1.65e-04
# 🏋️ Training TVAE...
# ⏱️ Training completed in 17.1 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5960
# [I 2025-11-05 21:17:33,106] Trial 34 finished with value: 0.7387525299878195 and parameters: {'epochs': 200, 'batch_size': 256, 'learning_rate': 0.00016473874843662818, 'compress_dims': [256, 128, 64], 'decompress_dims': [128, 128], 'embedding_dim': 256, 'l2scale': 1.160293117383715e-05, 'dropout': 0.08762748438137088, 'log_frequency': False, 'conditional_generation': True, 'verbose': True}. Best is trial 24 with value: 0.7895673162034724.
# [OK] TRTS (Synthetic->Real): 0.9814
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9529
# [CHART] Combined Score: 0.7388 (Similarity: 0.5960, Accuracy: 0.9529)
# ✅ TVAE Trial 35 Score: 0.7388 (Similarity: 0.5960, Accuracy: 0.9529)
#
# 🔄 TVAE Trial 36: epochs=250, batch_size=64, lr=2.35e-05
# 🏋️ Training TVAE...
# ⏱️ Training completed in 55.0 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6703
# [I 2025-11-05 21:18:28,514] Trial 35 finished with value: 0.7898788187358499 and parameters: {'epochs': 250, 'batch_size': 64, 'learning_rate': 2.3526218279135863e-05, 'compress_dims': [128, 128], 'decompress_dims': [128, 128], 'embedding_dim': 256, 'l2scale': 0.000713053716364107, 'dropout': 0.14609517317696746, 'log_frequency': False, 'conditional_generation': True, 'verbose': True}. Best is trial 35 with value: 0.7898788187358499.
# [OK] TRTS (Synthetic->Real): 0.9879
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9693
# [CHART] Combined Score: 0.7899 (Similarity: 0.6703, Accuracy: 0.9693)
# ✅ TVAE Trial 36 Score: 0.7899 (Similarity: 0.6703, Accuracy: 0.9693)
#
# 🔄 TVAE Trial 37: epochs=250, batch_size=64, lr=2.40e-05
# 🏋️ Training TVAE...
# ⏱️ Training completed in 52.3 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6659
# [I 2025-11-05 21:19:21,270] Trial 36 finished with value: 0.7843887029397244 and parameters: {'epochs': 250, 'batch_size': 64, 'learning_rate': 2.397130061058696e-05, 'compress_dims': [128, 128], 'decompress_dims': [128, 128], 'embedding_dim': 256, 'l2scale': 0.0006838925671820976, 'dropout': 0.1382872408031969, 'log_frequency': False, 'conditional_generation': True, 'verbose': True}. Best is trial 35 with value: 0.7898788187358499.
# [OK] TRTS (Synthetic->Real): 0.9836
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9622
# [CHART] Combined Score: 0.7844 (Similarity: 0.6659, Accuracy: 0.9622)
# ✅ TVAE Trial 37 Score: 0.7844 (Similarity: 0.6659, Accuracy: 0.9622)
#
# 🔄 TVAE Trial 38: epochs=150, batch_size=64, lr=1.50e-05
# 🏋️ Training TVAE...
# ⏱️ Training completed in 41.9 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6155
# [I 2025-11-05 21:20:03,512] Trial 37 finished with value: 0.7559411377107766 and parameters: {'epochs': 150, 'batch_size': 64, 'learning_rate': 1.4957493855230842e-05, 'compress_dims': [128, 128], 'decompress_dims': [64, 128, 256], 'embedding_dim': 192, 'l2scale': 0.0008894507626625696, 'dropout': 0.09363876223673431, 'log_frequency': False, 'conditional_generation': True, 'verbose': True}. Best is trial 35 with value: 0.7898788187358499.
# [OK] TRTS (Synthetic->Real): 0.9814
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9666
# [CHART] Combined Score: 0.7559 (Similarity: 0.6155, Accuracy: 0.9666)
# ✅ TVAE Trial 38 Score: 0.7559 (Similarity: 0.6155, Accuracy: 0.9666)
#
# 🔄 TVAE Trial 39: epochs=250, batch_size=64, lr=1.01e-05
# 🏋️ Training TVAE...
# ⏱️ Training completed in 61.5 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6223
# [I 2025-11-05 21:21:05,470] Trial 38 finished with value: 0.7621824302504427 and parameters: {'epochs': 250, 'batch_size': 64, 'learning_rate': 1.0078780233722361e-05, 'compress_dims': [256, 128, 64], 'decompress_dims': [128, 128], 'embedding_dim': 224, 'l2scale': 0.0017111089987705825, 'dropout': 0.038012047183305225, 'log_frequency': False, 'conditional_generation': True, 'verbose': True}. Best is trial 35 with value: 0.7898788187358499.
# [OK] TRTS (Synthetic->Real): 0.9901
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9720
# [CHART] Combined Score: 0.7622 (Similarity: 0.6223, Accuracy: 0.9720)
# ✅ TVAE Trial 39 Score: 0.7622 (Similarity: 0.6223, Accuracy: 0.9720)
#
# 🔄 TVAE Trial 40: epochs=300, batch_size=512, lr=2.28e-05
# 🏋️ Training TVAE...
# ⏱️ Training completed in 15.7 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6078
# [I 2025-11-05 21:21:21,502] Trial 39 finished with value: 0.7438208886136473 and parameters: {'epochs': 300, 'batch_size': 512, 'learning_rate': 2.283000964013455e-05, 'compress_dims': [128, 128], 'decompress_dims': [128, 128], 'embedding_dim': 96, 'l2scale': 0.0003366869000497148, 'dropout': 0.19623985990912657, 'log_frequency': False, 'conditional_generation': True, 'verbose': True}. Best is trial 35 with value: 0.7898788187358499.
# [OK] TRTS (Synthetic->Real): 0.9748
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9479
# [CHART] Combined Score: 0.7438 (Similarity: 0.6078, Accuracy: 0.9479)
# ✅ TVAE Trial 40 Score: 0.7438 (Similarity: 0.6078, Accuracy: 0.9479)
#
# 🔄 TVAE Trial 41: epochs=150, batch_size=64, lr=2.72e-04
# 🏋️ Training TVAE...
# ⏱️ Training completed in 32.6 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5813
# [I 2025-11-05 21:21:54,531] Trial 40 finished with value: 0.7347206789639948 and parameters: {'epochs': 150, 'batch_size': 64, 'learning_rate': 0.0002718730905499315, 'compress_dims': [128, 128], 'decompress_dims': [64, 128, 256], 'embedding_dim': 160, 'l2scale': 0.0019323421002594733, 'dropout': 0.154304797368007, 'log_frequency': False, 'conditional_generation': True, 'verbose': True}. Best is trial 35 with value: 0.7898788187358499.
# [OK] TRTS (Synthetic->Real): 0.9825
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9649
# [CHART] Combined Score: 0.7347 (Similarity: 0.5813, Accuracy: 0.9649)
# ✅ TVAE Trial 41 Score: 0.7347 (Similarity: 0.5813, Accuracy: 0.9649)
#
# 🔄 TVAE Trial 42: epochs=300, batch_size=64, lr=9.64e-05
# 🏋️ Training TVAE...
# ⏱️ Training completed in 61.3 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6468
# [I 2025-11-05 21:22:56,271] Trial 41 finished with value: 0.7716370117561144 and parameters: {'epochs': 300, 'batch_size': 64, 'learning_rate': 9.643650408200744e-05, 'compress_dims': [128, 128], 'decompress_dims': [128, 128], 'embedding_dim': 256, 'l2scale': 0.0001382185625529565, 'dropout': 0.2943621910608333, 'log_frequency': False, 'conditional_generation': True, 'verbose': True}. Best is trial 35 with value: 0.7898788187358499.
# [OK] TRTS (Synthetic->Real): 0.9825
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9589
# [CHART] Combined Score: 0.7716 (Similarity: 0.6468, Accuracy: 0.9589)
# ✅ TVAE Trial 42 Score: 0.7716 (Similarity: 0.6468, Accuracy: 0.9589)
#
# 🔄 TVAE Trial 43: epochs=350, batch_size=256, lr=5.39e-05
# 🏋️ Training TVAE...
# ⏱️ Training completed in 25.4 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6390
# [I 2025-11-05 21:23:22,193] Trial 42 finished with value: 0.7689035496504495 and parameters: {'epochs': 350, 'batch_size': 256, 'learning_rate': 5.3942857488131275e-05, 'compress_dims': [128, 128], 'decompress_dims': [128, 128], 'embedding_dim': 256, 'l2scale': 0.00026901951599046336, 'dropout': 0.17122271204495276, 'log_frequency': False, 'conditional_generation': False, 'verbose': True}. Best is trial 35 with value: 0.7898788187358499.
# [OK] TRTS (Synthetic->Real): 0.9890
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9638
# [CHART] Combined Score: 0.7689 (Similarity: 0.6390, Accuracy: 0.9638)
# ✅ TVAE Trial 43 Score: 0.7689 (Similarity: 0.6390, Accuracy: 0.9638)
#
# 🔄 TVAE Trial 44: epochs=400, batch_size=512, lr=1.62e-05
# 🏋️ Training TVAE...
# ⏱️ Training completed in 21.5 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6313
# [I 2025-11-05 21:23:44,198] Trial 43 finished with value: 0.7660739768825439 and parameters: {'epochs': 400, 'batch_size': 512, 'learning_rate': 1.6202215517298935e-05, 'compress_dims': [128, 128], 'decompress_dims': [128, 128], 'embedding_dim': 224, 'l2scale': 0.00010361741664449677, 'dropout': 0.09093309955114993, 'log_frequency': False, 'conditional_generation': True, 'verbose': True}. Best is trial 35 with value: 0.7898788187358499.
# [OK] TRTS (Synthetic->Real): 0.9814
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9682
# [CHART] Combined Score: 0.7661 (Similarity: 0.6313, Accuracy: 0.9682)
# ✅ TVAE Trial 44 Score: 0.7661 (Similarity: 0.6313, Accuracy: 0.9682)
#
# 🔄 TVAE Trial 45: epochs=450, batch_size=256, lr=2.04e-05
# 🏋️ Training TVAE...
# ⏱️ Training completed in 34.9 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6425
# [I 2025-11-05 21:24:19,584] Trial 44 finished with value: 0.7655349170712975 and parameters: {'epochs': 450, 'batch_size': 256, 'learning_rate': 2.0433854986827975e-05, 'compress_dims': [256, 128, 64], 'decompress_dims': [128, 128], 'embedding_dim': 32, 'l2scale': 4.1163069189488366e-05, 'dropout': 0.13608366279671918, 'log_frequency': False, 'conditional_generation': False, 'verbose': True}. Best is trial 35 with value: 0.7898788187358499.
# [OK] TRTS (Synthetic->Real): 0.9748
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9501
# [CHART] Combined Score: 0.7655 (Similarity: 0.6425, Accuracy: 0.9501)
# ✅ TVAE Trial 45 Score: 0.7655 (Similarity: 0.6425, Accuracy: 0.9501)
#
# 🔄 TVAE Trial 46: epochs=350, batch_size=128, lr=4.02e-05
# 🏋️ Training TVAE...
# ⏱️ Training completed in 45.2 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6539
# [I 2025-11-05 21:25:05,257] Trial 45 finished with value: 0.7813874147307516 and parameters: {'epochs': 350, 'batch_size': 128, 'learning_rate': 4.019992450802988e-05, 'compress_dims': [256, 128], 'decompress_dims': [128, 128], 'embedding_dim': 224, 'l2scale': 2.034124267555383e-05, 'dropout': 0.21702803529916814, 'log_frequency': False, 'conditional_generation': False, 'verbose': True}. Best is trial 35 with value: 0.7898788187358499.
# [OK] TRTS (Synthetic->Real): 0.9901
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9726
# [CHART] Combined Score: 0.7814 (Similarity: 0.6539, Accuracy: 0.9726)
# ✅ TVAE Trial 46 Score: 0.7814 (Similarity: 0.6539, Accuracy: 0.9726)
#
# 🔄 TVAE Trial 47: epochs=400, batch_size=256, lr=5.30e-04
# 🏋️ Training TVAE...
# ⏱️ Training completed in 30.8 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6709
# [I 2025-11-05 21:25:36,473] Trial 46 finished with value: 0.7913575996361577 and parameters: {'epochs': 400, 'batch_size': 256, 'learning_rate': 0.0005299602633136173, 'compress_dims': [128, 128], 'decompress_dims': [64, 128], 'embedding_dim': 256, 'l2scale': 0.00048745922674264976, 'dropout': 0.05183854415535084, 'log_frequency': False, 'conditional_generation': True, 'verbose': True}. Best is trial 46 with value: 0.7913575996361577.
# [OK] TRTS (Synthetic->Real): 0.9923
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9720
# [CHART] Combined Score: 0.7914 (Similarity: 0.6709, Accuracy: 0.9720)
# ✅ TVAE Trial 47 Score: 0.7914 (Similarity: 0.6709, Accuracy: 0.9720)
#
# 🔄 TVAE Trial 48: epochs=300, batch_size=256, lr=4.33e-04
# 🏋️ Training TVAE...
# ⏱️ Training completed in 20.7 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6537
# [I 2025-11-05 21:25:57,528] Trial 47 finished with value: 0.778397684703207 and parameters: {'epochs': 300, 'batch_size': 256, 'learning_rate': 0.0004332270045329205, 'compress_dims': [128, 128], 'decompress_dims': [64, 128], 'embedding_dim': 256, 'l2scale': 0.0005256770089160384, 'dropout': 0.05452856409088383, 'log_frequency': False, 'conditional_generation': True, 'verbose': True}. Best is trial 46 with value: 0.7913575996361577.
# [OK] TRTS (Synthetic->Real): 0.9781
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9655
# [CHART] Combined Score: 0.7784 (Similarity: 0.6537, Accuracy: 0.9655)
# ✅ TVAE Trial 48 Score: 0.7784 (Similarity: 0.6537, Accuracy: 0.9655)
#
# 🔄 TVAE Trial 49: epochs=400, batch_size=64, lr=6.90e-04
# 🏋️ Training TVAE...
# ⏱️ Training completed in 98.3 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6486
# [I 2025-11-05 21:27:36,346] Trial 48 finished with value: 0.776435926581416 and parameters: {'epochs': 400, 'batch_size': 64, 'learning_rate': 0.0006900672233154219, 'compress_dims': [128, 128], 'decompress_dims': [64, 128], 'embedding_dim': 224, 'l2scale': 0.0040138144833467785, 'dropout': 0.0038712113704502038, 'log_frequency': False, 'conditional_generation': True, 'verbose': True}. Best is trial 46 with value: 0.7913575996361577.
# [OK] TRTS (Synthetic->Real): 0.9890
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9682
# [CHART] Combined Score: 0.7764 (Similarity: 0.6486, Accuracy: 0.9682)
# ✅ TVAE Trial 49 Score: 0.7764 (Similarity: 0.6486, Accuracy: 0.9682)
#
# 🔄 TVAE Trial 50: epochs=200, batch_size=256, lr=4.23e-04
# 🏋️ Training TVAE...
# ⏱️ Training completed in 17.0 seconds
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6295
# [I 2025-11-05 21:27:53,857] Trial 49 finished with value: 0.7595037613574219 and parameters: {'epochs': 200, 'batch_size': 256, 'learning_rate': 0.00042326254158505923, 'compress_dims': [128, 128], 'decompress_dims': [64, 128], 'embedding_dim': 256, 'l2scale': 0.00041932920724190395, 'dropout': 0.039381576350726026, 'log_frequency': True, 'conditional_generation': True, 'verbose': True}. Best is trial 46 with value: 0.7913575996361577.
# [OK] TRTS (Synthetic->Real): 0.9693
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9545
# [CHART] Combined Score: 0.7595 (Similarity: 0.6295, Accuracy: 0.9545)
# ✅ TVAE Trial 50 Score: 0.7595 (Similarity: 0.6295, Accuracy: 0.9545)
#
# ✅ TVAE Optimization Complete:
# Best score: 0.7914
# Best params: {'epochs': 400, 'batch_size': 256, 'learning_rate': 0.0005299602633136173, 'compress_dims': [128, 128], 'decompress_dims': [64, 128], 'embedding_dim': 256, 'l2scale': 0.00048745922674264976, 'dropout': 0.05183854415535084, 'log_frequency': False, 'conditional_generation': True, 'verbose': True}
#
# 📊 TVAE hyperparameter optimization completed successfully!

# %%
# Generate Optuna visualizations for TVAEfrom src.visualization.section4 import create_optuna_visualizationscreate_optuna_visualizations(    study=tvae_study,    model_name='TVAE',    results_path=results_path,    verbose=True)

# %%
# Create Optuna summary comparing all modelsfrom src.visualization.section4 import create_all_models_optuna_summary# Collect all studies (only include those that completed successfully)studies_dict = {}if 'ctgan_study' in locals():    studies_dict['CTGAN'] = ctgan_studyif 'ctabgan_study' in locals():    studies_dict['CTABGAN'] = ctabgan_studyif 'ctabganplus_study' in locals():    studies_dict['CTABGAN+'] = ctabganplus_studyif 'ganeraid_study' in locals():    studies_dict['GANerAid'] = ganeraid_studyif 'copulagan_study' in locals():    studies_dict['CopulaGAN'] = copulagan_studyif 'tvae_study' in locals():    studies_dict['TVAE'] = tvae_studyif studies_dict:    create_all_models_optuna_summary(        studies_dict=studies_dict,        results_path=results_path,        verbose=True    )    print(f"\n[OK] Optuna summary visualization created for {len(studies_dict)} models")else:    print("[WARNING] No Optuna studies available for summary visualization")

# %% [markdown]
# ### 4.2 Batch process

# %% [markdown]
# This section outputs figures and graphics from models run in 4.1. The next chunk will output results for whatever subsections of 4.1 were run. I.e., if there's need to debug one method, there's no need to run all subsections of 4.1.

# %%
# Code Chunk ID: CHUNK_4_2_0_A
# ============================================================================
# SECTION 4 - BATCH HYPERPARAMETER OPTIMIZATION ANALYSIS
# ============================================================================

print("🔍 SECTION 4 - HYPERPARAMETER OPTIMIZATION BATCH ANALYSIS")
print("=" * 80)
print()

# Use enhanced batch evaluation function from setup.py
# Following exact same pattern as CHUNK_018 (Section 3) - no module reload needed!
try:
    # Run batch analysis with file export for all models
    section4_batch_results = evaluate_hyperparameter_optimization_results(
        section_number=4,
        scope=globals(),  # Pass notebook scope to access study variables
        target_column=TARGET_COLUMN
    )
    
    print("\n" + "="*80)
    print("✅ SECTION 4 HYPERPARAMETER OPTIMIZATION BATCH ANALYSIS COMPLETED!")
    print("="*80)
    print(f"📊 Models processed: {len(section4_batch_results['summary_data'])}")
    print(f"📁 Results exported to: {section4_batch_results['results_dir']}")
    print(f"📋 Individual model analysis files:")
    print("   • Hyperparameter parameter_analysis.png plots")
    print("   • Optimization convergence_analysis.png graphs")
    print("   • Parameter correlation matrices")
    print("   • Best trial summary tables")
    print("   • Comprehensive optimization summary CSV")

    
except Exception as e:
    print(f"❌ Batch hyperparameter analysis failed: {str(e)}")
    print(f"🔍 Error details: {type(e).__name__}")
    import traceback
    traceback.print_exc()
    print("\n⚠️  Falling back to individual chunk analysis if needed")

# ============================================================================
# SAVE BEST PARAMETERS TO CSV FOR SECTION 5 USE
# ============================================================================
print("\n" + "=" * 80)
print("💾 SAVING BEST PARAMETERS FROM SECTION 4 OPTIMIZATION")
print("=" * 80)

try:
    # Save all best parameters to CSV using setup.py function
    param_save_results = save_best_parameters_to_csv(
        scope=globals(),
        section_number=4,
        dataset_identifier=DATASET_IDENTIFIER
    )
    
    if param_save_results['success']:
        print(f"\n✅ Parameter saving completed successfully!")
        print(f"   • Files saved: {len(param_save_results['files_saved'])}")
        print(f"   • Parameter entries: {param_save_results['parameters_count']}")
        print(f"   • Models processed: {param_save_results['models_count']}")
        print(f"   • Directory: {param_save_results['results_dir']}")
        
        # Display saved files
        for file_path in param_save_results['files_saved']:
            print(f"     📁 {file_path.split('/')[-1]}")
    else:
        print(f"\n⚠️  Parameter saving completed with issues: {param_save_results['message']}")
        
except Exception as e:
    print(f"\n❌ Parameter saving failed: {str(e)}")
    print(f"   Section 5 will fall back to memory-based parameter retrieval")

print(f"\n📈 Section 4 hyperparameter optimization analysis complete!")
print("🏁 Ready for Section 5: Optimized model re-training")
# Out:
# 🔍 SECTION 4 - HYPERPARAMETER OPTIMIZATION BATCH ANALYSIS
# ================================================================================
#
# [LOCATION] Using DATASET_IDENTIFIER from scope: pakistani-diabetes-dataset
# [TARGET] Final DATASET_IDENTIFIER for Section 4: pakistani-diabetes-dataset
#
# ================================================================================
# SECTION 4 - HYPERPARAMETER OPTIMIZATION BATCH ANALYSIS
# ================================================================================
# [FOLDER] Base results directory: results/pakistani-diabetes-dataset/2025-11-05/Section-4
# [TARGET] Target column: Outcome
# [CHART] Dataset identifier: pakistani-diabetes-dataset
#
#
# [SEARCH] 4.1.1: CTGAN Hyperparameter Optimization Analysis
# ------------------------------------------------------------
# [OK] CTGAN optimization study found
# [FOLDER] Model directory: results/pakistani-diabetes-dataset/2025-11-05/Section-4/CTGAN
# [SEARCH] ANALYZING CTGAN HYPERPARAMETER OPTIMIZATION
# ============================================================
# [CHART] 1. TRIAL DATA EXTRACTION AND PROCESSING
# ----------------------------------------
# [OK] Extracted 50 trials for analysis
# [CHART] 2. PARAMETER SPACE EXPLORATION ANALYSIS
# ----------------------------------------
#    - Found 12 hyperparameters: ['params_batch_size', 'params_discriminator_decay', 'params_discriminator_dim', 'params_discriminator_lr', 'params_discriminator_steps', 'params_epochs', 'params_generator_decay', 'params_generator_dim', 'params_generator_lr', 'params_log_frequency', 'params_pac', 'params_verbose']
#    - Using 50 completed trials
# [STATS] Creating parameter vs performance visualizations...
#    [FOLDER] Parameter analysis plot saved: results/pakistani-diabetes-dataset/2025-11-05/Section-4/CTGAN/ctgan_parameter_analysis.png
# [CHART] 3. BEST TRIAL ANALYSIS
# ----------------------------------------
# [OK] Best Trial #38
#    - Best Score: 0.8358
#    - Duration: 97.9 seconds
#    - Best Parameters:
#      - batch_size: 1000
#      - discriminator_decay: 0.0000
#      - discriminator_dim: (256, 256)
#      - discriminator_lr: 0.0031
#      - discriminator_steps: 3
#      - epochs: 800
#      - generator_decay: 0.0000
#      - generator_dim: (256, 512, 256)
#      - generator_lr: 0.0001
#      - log_frequency: False
#      - pac: 3
#      - verbose: True
# [CHART] 4. CONVERGENCE ANALYSIS
# ----------------------------------------
#    [FOLDER] Convergence plot saved: results/pakistani-diabetes-dataset/2025-11-05/Section-4/CTGAN/ctgan_convergence_analysis.png
# [CHART] 5. STATISTICAL SUMMARY
# ----------------------------------------
# [OK] Performance Statistics:
#    - Mean Score: 0.7298
#    - Std Dev: 0.1012
#    - Min Score: 0.5064
#    - Max Score: 0.8358
#    - Median Score: 0.7687
#    [FOLDER] Trial results saved: results/pakistani-diabetes-dataset/2025-11-05/Section-4/CTGAN/ctgan_trial_results.csv
#    [FOLDER] Summary statistics saved: results/pakistani-diabetes-dataset/2025-11-05/Section-4/CTGAN/ctgan_optimization_summary.csv
# [OK] CTGAN optimization analysis completed successfully!
# [FOLDER] Results saved to: results/pakistani-diabetes-dataset/2025-11-05/Section-4/CTGAN
# [OK] CTGAN analysis completed - files exported to results/pakistani-diabetes-dataset/2025-11-05/Section-4/CTGAN
#
# [SEARCH] 4.2.1: CTAB-GAN Hyperparameter Optimization Analysis
# ------------------------------------------------------------
# [WARNING]  CTAB-GAN optimization study not found (variable: ctabgan_study)
#    Skipping CTAB-GAN analysis
#
# [SEARCH] 4.3.1: CTAB-GAN+ Hyperparameter Optimization Analysis
# ------------------------------------------------------------
# [WARNING]  CTAB-GAN+ optimization study not found (variable: ctabganplus_study)
#    Skipping CTAB-GAN+ analysis
#
# [SEARCH] 4.4.1: GANerAid Hyperparameter Optimization Analysis
# ------------------------------------------------------------
# [WARNING]  GANerAid optimization study not found (variable: ganeraid_study)
#    Skipping GANerAid analysis
#
# [SEARCH] 4.5.1: CopulaGAN Hyperparameter Optimization Analysis
# ------------------------------------------------------------
# [OK] CopulaGAN optimization study found
# [FOLDER] Model directory: results/pakistani-diabetes-dataset/2025-11-05/Section-4/COPULAGAN
# [SEARCH] ANALYZING COPULAGAN HYPERPARAMETER OPTIMIZATION
# ============================================================
# [CHART] 1. TRIAL DATA EXTRACTION AND PROCESSING
# ----------------------------------------
# [OK] Extracted 50 trials for analysis
# [CHART] 2. PARAMETER SPACE EXPLORATION ANALYSIS
# ----------------------------------------
#    - Found 6 hyperparameters: ['params_batch_size', 'params_discriminator_decay', 'params_discriminator_lr', 'params_epochs', 'params_generator_decay', 'params_generator_lr']
#    - Using 50 completed trials
# [STATS] Creating parameter vs performance visualizations...
#    [FOLDER] Parameter analysis plot saved: results/pakistani-diabetes-dataset/2025-11-05/Section-4/COPULAGAN/copulagan_parameter_analysis.png
# [CHART] 3. BEST TRIAL ANALYSIS
# ----------------------------------------
# [OK] Best Trial #21
#    - Best Score: 0.7672
#    - Duration: 216.4 seconds
#    - Best Parameters:
#      - batch_size: 100
#      - discriminator_decay: 0.0000
#      - discriminator_lr: 0.0001
#      - epochs: 500
#      - generator_decay: 0.0000
#      - generator_lr: 0.0000
# [CHART] 4. CONVERGENCE ANALYSIS
# ----------------------------------------
#    [FOLDER] Convergence plot saved: results/pakistani-diabetes-dataset/2025-11-05/Section-4/COPULAGAN/copulagan_convergence_analysis.png
# [CHART] 5. STATISTICAL SUMMARY
# ----------------------------------------
# [OK] Performance Statistics:
#    - Mean Score: 0.6797
#    - Std Dev: 0.0855
#    - Min Score: 0.5036
#    - Max Score: 0.7672
#    - Median Score: 0.7228
#    [FOLDER] Trial results saved: results/pakistani-diabetes-dataset/2025-11-05/Section-4/COPULAGAN/copulagan_trial_results.csv
#    [FOLDER] Summary statistics saved: results/pakistani-diabetes-dataset/2025-11-05/Section-4/COPULAGAN/copulagan_optimization_summary.csv
# [OK] COPULAGAN optimization analysis completed successfully!
# [FOLDER] Results saved to: results/pakistani-diabetes-dataset/2025-11-05/Section-4/COPULAGAN
# [OK] CopulaGAN analysis completed - files exported to results/pakistani-diabetes-dataset/2025-11-05/Section-4/COPULAGAN
#
# [SEARCH] 4.6.1: TVAE Hyperparameter Optimization Analysis
# ------------------------------------------------------------
# [OK] TVAE optimization study found
# [FOLDER] Model directory: results/pakistani-diabetes-dataset/2025-11-05/Section-4/TVAE
# [SEARCH] ANALYZING TVAE HYPERPARAMETER OPTIMIZATION
# ============================================================
# [CHART] 1. TRIAL DATA EXTRACTION AND PROCESSING
# ----------------------------------------
# [OK] Extracted 50 trials for analysis
# [CHART] 2. PARAMETER SPACE EXPLORATION ANALYSIS
# ----------------------------------------
#    - Found 11 hyperparameters: ['params_batch_size', 'params_compress_dims', 'params_conditional_generation', 'params_decompress_dims', 'params_dropout', 'params_embedding_dim', 'params_epochs', 'params_l2scale', 'params_learning_rate', 'params_log_frequency', 'params_verbose']
#    - Using 50 completed trials
# [STATS] Creating parameter vs performance visualizations...
#    [FOLDER] Parameter analysis plot saved: results/pakistani-diabetes-dataset/2025-11-05/Section-4/TVAE/tvae_parameter_analysis.png
# [CHART] 3. BEST TRIAL ANALYSIS
# ----------------------------------------
# [OK] Best Trial #46
#    - Best Score: 0.7914
#    - Duration: 31.2 seconds
#    - Best Parameters:
#      - batch_size: 256
#      - compress_dims: [128, 128]
#      - conditional_generation: True
#      - decompress_dims: [64, 128]
#      - dropout: 0.0518
#      - embedding_dim: 256
#      - epochs: 400
#      - l2scale: 0.0005
#      - learning_rate: 0.0005
#      - log_frequency: False
#      - verbose: True
# [CHART] 4. CONVERGENCE ANALYSIS
# ----------------------------------------
#    [FOLDER] Convergence plot saved: results/pakistani-diabetes-dataset/2025-11-05/Section-4/TVAE/tvae_convergence_analysis.png
# [CHART] 5. STATISTICAL SUMMARY
# ----------------------------------------
# [OK] Performance Statistics:
#    - Mean Score: 0.7657
#    - Std Dev: 0.0230
#    - Min Score: 0.6875
#    - Max Score: 0.7914
#    - Median Score: 0.7737
#    [FOLDER] Trial results saved: results/pakistani-diabetes-dataset/2025-11-05/Section-4/TVAE/tvae_trial_results.csv
#    [FOLDER] Summary statistics saved: results/pakistani-diabetes-dataset/2025-11-05/Section-4/TVAE/tvae_optimization_summary.csv
# [OK] TVAE optimization analysis completed successfully!
# [FOLDER] Results saved to: results/pakistani-diabetes-dataset/2025-11-05/Section-4/TVAE
# [OK] TVAE analysis completed - files exported to results/pakistani-diabetes-dataset/2025-11-05/Section-4/TVAE
#
# ============================================================
# HYPERPARAMETER OPTIMIZATION SUMMARY
# ============================================================
# [CHART] Models analyzed: 3
# [STATS] Total optimization trials: 150
# [OK] Successful trials: 150
#
# [INFO] OPTIMIZATION RESULTS SUMMARY:
#     model section  best_score  total_trials  completed_trials  best_trial_number  study_variable
#     CTGAN   4.1.1    0.835835            50                50                 38     ctgan_study
# CopulaGAN   4.5.1    0.767208            50                50                 21 copulagan_study
#      TVAE   4.6.1    0.791358            50                50                 46      tvae_study
#
# [SAVE] Summary exported to: results/pakistani-diabetes-dataset/2025-11-05/Section-4/hyperparameter_optimization_summary.csv
#
# [BEST] BEST PERFORMING MODEL: CTGAN
#    - Score: 0.8358
#    - Section: 4.1.1
#    - Trials completed: 50
#
# [OK] Section 4 hyperparameter optimization batch analysis completed!
# [FOLDER] All figures and tables exported to: results/pakistani-diabetes-dataset/2025-11-05/Section-4
# [CHART] Model-specific results in subdirectories: ['CTGAN', 'CTABGAN', 'CTABGANPLUS', 'GANERAID', 'COPULAGAN', 'TVAE']
#
# ================================================================================
# ✅ SECTION 4 HYPERPARAMETER OPTIMIZATION BATCH ANALYSIS COMPLETED!
# ================================================================================
# 📊 Models processed: 3
# 📁 Results exported to: results/pakistani-diabetes-dataset/2025-11-05/Section-4
# 📋 Individual model analysis files:
#    • Hyperparameter parameter_analysis.png plots
#    • Optimization convergence_analysis.png graphs
#    • Parameter correlation matrices
#    • Best trial summary tables
#    • Comprehensive optimization summary CSV
#
# ================================================================================
# 💾 SAVING BEST PARAMETERS FROM SECTION 4 OPTIMIZATION
# ================================================================================
# [SAVE] SAVING BEST PARAMETERS FROM SECTION 4
# ============================================================
# [FOLDER] Target directory: results/pakistani-diabetes-dataset/2025-11-05/Section-4
#
# [CHART] Processing CTGAN parameters...
# [OK] Found CTGAN: 12 parameters, score: 0.8358
#
# [CHART] Processing CTAB-GAN parameters...
# [WARNING]  CTAB-GAN: Study variable 'ctabgan_study' not found
#
# [CHART] Processing CTAB-GAN+ parameters...
# [WARNING]  CTAB-GAN+: Study variable 'ctabganplus_study' not found
#
# [CHART] Processing GANerAid parameters...
# [WARNING]  GANerAid: Study variable 'ganeraid_study' not found
#
# [CHART] Processing CopulaGAN parameters...
# [OK] Found CopulaGAN: 6 parameters, score: 0.7672
#
# [CHART] Processing TVAE parameters...
# [OK] Found TVAE: 11 parameters, score: 0.7914
#
# [OK] Parameters saved: results/pakistani-diabetes-dataset/2025-11-05/Section-4/best_parameters.csv
#    - Total parameter entries: 31
# [OK] Summary saved: results/pakistani-diabetes-dataset/2025-11-05/Section-4/best_parameters_summary.csv
#    - Models processed: 3
#
# [SAVE] Parameter saving completed!
# [FOLDER] Files saved to: results/pakistani-diabetes-dataset/2025-11-05/Section-4
#
# ✅ Parameter saving completed successfully!
#    • Files saved: 2
#    • Parameter entries: 31
#    • Models processed: 3
#    • Directory: results/pakistani-diabetes-dataset/2025-11-05/Section-4
#      📁 best_parameters.csv
#      📁 best_parameters_summary.csv
#
# 📈 Section 4 hyperparameter optimization analysis complete!
# 🏁 Ready for Section 5: Optimized model re-training

# %% [markdown]
# ## Section 5: Final Model Comparison and Best-of-Best Selection

# %% [markdown]
# ### 5.1 Re-run of models with best hyperparameters identified from Section 4

# %% [markdown]
# #### 5.1.1 Best CTGAN Model Evaluation

# %%
# Code Chunk ID: CHUNK_5_1_1_A
# Section 5.1: Best CTGAN Model Evaluation  
print("🏆 SECTION 5.1: BEST CTGAN MODEL EVALUATION")
print("=" * 60)

# ============================================================================
# LOAD BEST PARAMETERS FROM SECTION 4 (CSV + MEMORY FALLBACK)
# ============================================================================
print("📖 5.1.0 Loading best parameters from Section 4...")

try:
    # Load all best parameters using setup.py function
    param_data = load_best_parameters_from_csv(
        section_number=4,
        dataset_identifier=DATASET_IDENTIFIER,
        fallback_to_memory=True,
        scope=globals()
    )
    
    print(f"✅ Parameter loading completed from {param_data['source']}")
    print(f"   • Models available: {param_data['models_count']}")
    
    # Extract CTGAN parameters specifically
    loaded_ctgan_params = param_data['parameters'].get('ctgan', None)
    
except Exception as e:
    print(f"⚠️  Parameter loading failed: {str(e)}")
    print(f"   Falling back to direct memory access")
    loaded_ctgan_params = None

# 5.1.1 Retrieve Best Model Results from Section 4.1
print("\n📊 5.1.1 Retrieving best CTGAN results from Section 4.1...")

try:
    # Primary: Use loaded parameters if available
    if loaded_ctgan_params is not None:
        print(f"✅ Using loaded CTGAN parameters from {param_data['source']}")
        best_params = loaded_ctgan_params
        
        # Try to get additional metadata from memory if available
        if 'ctgan_study' in globals() and ctgan_study is not None and hasattr(ctgan_study, 'best_trial'):
            best_trial = ctgan_study.best_trial
            best_value = best_trial.value
            trial_number = best_trial.number
        else:
            # Use fallback values when memory unavailable  
            best_value = 0.0  # Will be recalculated during evaluation
            trial_number = "loaded_from_csv"
            print(f"   ⚠️  Memory study unavailable - using loaded parameters only")
        
    else:
        # Fallback: Direct memory access
        print(f"🔄 Falling back to direct memory access...")
        best_trial = ctgan_study.best_trial
        best_params = best_trial.params
        best_value = best_trial.value
        trial_number = best_trial.number
        print(f"✅ Using CTGAN parameters from memory")
    
    print(f"\n✅ Section 4.1 CTGAN optimization parameters retrieved!")
    print(f"   • Best Trial: #{trial_number}")
    print(f"   • Best Objective Score: {best_value:.4f}" if isinstance(best_value, (int, float)) else f"   • Best Objective Score: {best_value}")
    print(f"   • Parameter count: {len(best_params)}")
    
    # Display parameters
    print(f"\n📈 5.1.2 Best CTGAN configuration:")
    for param, value in best_params.items():
        if isinstance(value, float):
            print(f"   • {param}: {value:.4f}")
        else:
            print(f"   • {param}: {value}")
    
    print(f"🔍 Parameter source: {param_data.get('source', 'memory') if loaded_ctgan_params else 'memory'}")
    
    # ============================================================================
    # 5.1.3 TRAIN FINAL CTGAN MODEL WITH OPTIMIZED PARAMETERS
    # ============================================================================
    
    print(f"\n🔧 5.1.3 Training final CTGAN model with optimized parameters...")
    
    try:
        # Use ModelFactory pattern
        from src.models.model_factory import ModelFactory
        
        # Create CTGAN model
        final_ctgan_model = ModelFactory.create("ctgan", random_state=42)
        
        # Apply best parameters with defaults for missing values
        final_ctgan_params = {
            'epochs': best_params.get('epochs', 300),
            'batch_size': best_params.get('batch_size', 500),
            'generator_lr': best_params.get('generator_lr', 2e-4),
            'discriminator_lr': best_params.get('discriminator_lr', 2e-4),
            'generator_decay': best_params.get('generator_decay', 1e-6),
            'discriminator_decay': best_params.get('discriminator_decay', 1e-6),
            'pac': best_params.get('pac', 10),
            'verbose': best_params.get('verbose', True)
        }
        
        print("🔧 Training CTGAN with optimal hyperparameters...")
        for param, value in final_ctgan_params.items():
            print(f"   • Using {param}: {value}")
        
        # Train the model
        final_ctgan_model.train(data, **final_ctgan_params)
        print("✅ CTGAN training completed successfully!")
        
        # Generate synthetic data
        print("🎲 Generating synthetic data...")
        synthetic_ctgan_final = final_ctgan_model.generate(len(data))
        print(f"✅ Generated {len(synthetic_ctgan_final)} synthetic samples")
        
        # ============================================================================
        # 5.1.4 EVALUATE FINAL CTGAN MODEL PERFORMANCE
        # ============================================================================
        
        print("\n📊 5.1.4 Final CTGAN Model Evaluation...")
        
        # Use enhanced objective function for evaluation
        if 'enhanced_objective_function_v2' in globals():
            print("🎯 Enhanced objective function evaluation:")
            
            ctgan_final_score, ctgan_similarity, ctgan_accuracy = enhanced_objective_function_v2(
                real_data=data, 
                synthetic_data=synthetic_ctgan_final, 
                target_column=TARGET_COLUMN
            )
            
            print(f"\n✅ Final CTGAN Evaluation Results:")
            print(f"   • Overall Score: {ctgan_final_score:.4f}")
            print(f"   • Similarity Score: {ctgan_similarity:.4f} (60% weight)")  
            print(f"   • Accuracy Score: {ctgan_accuracy:.4f} (40% weight)")
            
            # Store results for Section 5.7 comparison
            ctgan_final_results = {
                'model_name': 'CTGAN',
                'objective_score': ctgan_final_score,
                'similarity_score': ctgan_similarity,
                'accuracy_score': ctgan_accuracy,
                'best_params': best_params,
                'parameter_source': param_data.get('source', 'memory') if loaded_ctgan_params else 'memory',
                'synthetic_data': synthetic_ctgan_final
            }
            
            print("🎯 CTGAN Final Assessment:")
            print(f"   • Production Ready: {'✅ Yes' if ctgan_final_score > 0.6 else '⚠️ Review Required'}")
            print(f"   • Recommended for: General-purpose tabular synthetic data generation")
            print(f"   • Final Score vs Optimization Score: {ctgan_final_score:.4f} vs {best_value:.4f}" if isinstance(best_value, (int, float)) else f"   • Final Score: {ctgan_final_score:.4f}")
            
        else:
            print("⚠️ Enhanced objective function not available - using basic evaluation")
            ctgan_final_results = {
                'model_name': 'CTGAN',
                'objective_score': best_value if isinstance(best_value, (int, float)) else 0.0,
                'best_params': best_params,
                'parameter_source': param_data.get('source', 'memory') if loaded_ctgan_params else 'memory',
                'synthetic_data': synthetic_ctgan_final
            }
                
    except Exception as train_error:
        print(f"❌ Failed to train final CTGAN model: {train_error}")
        import traceback
        traceback.print_exc()
        synthetic_ctgan_final = None
        ctgan_final_score = 0.0
        ctgan_final_results = {
            'model_name': 'CTGAN',
            'objective_score': 0.0,
            'error': str(train_error)
        }

except Exception as e:
    print(f"❌ Error accessing CTGAN parameters: {e}")
    print("   Please ensure Section 4.1 has been executed successfully or parameter CSV exists.")
    # Create empty results to prevent downstream errors
    synthetic_ctgan_final = None
    ctgan_final_results = {
        'model_name': 'CTGAN',
        'objective_score': 0.0,
        'error': str(e)
    }
    
print("\n" + "=" * 60)
print("✅ SECTION 5.1 COMPLETE: Best CTGAN model trained and evaluated")
print("🔄 Ready for Section 5.2: CTAB-GAN model training")
# Out:
# 🏆 SECTION 5.1: BEST CTGAN MODEL EVALUATION
# ============================================================
# 📖 5.1.0 Loading best parameters from Section 4...
# [LOAD] LOADING BEST PARAMETERS FROM SECTION 4
# ============================================================
# [FOLDER] Looking for: results/pakistani-diabetes-dataset/2025-11-05/Section-4/best_parameters.csv
# [OK] Found parameter CSV file
# [OK] Loaded CTGAN: 12 parameters
# [OK] Loaded CopulaGAN: 6 parameters
# [OK] Loaded TVAE: 11 parameters
#
# [LOAD] Parameter loading completed!
# [SEARCH] Source: CSV file
# [CHART] Models loaded: 3
#    - ctgan: 12 parameters
#    - copulagan: 6 parameters
#    - tvae: 11 parameters
# ✅ Parameter loading completed from CSV file
#    • Models available: 3
#
# 📊 5.1.1 Retrieving best CTGAN results from Section 4.1...
# ✅ Using loaded CTGAN parameters from CSV file
#
# ✅ Section 4.1 CTGAN optimization parameters retrieved!
#    • Best Trial: #38
#    • Best Objective Score: 0.8358
#    • Parameter count: 12
#
# 📈 5.1.2 Best CTGAN configuration:
#    • batch_size: 1000
#    • pac: 3
#    • epochs: 800
#    • generator_lr: 0.0001
#    • discriminator_lr: 0.0031
#    • generator_dim: (256, 512, 256)
#    • discriminator_dim: (256, 256)
#    • discriminator_steps: 3
#    • generator_decay: 0.0000
#    • discriminator_decay: 0.0000
#    • log_frequency: False
#    • verbose: True
# 🔍 Parameter source: CSV file
#
# 🔧 5.1.3 Training final CTGAN model with optimized parameters...
# 🔧 Training CTGAN with optimal hyperparameters...
#    • Using epochs: 800
#    • Using batch_size: 1000
#    • Using generator_lr: 6.06656088925087e-05
#    • Using discriminator_lr: 0.0031235585599621325
#    • Using generator_decay: 3.221089025088075e-07
#    • Using discriminator_decay: 3.547122654188149e-05
#    • Using pac: 3
#    • Using verbose: True
# Gen. (-0.48) | Discrim. (-0.26): 100%|██████████| 800/800 [00:37<00:00, 21.25it/s]
# ✅ CTGAN training completed successfully!
# 🎲 Generating synthetic data...
# ✅ Generated 912 synthetic samples
#
# 📊 5.1.4 Final CTGAN Model Evaluation...
# 🎯 Enhanced objective function evaluation:
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.5531
# [OK] TRTS (Synthetic->Real): 0.9770
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.8684
# [CHART] Combined Score: 0.6792 (Similarity: 0.5531, Accuracy: 0.8684)
#
# ✅ Final CTGAN Evaluation Results:
#    • Overall Score: 0.6792
#    • Similarity Score: 0.5531 (60% weight)
#    • Accuracy Score: 0.8684 (40% weight)
# 🎯 CTGAN Final Assessment:
#    • Production Ready: ✅ Yes
#    • Recommended for: General-purpose tabular synthetic data generation
#    • Final Score vs Optimization Score: 0.6792 vs 0.8358
#
# ============================================================
# ✅ SECTION 5.1 COMPLETE: Best CTGAN model trained and evaluated
# 🔄 Ready for Section 5.2: CTAB-GAN model training

# %% [markdown]
# #### 5.1.2 Best CTAB-GAN Model Evaluation

# %%
# Code Chunk ID: CHUNK_5_1_1_Aa

# Section 5.2: Best CTAB-GAN Model Evaluation
print("🏆 SECTION 5.2: BEST CTAB-GAN MODEL EVALUATION")
print("=" * 60)

# 5.2.1 Retrieve Best Model Results from Section 4.2
print("📊 5.2.1 Retrieving best CTAB-GAN results from Section 4.2...")

try:
    # Use unified parameter loading function
    ctabgan_params = get_model_parameters(
        model_name='ctab-gan',
        section_number=4,
        dataset_identifier=DATASET_IDENTIFIER,
        scope=globals()
    )
    
    if ctabgan_params is not None:
        best_params = ctabgan_params
        
        # Try to get additional metadata from memory if available
        if 'ctabgan_study' in globals() and ctabgan_study is not None:
            best_trial = ctabgan_study.best_trial
            best_objective_score = best_trial.value
            trial_number = best_trial.number
            print(f"✅ Section 4.2 CTAB-GAN optimization completed successfully!")
            print(f"   • Best Trial: #{trial_number}")
        else:
            # Use fallback values when memory unavailable
            best_objective_score = 0.0
            trial_number = "loaded_from_csv"
            print(f"✅ Section 4.2 CTAB-GAN parameters loaded from CSV!")
            print(f"   • Best Trial: #{trial_number}")
        
        print(f"   • Best Objective Score: {best_objective_score:.4f}" if isinstance(best_objective_score, (int, float)) else f"   • Best Objective Score: {best_objective_score}")
        print(f"   • Best Parameters:")
        for param, value in best_params.items():
            print(f"     - {param}: {value}")
        
        # 5.2.2 Train Final CTAB-GAN Model using Section 5.1 Pattern
        print("🔧 Training final CTAB-GAN model using Section 5.1 proven pattern with optimized parameters...")
        
        try:
            # Use the exact same ModelFactory pattern that works in Section 5.1
            from src.models.model_factory import ModelFactory
            
            # Create CTAB-GAN model using the working pattern
            final_ctabgan_model = ModelFactory.create("ctabgan", random_state=42)
            
            # Apply the best parameters found in Section 4.2 optimization
            final_ctabgan_params = {
                'epochs': best_params.get('epochs', 300),
                'batch_size': best_params.get('batch_size', 512),
                'lr': best_params.get('lr', 2e-4),
                'betas': best_params.get('betas', (0.5, 0.9)),
                'l2scale': best_params.get('l2scale', 1e-5),
                'mixed_precision': best_params.get('mixed_precision', False),
                'test_ratio': best_params.get('test_ratio', 0.20),
                'verbose': best_params.get('verbose', True)
            }
            
            print("🔧 Training CTAB-GAN with optimal hyperparameters...")
            for param, value in final_ctabgan_params.items():
                print(f"   • Using {param}: {value}")
            
            # Train the model with best parameters
            final_ctabgan_model.train(data, **final_ctabgan_params)
            print("✅ CTAB-GAN training completed successfully!")
            
            # Generate synthetic data
            print("📊 Generating synthetic data for evaluation...")
            synthetic_ctabgan_final = final_ctabgan_model.generate(len(data))
            print(f"✅ Generated {len(synthetic_ctabgan_final)} synthetic samples")
            
            # Evaluate using enhanced objective function
            if 'enhanced_objective_function_v2' in globals():
                print("🎯 CTAB-GAN Classification Performance Analysis:")
                
                ctabgan_final_score, ctabgan_similarity, ctabgan_accuracy = enhanced_objective_function_v2(
                    real_data=data, 
                    synthetic_data=synthetic_ctabgan_final, 
                    target_column=TARGET_COLUMN
                )
                
                print(f"✅ CTAB-GAN Final Results:")
                print(f"   • Overall Score: {ctabgan_final_score:.4f}")
                print(f"   • Similarity Score: {ctabgan_similarity:.4f}")  
                print(f"   • Accuracy Score: {ctabgan_accuracy:.4f}")
                
                # Store results for Section 5.7 comparison
                ctabgan_final_results = {
                    'model_name': 'CTAB-GAN',
                    'objective_score': ctabgan_final_score,
                    'similarity_score': ctabgan_similarity,
                    'accuracy_score': ctabgan_accuracy,
                    'best_params': best_params,
                    'synthetic_data': synthetic_ctabgan_final
                }
                
            else:
                print("⚠️ Enhanced objective function not available - using basic evaluation")
                ctabgan_final_results = {
                    'model_name': 'CTAB-GAN',
                    'objective_score': best_objective_score,
                    'best_params': best_params,
                    'synthetic_data': synthetic_ctabgan_final
                }
                
        except Exception as e:
            print(f"❌ CTAB-GAN training failed: {str(e)}")
            synthetic_ctabgan_final = None
            ctabgan_final_results = {
                'model_name': 'CTAB-GAN',
                'objective_score': 0.0,
                'error': str(e)
            }
        
    else:
        print("❌ CTAB-GAN study results not found - Section 4.2 may not have completed successfully")
        print("    Please ensure Section 4.2 has been executed before running Section 5.2")
        synthetic_ctabgan_final = None
        ctabgan_final_score = 0.0
        ctabgan_final_results = {
            'model_name': 'CTAB-GAN',
            'objective_score': 0.0,
            'error': 'Section 4.2 not completed'
        }
        
except Exception as e:
    print(f"❌ Error in Section 5.2 CTAB-GAN evaluation: {e}")
    import traceback
    traceback.print_exc()
    synthetic_ctabgan_final = None
    ctabgan_final_score = 0.0
    ctabgan_final_results = {
        'model_name': 'CTAB-GAN',
        'objective_score': 0.0,
        'error': str(e)
    }

print("✅ Section 5.2 CTAB-GAN evaluation completed!")
print("=" * 60)

# %% [markdown]
# #### 5.1.3 Best CTAB-GAN+ Model Evaluation

# %%
# Code Chunk ID: CHUNK_5_1_3_A
# ============================================================================
# Section 5.3: Best CTAB-GAN+ Model Evaluation - FIXED IMPLEMENTATION
# ============================================================================
# Using Section 4.3 optimized hyperparameters with proven ModelFactory pattern

print("🏆 SECTION 5.3: BEST CTAB-GAN+ MODEL EVALUATION")
print("=" * 80)

try:
    # Step 1: Retrieve Section 4.3 CTAB-GAN+ optimization results
    if 'ctabganplus_study' in globals():
        best_trial = ctabganplus_study.best_trial
        best_params = best_trial.params
        best_objective_score = best_trial.value
        
        print(f"✅ Retrieved Section 4.3 CTAB-GAN+ optimization results")
        print(f"   • Best Trial: #{best_trial.number}")
        print(f"   • Best Objective Score: {best_objective_score:.4f}")
        print(f"   • Parameters: {len(best_params)} hyperparameters")
        
        # Display best parameters
        print(f"\n📊 Best CTAB-GAN+ Hyperparameters:")
        print("-" * 40)
        for param, value in best_params.items():
            if isinstance(value, float):
                print(f"   • {param}: {value:.4f}")
            else:
                print(f"   • {param}: {value}")
                
    else:
        print("⚠️ CTAB-GAN+ optimization results not found - using fallback parameters")
        # Fallback CTAB-GAN+ parameters (basic working configuration)
        best_params = {
            'epochs': 100,
            'batch_size': 128,
            'lr_generator': 1e-4,
            'lr_discriminator': 2e-4,
            'beta_1': 0.5,
            'beta_2': 0.9,
            'lambda_gp': 10,
            'pac': 1
        }
        best_objective_score = None
        print(f"   Using fallback parameters: {best_params}")

    # Step 2: Create CTAB-GAN+ model using proven ModelFactory pattern (SAME AS SECTION 5.2)
    print(f"\n🏗️ Creating CTAB-GAN+ model using ModelFactory...")
    from src.models.model_factory import ModelFactory
    
    # CRITICAL FIX: Use the exact same ModelFactory pattern that works in Section 5.1 & 5.2
    final_ctabganplus_model = ModelFactory.create("ctabganplus", random_state=42)
    print(f"✅ CTAB-GAN+ model created successfully")
    
    # Step 3: Train using the correct method name: .train() (NOT .fit())
    print(f"\n🚀 Training CTAB-GAN+ model with optimized hyperparameters...")
    print(f"   • Data shape: {data.shape}")
    print(f"   • Target column: '{TARGET_COLUMN}'")
    print(f"   • Training with Section 4.3 parameters")
    
    # Store final parameters for results tracking
    final_ctabganplus_params = best_params.copy()
    
    # CRITICAL FIX: Train using .train() method (proven pattern from Sections 5.1 & 5.2)
    final_ctabganplus_model.train(data, **final_ctabganplus_params)
    print(f"✅ CTAB-GAN+ model training completed successfully!")
    
    # Step 4: Generate synthetic data using the correct method: .generate()
    print(f"\n📊 Generating synthetic data for evaluation...")
    synthetic_ctabganplus_final = final_ctabganplus_model.generate(len(data))
    print(f"✅ Synthetic data generated successfully!")
    print(f"   • Synthetic data shape: {synthetic_ctabganplus_final.shape}")
    print(f"   • Columns match: {list(synthetic_ctabganplus_final.columns) == list(data.columns)}")
    
    # Step 5: Quick evaluation using enhanced objective function (NO IMPORT - function in globals)
    if 'enhanced_objective_function_v2' in globals():
        ctabganplus_final_score, ctabganplus_similarity, ctabganplus_accuracy = enhanced_objective_function_v2(
            real_data=data, 
            synthetic_data=synthetic_ctabganplus_final, 
            target_column=TARGET_COLUMN
        )
        
        print(f"\n📊 CTAB-GAN+ Enhanced Objective Function v2 Results:")
        print(f"   • Final Combined Score: {ctabganplus_final_score:.4f}")
        print(f"   • Statistical Similarity (60%): {ctabganplus_similarity:.4f}")
        print(f"   • Classification Accuracy (40%): {ctabganplus_accuracy:.4f}")
    else:
        print("⚠️ Enhanced objective function not available - using basic metrics")
        ctabganplus_final_score = 0.5  # Fallback score
        ctabganplus_similarity = 0.5
        ctabganplus_accuracy = 0.5
    
    # Store results for Section 5.7 comparative analysis
    ctabganplus_final_results = {
        'model_name': 'CTAB-GAN+',
        'objective_score': ctabganplus_final_score,
        'similarity_score': ctabganplus_similarity,
        'accuracy_score': ctabganplus_accuracy,
        'final_combined_score': ctabganplus_final_score,
        'sections_completed': ['5.3.1'],
        'evaluation_method': 'section_5_1_pattern',
        'section_4_optimization': best_objective_score is not None,
        'best_section_4_score': best_objective_score
    }
    
    print(f"\n✅ SECTION 5.3 COMPLETED SUCCESSFULLY!")
    print(f"🎯 CTAB-GAN+ evaluation completed using Section 4.3 optimized parameters")
    print(f"📊 Results ready for Section 5.7 comparative analysis")
    print("-" * 80)

except Exception as e:
    print(f"❌ CTAB-GAN+ evaluation failed: {str(e)}")
    import traceback
    traceback.print_exc()
    # Set fallback for subsequent sections
    synthetic_ctabganplus_final = None
    ctabganplus_final_results = {'error': str(e), 'evaluation_failed': True}

# %% [markdown]
# #### Section 5.1.4 BEST GANerAid MODEL

# %%
# Code Chunk ID: CHUNK_5_1_4_A
# ============================================================================
# Section 5.4.1: Best GANerAid Model Training
# ============================================================================
# Using Section 4.4 optimized hyperparameters with proven ModelFactory pattern

print("🏆 SECTION 5.4.1: BEST GANerAid MODEL TRAINING")
print("=" * 80)

try:
    # Step 1: Retrieve Section 4.4 GANerAid optimization results
    if 'ganeraid_study' in globals():
        best_trial = ganeraid_study.best_trial
        final_ganeraid_params = best_trial.params
        best_objective_score = best_trial.value
        
        print(f"✅ Retrieved Section 4.4 GANerAid optimization results")
        print(f"   • Best Trial: #{best_trial.number}")
        print(f"   • Best Objective Score: {best_objective_score:.4f}")
        print(f"   • Parameters: {len(final_ganeraid_params)} hyperparameters")
        
    else:
        print("⚠️ GANerAid optimization results not found - using fallback parameters")
        # Fallback GANerAid parameters
        final_ganeraid_params = {
            'epochs': 100,
            'batch_size': 128,
            'learning_rate': 1e-4
        }
        best_objective_score = None

    # Step 2: Create GANerAid model using proven ModelFactory pattern
    print(f"\n🏗️ Creating GANerAid model using ModelFactory...")
    from src.models.model_factory import ModelFactory
    
    final_ganeraid_model = ModelFactory.create("ganeraid", random_state=42)
    print(f"✅ GANerAid model created successfully")
    
    # Step 3: Train using .train() method (NOT .fit())
    print(f"\n🚀 Training GANerAid model with optimized hyperparameters...")
    final_ganeraid_model.train(data, **final_ganeraid_params)
    print(f"✅ GANerAid model training completed successfully!")
    
    # Step 4: Generate synthetic data
    synthetic_ganeraid_final = final_ganeraid_model.generate(len(data))
    print(f"✅ GANerAid synthetic data generated: {synthetic_ganeraid_final.shape}")
    
    # Step 5: Quick evaluation using enhanced objective function (NO IMPORT - function in globals)
    if 'enhanced_objective_function_v2' in globals():
        ganeraid_final_score, ganeraid_similarity, ganeraid_accuracy = enhanced_objective_function_v2(
            real_data=data, synthetic_data=synthetic_ganeraid_final, target_column=TARGET_COLUMN
        )
        
        print(f"\n📊 GANerAid Enhanced Objective Function v2 Results:")
        print(f"   • Final Combined Score: {ganeraid_final_score:.4f}")
        print(f"   • Statistical Similarity (60%): {ganeraid_similarity:.4f}")
        print(f"   • Classification Accuracy (40%): {ganeraid_accuracy:.4f}")
    else:
        print("⚠️ Enhanced objective function not available - using basic metrics")
        ganeraid_final_score = 0.5  # Fallback score
        ganeraid_similarity = 0.5
        ganeraid_accuracy = 0.5
    
    # Store results
    ganeraid_final_results = {
        'model_name': 'GANerAid',
        'objective_score': ganeraid_final_score,
        'similarity_score': ganeraid_similarity,
        'accuracy_score': ganeraid_accuracy,
        'final_combined_score': ganeraid_final_score,
        'sections_completed': ['5.4.1'],
        'evaluation_method': 'section_5_1_pattern',
        'section_4_optimization': best_objective_score is not None,
        'best_section_4_score': best_objective_score,
        'optimized_params': final_ganeraid_params
    }
    
    print(f"\n✅ SECTION 5.4.1 - GANerAid MODEL TRAINING COMPLETED!")
    print("-" * 80)

except Exception as e:
    print(f"❌ GANerAid training failed: {str(e)}")
    import traceback
    traceback.print_exc()
    synthetic_ganeraid_final = None
    ganeraid_final_results = {'error': str(e), 'training_failed': True}

# %% [markdown]
# #### 5.1.5: Best CopulaGAN Model

# %%
# Code Chunk ID: CHUNK_5_1_5_A
# ============================================================================
# Section 5.5: Best CopulaGAN Model Evaluation
# ============================================================================
# Using Section 4.5 optimized hyperparameters with proven ModelFactory pattern

# Import ModelFactory for CopulaGAN creation
from src.models.model_factory import ModelFactory

print("🎯 ============================================================================")
print("🎯 Section 5.5: CopulaGAN Final Model Training & Evaluation")
print("🎯 ============================================================================")

try:
    # Load all best parameters using setup.py function
    param_data = load_best_parameters_from_csv(
        section_number=4,
        dataset_identifier=DATASET_IDENTIFIER,
        fallback_to_memory=True,
        scope=globals()
    )
    
    # Extract CopulaGAN parameters specifically
    loaded_copulagan_params = param_data['parameters'].get('copulagan', None)
    
    if loaded_copulagan_params:
        print(f"📋 Loaded CopulaGAN parameters from {param_data.get('source', 'unknown')}:")
        for param, value in loaded_copulagan_params.items():
            print(f"   • {param}: {value}")
        # Use all optimized parameters from Section 4.5
        best_params = loaded_copulagan_params.copy()
        param_source = param_data.get('source', 'CSV')
    else:
        print("⚠️ CopulaGAN optimization results not found - using fallback parameters")
        best_params = {'epochs': 500, 'batch_size': 100}  # Use Section 3 proven values
        param_source = 'fallback'
    
    print(f"\n🔧 Preprocessing data for CopulaGAN...")
    data_preprocessed = data.copy()
    print(f"   ✅ Data preprocessing completed: {data_preprocessed.shape}")
    print(f"   • Missing values: {data_preprocessed.isnull().sum().sum()}")
    
    # Show data types
    dtype_counts = data_preprocessed.dtypes.value_counts()
    print(f"   • Data types: {dict(dtype_counts)}")
    
    print(f"\n🏗️ Creating CopulaGAN model using ModelFactory...")
    final_copulagan_model = ModelFactory.create("copulagan", random_state=42)
    print("✅ CopulaGAN model created successfully")
    
    print(f"\n🚀 Training CopulaGAN model with optimized hyperparameters...")
    print(f"   • Using parameters: {best_params}")
    
    # Train the model with all optimized parameters
    final_copulagan_model.train(data_preprocessed, **best_params)
    
    print("✅ CopulaGAN model training completed successfully")
    
    # Generate synthetic data
    print(f"\n🎲 Generating {len(data_preprocessed)} synthetic samples...")
    synthetic_copulagan_final = final_copulagan_model.generate(len(data_preprocessed))
    print(f"   ✅ Generated synthetic data: {synthetic_copulagan_final.shape}")
    
    # Comprehensive evaluation with enhanced objective function - using correct parameters
    print(f"\n📊 Comprehensive model evaluation...")
    copulagan_final_score, copulagan_similarity, copulagan_accuracy = enhanced_objective_function_v2(
        real_data=data_preprocessed,
        synthetic_data=synthetic_copulagan_final,
        target_column=TARGET_COLUMN
    )
    
    print(f"\n🎯 === CopulaGAN Final Results (Section 5.5) ===")
    print(f"📈 Combined Score: {copulagan_final_score:.4f}")
    print(f"📊 Statistical Similarity: {copulagan_similarity:.4f}")
    print(f"🎯 Predictive Accuracy: {copulagan_accuracy:.4f}")
    print(f"🔧 Parameter Source: {param_source}")
    
    # Store results for comparison
    copulagan_final_result = {
        'model_name': 'CopulaGAN_Final',
        'combined_score': copulagan_final_score,
        'similarity_score': copulagan_similarity,
        'accuracy_score': copulagan_accuracy,
        'hyperparameters': best_params,
        'parameter_source': param_source
    }
    
    print("✅ CopulaGAN final model evaluation completed successfully")
    
except Exception as e:
    print(f"❌ Error in CopulaGAN final model evaluation: {str(e)}")
    import traceback
    traceback.print_exc()
    
    # Fallback result to prevent pipeline failure
    copulagan_final_result = {
        'model_name': 'CopulaGAN_Final',
        'combined_score': 0.0,
        'similarity_score': 0.0,
        'accuracy_score': 0.0,
        'hyperparameters': {},
        'parameter_source': 'error_fallback'
    }
# Out:
# 🎯 ============================================================================
# 🎯 Section 5.5: CopulaGAN Final Model Training & Evaluation
# 🎯 ============================================================================
# [LOAD] LOADING BEST PARAMETERS FROM SECTION 4
# ============================================================
# [FOLDER] Looking for: results/pakistani-diabetes-dataset/2025-11-05/Section-4/best_parameters.csv
# [OK] Found parameter CSV file
# [OK] Loaded CTGAN: 12 parameters
# [OK] Loaded CopulaGAN: 6 parameters
# [OK] Loaded TVAE: 11 parameters
#
# [LOAD] Parameter loading completed!
# [SEARCH] Source: CSV file
# [CHART] Models loaded: 3
#    - ctgan: 12 parameters
#    - copulagan: 6 parameters
#    - tvae: 11 parameters
# 📋 Loaded CopulaGAN parameters from CSV file:
#    • epochs: 500
#    • batch_size: 100
#    • generator_lr: 1.0890284891781855e-05
#    • discriminator_lr: 8.924578567594168e-05
#    • generator_decay: 9.447062089525266e-08
#    • discriminator_decay: 6.487869822916734e-06
#
# 🔧 Preprocessing data for CopulaGAN...
#    ✅ Data preprocessing completed: (912, 19)
#    • Missing values: 0
#    • Data types: {dtype('int64'): 13, dtype('float64'): 6}
#
# 🏗️ Creating CopulaGAN model using ModelFactory...
# ✅ CopulaGAN model created successfully
#
# 🚀 Training CopulaGAN model with optimized hyperparameters...
#    • Using parameters: {'epochs': 500, 'batch_size': 100, 'generator_lr': 1.0890284891781855e-05, 'discriminator_lr': 8.924578567594168e-05, 'generator_decay': 9.447062089525266e-08, 'discriminator_decay': 6.487869822916734e-06}
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# ✅ CopulaGAN model training completed successfully
#
# 🎲 Generating 912 synthetic samples...
#    ✅ Generated synthetic data: (912, 19)
#
# 📊 Comprehensive model evaluation...
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6175
# [OK] TRTS (Synthetic->Real): 0.9912
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9507
# [CHART] Combined Score: 0.7508 (Similarity: 0.6175, Accuracy: 0.9507)
#
# 🎯 === CopulaGAN Final Results (Section 5.5) ===
# 📈 Combined Score: 0.7508
# 📊 Statistical Similarity: 0.6175
# 🎯 Predictive Accuracy: 0.9507
# 🔧 Parameter Source: CSV file
# ✅ CopulaGAN final model evaluation completed successfully

# %% [markdown]
# #### 5.1.6: Best TVAE Model Evaluation

# %%
# Code Chunk ID: CHUNK_5_1_6_A
# ============================================================================
# Section 5.6.1: Best TVAE Model Training
# ============================================================================
# Using Section 4.6 optimized hyperparameters with proven ModelFactory pattern

print("🏆 SECTION 5.6.1: BEST TVAE MODEL TRAINING")
print("=" * 80)

try:
    # Step 1: Retrieve Section 4.6 TVAE optimization results
    if 'tvae_study' in globals():
        best_trial = tvae_study.best_trial
        final_tvae_params = best_trial.params
        best_objective_score = best_trial.value
        
        print(f"✅ Retrieved Section 4.6 TVAE optimization results")
        print(f"   • Best Trial: #{best_trial.number}")
        print(f"   • Best Objective Score: {best_objective_score:.4f}")
        print(f"   • Parameters: {len(final_tvae_params)} hyperparameters")
        
    else:
        print("⚠️ TVAE optimization results not found - using fallback parameters")
        # Fallback TVAE parameters
        final_tvae_params = {
            'epochs': 100,
            'batch_size': 128,
            'lr': 1e-4,
            'compress_dims': [128, 64],
            'decompress_dims': [64, 128]
        }
        best_objective_score = None

    # Step 2: Create TVAE model using proven ModelFactory pattern
    print(f"\n🏗️ Creating TVAE model using ModelFactory...")
    from src.models.model_factory import ModelFactory
    
    final_tvae_model = ModelFactory.create("tvae", random_state=42)
    print(f"✅ TVAE model created successfully")
    
    # Step 3: Train using .train() method (NOT .fit())
    print(f"\n🚀 Training TVAE model with optimized hyperparameters...")
    final_tvae_model.train(data, **final_tvae_params)
    print(f"✅ TVAE model training completed successfully!")
    
    # Step 4: Generate synthetic data
    synthetic_tvae_final = final_tvae_model.generate(len(data))
    print(f"✅ TVAE synthetic data generated: {synthetic_tvae_final.shape}")
    
    # Step 5: Quick evaluation using enhanced objective function (NO IMPORT - function in globals)
    if 'enhanced_objective_function_v2' in globals():
        tvae_final_score, tvae_similarity, tvae_accuracy = enhanced_objective_function_v2(
            real_data=data, synthetic_data=synthetic_tvae_final, target_column=TARGET_COLUMN
        )
        
        print(f"\n📊 TVAE Enhanced Objective Function v2 Results:")
        print(f"   • Final Combined Score: {tvae_final_score:.4f}")
        print(f"   • Statistical Similarity (60%): {tvae_similarity:.4f}")
        print(f"   • Classification Accuracy (40%): {tvae_accuracy:.4f}")
    else:
        print("⚠️ Enhanced objective function not available - using basic metrics")
        tvae_final_score = 0.5  # Fallback score
        tvae_similarity = 0.5
        tvae_accuracy = 0.5
    
    # Store results
    tvae_final_results = {
        'model_name': 'TVAE',
        'objective_score': tvae_final_score,
        'similarity_score': tvae_similarity,
        'accuracy_score': tvae_accuracy,
        'final_combined_score': tvae_final_score,
        'sections_completed': ['5.6.1'],
        'evaluation_method': 'section_5_1_pattern',
        'section_4_optimization': best_objective_score is not None,
        'best_section_4_score': best_objective_score,
        'optimized_params': final_tvae_params
    }
    
    print(f"\n✅ SECTION 5.6.1 - TVAE MODEL TRAINING COMPLETED!")
    print("-" * 80)

except Exception as e:
    print(f"❌ TVAE training failed: {str(e)}")
    import traceback
    traceback.print_exc()
    synthetic_tvae_final = None
    tvae_final_results = {'error': str(e), 'training_failed': True}
# Out:
# 🏆 SECTION 5.6.1: BEST TVAE MODEL TRAINING
# ================================================================================
# ✅ Retrieved Section 4.6 TVAE optimization results
#    • Best Trial: #46
#    • Best Objective Score: 0.7914
#    • Parameters: 11 hyperparameters
#
# 🏗️ Creating TVAE model using ModelFactory...
# ✅ TVAE model created successfully
#
# 🚀 Training TVAE model with optimized hyperparameters...
# ✅ TVAE model training completed successfully!
# ✅ TVAE synthetic data generated: (912, 19)
# [TARGET] Enhanced objective function using target column: 'Outcome'
# [OK] Similarity Analysis: 19/19 valid metrics, Average: 0.6211
# [OK] TRTS (Synthetic->Real): 0.9890
# [OK] TRTS Evaluation: 2 scenarios, Average: 0.9737
# [CHART] Combined Score: 0.7622 (Similarity: 0.6211, Accuracy: 0.9737)
#
# 📊 TVAE Enhanced Objective Function v2 Results:
#    • Final Combined Score: 0.7622
#    • Statistical Similarity (60%): 0.6211
#    • Classification Accuracy (40%): 0.9737
#
# ✅ SECTION 5.6.1 - TVAE MODEL TRAINING COMPLETED!
# --------------------------------------------------------------------------------

# %% [markdown]
# ### 5.2 Batch Process

# %% [markdown]
# This section outputs figures and graphics from models run in 54.1. The next chunk will output results for whatever subsections of 5.1 were run. I.e., if there's need to debug one method, there's no need to run all subsections of 5.1.

# %%
# Code Chunk ID: CHUNK_5_2_0_A
# ============================================================================
# SECTION 5.2 - OPTIMIZED MODELS BATCH EVALUATION
# Following CHUNK_018 pattern with comprehensive file export to Section-5 directory
# ============================================================================

print("🔍 SECTION 5.2 - OPTIMIZED MODELS BATCH EVALUATION")
print("=" * 80)
print("📋 Evaluating all available optimized models from Section 5.1.x")
print("📁 Exporting all tables and analysis to Section-5 directory")
print("🔄 Following Section 3 comprehensive evaluation pattern")
print()

# Ensure setup module function is available
from setup import evaluate_section5_optimized_models

# Use Section 5 batch evaluation function from setup.py
# Following exact same pattern as CHUNK_018 (Section 3) - comprehensive file export!
try:
    # Run batch evaluation with file export for all optimized models
    section5_batch_results = evaluate_section5_optimized_models(
        section_number=5,
        scope=globals(),  # Pass notebook scope to access synthetic data variables
        target_column=TARGET_COLUMN
    )
    
    print("\n" + "="*80)
    print("✅ SECTION 5.2 OPTIMIZED MODELS BATCH EVALUATION COMPLETED!")
    print("="*80)
    print(f"📊 Models processed: {section5_batch_results['models_processed']}")
    print(f"📁 Results exported to: {section5_batch_results['results_dir']}")
    
    # Show summary of all evaluations
    if 'evaluation_summaries' in section5_batch_results:
        print("\n📋 EVALUATION SUMMARIES:")
        print("-" * 40)
        for model_name, summary in section5_batch_results['evaluation_summaries'].items():
            print(f"🤖 {model_name}:")
            print(f"   📊 Synthetic samples: {summary.get('synthetic_samples', 'N/A')}")
            print(f"   📈 Overall score: {summary.get('overall_score', 'N/A')}")
            
    print("\n" + "="*80)
            
except Exception as e:
    print(f"❌ Section 5.2 batch evaluation failed: {e}")
    print(f"🔍 Error details: {type(e).__name__}")
    print()
    print("⚠️  Check that Section 5.1.x models completed successfully")

print("\n📈 Section 5.2 optimized model batch evaluation complete!")
print("🏁 Ready for final model comparison and production deployment!")
# Out:
# 🔍 SECTION 5.2 - OPTIMIZED MODELS BATCH EVALUATION
# ================================================================================
# 📋 Evaluating all available optimized models from Section 5.1.x
# 📁 Exporting all tables and analysis to Section-5 directory
# 🔄 Following Section 3 comprehensive evaluation pattern
#
# [SEARCH] UNIFIED BATCH EVALUATION - SECTION 5
# ============================================================
# [INFO] Dataset: pakistani-diabetes-dataset
# [INFO] Target column: Outcome
# [INFO] Variable pattern: final
# [INFO] Found 3 trained models:
#    [OK] CTGAN
#    [OK] CopulaGAN
#    [OK] TVAE
#
# ==================== EVALUATING CTGAN ====================
# [SEARCH] CTGAN - COMPREHENSIVE DATA QUALITY EVALUATION
# ============================================================
# [FOLDER] Output directory: results/pakistani-diabetes-dataset/2025-11-05/Section-5/CTGAN
#
# [1] STATISTICAL SIMILARITY
# ------------------------------
#    [CHART] Average Statistical Similarity: 0.829
#
# [2] PCA COMPARISON ANALYSIS WITH OUTCOME COLOR-CODING
# --------------------------------------------------
#    [CHART] PCA comparison plot saved: pca_comparison_with_outcome.png
#    [CHART] PCA Overall Similarity: 0.019
#    [CHART] Explained Variance (PC1, PC2): 0.303, 0.085
#
# [3] DISTRIBUTION SIMILARITY
# ------------------------------
#    [CHART] Average Distribution Similarity: 0.841
#
# [4] CORRELATION STRUCTURE
# ------------------------------
#    [CHART] Correlation Structure Preservation: 0.829
#
# [5] MACHINE LEARNING UTILITY
# ------------------------------
#    [CHART] ML Utility (Cross-Accuracy): 0.884
#    [CHART] Real->Synth Accuracy: 0.793
#    [CHART] Synth->Real Accuracy: 0.976
#
# ============================================================
# [BEST] CTGAN OVERALL QUALITY SCORE: 0.680
# [INFO] Quality Assessment: GOOD
# ============================================================
#
# [FOLDER] Generated 5 output files:
#    - statistical_similarity.csv
#    - pca_comparison_with_outcome.png
#    - distribution_comparison.png
#    - correlation_comparison.png
#    - evaluation_summary.csv
# [OK] CTGAN evaluation completed successfully!
#
# ==================== EVALUATING CopulaGAN ====================
# [SEARCH] COPULAGAN - COMPREHENSIVE DATA QUALITY EVALUATION
# ============================================================
# [FOLDER] Output directory: results/pakistani-diabetes-dataset/2025-11-05/Section-5/COPULAGAN
#
# [1] STATISTICAL SIMILARITY
# ------------------------------
#    [CHART] Average Statistical Similarity: 0.887
#
# [2] PCA COMPARISON ANALYSIS WITH OUTCOME COLOR-CODING
# --------------------------------------------------
#    [CHART] PCA comparison plot saved: pca_comparison_with_outcome.png
#    [CHART] PCA Overall Similarity: 0.035
#    [CHART] Explained Variance (PC1, PC2): 0.303, 0.085
#
# [3] DISTRIBUTION SIMILARITY
# ------------------------------
#    [CHART] Average Distribution Similarity: 0.881
#
# [4] CORRELATION STRUCTURE
# ------------------------------
#    [CHART] Correlation Structure Preservation: 0.941
#
# [5] MACHINE LEARNING UTILITY
# ------------------------------
#    [CHART] ML Utility (Cross-Accuracy): 0.950
#    [CHART] Real->Synth Accuracy: 0.910
#    [CHART] Synth->Real Accuracy: 0.990
#
# ============================================================
# [BEST] COPULAGAN OVERALL QUALITY SCORE: 0.739
# [INFO] Quality Assessment: GOOD
# ============================================================
#
# [FOLDER] Generated 5 output files:
#    - statistical_similarity.csv
#    - pca_comparison_with_outcome.png
#    - distribution_comparison.png
#    - correlation_comparison.png
#    - evaluation_summary.csv
# [OK] CopulaGAN evaluation completed successfully!
#
# ==================== EVALUATING TVAE ====================
# [SEARCH] TVAE - COMPREHENSIVE DATA QUALITY EVALUATION
# ============================================================
# [FOLDER] Output directory: results/pakistani-diabetes-dataset/2025-11-05/Section-5/TVAE
#
# [1] STATISTICAL SIMILARITY
# ------------------------------
#    [CHART] Average Statistical Similarity: 0.810
#
# [2] PCA COMPARISON ANALYSIS WITH OUTCOME COLOR-CODING
# --------------------------------------------------
#    [CHART] PCA comparison plot saved: pca_comparison_with_outcome.png
#    [CHART] PCA Overall Similarity: 0.012
#    [CHART] Explained Variance (PC1, PC2): 0.303, 0.085
#
# [3] DISTRIBUTION SIMILARITY
# ------------------------------
#    [CHART] Average Distribution Similarity: 0.863
#
# [4] CORRELATION STRUCTURE
# ------------------------------
#    [CHART] Correlation Structure Preservation: 0.900
#
# [5] MACHINE LEARNING UTILITY
# ------------------------------
#    [CHART] ML Utility (Cross-Accuracy): 0.973
#    [CHART] Real->Synth Accuracy: 0.958
#    [CHART] Synth->Real Accuracy: 0.988
#
# ============================================================
# [BEST] TVAE OVERALL QUALITY SCORE: 0.712
# [INFO] Quality Assessment: GOOD
# ============================================================
#
# [FOLDER] Generated 5 output files:
#    - statistical_similarity.csv
#    - pca_comparison_with_outcome.png
#    - distribution_comparison.png
#    - correlation_comparison.png
#    - evaluation_summary.csv
# [OK] TVAE evaluation completed successfully!
#
# ========================= EVALUATION SUMMARY =========================
# Model           Quality Score   Assessment   Files
# -----------------------------------------------------------------
# CTGAN           0.680           GOOD         5
# CopulaGAN       0.739           GOOD         5
# TVAE            0.712           GOOD         5
#
# [CHART] Batch summary saved to: results/pakistani-diabetes-dataset/2025-11-05/Section-5/batch_evaluation_summary.csv
#
# ========================= COMPREHENSIVE TRTS ANALYSIS =========================
#
# [ANALYSIS] Running TRTS analysis for CTGAN...
# [ANALYSIS] COMPREHENSIVE TRTS FRAMEWORK ANALYSIS
# ============================================================
# [CHART] Data shapes:
#    - Real: (912, 18), Target unique values: 2
#    - Synthetic: (912, 18), Target unique values: 2
#    - Using 18 common features
#
# [PROCESS] 1. TRTR - Train Real, Test Real (Baseline)
#    [OK] TRTR Accuracy: 1.0000 (Time: 0.181s)
# [PROCESS] 2. TRTS - Train Real, Test Synthetic
#    [OK] TRTS Accuracy: 0.7978 (Time: 0.216s)
# [PROCESS] 3. TSTR - Train Synthetic, Test Real
#    [OK] TSTR Accuracy: 0.9781 (Time: 0.286s)
# [PROCESS] 4. TSTS - Train Synthetic, Test Synthetic
#    [OK] TSTS Accuracy: 0.8142 (Time: 0.276s)
#
# [CHART] Summary Statistics:
#    - Successful scenarios: 4/4
#    - Average accuracy: 0.8975 (+/-0.0920)
#    - Total training time: 0.959s
#
# [ANALYSIS] Running TRTS analysis for CopulaGAN...
# [ANALYSIS] COMPREHENSIVE TRTS FRAMEWORK ANALYSIS
# ============================================================
# [CHART] Data shapes:
#    - Real: (912, 18), Target unique values: 2
#    - Synthetic: (912, 18), Target unique values: 2
#    - Using 18 common features
#
# [PROCESS] 1. TRTR - Train Real, Test Real (Baseline)
#    [OK] TRTR Accuracy: 1.0000 (Time: 0.201s)
# [PROCESS] 2. TRTS - Train Real, Test Synthetic
#    [OK] TRTS Accuracy: 0.9071 (Time: 0.166s)
# [PROCESS] 3. TSTR - Train Synthetic, Test Real
#    [OK] TSTR Accuracy: 1.0000 (Time: 0.213s)
# [PROCESS] 4. TSTS - Train Synthetic, Test Synthetic
#    [OK] TSTS Accuracy: 0.9344 (Time: 0.219s)
#
# [CHART] Summary Statistics:
#    - Successful scenarios: 4/4
#    - Average accuracy: 0.9604 (+/-0.0408)
#    - Total training time: 0.799s
#
# [ANALYSIS] Running TRTS analysis for TVAE...
# [ANALYSIS] COMPREHENSIVE TRTS FRAMEWORK ANALYSIS
# ============================================================
# [CHART] Data shapes:
#    - Real: (912, 18), Target unique values: 2
#    - Synthetic: (912, 18), Target unique values: 2
#    - Using 18 common features
#
# [PROCESS] 1. TRTR - Train Real, Test Real (Baseline)
#    [OK] TRTR Accuracy: 1.0000 (Time: 0.213s)
# [PROCESS] 2. TRTS - Train Real, Test Synthetic
#    [OK] TRTS Accuracy: 0.9508 (Time: 0.219s)
# [PROCESS] 3. TSTR - Train Synthetic, Test Real
#    [OK] TSTR Accuracy: 1.0000 (Time: 0.238s)
# [PROCESS] 4. TSTS - Train Synthetic, Test Synthetic
#    [OK] TSTS Accuracy: 0.9563 (Time: 0.240s)
#
# [CHART] Summary Statistics:
#    - Successful scenarios: 4/4
#    - Average accuracy: 0.9768 (+/-0.0233)
#    - Total training time: 0.910s
#
# [CHART] Creating TRTS visualizations...
# [CHART] TRTS comprehensive plot saved: results/pakistani-diabetes-dataset/2025-11-05/Section-5/trts_comprehensive_analysis.png
# [FOLDER] TRTS tables saved: 3 files
# [OK] TRTS visualization files generated:
#    [FOLDER] trts_comprehensive_analysis.png
#    [FOLDER] trts_summary_metrics.csv
#    [FOLDER] trts_detailed_results.csv
#
# [STATS] TRTS Analysis Summary:
#    - Models analyzed: 3
#    - Average combined score: 0.9449
#    - Best performing model: TVAE
#    - Total scenarios tested: 12
#
# ================================================================================
# ✅ SECTION 5.2 OPTIMIZED MODELS BATCH EVALUATION COMPLETED!
# ================================================================================
# ❌ Section 5.2 batch evaluation failed: 'models_processed'
# 🔍 Error details: KeyError
#
# ⚠️  Check that Section 5.1.x models completed successfully
#
# 📈 Section 5.2 optimized model batch evaluation complete!
# 🏁 Ready for final model comparison and production deployment!

# %%
# Generate Section 5 README documentationfrom src.utils.documentation import create_section5_readmecreate_section5_readme(    results_path=results_path,    dataset_id=DATASET_IDENTIFIER,    timestamp=SESSION_TIMESTAMP)
